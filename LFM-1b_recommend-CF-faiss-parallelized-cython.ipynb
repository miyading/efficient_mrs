# %% [markdown]
# # LFM-1b_recommend-CF-faiss-parallelized-cython

# %%
import pandas as pd
import numpy as np
import random
import time
import faiss
import concurrent.futures
import cython
import cProfile

# %%
# Set number of neighbors to retrieve (K)
K = 5

# Load interaction log
file_path = "lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv"
interactions = pd.read_csv(file_path, sep="\t", header=None,
                           names=["user_id", "timestamp", "artist_id", "artist_name", "track_id", "track_name"],
                           on_bad_lines='skip')

# %% [markdown]
# ## cProfile from CF-faiss-parallelized version

# %%
# Load interaction log
interactions = pd.read_csv(file_path, sep="\t", header=None,
                           names=["user_id", "timestamp", "artist_id", "artist_name", "track_id", "track_name"],
                           on_bad_lines='skip')

# Count number of times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mappings: user/artist to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map to index
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build dense user-artist matrix (playcounts)
n_users = len(user_id_to_idx)
n_artists = len(artist_name_to_idx)
user_matrix = np.zeros((n_users, n_artists), dtype='float32')

for row in playcounts.itertuples(index=False):
    user_matrix[row.user_idx, row.artist_idx] += row.playcount

# Normalize rows to unit length for cosine similarity
faiss.normalize_L2(user_matrix)

# Create FAISS index for cosine similarity (inner product after normalization)
index = faiss.IndexFlatIP(n_artists)
index.add(user_matrix)  # Add all user vectors

# Reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

def recommend_user(u):
    neighbor_indices = neighbors[u][1:]  # skip self
    neighbor_scores = distances[u][1:]

    recommended_artists_idx = []
    for neighbor in neighbor_indices:
        neighbor_vector = user_matrix[neighbor]
        recommended_artists_idx.extend(np.where(neighbor_vector > 0)[0])

    known_artists = np.where(user_matrix[u] > 0)[0]
    recommended_artists_idx = list(set(recommended_artists_idx) - set(known_artists))

    if len(recommended_artists_idx) >= 5:
        random_indices = random.sample(recommended_artists_idx, 5)
    else:
        random_indices = recommended_artists_idx

    return {
        "user": user_ids[u],
        "neighbors": user_ids[neighbor_indices],
        "artist_indices": random_indices,
        "artist_names": [artist_ids[i] for i in random_indices]
    }

def run_recommendations():
    """Run FAISS search and print recommendation results."""
    start_time = time.time()
    distances, neighbors = index.search(user_matrix, K + 1)

    with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
        results = list(executor.map(recommend_user, range(n_users)))

    for res in results:
        print("Seed user-id:", res["user"])
        print(f"Nearest K={K} neighbors' user-ids:", res["neighbors"])
        print(f"Indices of {len(res['artist_indices'])} recommended artists:", res["artist_indices"])
        print("Recommended artist names:", res["artist_names"])
        print('-' * 80)

    end_time = time.time()
    avg_time = (end_time - start_time) / n_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")


if __name__ == "__main__":
    run_recommendations()
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Indices of 5 recommended artists: [np.int64(31621), np.int64(2997), np.int64(21022), np.int64(3137), np.int64(8970)]
# Recommended artist names: [np.str_('Mc Frontalot'), np.str_('Depeche Mode'), np.str_('Lfo Vs. F.U.S.E.'), np.str_('Glen Hansard & Markéta Irglová'), np.str_('Marcia Griffiths')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Indices of 5 recommended artists: [np.int64(18317), np.int64(587), np.int64(2129), np.int64(10673), np.int64(2900)]
# Recommended artist names: [np.str_('Fito & Fitipaldis'), np.str_('Tiga'), np.str_('Eagles'), np.str_('Horace Andy'), np.str_('Charlotte Hatherley')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Indices of 5 recommended artists: [np.int64(23274), np.int64(30390), np.int64(4036), np.int64(115290), np.int64(17063)]
# Recommended artist names: [np.str_("Richard O'Brien"), np.str_('Michael Sembello'), np.str_('Alex Gaudino'), np.str_('Ron D Core Vs. Dj Dan'), np.str_('Bass Kleph')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Indices of 5 recommended artists: [np.int64(148553), np.int64(10967), np.int64(32430), np.int64(148550), np.int64(7662)]
# Recommended artist names: [np.str_('Franz Vorraber, Piano'), np.str_('The Boo Radleys'), np.str_('Toby Lightman'), np.str_('Feisty'), np.str_('Luniz')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Indices of 5 recommended artists: [np.int64(49293), np.int64(22820), np.int64(12926), np.int64(663), np.int64(5344)]
# Recommended artist names: [np.str_('Les Jumeaux'), np.str_('Dj Nuts'), np.str_('The Temptations'), np.str_('2Raumwohnung'), np.str_('Hüsker Dü')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Indices of 5 recommended artists: [np.int64(714), np.int64(951), np.int64(30093), np.int64(1074), np.int64(95622)]
# Recommended artist names: [np.str_('Andy Williams'), np.str_('Dilated Peoples'), np.str_('Lao Che'), np.str_('Grandaddy'), np.str_('Namlook')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Indices of 5 recommended artists: [np.int64(26569), np.int64(100497), np.int64(1003), np.int64(149065), np.int64(2129)]
# Recommended artist names: [np.str_('Red Cafe'), np.str_('Oman Chali'), np.str_('Eric Clapton'), np.str_('Timbaland F/M.I.A.'), np.str_('Eagles')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Indices of 5 recommended artists: [np.int64(4030), np.int64(44791), np.int64(1667), np.int64(59570), np.int64(59653)]
# Recommended artist names: [np.str_('Airbase'), np.str_('Eyes'), np.str_('The Dandy Warhols'), np.str_('Ce Ce Peniston & Henrik B'), np.str_('First State Vs. Anita Kelsey')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Indices of 5 recommended artists: [np.int64(88404), np.int64(29892), np.int64(11533), np.int64(88370), np.int64(19283)]
# Recommended artist names: [np.str_('Sonny Fisher'), np.str_('Frente!'), np.str_('Electric Light Orchestra Part Ii'), np.str_('Psychick Warriors Ov Gaia'), np.str_('Section 25')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Indices of 5 recommended artists: [np.int64(63251), np.int64(63055), np.int64(481), np.int64(63398), np.int64(84304)]
# Recommended artist names: [np.str_('Psychedelic Breaks (Part 2)'), np.str_('Dt8 Project Feat. Mory Kante'), np.str_('Roy Ayers'), np.str_('Whitelabel'), np.str_('Dead Rock Machine')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Indices of 5 recommended artists: [np.int64(137209), np.int64(16694), np.int64(11159), np.int64(11561), np.int64(27361)]
# Recommended artist names: [np.str_('Thelonious Monk;Coleman Hawkins'), np.str_('Bally Sagoo'), np.str_('Accept'), np.str_('Evergrey'), np.str_('Richard Galliano')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Indices of 5 recommended artists: [np.int64(19351), np.int64(117567), np.int64(50874), np.int64(29929), np.int64(29715)]
# Recommended artist names: [np.str_('Someone Else'), np.str_('Dinosaur'), np.str_('Junior Brown'), np.str_('Kelly Joe Phelps'), np.str_('Thee More Shallows')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Indices of 5 recommended artists: [np.int64(38020), np.int64(37986), np.int64(7669), np.int64(7999), np.int64(51931)]
# Recommended artist names: [np.str_('Novalis'), np.str_('Michel Camilo'), np.str_('Marillion'), np.str_('Bebel Gilberto'), np.str_('Ömür Göksel')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Indices of 5 recommended artists: [np.int64(1365), np.int64(45921), np.int64(45489), np.int64(20264), np.int64(10710)]
# Recommended artist names: [np.str_('Nirvana'), np.str_('Whispertown2000'), np.str_('The Pussy Mafia'), np.str_('Tommy February6'), np.str_('John Vanderslice')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Indices of 5 recommended artists: [np.int64(79513), np.int64(632), np.int64(74194), np.int64(36789), np.int64(48728)]
# Recommended artist names: [np.str_('Axel Coon'), np.str_('[Unknown]'), np.str_('Lilly Allen Feat. Mick Jones'), np.str_('St'), np.str_('The Kids')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Indices of 5 recommended artists: [np.int64(3866), np.int64(2580), np.int64(150257), np.int64(2857), np.int64(12076)]
# Recommended artist names: [np.str_('The Veronicas'), np.str_('The Starting Line'), np.str_('Ladysmith Black Mambazo Featuring China Black'), np.str_('Béla Bartók'), np.str_('Mud')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Indices of 5 recommended artists: [np.int64(11071), np.int64(34836), np.int64(15352), np.int64(17938), np.int64(15914)]
# Recommended artist names: [np.str_('The Thorns'), np.str_('Florin Chilian'), np.str_('Amon Amarth'), np.str_('Blind Lemon Jefferson'), np.str_('Monica Zetterlund')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Indices of 5 recommended artists: [np.int64(11533), np.int64(4763), np.int64(15160), np.int64(10520), np.int64(22506)]
# Recommended artist names: [np.str_('Electric Light Orchestra Part Ii'), np.str_('Tears For Fears'), np.str_('Scraps Of Tape'), np.str_('Blackbud'), np.str_('These New Puritans')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Indices of 5 recommended artists: [np.int64(1111), np.int64(44452), np.int64(7885), np.int64(3961), np.int64(1886)]
# Recommended artist names: [np.str_('Idlewild'), np.str_('Naglfar'), np.str_('Adam F & Tko'), np.str_('World Leader Pretend'), np.str_('Wir Sind Helden')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Indices of 5 recommended artists: [np.int64(3986), np.int64(4567), np.int64(5966), np.int64(7682), np.int64(13958)]
# Recommended artist names: [np.str_('Ólafur Arnalds'), np.str_('Outlandish'), np.str_("The 5.6.7.8'S"), np.str_('Mike Oldfield'), np.str_('Foxboro Hot Tubs')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Indices of 5 recommended artists: [np.int64(129562), np.int64(19457), np.int64(160339), np.int64(133493), np.int64(27300)]
# Recommended artist names: [np.str_('Barebones'), np.str_('The Dave Clark Five'), np.str_('Robert Rodriguez & Carl Thiel'), np.str_('Otherstarpeople'), np.str_('Bondage Fairies')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Indices of 5 recommended artists: [np.int64(40985), np.int64(115394), np.int64(10809), np.int64(26271), np.int64(102605)]
# Recommended artist names: [np.str_('Tim Maia'), np.str_('Black Pig Liberation Front'), np.str_('Neil Diamond'), np.str_('Mf Doom [The Doomilation Bootleg]'), np.str_('Willits + Sakamoto')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Indices of 5 recommended artists: [np.int64(75403), np.int64(10028), np.int64(5302), np.int64(35208), np.int64(2274)]
# Recommended artist names: [np.str_('Absolute Zero'), np.str_('Laibach'), np.str_('Gregor Tresher'), np.str_('Taylor Deupree'), np.str_('Juvenile')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Indices of 5 recommended artists: [np.int64(12088), np.int64(47289), np.int64(86116), np.int64(9940), np.int64(18219)]
# Recommended artist names: [np.str_('Nanci Griffith'), np.str_('John Mclaughlin'), np.str_('Aneuretical'), np.str_('Diamanda Galás'), np.str_('Duane Stephenson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Indices of 5 recommended artists: [np.int64(744), np.int64(10010), np.int64(38350), np.int64(1722), np.int64(29922)]
# Recommended artist names: [np.str_('Art Brut'), np.str_('Juliette And The Licks'), np.str_('Lisa "Left Eye" Lopes'), np.str_('The Long Blondes'), np.str_('John Hunter')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Indices of 5 recommended artists: [np.int64(960), np.int64(1265), np.int64(51501), np.int64(1211), np.int64(51763)]
# Recommended artist names: [np.str_('Dizzy Gillespie'), np.str_('Lou Reed'), np.str_('Düş Sokağı Sakinleri'), np.str_('Kate Havnevik'), np.str_('Psychotic Waltz')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Indices of 5 recommended artists: [np.int64(1811), np.int64(69668), np.int64(70029), np.int64(16166), np.int64(39407)]
# Recommended artist names: [np.str_('The Zutons'), np.str_('Benny Benassi Featuring Sandy'), np.str_('Dj M-Traxxx'), np.str_('The Attic'), np.str_('Princess')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Indices of 5 recommended artists: [np.int64(22164), np.int64(7995), np.int64(2476), np.int64(14889), np.int64(90226)]
# Recommended artist names: [np.str_('D. Kay'), np.str_('Beach House'), np.str_('Sebastian'), np.str_('Burzum'), np.str_('Gene Dunlap')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Indices of 5 recommended artists: [np.int64(4507), np.int64(136996), np.int64(86462), np.int64(136948), np.int64(11864)]
# Recommended artist names: [np.str_('Modern Talking'), np.str_('Prztz'), np.str_('The Boys From Brazil'), np.str_('Juan Trip'), np.str_('Kenny Rogers')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Indices of 5 recommended artists: [np.int64(94566), np.int64(19713), np.int64(19091), np.int64(18173), np.int64(831)]
# Recommended artist names: [np.str_('Dj Shufflemaster'), np.str_('Wanda Sá'), np.str_('Pete Molinari'), np.str_('Der Kfc'), np.str_('Bromheads Jacket')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Indices of 5 recommended artists: [np.int64(86430), np.int64(1151), np.int64(17698), np.int64(20264), np.int64(86508)]
# Recommended artist names: [np.str_('Seclusion'), np.str_('Jessica Simpson'), np.str_('The Darling Buds'), np.str_('Tommy February6'), np.str_('Watson & Company')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Indices of 5 recommended artists: [np.int64(51775), np.int64(40900), np.int64(133912), np.int64(57563), np.int64(28435)]
# Recommended artist names: [np.str_('Rebel Moves'), np.str_('Construcdead'), np.str_('Cock And Ball Torture [Egoleech 2004]'), np.str_('Giuseppe Ottaviani'), np.str_('Lost Balance')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Indices of 5 recommended artists: [np.int64(2759), np.int64(119288), np.int64(10151), np.int64(119324), np.int64(60069)]
# Recommended artist names: [np.str_('Ayreon'), np.str_('12B Eatz'), np.str_('The Section Quartet'), np.str_('Неизвестный'), np.str_('Projekti 3')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Indices of 5 recommended artists: [np.int64(19473), np.int64(18365), np.int64(7799), np.int64(18810), np.int64(2980)]
# Recommended artist names: [np.str_('The Exciters'), np.str_('Gang Wizard'), np.str_('The Hellacopters'), np.str_('Lukie D'), np.str_('David Gilmour')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Indices of 5 recommended artists: [np.int64(10171), np.int64(12773), np.int64(3908), np.int64(101445), np.int64(55166)]
# Recommended artist names: [np.str_('Vetiver'), np.str_('Cryptopsy'), np.str_('Tricky'), np.str_('2 Am/Fm'), np.str_('Ferrante And Teicher')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Indices of 5 recommended artists: [np.int64(18039), np.int64(36315), np.int64(146958), np.int64(9104), np.int64(9094)]
# Recommended artist names: [np.str_('Chaz Jankel'), np.str_('Broken Radio & A Million Mercies'), np.str_('Ocha La Rocha'), np.str_('Neko Case'), np.str_('Nancy Sinatra & Lee Hazlewood')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Indices of 5 recommended artists: [np.int64(50463), np.int64(8159), np.int64(79163), np.int64(2813), np.int64(41741)]
# Recommended artist names: [np.str_('Raw Herbs'), np.str_('Chic'), np.str_('Beaut'), np.str_('Blackalicious'), np.str_('Jennifer Knapp')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Indices of 5 recommended artists: [np.int64(43720), np.int64(22740), np.int64(104560), np.int64(60033), np.int64(1970)]
# Recommended artist names: [np.str_('For My Pain...'), np.str_('Cryo'), np.str_('Suspiria'), np.str_('Loudness'), np.str_('Armin Van Buuren')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Indices of 5 recommended artists: [np.int64(831), np.int64(1035), np.int64(2819), np.int64(13442), np.int64(14293)]
# Recommended artist names: [np.str_('Bromheads Jacket'), np.str_('Forty Foot Echo'), np.str_('Blood Red Shoes'), np.str_('Street Dogs'), np.str_('Ripchord')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Indices of 5 recommended artists: [np.int64(13077), np.int64(5527), np.int64(4143), np.int64(1596), np.int64(4339)]
# Recommended artist names: [np.str_('Pierrot'), np.str_('Magnet'), np.str_('Chris Isaak'), np.str_('Supreme Beings Of Leisure'), np.str_('Hi_Tack')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Indices of 5 recommended artists: [np.int64(18926), np.int64(94511), np.int64(4422), np.int64(46040), np.int64(35489)]
# Recommended artist names: [np.str_('Miranda Sex Garden'), np.str_('Cygnus'), np.str_('Laura Branigan'), np.str_('Dina'), np.str_('Robson & Jerome')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Indices of 5 recommended artists: [np.int64(9615), np.int64(44175), np.int64(34113), np.int64(1435), np.int64(11284)]
# Recommended artist names: [np.str_('The Gift Of Gab'), np.str_('Black Sun Empire & Chris.Su'), np.str_('Bang Bang'), np.str_('Portishead'), np.str_('Billy Corgan')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Indices of 5 recommended artists: [np.int64(15177), np.int64(19383), np.int64(36864), np.int64(18425), np.int64(18757)]
# Recommended artist names: [np.str_('Something Happens'), np.str_('Sub Focus'), np.str_('James Hook'), np.str_('Guillaume Dufay'), np.str_('Lijie')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Indices of 5 recommended artists: [np.int64(17817), np.int64(3329), np.int64(24729), np.int64(101086), np.int64(9697)]
# Recommended artist names: [np.str_('Antiworld'), np.str_('Lenny Kravitz'), np.str_('Murderdolls'), np.str_('Philippe Geluck'), np.str_('The Trashmen')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Indices of 5 recommended artists: [np.int64(1456), np.int64(6645), np.int64(43808), np.int64(11492), np.int64(1177)]
# Recommended artist names: [np.str_('Razorlight'), np.str_('The Notorious B.I.G.'), np.str_('Biquini Cavadão'), np.str_('Down'), np.str_('Johnny Cash')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Indices of 5 recommended artists: [np.int64(60053), np.int64(23174), np.int64(1676), np.int64(28972), np.int64(13327)]
# Recommended artist names: [np.str_('North'), np.str_('Neuroactive'), np.str_('The Dresden Dolls'), np.str_('Gogogo Airheart'), np.str_('Lucero')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Indices of 5 recommended artists: [np.int64(11277), np.int64(172201), np.int64(145703), np.int64(59831), np.int64(77387)]
# Recommended artist names: [np.str_('Big Brother & The Holding Company'), np.str_('Chum'), np.str_('11. Nukom'), np.str_('Sidney Samson'), np.str_('Little Hat Jones')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Indices of 5 recommended artists: [np.int64(10736), np.int64(14781), np.int64(1880), np.int64(150209), np.int64(11697)]
# Recommended artist names: [np.str_('Kelly Jones'), np.str_('You Am I'), np.str_('Wheatus'), np.str_('Gerbil Sandwich'), np.str_('Hello Saferide')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Indices of 5 recommended artists: [np.int64(18014), np.int64(26472), np.int64(28169), np.int64(2231), np.int64(2389)]
# Recommended artist names: [np.str_('Casey Dienel'), np.str_('Percee P'), np.str_('Natalie Cole'), np.str_('Iggy Pop'), np.str_('My Bloody Valentine')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Indices of 5 recommended artists: [np.int64(13847), np.int64(2782), np.int64(9606), np.int64(1338), np.int64(44609)]
# Recommended artist names: [np.str_('Colours Run'), np.str_('Baxter'), np.str_('The Fall'), np.str_('Nancy Sinatra'), np.str_('Little Fish')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Indices of 5 recommended artists: [np.int64(7786), np.int64(1459), np.int64(738), np.int64(14293), np.int64(66328)]
# Recommended artist names: [np.str_('Talib Kweli'), np.str_('Reel Big Fish'), np.str_('Arcade Fire'), np.str_('Ripchord'), np.str_('Tom Palmer')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Indices of 5 recommended artists: [np.int64(54164), np.int64(59281), np.int64(22592), np.int64(58847), np.int64(58986)]
# Recommended artist names: [np.str_('Forgotten Freaks'), np.str_('Subhuman'), np.str_('All Gone Dead'), np.str_('James Galway'), np.str_('Abraksas')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Indices of 5 recommended artists: [np.int64(54340), np.int64(2042), np.int64(21587), np.int64(108457), np.int64(72544)]
# Recommended artist names: [np.str_('Arts The Beat Doctor'), np.str_('Chamillionaire'), np.str_('Andy Mckee'), np.str_('Ep Allan'), np.str_('Lost Weight')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Indices of 5 recommended artists: [np.int64(2018), np.int64(2361), np.int64(62557), np.int64(48640), np.int64(48667)]
# Recommended artist names: [np.str_('Boys Noize'), np.str_('Method Man'), np.str_('Byzantine'), np.str_('Ole Paus'), np.str_('Snoop Feat. Xibit, & Nate Dogg')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Indices of 5 recommended artists: [np.int64(3841), np.int64(3493), np.int64(118331), np.int64(81544), np.int64(104741)]
# Recommended artist names: [np.str_('The Rosebuds'), np.str_('New Order'), np.str_('Only Oceans Remain'), np.str_('Cj Grogan'), np.str_('Jim Elliott')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Indices of 5 recommended artists: [np.int64(11141), np.int64(20861), np.int64(14476), np.int64(18722), np.int64(10438)]
# Recommended artist names: [np.str_('*Nsync'), np.str_('Gataka'), np.str_('The Books'), np.str_('Lauri Des Marais'), np.str_('X-Fusion')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Indices of 5 recommended artists: [np.int64(1631), np.int64(1437), np.int64(11141), np.int64(14589), np.int64(49602)]
# Recommended artist names: [np.str_('The Ataris'), np.str_('Pretty Girls Make Graves'), np.str_('*Nsync'), np.str_('The Mae Shi'), np.str_('The Sick Lipstick')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Indices of 5 recommended artists: [np.int64(1086), np.int64(33188), np.int64(894), np.int64(662), np.int64(919)]
# Recommended artist names: [np.str_('Hard-Fi'), np.str_('Taana Gardner'), np.str_('Crosby, Stills, Nash & Young'), np.str_('10Cc'), np.str_('Death Cab For Cutie')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Indices of 5 recommended artists: [np.int64(25726), np.int64(14418), np.int64(8385), np.int64(10420), np.int64(12147)]
# Recommended artist names: [np.str_('Gary Bartz'), np.str_('Tall Dwarfs'), np.str_('Doormouse'), np.str_('Tiger Army'), np.str_('Paloma')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Indices of 5 recommended artists: [np.int64(72198), np.int64(19175), np.int64(6477), np.int64(13860), np.int64(3420)]
# Recommended artist names: [np.str_('One-Two'), np.str_('Raïna Raï'), np.str_('Karsh Kale'), np.str_('Count Five'), np.str_('Menomena')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Indices of 5 recommended artists: [np.int64(2020), np.int64(1144), np.int64(4476), np.int64(69600), np.int64(23204)]
# Recommended artist names: [np.str_('Broken Social Scene'), np.str_('Jeff Buckley'), np.str_('Mason Vs. Princess Superstar'), np.str_('Armin Van Buuren (Feat. Nadia Ali)'), np.str_('Ottawan')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Indices of 5 recommended artists: [np.int64(18667), np.int64(61281), np.int64(14210), np.int64(12599), np.int64(17714)]
# Recommended artist names: [np.str_('Kind Of Girl'), np.str_('Blue King Brown'), np.str_('Odd Nosdam'), np.str_('Vangelis'), np.str_('1000 Hours Of Staring')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Indices of 5 recommended artists: [np.int64(84726), np.int64(15105), np.int64(99407), np.int64(28287), np.int64(19985)]
# Recommended artist names: [np.str_('Ananda And Craig Pruess'), np.str_('Nilsson'), np.str_('Armani & Ghost'), np.str_('Craig Pruess'), np.str_('Buck-Tick')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Indices of 5 recommended artists: [np.int64(3343), np.int64(5065), np.int64(57641), np.int64(9747), np.int64(1553)]
# Recommended artist names: [np.str_('Linda Perry'), np.str_('Charlie Feathers'), np.str_('Mazedude'), np.str_('Toad The Wet Sprocket'), np.str_('Something Corporate')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Indices of 5 recommended artists: [np.int64(705), np.int64(10777), np.int64(94146), np.int64(2517), np.int64(5167)]
# Recommended artist names: [np.str_('Ambulance Ltd'), np.str_('Madness'), np.str_('Watkins'), np.str_('Sugar Ray'), np.str_('Dj Koze')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Indices of 5 recommended artists: [np.int64(28303), np.int64(121205), np.int64(11992), np.int64(104180), np.int64(121094)]
# Recommended artist names: [np.str_('Deepak Ram'), np.str_('Screama Feat. Teresa'), np.str_('Marc Seales, Composer. New Stories. Ernie Watts, Saxophone.'), np.str_('Camille Bazbaz'), np.str_('Klim')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Indices of 5 recommended artists: [np.int64(2345), np.int64(6275), np.int64(3838), np.int64(13086), np.int64(125688)]
# Recommended artist names: [np.str_('Marcy Playground'), np.str_('布袋寅泰'), np.str_('The Postmarks'), np.str_('Roger Ferguson'), np.str_('Fragma & Kirsty Hawkshaw')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Indices of 5 recommended artists: [np.int64(163677), np.int64(141538), np.int64(163810), np.int64(15173), np.int64(3412)]
# Recommended artist names: [np.str_('Apollo Xi'), np.str_('Lame Ducks'), np.str_('Enigma & Pm Dawn'), np.str_('Slint'), np.str_('Meanwhile, Back In Communist Russia...')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Indices of 5 recommended artists: [np.int64(145163), np.int64(127949), np.int64(16986), np.int64(428), np.int64(10800)]
# Recommended artist names: [np.str_('Jimmy Mcgriff & Junior Parker'), np.str_('Zwart Licht'), np.str_('Sway Feat. Pyrelli'), np.str_('Pendulum'), np.str_('Money Mark')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Indices of 5 recommended artists: [np.int64(750), np.int64(80193), np.int64(81062), np.int64(1551), np.int64(10516)]
# Recommended artist names: [np.str_('Athlete'), np.str_('A.R. Rahman Feat. Sukhwinder Singh, Tanvi Shah & Mahalakshmi Iyer'), np.str_('A. R. Rahman Featuring Alka Yagnik And Ila Arun'), np.str_('Solomon Burke'), np.str_('Black Francis')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Indices of 5 recommended artists: [np.int64(1816), np.int64(36277), np.int64(12492), np.int64(1750), np.int64(354)]
# Recommended artist names: [np.str_('Thirteen Senses'), np.str_('Ranking Dread'), np.str_('The Pillows'), np.str_('The Police'), np.str_('Manual')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Indices of 5 recommended artists: [np.int64(10218), np.int64(61596), np.int64(4400), np.int64(32084), np.int64(1336)]
# Recommended artist names: [np.str_('Aly & Aj'), np.str_('Demi Lovato'), np.str_('Kelly Rowland'), np.str_('Stephen Kellogg And The Sixers'), np.str_('Nada Surf')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Indices of 5 recommended artists: [np.int64(166634), np.int64(7844), np.int64(21822), np.int64(110067), np.int64(774)]
# Recommended artist names: [np.str_('Kauluri'), np.str_('Wishbone Ash'), np.str_('Ten Sharp'), np.str_('Giancarlo Toniutti'), np.str_('Beatsteaks')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Indices of 5 recommended artists: [np.int64(17386), np.int64(9529), np.int64(3955), np.int64(1432), np.int64(11329)]
# Recommended artist names: [np.str_('Mixmaster Morris'), np.str_('Taylor Dayne'), np.str_('Wolf Parade'), np.str_("Plain White T'S"), np.str_('Brant Bjork')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Indices of 5 recommended artists: [np.int64(11514), np.int64(10645), np.int64(20035), np.int64(11481), np.int64(12350)]
# Recommended artist names: [np.str_('Eda Zari'), np.str_('George Thorogood & The Destroyers'), np.str_('Flow'), np.str_('Dolly Parton'), np.str_('Solas')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Indices of 5 recommended artists: [np.int64(12508), np.int64(47254), np.int64(8344), np.int64(64043), np.int64(128842)]
# Recommended artist names: [np.str_('The Skygreen Leopards'), np.str_('Jacknife Lee'), np.str_('Dj Food'), np.str_('Institut Für Feinmotorik'), np.str_('Maciek Szymczuk')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Indices of 5 recommended artists: [np.int64(17385), np.int64(3789), np.int64(1999), np.int64(32734), np.int64(449)]
# Recommended artist names: [np.str_('Mission Of Burma'), np.str_('The Dodos'), np.str_('Big L'), np.str_('Cybophonia'), np.str_('Quasimode')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Indices of 5 recommended artists: [np.int64(20140), np.int64(12661), np.int64(17697), np.int64(113155), np.int64(9983)]
# Recommended artist names: [np.str_('Machines Of Loving Grace'), np.str_('Zion Train'), np.str_('Swell Maps'), np.str_('The Kin'), np.str_('Hammock')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Indices of 5 recommended artists: [np.int64(6534), np.int64(34509), np.int64(2464), np.int64(9927), np.int64(34158)]
# Recommended artist names: [np.str_('Michelle Sharprow'), np.str_('Old Boy'), np.str_('Samuel L. Jackson'), np.str_('Cranes'), np.str_('Change Of Plans')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Indices of 5 recommended artists: [np.int64(9254), np.int64(19718), np.int64(18264), np.int64(10967), np.int64(13217)]
# Recommended artist names: [np.str_('Propellerheads'), np.str_('We Are The Fury'), np.str_('Eric Roberson'), np.str_('The Boo Radleys'), np.str_('D.O.A.')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Indices of 5 recommended artists: [np.int64(14230), np.int64(911), np.int64(13187), np.int64(6374), np.int64(1671)]
# Recommended artist names: [np.str_('Pants Yell!'), np.str_('Dave Matthews Band'), np.str_('Broken Social Scene Presents: Kevin Drew'), np.str_('D4L'), np.str_('The Dears')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Indices of 5 recommended artists: [np.int64(48974), np.int64(39347), np.int64(11034), np.int64(6951), np.int64(62230)]
# Recommended artist names: [np.str_('Blob'), np.str_('Paper Lace'), np.str_('The Mooney Suzuki'), np.str_('Kansas'), np.str_('Kaos')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Indices of 5 recommended artists: [np.int64(34892), np.int64(1825), np.int64(34877), np.int64(41722), np.int64(4769)]
# Recommended artist names: [np.str_('Reid Paley'), np.str_('Tina Turner'), np.str_('Mistrust'), np.str_('Indy Go'), np.str_('The Byrds')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Indices of 5 recommended artists: [np.int64(121398), np.int64(46), np.int64(121370), np.int64(20411), np.int64(11471)]
# Recommended artist names: [np.str_('Deep Funk Project'), np.str_('Battles'), np.str_('Bate_Pe60 Feat Tina'), np.str_('大島ミチル'), np.str_('Dio')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Indices of 5 recommended artists: [np.int64(35316), np.int64(47312), np.int64(8008), np.int64(1784), np.int64(86547)]
# Recommended artist names: [np.str_('Chaka Demus & Pliers'), np.str_('Kalimba'), np.str_('Berlin'), np.str_('The Streets'), np.str_('Jim Sturgess, Evan Rachel Wood, Lisa Hogg')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Indices of 5 recommended artists: [np.int64(26418), np.int64(764), np.int64(8245), np.int64(18927), np.int64(11029)]
# Recommended artist names: [np.str_('Olivier Messiaen'), np.str_('Bad Company'), np.str_('Culture Beat'), np.str_('Mirco De Govia'), np.str_('The Milestone Corporation')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Indices of 5 recommended artists: [np.int64(6833), np.int64(96763), np.int64(96879), np.int64(33627), np.int64(43711)]
# Recommended artist names: [np.str_('Buckcherry'), np.str_("Dakken Kaeon'S Retro Sphere"), np.str_('Thee Pirates'), np.str_('Jessica Molaskey'), np.str_('Deicide')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Indices of 5 recommended artists: [np.int64(857), np.int64(15206), np.int64(22451), np.int64(28595), np.int64(137355)]
# Recommended artist names: [np.str_('Charlie Parker'), np.str_('The Comas'), np.str_('Sixtoo'), np.str_('Strifeii'), np.str_('Nicole Kidman Mash-Up With Hugh Jackman')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Indices of 5 recommended artists: [np.int64(14763), np.int64(18491), np.int64(11225), np.int64(72455), np.int64(28637)]
# Recommended artist names: [np.str_('We All Have Hooks For Hands'), np.str_('Huggy Bear'), np.str_('Ash Ra Tempel'), np.str_('Ballroom'), np.str_('Tom Richardson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Indices of 5 recommended artists: [np.int64(1879), np.int64(173593), np.int64(3726), np.int64(12691), np.int64(1074)]
# Recommended artist names: [np.str_('Wham!'), np.str_('Aurora Feat. Lizzy Pattinson'), np.str_('Suzanne Vega'), np.str_('Antony'), np.str_('Grandaddy')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Indices of 5 recommended artists: [np.int64(102574), np.int64(6882), np.int64(128825), np.int64(16928), np.int64(867)]
# Recommended artist names: [np.str_('Loco Star'), np.str_('Doubting Thomas'), np.str_('Kingbastard'), np.str_('Pinch'), np.str_('Chuck Berry')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Indices of 5 recommended artists: [np.int64(11851), np.int64(79141), np.int64(4284), np.int64(47679), np.int64(13664)]
# Recommended artist names: [np.str_('Kashmir'), np.str_('007'), np.str_('Extrawelt'), np.str_('Terne Chave'), np.str_('Airport Girl')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Indices of 5 recommended artists: [np.int64(162687), np.int64(1101), np.int64(36642), np.int64(3715), np.int64(126945)]
# Recommended artist names: [np.str_('Dennis Hopper/Gorillaz'), np.str_('Howie Day'), np.str_('Nada'), np.str_('Stratovarius'), np.str_('Prophet Omega')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Indices of 5 recommended artists: [np.int64(1142), np.int64(14848), np.int64(1633), np.int64(18022), np.int64(22903)]
# Recommended artist names: [np.str_('Jason Mraz'), np.str_('Alan Silvestri'), np.str_("The B-52'S"), np.str_('Cecilia Bartoli'), np.str_('Ewan Mcgregor, Jose Feliciano And Jacek Koman')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Indices of 5 recommended artists: [np.int64(21652), np.int64(1570), np.int64(2389), np.int64(24092), np.int64(1116)]
# Recommended artist names: [np.str_('Elmo & Patsy'), np.str_('Stacie Orrico'), np.str_('My Bloody Valentine'), np.str_('Beyoncé & Shakira'), np.str_('Ingrid Michaelson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Indices of 5 recommended artists: [np.int64(15176), np.int64(714), np.int64(12731), np.int64(126206), np.int64(2672)]
# Recommended artist names: [np.str_('Sofa Surfers'), np.str_('Andy Williams'), np.str_('Antonín Dvořák'), np.str_('Kuase Nada'), np.str_('A Place To Bury Strangers')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Indices of 5 recommended artists: [np.int64(57567), np.int64(71284), np.int64(20660), np.int64(18479), np.int64(137953)]
# Recommended artist names: [np.str_('Gonzaguinha'), np.str_('Sounds Of Blackness'), np.str_('Bryan Zentz'), np.str_('Honeyroot'), np.str_('Miranda Lambert & Buddy Jewell')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Indices of 5 recommended artists: [np.int64(148438), np.int64(816), np.int64(794), np.int64(1011), np.int64(1454)]
# Recommended artist names: [np.str_('Oasis - Sotsog Demos'), np.str_('Bonnie Somerville'), np.str_('Biffy Clyro'), np.str_('Eve 6'), np.str_('Ray Davies')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# ...
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Indices of 5 recommended artists: [np.int64(1142), np.int64(39437), np.int64(15581), np.int64(9863), np.int64(53542)]
# Recommended artist names: [np.str_('Jason Mraz'), np.str_('Reparata & The Delrons'), np.str_('Envy'), np.str_('Étienne Daho'), np.str_('The Sorayas')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Indices of 5 recommended artists: [np.int64(820), np.int64(143256), np.int64(99466), np.int64(17438), np.int64(20117)]
# Recommended artist names: [np.str_('Boy Division'), np.str_('Inaia'), np.str_('Ewan Mcdermott & The Vibrators'), np.str_('Pole'), np.str_('Kobranocka')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Indices of 5 recommended artists: [np.int64(31397), np.int64(35301), np.int64(488), np.int64(10654), np.int64(133222)]
# Recommended artist names: [np.str_('Jason Falkner'), np.str_('Beatniks'), np.str_('Röyksopp'), np.str_('Goldspot'), np.str_('Dave Burland')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Indices of 5 recommended artists: [np.int64(124035), np.int64(91571), np.int64(91436), np.int64(1015), np.int64(1040)]
# Recommended artist names: [np.str_("Tony Hawk'S American Wasteland - Thrice"), np.str_('Smackdown'), np.str_('Love In October'), np.str_('Face To Face'), np.str_('Frank Sinatra')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Indices of 5 recommended artists: [np.int64(91457), np.int64(2035), np.int64(74253), np.int64(8968), np.int64(91531)]
# Recommended artist names: [np.str_('More To Pride'), np.str_('Cartel'), np.str_('Far From Finished'), np.str_('Maps & Atlases'), np.str_('Rosematter')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Indices of 5 recommended artists: [np.int64(1789), np.int64(77024), np.int64(24137), np.int64(90813), np.int64(6968)]
# Recommended artist names: [np.str_('The Suicide Machines'), np.str_('Munir Bashir & Omar Bashir'), np.str_('Flyer'), np.str_('African Rhythms'), np.str_('Lee Ann Womack')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Indices of 5 recommended artists: [np.int64(50326), np.int64(17797), np.int64(15019), np.int64(44518), np.int64(18607)]
# Recommended artist names: [np.str_('Jason Nevins'), np.str_('Andrea Bocelli'), np.str_('Jim Sturgess & Joe Anderson'), np.str_('Amy Spanger'), np.str_('Joint Venture')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Indices of 5 recommended artists: [np.int64(36444), np.int64(17665), np.int64(9630), np.int64(114458), np.int64(9593)]
# Recommended artist names: [np.str_('That Dog.'), np.str_('James Chance And The Contortions'), np.str_('The Jesus Lizard'), np.str_('Golden Hotel'), np.str_('The Ditty Bops')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Indices of 5 recommended artists: [np.int64(1027), np.int64(13108), np.int64(30415), np.int64(48847), np.int64(89694)]
# Recommended artist names: [np.str_('Fiona Apple'), np.str_('The Living End'), np.str_('Over It'), np.str_('The Artist Life'), np.str_('All Out War')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Indices of 5 recommended artists: [np.int64(340), np.int64(3587), np.int64(10960), np.int64(15120), np.int64(7295)]
# Recommended artist names: [np.str_('Louie Austen'), np.str_('Ra Ra Riot'), np.str_('The Black Crowes'), np.str_('Peasant'), np.str_('Kid Cudi')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Indices of 5 recommended artists: [np.int64(136776), np.int64(15057), np.int64(36982), np.int64(47220), np.int64(12111)]
# Recommended artist names: [np.str_('Urszula Dudziak And Adam Makowicz'), np.str_('Little Brother'), np.str_('Behiye Aksoy'), np.str_('Hitomi'), np.str_('Norfolk & Western')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Indices of 5 recommended artists: [np.int64(17561), np.int64(11448), np.int64(19478), np.int64(4399), np.int64(2217)]
# Recommended artist names: [np.str_('The Jonah Jones Quartet'), np.str_('De Dannan'), np.str_('The Fantômasmelvins Big Band'), np.str_('Karunesh'), np.str_('Hieroglyphics')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Indices of 5 recommended artists: [np.int64(1632), np.int64(49563), np.int64(1924), np.int64(1695), np.int64(30616)]
# Recommended artist names: [np.str_('The Automatic'), np.str_('Telepathy (Dja Remix)'), np.str_('65Daysofstatic'), np.str_('The Get Up Kids'), np.str_('Gael García Bernal, Sacha Bourdo, Alain Chabat & Aurelia Petit')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Indices of 5 recommended artists: [np.int64(44990), np.int64(9678), np.int64(4049), np.int64(2118), np.int64(10235)]
# Recommended artist names: [np.str_('Paul Van Dyk Feat. Rea Garvey'), np.str_('The Specials'), np.str_('Angie Stone'), np.str_('Dominic Plaza'), np.str_('C')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Indices of 5 recommended artists: [np.int64(12951), np.int64(15014), np.int64(11820), np.int64(2296), np.int64(2696)]
# Recommended artist names: [np.str_('Ιάννης Ξενάκης'), np.str_('Jaylib'), np.str_("Jordan O'Jordan"), np.str_('Krazy Baldhead'), np.str_('Alela Diane')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Indices of 5 recommended artists: [np.int64(41121), np.int64(173595), np.int64(4033), np.int64(7852), np.int64(173599)]
# Recommended artist names: [np.str_('Damezumari'), np.str_('Celda & Sonja'), np.str_('Akon'), np.str_('Zen Café'), np.str_('Dj Mobster Ft.Paleface&Redrama')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Indices of 5 recommended artists: [np.int64(157834), np.int64(732), np.int64(7740), np.int64(1188), np.int64(26451)]
# Recommended artist names: [np.str_('David Warner'), np.str_('Antonio Vivaldi'), np.str_('Reflection Eternal'), np.str_('Joseph Arthur'), np.str_('Pase Rock')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Indices of 5 recommended artists: [np.int64(12109), np.int64(89430), np.int64(80021), np.int64(159782), np.int64(1168)]
# Recommended artist names: [np.str_('Nizlopi'), np.str_('Jim Cummings'), np.str_('Nico Stai'), np.str_('Paul Brandt'), np.str_('John Lennon')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Indices of 5 recommended artists: [np.int64(30975), np.int64(164748), np.int64(17543), np.int64(25096), np.int64(97839)]
# Recommended artist names: [np.str_('By The End Of Tonight'), np.str_('Tok¥O $Kunx'), np.str_('The Arlenes'), np.str_('Aoki Takamasa + Tujiko Noriko'), np.str_('The Detroit Escalator Co.')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Indices of 5 recommended artists: [np.int64(26923), np.int64(7114), np.int64(14565), np.int64(34729), np.int64(19735)]
# Recommended artist names: [np.str_('The Heliocentrics'), np.str_('Venetian Snares'), np.str_('The Kingsbury Manx'), np.str_('Vladislav Delay'), np.str_('Willy Deville')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Indices of 5 recommended artists: [np.int64(38774), np.int64(1399), np.int64(9505), np.int64(760), np.int64(39330)]
# Recommended artist names: [np.str_('Disco Tex & The Sex-O-Lettes'), np.str_('Patrick Swayze'), np.str_('Swing Out Sister'), np.str_('B.J. Thomas'), np.str_('Olivia Newton-John & Cliff Richard')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Indices of 5 recommended artists: [np.int64(11126), np.int64(9303), np.int64(55776), np.int64(99458), np.int64(12052)]
# Recommended artist names: [np.str_('White Denim'), np.str_('Right Said Fred'), np.str_('Kutmasta Kurt'), np.str_('Drew Sidora'), np.str_('Midge Ure')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Indices of 5 recommended artists: [np.int64(7854), np.int64(20031), np.int64(14449), np.int64(2253), np.int64(1710)]
# Recommended artist names: [np.str_('[Television Theme Songs]'), np.str_('Fair To Midland'), np.str_('The Apples In Stereo'), np.str_('Jethro Tull'), np.str_('The Killers')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Indices of 5 recommended artists: [np.int64(11242), np.int64(108510), np.int64(82960), np.int64(11166), np.int64(3025)]
# Recommended artist names: [np.str_("B'Z"), np.str_('Nashville String Machine/Nichole Nordeman'), np.str_('Luisa Mandou Um Beijo'), np.str_('Adiemus'), np.str_('Drowning Pool')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Indices of 5 recommended artists: [np.int64(15250), np.int64(12023), np.int64(248), np.int64(123234), np.int64(35539)]
# Recommended artist names: [np.str_('Tie-Dye Quartet'), np.str_('Mcfly'), np.str_("Jacob'S Optical Stairway"), np.str_('Sami Kukka'), np.str_('Vargo')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Indices of 5 recommended artists: [np.int64(173279), np.int64(1296), np.int64(41797), np.int64(11707), np.int64(1897)]
# Recommended artist names: [np.str_('Diego Mongelos'), np.str_('Matisyahu'), np.str_('Mans Draugs Nen.Cilveks (1975)'), np.str_('Hitchcockgohome!'), np.str_('Yeah Yeah Yeahs')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Indices of 5 recommended artists: [np.int64(74806), np.int64(12357), np.int64(903), np.int64(11262), np.int64(29798)]
# Recommended artist names: [np.str_('Ethan Hawke'), np.str_('Soul Coughing'), np.str_('Danko Jones'), np.str_('Batmobile'), np.str_('Xbxrx')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Indices of 5 recommended artists: [np.int64(2111), np.int64(34724), np.int64(2956), np.int64(753), np.int64(13711)]
# Recommended artist names: [np.str_('Dj Sammy'), np.str_('Venus Hum'), np.str_('Crustation'), np.str_('Audioslave'), np.str_('B.B.E.')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Indices of 5 recommended artists: [np.int64(18793), np.int64(18347), np.int64(86136), np.int64(90045), np.int64(3553)]
# Recommended artist names: [np.str_('Lou Reed / John Cale'), np.str_('Freddie Mcgregor'), np.str_('Behrouz'), np.str_('98 Degrees & Stevie Wonder'), np.str_('Pere Ubu')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Indices of 5 recommended artists: [np.int64(165168), np.int64(34858), np.int64(15253), np.int64(14034), np.int64(15280)]
# Recommended artist names: [np.str_('Tobey Maguire; Willem Dafoe; Kirsten Dunst; James Franco; Cliff Robertson'), np.str_('John Frusciante And Josh Klinghoffer'), np.str_('Tkatka'), np.str_('Ida Maria'), np.str_('Xanax')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Indices of 5 recommended artists: [np.int64(109208), np.int64(480), np.int64(6006), np.int64(110030), np.int64(911)]
# Recommended artist names: [np.str_('Tnt Jackson & Chris Corner'), np.str_('Rouge Rouge'), np.str_('Thomas/Mayer'), np.str_('Dubia Fortuna'), np.str_('Dave Matthews Band')]
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Indices of 5 recommended artists: [np.int64(28637), np.int64(2055), np.int64(10451), np.int64(72259), np.int64(46718)]
# Recommended artist names: [np.str_('Tom Richardson'), np.str_('Conil'), np.str_('1990S'), np.str_('Television Room'), np.str_('Axiome')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0016 seconds

# %% [markdown]
# Average time per user recommendation: 0.0015s

# %%
# %prun -s cumulative run_recommendations()
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Indices of 5 recommended artists: [np.int64(1773), np.int64(42297), np.int64(27425), np.int64(10698), np.int64(18469)]
# Recommended artist names: [np.str_('The Shins'), np.str_('Fanfare Ciocarlia'), np.str_('And One - Sometimes (Radio Edit)'), np.str_('Japan'), np.str_('Hildegard Knef')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Indices of 5 recommended artists: [np.int64(2584), np.int64(2007), np.int64(2295), np.int64(2872), np.int64(42248)]
# Recommended artist names: [np.str_('The Used'), np.str_('Bob Marley'), np.str_('Kraftwerk'), np.str_('Cansei De Ser Sexy'), np.str_('Alina Orlova')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Indices of 5 recommended artists: [np.int64(7793), np.int64(52457), np.int64(8476), np.int64(30706), np.int64(59898)]
# Recommended artist names: [np.str_('The Black Mages'), np.str_('Jan Driver'), np.str_('Falco'), np.str_('Thomas Bangalter & Dj Falcon'), np.str_('Tv Rock Feat. Rudy')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Indices of 5 recommended artists: [np.int64(8294), np.int64(22360), np.int64(6884), np.int64(18368), np.int64(16605)]
# Recommended artist names: [np.str_('Deastro'), np.str_('Mood Ii Swing'), np.str_('E.S. Posthumus'), np.str_('Gary Puckett & The Union Gap'), np.str_('Foreign Born')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Indices of 5 recommended artists: [np.int64(2452), np.int64(2086), np.int64(23456), np.int64(2434), np.int64(13055)]
# Recommended artist names: [np.str_('Ravi Shankar'), np.str_('Death In Vegas'), np.str_('Traci Lords'), np.str_('Petter'), np.str_('Mclusky')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Indices of 5 recommended artists: [np.int64(14121), np.int64(128701), np.int64(2169), np.int64(10785), np.int64(252)]
# Recommended artist names: [np.str_('Lodger'), np.str_('A Lily'), np.str_('Foals'), np.str_('Maria Taylor'), np.str_('Janet Jackson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Indices of 5 recommended artists: [np.int64(42222), np.int64(10458), np.int64(10716), np.int64(100194), np.int64(100661)]
# Recommended artist names: [np.str_('Trillville'), np.str_('Acceptance'), np.str_('Jordan Knight'), np.str_('Cherish Feat. Yung Joc, Jody Breeze, Chingy & Fabo Of D4L'), np.str_('Wyclef Jean Feat. Wayne Wonder & Elephant Man (Onthastreets.Com)')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Indices of 5 recommended artists: [np.int64(2500), np.int64(59618), np.int64(5789), np.int64(59523), np.int64(9345)]
# Recommended artist names: [np.str_('Solarstone'), np.str_('Dj Shah Feat. Inger Hansen'), np.str_('Rhythm & Sound'), np.str_('Andy Duguid Feat Leah'), np.str_('Santigold')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Indices of 5 recommended artists: [np.int64(2380), np.int64(11873), np.int64(1228), np.int64(156274), np.int64(88185)]
# Recommended artist names: [np.str_('Misfits'), np.str_('King Diamond'), np.str_('Kimya Dawson'), np.str_('Jenny & Nicole'), np.str_('Brand New Year')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Indices of 5 recommended artists: [np.int64(54978), np.int64(154459), np.int64(32659), np.int64(63050), np.int64(3508)]
# Recommended artist names: [np.str_('Dj Qbert'), np.str_('The Ks Feat. Robert Owens'), np.str_('Barbara Mendes'), np.str_('Dogzilla'), np.str_('Nouvelle Vague')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Indices of 5 recommended artists: [np.int64(2259), np.int64(137177), np.int64(25955), np.int64(32997), np.int64(45726)]
# Recommended artist names: [np.str_('Johann Sebastian Bach'), np.str_('Paul Agnew'), np.str_('John Travolta/Samuel L. Jackson'), np.str_('Machine Gun Fellatio'), np.str_('Grouper')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Indices of 5 recommended artists: [np.int64(136905), np.int64(29165), np.int64(88712), np.int64(3582), np.int64(68408)]
# Recommended artist names: [np.str_('Cimarosa Collective'), np.str_('New Age Steepers'), np.str_('John Wilkes Booze'), np.str_('Puressence'), np.str_('Aden')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Indices of 5 recommended artists: [np.int64(162182), np.int64(51817), np.int64(51930), np.int64(51552), np.int64(2995)]
# Recommended artist names: [np.str_('Taipuva Luotisuora'), np.str_('Soundtrack Braveheart'), np.str_('Âşık Veysel'), np.str_('Garfi.Gen.Tr - Neredesin Firuze'), np.str_('Denali')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Indices of 5 recommended artists: [np.int64(18306), np.int64(1611), np.int64(1827), np.int64(3178), np.int64(2932)]
# Recommended artist names: [np.str_('Fefe Dobson'), np.str_('Ted Leo And The Pharmacists'), np.str_('Tokyo Police Club'), np.str_('Hawksley Workman'), np.str_('Cloud Cult')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Indices of 5 recommended artists: [np.int64(5848), np.int64(3469), np.int64(33114), np.int64(17580), np.int64(109132)]
# Recommended artist names: [np.str_('Sety'), np.str_('Myslovitz'), np.str_('Ready For The World'), np.str_('The Scene'), np.str_('Eddie Vedder & The Strokes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Indices of 5 recommended artists: [np.int64(1367), np.int64(3842), np.int64(38439), np.int64(79108), np.int64(52830)]
# Recommended artist names: [np.str_('No Use For A Name'), np.str_('The Rubettes'), np.str_('28 Costumes'), np.str_('Tommy Shane Steiner'), np.str_('Horne & Corden')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Indices of 5 recommended artists: [np.int64(1808), np.int64(34894), np.int64(64423), np.int64(104636), np.int64(16800)]
# Recommended artist names: [np.str_('The Wombats'), np.str_('Relative Q'), np.str_('Nitro2K01'), np.str_('Biel Ballester Trio, Graci Pedro, Leo Hipaucha'), np.str_('Fabolous')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Indices of 5 recommended artists: [np.int64(3465), np.int64(1047), np.int64(44792), np.int64(13910), np.int64(42417)]
# Recommended artist names: [np.str_('My Morning Jacket'), np.str_('Friendly Fires'), np.str_('Fabulous Disaster'), np.str_('Earlimart'), np.str_('Rudimentary Peni')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Indices of 5 recommended artists: [np.int64(21890), np.int64(1288), np.int64(6042), np.int64(1310), np.int64(59873)]
# Recommended artist names: [np.str_('Atrocity'), np.str_('Mark Knopfler'), np.str_('Transplants'), np.str_('Michael Brecker'), np.str_('The Last Atlant')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Indices of 5 recommended artists: [np.int64(48088), np.int64(2259), np.int64(10626), np.int64(1066), np.int64(14853)]
# Recommended artist names: [np.str_('Brian De Mercier'), np.str_('Johann Sebastian Bach'), np.str_('Frankie Goes To Hollywood'), np.str_('Gnarls Barkley'), np.str_('Alpha Beat')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Indices of 5 recommended artists: [np.int64(12311), np.int64(1027), np.int64(131283), np.int64(130161), np.int64(1773)]
# Recommended artist names: [np.str_('Seu Jorge'), np.str_('Fiona Apple'), np.str_('Uncle Bunt Stephens'), np.str_('Joe "King" Carrasco And The Crowns'), np.str_('The Shins')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Indices of 5 recommended artists: [np.int64(111853), np.int64(13356), np.int64(180), np.int64(12923), np.int64(5324)]
# Recommended artist names: [np.str_('Kristofer Åström & Ronny Eriksson'), np.str_('Neko Case And Her Boyfriends'), np.str_('Fila Brazillia'), np.str_('The Seeds'), np.str_('Hell On Wheels')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Indices of 5 recommended artists: [np.int64(11134), np.int64(12094), np.int64(23030), np.int64(99546), np.int64(20437)]
# Recommended artist names: [np.str_('Year Long Disaster'), np.str_('Nena'), np.str_('Kevin Dellinger'), np.str_('Mysolvitz'), np.str_('梶浦由記')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Indices of 5 recommended artists: [np.int64(8770), np.int64(18892), np.int64(23730), np.int64(8152), np.int64(16400)]
# Recommended artist names: [np.str_('Julian Cope'), np.str_('Meat Pie'), np.str_('The Go Find'), np.str_('Charles Mingus'), np.str_('Death')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Indices of 5 recommended artists: [np.int64(126140), np.int64(11192), np.int64(87420), np.int64(3748), np.int64(38404)]
# Recommended artist names: [np.str_('Billy Thorpe & The Aztecs'), np.str_('Alter Bridge'), np.str_('Nara Leão & Elis Regina'), np.str_('Texas'), np.str_('The Ossis')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Indices of 5 recommended artists: [np.int64(748), np.int64(23656), np.int64(21333), np.int64(12074), np.int64(9948)]
# Recommended artist names: [np.str_('Astrud Gilberto'), np.str_('La Rue Kétanou'), np.str_('The Eternals'), np.str_('Moya Brennan'), np.str_('Eagle Seagull')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Indices of 5 recommended artists: [np.int64(41107), np.int64(69996), np.int64(138534), np.int64(15864), np.int64(39300)]
# Recommended artist names: [np.str_('Circ'), np.str_('Dis-Creet Ft Jodie'), np.str_('Diomedes Díaz'), np.str_('Manfred Mann'), np.str_('N-Joi')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Indices of 5 recommended artists: [np.int64(3877), np.int64(11716), np.int64(50388), np.int64(21071), np.int64(107656)]
# Recommended artist names: [np.str_('The Whitest Boy Alive'), np.str_("Howlin' Wolf"), np.str_('Silver Bullet'), np.str_('Mary Jane Girls'), np.str_('The Arsonists - Language Arts')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Indices of 5 recommended artists: [np.int64(19049), np.int64(113017), np.int64(3427), np.int64(8001), np.int64(86493)]
# Recommended artist names: [np.str_('Orchestra Baobab'), np.str_("Good Golly! It'S Mr. Nick!"), np.str_('Mf Doom'), np.str_('Bell Biv Devoe'), np.str_('Theboylucas')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Indices of 5 recommended artists: [np.int64(5712), np.int64(18273), np.int64(18557), np.int64(60775), np.int64(19739)]
# Recommended artist names: [np.str_('Paul Kalkbrenner'), np.str_('Eu Quero Sol'), np.str_('Jeff Lorber'), np.str_('The Bears'), np.str_('Woody Herman')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Indices of 5 recommended artists: [np.int64(86353), np.int64(86238), np.int64(86339), np.int64(3796), np.int64(86478)]
# Recommended artist names: [np.str_('Ncqtl'), np.str_('Global Tourists'), np.str_('Mohammed Jiwa'), np.str_('The Field'), np.str_('The Neins Circa')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Indices of 5 recommended artists: [np.int64(134328), np.int64(38381), np.int64(19327), np.int64(7157), np.int64(1155)]
# Recommended artist names: [np.str_('Soulslide'), np.str_('Roger Daltrey'), np.str_('Skeletal Family'), np.str_('Basic Element'), np.str_('Jim Jacobs & Warren Casey')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Indices of 5 recommended artists: [np.int64(28152), np.int64(7710), np.int64(6705), np.int64(9950), np.int64(173541)]
# Recommended artist names: [np.str_('Eric Burdon And The Animals'), np.str_('Paradise Lost'), np.str_('Chris Cornell'), np.str_('Einstürzende Neubauten'), np.str_('Tonari No Totoro Ost')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Indices of 5 recommended artists: [np.int64(14244), np.int64(38663), np.int64(107), np.int64(9428), np.int64(12183)]
# Recommended artist names: [np.str_('Pernice Brothers'), np.str_('Christmas Baubles'), np.str_('Clémentine'), np.str_('Sofa'), np.str_('Phil Ochs')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Indices of 5 recommended artists: [np.int64(41446), np.int64(5936), np.int64(106586), np.int64(1838), np.int64(8902)]
# Recommended artist names: [np.str_('Valencia'), np.str_('Sutekh'), np.str_('Gator Soundtrack'), np.str_('Toto'), np.str_('Lifelike')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Indices of 5 recommended artists: [np.int64(642), np.int64(10669), np.int64(108532), np.int64(9958), np.int64(11931)]
# Recommended artist names: [np.str_('吉澤はじめ'), np.str_('Hinder'), np.str_('Ring Out Solstice Bells'), np.str_('Faith And The Muse'), np.str_('Lisa Loeb')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Indices of 5 recommended artists: [np.int64(11422), np.int64(23755), np.int64(10746), np.int64(54002), np.int64(13566)]
# Recommended artist names: [np.str_('Curved Air'), np.str_('Ace Frehley'), np.str_('Kubb'), np.str_('Younger Younger 28S'), np.str_('The Slits')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Indices of 5 recommended artists: [np.int64(24709), np.int64(27845), np.int64(3858), np.int64(27836), np.int64(16396)]
# Recommended artist names: [np.str_('Marduk'), np.str_('Sarbel'), np.str_('The Ting Tings'), np.str_('Russian Dream Vol.1 Valdaj'), np.str_('Dark Tranquillity')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Indices of 5 recommended artists: [np.int64(120661), np.int64(7259), np.int64(17538), np.int64(159741), np.int64(48227)]
# Recommended artist names: [np.str_('Pendulum Featuring Fresh, $Pyda & Tenor Fly'), np.str_('Godsmack'), np.str_('Terrorvision'), np.str_('Aaron Lewis; Fred Durst'), np.str_('Dragon Ball Z')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Indices of 5 recommended artists: [np.int64(1694), np.int64(13072), np.int64(28433), np.int64(1792), np.int64(4654)]
# Recommended artist names: [np.str_('The Gaslight Anthem'), np.str_('Orange Range'), np.str_('Loopless'), np.str_('The Thrills'), np.str_('Roxette')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Indices of 5 recommended artists: [np.int64(5415), np.int64(59590), np.int64(90110), np.int64(122237), np.int64(14957)]
# Recommended artist names: [np.str_('Junior Boys'), np.str_('Dave 202'), np.str_('Danielle Paris'), np.str_('Bomfunk Mcs & Jessica Folcker'), np.str_('Florian Filsinger')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Indices of 5 recommended artists: [np.int64(40150), np.int64(25053), np.int64(21119), np.int64(1364), np.int64(153527)]
# Recommended artist names: [np.str_('Datblygu'), np.str_('Aloe Blacc'), np.str_('Neil Landstrumm'), np.str_('Nine Inch Nails'), np.str_('Circle Six')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Indices of 5 recommended artists: [np.int64(18247), np.int64(2996), np.int64(722), np.int64(34687), np.int64(12169)]
# Recommended artist names: [np.str_('Electro Hippies'), np.str_('Dengue Fever'), np.str_('Anita Baker'), np.str_('The Plot To Blow Up The Eiffel Tower'), np.str_('Penguin Cafe Orchestra')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Indices of 5 recommended artists: [np.int64(24848), np.int64(6870), np.int64(1758), np.int64(20076), np.int64(30712)]
# Recommended artist names: [np.str_('Tierra Santa'), np.str_('Dimmu Borgir'), np.str_('The Pussycat Dolls'), np.str_('Jacek Kaczmarski'), np.str_('Belinda')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Indices of 5 recommended artists: [np.int64(1370), np.int64(17642), np.int64(86526), np.int64(24146), np.int64(102686)]
# Recommended artist names: [np.str_('Norah Jones'), np.str_('少年ナイフ'), np.str_('80'), np.str_('Ignite'), np.str_('The Vaz')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Indices of 5 recommended artists: [np.int64(149404), np.int64(810), np.int64(36575), np.int64(66184), np.int64(28691)]
# Recommended artist names: [np.str_('V/A: We Reach'), np.str_('Blur'), np.str_('Rockaway'), np.str_('City Riots'), np.str_('Accident')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Indices of 5 recommended artists: [np.int64(23967), np.int64(65242), np.int64(22071), np.int64(145969), np.int64(51285)]
# Recommended artist names: [np.str_('Bolt Thrower'), np.str_('E-De-Cologne'), np.str_('The Almost'), np.str_('Drokz&Tails'), np.str_('The Stanley Brothers')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Indices of 5 recommended artists: [np.int64(39675), np.int64(2366), np.int64(2291), np.int64(3324), np.int64(150266)]
# Recommended artist names: [np.str_('The Israelites'), np.str_('Michael Gray'), np.str_('Klaxons'), np.str_('Laura Marling'), np.str_('Louis Prima & Phil Harris')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Indices of 5 recommended artists: [np.int64(15259), np.int64(2864), np.int64(1293), np.int64(31201), np.int64(54725)]
# Recommended artist names: [np.str_('Ugly Duckling'), np.str_('Camille'), np.str_('Massive Attack'), np.str_('Eric Hutchinson'), np.str_('Clifford Nyren')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Indices of 5 recommended artists: [np.int64(10499), np.int64(45840), np.int64(19033), np.int64(46764), np.int64(722)]
# Recommended artist names: [np.str_('Beachwood Sparks'), np.str_('Ronderlin'), np.str_('Numbers'), np.str_('Gepe'), np.str_('Anita Baker')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Indices of 5 recommended artists: [np.int64(53600), np.int64(1395), np.int64(66282), np.int64(12083), np.int64(1558)]
# Recommended artist names: [np.str_('You Slut!'), np.str_('Papa Roach'), np.str_('Situationists'), np.str_('Mute Math'), np.str_('Sophie Zelmani')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Indices of 5 recommended artists: [np.int64(3978), np.int64(59138), np.int64(27522), np.int64(43755), np.int64(22823)]
# Recommended artist names: [np.str_('Zero Assoluto'), np.str_('I.C.S.'), np.str_('Deadsy'), np.str_('Thy Serpent'), np.str_('Dj Quicksilver')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Indices of 5 recommended artists: [np.int64(27336), np.int64(22894), np.int64(69607), np.int64(22360), np.int64(91772)]
# Recommended artist names: [np.str_('Juliet'), np.str_('Erma Franklin'), np.str_('Ascension'), np.str_('Mood Ii Swing'), np.str_('Bushwackas')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Indices of 5 recommended artists: [np.int64(116689), np.int64(46221), np.int64(159), np.int64(30128), np.int64(17072)]
# Recommended artist names: [np.str_('Lobotomia'), np.str_('M.O.D.'), np.str_('Dubfire'), np.str_('Sonny & Cher'), np.str_('Big Black')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Indices of 5 recommended artists: [np.int64(18644), np.int64(25919), np.int64(1670), np.int64(2446), np.int64(4442)]
# Recommended artist names: [np.str_('Katharine Mcphee'), np.str_('Jazzkantine'), np.str_('The Dead 60S'), np.str_('Queen'), np.str_('Londonbeat')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Indices of 5 recommended artists: [np.int64(23345), np.int64(46235), np.int64(23601), np.int64(10777), np.int64(5572)]
# Recommended artist names: [np.str_('Social Ambitions'), np.str_('Michel Corboz'), np.str_('Boom Bip & Doseone'), np.str_('Madness'), np.str_('Max Richter')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Indices of 5 recommended artists: [np.int64(2457), np.int64(1277), np.int64(745), np.int64(1055), np.int64(125454)]
# Recommended artist names: [np.str_('Robbie Rivera'), np.str_('Mando Diao'), np.str_('Ash'), np.str_('Gabrielle'), np.str_('Jonathan Peters')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Indices of 5 recommended artists: [np.int64(123812), np.int64(104000), np.int64(155982), np.int64(60709), np.int64(94202)]
# Recommended artist names: [np.str_('The Life And Times'), np.str_('Grand Prix'), np.str_('Jobe'), np.str_('Smashing Orange'), np.str_('My Red Cell')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Indices of 5 recommended artists: [np.int64(9195), np.int64(626), np.int64(8061), np.int64(7564), np.int64(14940)]
# Recommended artist names: [np.str_('Paul Mccartney & Wings'), np.str_('Yael Naim'), np.str_('Bolt Action Five'), np.str_('Gary Moore'), np.str_('Ebony Bones!')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Indices of 5 recommended artists: [np.int64(18637), np.int64(18313), np.int64(1080), np.int64(38564), np.int64(17796)]
# Recommended artist names: [np.str_('Kak'), np.str_('Fila Brazillia - Café Del Mar Edition'), np.str_('Guillemots'), np.str_('Black Lace'), np.str_('Andre Williams')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Indices of 5 recommended artists: [np.int64(39373), np.int64(4991), np.int64(70382), np.int64(105681), np.int64(10647)]
# Recommended artist names: [np.str_('Peter Andre'), np.str_('Aventura'), np.str_('Jenny Bliss'), np.str_('D-Jmc Feat. Beat Monique'), np.str_('Get Set Go')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Indices of 5 recommended artists: [np.int64(33075), np.int64(7040), np.int64(3969), np.int64(19237), np.int64(19390)]
# Recommended artist names: [np.str_('Parov Stellar'), np.str_('Rob Zombie'), np.str_('Yoko Ono'), np.str_("Royer'S One Man Band"), np.str_('Sundaysounds')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Indices of 5 recommended artists: [np.int64(1734), np.int64(84121), np.int64(35053), np.int64(22858), np.int64(19904)]
# Recommended artist names: [np.str_('The Moldy Peaches'), np.str_('S.P. Balasubrahmanyam'), np.str_("Fredrik Thordendal'S Special Defects"), np.str_('Dumonde'), np.str_('Tiamat')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Indices of 5 recommended artists: [np.int64(31885), np.int64(86890), np.int64(2551), np.int64(2086), np.int64(2876)]
# Recommended artist names: [np.str_('Queen & Wyclef Jean'), np.str_('Heavydance'), np.str_('The Dirtbombs'), np.str_('Death In Vegas'), np.str_('Carly Simon')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Indices of 5 recommended artists: [np.int64(10710), np.int64(761), np.int64(104311), np.int64(28639), np.int64(16477)]
# Recommended artist names: [np.str_('John Vanderslice'), np.str_('Babyshambles'), np.str_('The Havana Boys Meet The Dave Pike Set'), np.str_('Tribalistas'), np.str_('Moneen')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Indices of 5 recommended artists: [np.int64(21584), np.int64(40565), np.int64(6444), np.int64(8779), np.int64(57704)]
# Recommended artist names: [np.str_('Amaral'), np.str_('Leslie Parrish'), np.str_('Jagged Edge'), np.str_('K-Os'), np.str_('Roberto Sol')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Indices of 5 recommended artists: [np.int64(882), np.int64(4670), np.int64(145631), np.int64(15057), np.int64(7307)]
# Recommended artist names: [np.str_('Common Rider'), np.str_('Sash!'), np.str_('Āåšźą Ńåšäž÷Źą'), np.str_('Little Brother'), np.str_('Marcel Woods')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Indices of 5 recommended artists: [np.int64(15088), np.int64(18597), np.int64(47123), np.int64(50924), np.int64(24016)]
# Recommended artist names: [np.str_('Mira Calix'), np.str_('John Scofield'), np.str_('Enzo Enzo'), np.str_('7 Hurtz With Peaches'), np.str_('The Cox Family')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Indices of 5 recommended artists: [np.int64(17014), np.int64(12970), np.int64(127744), np.int64(16841), np.int64(84316)]
# Recommended artist names: [np.str_('Young Noble'), np.str_('Autolux'), np.str_('Jin Feat. Swizz Beatz'), np.str_('Jamesy P'), np.str_('Dj Fresh Feat. Mc Darrison')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Indices of 5 recommended artists: [np.int64(4774), np.int64(31091), np.int64(8925), np.int64(14821), np.int64(31922)]
# Recommended artist names: [np.str_('The Flying Burrito Brothers'), np.str_('Delta Spirit'), np.str_('Longwave'), np.str_('Neu!'), np.str_('Rhett Miller')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Indices of 5 recommended artists: [np.int64(1010), np.int64(46653), np.int64(774), np.int64(3582), np.int64(1838)]
# Recommended artist names: [np.str_('Evanescence'), np.str_('Sunset Strippers'), np.str_('Beatsteaks'), np.str_('Puressence'), np.str_('Toto')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Indices of 5 recommended artists: [np.int64(6702), np.int64(8902), np.int64(6062), np.int64(24220), np.int64(22903)]
# Recommended artist names: [np.str_('Cast'), np.str_('Lifelike'), np.str_('Velvet Revolver'), np.str_('Youngbloodz'), np.str_('Ewan Mcgregor, Jose Feliciano And Jacek Koman')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Indices of 5 recommended artists: [np.int64(1159), np.int64(45807), np.int64(54561), np.int64(3572), np.int64(166642)]
# Recommended artist names: [np.str_('Jimmy Eat World'), np.str_('Monta'), np.str_('Bullion'), np.str_('Pretty Balanced'), np.str_('Melodika & Setä Ben')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Indices of 5 recommended artists: [np.int64(31422), np.int64(6739), np.int64(10048), np.int64(13082), np.int64(26586)]
# Recommended artist names: [np.str_('Jim Bianco'), np.str_('Jewel'), np.str_('Ministry'), np.str_('Popsicle'), np.str_('Richard Bartz')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Indices of 5 recommended artists: [np.int64(9593), np.int64(92441), np.int64(11875), np.int64(164569), np.int64(3997)]
# Recommended artist names: [np.str_('The Ditty Bops'), np.str_('Tom Peel'), np.str_('Kingdon Come'), np.str_('Tyl Alvim Rulez'), np.str_('小西香葉、近藤由紀夫')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Indices of 5 recommended artists: [np.int64(21333), np.int64(151118), np.int64(64648), np.int64(63916), np.int64(151124)]
# Recommended artist names: [np.str_('The Eternals'), np.str_('Zavoloka & Kotra'), np.str_('Sei Miguel'), np.str_('Forehead Bros'), np.str_('Zenial [Palsecam]')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Indices of 5 recommended artists: [np.int64(47672), np.int64(25653), np.int64(108406), np.int64(8245), np.int64(47235)]
# Recommended artist names: [np.str_('Tata Bojs'), np.str_('Fauna Flash'), np.str_('C S Cook'), np.str_('Culture Beat'), np.str_('Ibizarre')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Indices of 5 recommended artists: [np.int64(17682), np.int64(118734), np.int64(15007), np.int64(124530), np.int64(8131)]
# Recommended artist names: [np.str_('Ornette Coleman'), np.str_('Hardcore Surf Ants'), np.str_('James Horner'), np.str_('Wukimon'), np.str_('Caribou')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Indices of 5 recommended artists: [np.int64(8893), np.int64(52875), np.int64(34080), np.int64(34754), np.int64(16235)]
# Recommended artist names: [np.str_('Les Gammas'), np.str_('Liv Tyler'), np.str_('Aguayo/Rossknecht'), np.str_('Zabriskie Point'), np.str_('Tiger Tunes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Indices of 5 recommended artists: [np.int64(4393), np.int64(1076), np.int64(19309), np.int64(58020), np.int64(17887)]
# Recommended artist names: [np.str_('Junior Jack'), np.str_('Green Day'), np.str_('Shriekback'), np.str_('Dryft'), np.str_('Bbc World Service')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Indices of 5 recommended artists: [np.int64(3415), np.int64(3976), np.int64(765), np.int64(48312), np.int64(12846)]
# Recommended artist names: [np.str_('Meligrove Band'), np.str_('Zager & Evans'), np.str_('Bad Religion'), np.str_('News'), np.str_('Lauryn Hill')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Indices of 5 recommended artists: [np.int64(12629), np.int64(90366), np.int64(49764), np.int64(22506), np.int64(36305)]
# Recommended artist names: [np.str_('Willie Nelson'), np.str_('Arielle'), np.str_('Negative Approach'), np.str_('These New Puritans'), np.str_('Baby Dee')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Indices of 5 recommended artists: [np.int64(43515), np.int64(2765), np.int64(41975), np.int64(6918), np.int64(15465)]
# Recommended artist names: [np.str_('Andru Donalds'), np.str_('B.B. King'), np.str_('The Buzzhorn'), np.str_('Godhead'), np.str_('Bryan Ferry')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Indices of 5 recommended artists: [np.int64(1675), np.int64(70074), np.int64(2670), np.int64(69781), np.int64(3142)]
# Recommended artist names: [np.str_('The Doors'), np.str_('Dv Roxx'), np.str_('A Flock Of Seagulls'), np.str_('Cazwell'), np.str_('Golden Boy With Miss Kittin')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Indices of 5 recommended artists: [np.int64(1009), np.int64(1653), np.int64(2481), np.int64(42478), np.int64(42389)]
# Recommended artist names: [np.str_('Eva Cassidy'), np.str_('The Chordettes'), np.str_('September'), np.str_('關正傑'), np.str_('Neutral')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Indices of 5 recommended artists: [np.int64(17928), np.int64(5896), np.int64(8818), np.int64(18731), np.int64(95630)]
# Recommended artist names: [np.str_('Birdland With Lester Bangs'), np.str_('Speedy J'), np.str_('King Khan & The Shrines'), np.str_('Lee Wiley'), np.str_('Oh Romeo')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Indices of 5 recommended artists: [np.int64(4707), np.int64(9872), np.int64(120694), np.int64(96785), np.int64(7258)]
# Recommended artist names: [np.str_('Snap!'), np.str_('3'), np.str_('C-Sixty Four'), np.str_('Force Of Evil'), np.str_('Globay Deejays')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Indices of 5 recommended artists: [np.int64(26627), np.int64(42714), np.int64(118335), np.int64(11029), np.int64(12633)]
# Recommended artist names: [np.str_('Ryukyu Underground'), np.str_('Carlos Puebla'), np.str_('Paperface'), np.str_('The Milestone Corporation'), np.str_('Witchcraft')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Indices of 5 recommended artists: [np.int64(6748), np.int64(8961), np.int64(1986), np.int64(8909), np.int64(86351)]
# Recommended artist names: [np.str_('Linkin Park'), np.str_('Magik Markers'), np.str_('Bahamadia'), np.str_('Lindsay Lohan'), np.str_('Naked Rhythm')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Indices of 5 recommended artists: [np.int64(16174), np.int64(43236), np.int64(3329), np.int64(7756), np.int64(21603)]
# Recommended artist names: [np.str_('The Centurions'), np.str_('Sabrina Malheiros'), np.str_('Lenny Kravitz'), np.str_('Sepultura'), np.str_('Bobby Helms')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Indices of 5 recommended artists: [np.int64(65619), np.int64(18345), np.int64(1789), np.int64(34669), np.int64(10438)]
# Recommended artist names: [np.str_('The Hip Type'), np.str_('Fred Frith'), np.str_('The Suicide Machines'), np.str_('Taxi'), np.str_('X-Fusion')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Indices of 5 recommended artists: [np.int64(1163), np.int64(2169), np.int64(17797), np.int64(26580), np.int64(78114)]
# Recommended artist names: [np.str_('Joaquin Phoenix & Reese Witherspoon'), np.str_('Foals'), np.str_('Andrea Bocelli'), np.str_('Rework'), np.str_('Mccoy Tyner Trio & Michael Brecker')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Indices of 5 recommended artists: [np.int64(7024), np.int64(30319), np.int64(2669), np.int64(99698), np.int64(23695)]
# Recommended artist names: [np.str_('Peter Gabriel'), np.str_('Jim Carrey'), np.str_('A Fine Frenzy'), np.str_('Rachid'), np.str_('Pedestrian')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Indices of 5 recommended artists: [np.int64(23704), np.int64(107453), np.int64(17628), np.int64(15259), np.int64(2417)]
# Recommended artist names: [np.str_('Quannum Mcs'), np.str_('M2O Diabolika'), np.str_('X-Press 2'), np.str_('Ugly Duckling'), np.str_('Pakito')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Indices of 5 recommended artists: [np.int64(6182), np.int64(38420), np.int64(4465), np.int64(3134), np.int64(11546)]
# Recommended artist names: [np.str_('Мара'), np.str_('Uusi Fantasia'), np.str_('Marques Houston'), np.str_('Girl Talk'), np.str_('En Vogue')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Indices of 5 recommended artists: [np.int64(102887), np.int64(4160), np.int64(26396), np.int64(30151), np.int64(58607)]
# Recommended artist names: [np.str_('Kids Alive'), np.str_('Cornershop'), np.str_('Novika'), np.str_('Yugoton'), np.str_('The Johnny Burnette Trio')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Indices of 5 recommended artists: [np.int64(137970), np.int64(44639), np.int64(89650), np.int64(9512), np.int64(10382)]
# Recommended artist names: [np.str_('New Revelation'), np.str_('Shakira Ft Wyclef Jean'), np.str_('Catalpa Catalpa'), np.str_('Sœur Sourire'), np.str_('Satyricon')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Indices of 5 recommended artists: [np.int64(105081), np.int64(124060), np.int64(1249), np.int64(1398), np.int64(1700)]
# Recommended artist names: [np.str_('Eletrosamba'), np.str_('Jeff Lynne & George Harrison'), np.str_('Leona Naess'), np.str_('Patrick Park'), np.str_('The Hives')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# ...
# Indices of 5 recommended artists: [np.int64(8245), np.int64(11038), np.int64(16907), np.int64(157953), np.int64(65731)]
# Recommended artist names: [np.str_('Culture Beat'), np.str_('The New Seekers'), np.str_('Organized Konfusion'), np.str_('Usaf Heritage Of America Band'), np.str_('C.J. Lewis')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Indices of 5 recommended artists: [np.int64(99520), np.int64(24819), np.int64(1739), np.int64(60062), np.int64(1622)]
# Recommended artist names: [np.str_('Ksu [Umarłe Drzewa'), np.str_('Textures'), np.str_('The Offspring'), np.str_('Penicillin'), np.str_('The Academy Is...')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Indices of 5 recommended artists: [np.int64(73072), np.int64(10517), np.int64(2639), np.int64(108586), np.int64(18519)]
# Recommended artist names: [np.str_('Giant Paw'), np.str_('Black Label Society'), np.str_('Winterpills'), np.str_('奥村愛子'), np.str_('Ivan Lins')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Indices of 5 recommended artists: [np.int64(86215), np.int64(15273), np.int64(123234), np.int64(12929), np.int64(7001)]
# Recommended artist names: [np.str_('Ester Brinkmann'), np.str_('Wilderness'), np.str_('Sami Kukka'), np.str_('The Vaselines'), np.str_('Namnambulu')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Indices of 5 recommended artists: [np.int64(3223), np.int64(9950), np.int64(36868), np.int64(1788), np.int64(70858)]
# Recommended artist names: [np.str_('Iron & Wine And Calexico'), np.str_('Einstürzende Neubauten'), np.str_('Kammerflimmer Kollektief'), np.str_('The Subways'), np.str_('Nayer')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Indices of 5 recommended artists: [np.int64(29798), np.int64(54013), np.int64(9731), np.int64(1268), np.int64(1426)]
# Recommended artist names: [np.str_('Xbxrx'), np.str_('Dj Wally'), np.str_('Throwing Muses'), np.str_('Lucinda Williams'), np.str_('Pinback')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Indices of 5 recommended artists: [np.int64(2129), np.int64(31861), np.int64(6985), np.int64(3604), np.int64(12840)]
# Recommended artist names: [np.str_('Eagles'), np.str_('Polly Paulusma'), np.str_('Mesh'), np.str_('Remi Nicole'), np.str_('Juno Reactor')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Indices of 5 recommended artists: [np.int64(3731), np.int64(104198), np.int64(20561), np.int64(9984), np.int64(29296)]
# Recommended artist names: [np.str_('Syd Matters'), np.str_('Daniel Kehrmann'), np.str_('Wookie'), np.str_('Hank Williams Iii'), np.str_('Sarah Jane Hudson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Indices of 5 recommended artists: [np.int64(602), np.int64(9166), np.int64(9051), np.int64(67810), np.int64(14887)]
# Recommended artist names: [np.str_('Underworld'), np.str_('Orchestral Manoeuvres In The Dark'), np.str_('Mobius Band'), np.str_('Floater'), np.str_('Brother Ali')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Indices of 5 recommended artists: [np.int64(16414), np.int64(13919), np.int64(110132), np.int64(99485), np.int64(109143)]
# Recommended artist names: [np.str_('Emperor'), np.str_('Electric President'), np.str_('Mercy Giants'), np.str_('Ice Cube & Paul Oakenfeld'), np.str_('Guillaume Grosso')]
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Indices of 5 recommended artists: [np.int64(805), np.int64(27803), np.int64(81), np.int64(15181), np.int64(18960)]
# Recommended artist names: [np.str_('Blink-182'), np.str_('Red Flag'), np.str_('Bugge Wesseltoft'), np.str_('Spirit'), np.str_('Motorpsycho + Jaga Jazzist Horns')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0017 seconds
#          570362 function calls (565402 primitive calls) in 1.702 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.702    1.702 {built-in method builtins.exec}
#         1    0.001    0.001    1.701    1.701 <string>:1(<module>)
#         1    0.002    0.002    1.701    1.701 3631488482.py:60(run_recommendations)
#       993    0.001    0.000    1.035    0.001 _base.py:612(result_iterator)
#       992    0.001    0.000    1.034    0.001 _base.py:314(_result_or_cancel)
#      1601    0.002    0.000    1.034    0.001 threading.py:295(wait)
#       992    0.002    0.000    1.032    0.001 _base.py:428(result)
#      5212    1.030    0.000    1.030    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.353    0.353 class_wrappers.py:300(replacement_search)
#         1    0.000    0.000    0.352    0.352 swigfaiss.py:2367(search)
#         1    0.352    0.352    0.352    0.352 {built-in method faiss._swigfaiss.IndexFlat_search}
#      4961    0.010    0.000    0.300    0.000 {built-in method builtins.print}
#     17858    0.188    0.000    0.262    0.000 interactiveshell.py:3025(write)
#     17858    0.031    0.000    0.047    0.000 iostream.py:655(write)
#       992    0.001    0.000    0.029    0.000 arrayprint.py:1685(_array_str_implementation)
#       992    0.001    0.000    0.028    0.000 arrayprint.py:605(array2string)
#       992    0.001    0.000    0.024    0.000 arrayprint.py:550(wrapper)
#       992    0.002    0.000    0.023    0.000 arrayprint.py:567(_array2string)
#     35716    0.011    0.000    0.022    0.000 traitlets.py:676(__get__)
#       992    0.000    0.000    0.018    0.000 arrayprint.py:828(_formatArray)
#  5952/992    0.006    0.000    0.018    0.000 arrayprint.py:837(recurser)
#         1    0.000    0.000    0.011    0.011 _base.py:583(map)
#         1    0.000    0.000    0.011    0.011 _base.py:608(<listcomp>)
#       992    0.001    0.000    0.011    0.000 thread.py:161(submit)
#     35716    0.008    0.000    0.010    0.000 traitlets.py:629(get)
#       992    0.000    0.000    0.008    0.000 thread.py:180(_adjust_thread_count)
#      4960    0.002    0.000    0.005    0.000 arrayprint.py:801(_extendLine_pretty)
#      4960    0.002    0.000    0.005    0.000 arrayprint.py:436(repr_format)
#     17858    0.004    0.000    0.005    0.000 iostream.py:550(_is_master_process)
#       992    0.002    0.000    0.004    0.000 threading.py:440(acquire)
#     17858    0.003    0.000    0.004    0.000 iostream.py:505(parent_header)
#       992    0.002    0.000    0.003    0.000 arrayprint.py:496(_get_format_function)
#     71432    0.003    0.000    0.003    0.000 typing.py:2287(cast)
#      4960    0.002    0.000    0.003    0.000 arrayprint.py:787(_extendLine)
#         8    0.000    0.000    0.003    0.000 threading.py:945(start)
#     56546    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#         8    0.000    0.000    0.002    0.000 threading.py:611(wait)
#      4960    0.002    0.000    0.002    0.000 {method 'item' of 'numpy.generic' objects}
#       992    0.001    0.000    0.002    0.000 arrayprint.py:50(_make_options_dict)
#     19870    0.002    0.000    0.002    0.000 {method '__exit__' of '_thread.RLock' objects}
#     17858    0.001    0.000    0.002    0.000 iostream.py:577(_schedule_flush)
#     17858    0.001    0.000    0.001    0.000 {built-in method builtins.any}
#       992    0.000    0.000    0.001    0.000 _base.py:328(__init__)
#     17858    0.001    0.000    0.001    0.000 displaypub.py:150(is_publishing)
#     17858    0.001    0.000    0.001    0.000 displayhook.py:118(is_active)
#       992    0.001    0.000    0.001    0.000 _base.py:364(cancel)
#     22858    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#     17858    0.001    0.000    0.001    0.000 {method 'write' of '_io.StringIO' objects}
#     19842    0.001    0.000    0.001    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#      1001    0.001    0.000    0.001    0.000 threading.py:243(__init__)
#     18850    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#     17858    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#      2984    0.001    0.000    0.001    0.000 threading.py:271(__enter__)
#       992    0.001    0.000    0.001    0.000 arrayprint.py:446(_get_formatdict)
#      2984    0.001    0.000    0.001    0.000 threading.py:274(__exit__)
#       992    0.001    0.000    0.001    0.000 arrayprint.py:59(<dictcomp>)
#         3    0.001    0.000    0.001    0.000 swigfaiss.py:12226(swig_ptr)
#      4960    0.001    0.000    0.001    0.000 {built-in method builtins.repr}
#       992    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#      1611    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#      4960    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#      4960    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 _base.py:646(__exit__)
#         1    0.000    0.000    0.000    0.000 thread.py:216(shutdown)
#         8    0.000    0.000    0.000    0.000 threading.py:1087(join)
#         8    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#        10    0.000    0.000    0.000    0.000 threading.py:1125(_wait_for_tstate_lock)
#      1000    0.000    0.000    0.000    0.000 threading.py:286(_is_owned)
#       601    0.000    0.000    0.000    0.000 {method '_acquire_restore' of '_thread.RLock' objects}
#      1000    0.000    0.000    0.000    0.000 threading.py:280(_release_save)
#       992    0.000    0.000    0.000    0.000 threading.py:90(RLock)
#      1000    0.000    0.000    0.000    0.000 threading.py:283(_acquire_restore)
#        40    0.000    0.000    0.000    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#      1984    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#      2993    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       992    0.000    0.000    0.000    0.000 thread.py:47(__init__)
#       992    0.000    0.000    0.000    0.000 _base.py:398(__get_result)
#         2    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#         8    0.000    0.000    0.000    0.000 ipkernel.py:768(init_closure)
#       992    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#      1984    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         8    0.000    0.000    0.000    0.000 threading.py:856(__init__)
#         2    0.000    0.000    0.000    0.000 socket.py:623(send)
#       601    0.000    0.000    0.000    0.000 {method '_release_save' of '_thread.RLock' objects}
#      1603    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        20    0.000    0.000    0.000    0.000 ipkernel.py:790(<setcomp>)
#      1008    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       992    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       992    0.000    0.000    0.000    0.000 arrayprint.py:467(<lambda>)
#       992    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       992    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#       992    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 thread.py:123(__init__)
#       993    0.000    0.000    0.000    0.000 {method 'put' of '_queue.SimpleQueue' objects}
#      1000    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       992    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#      1016    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       992    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#      1000    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#      1008    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       992    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         8    0.000    0.000    0.000    0.000 threading.py:1051(_stop)
#       601    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#       320    0.000    0.000    0.000    0.000 threading.py:1168(ident)
#         1    0.000    0.000    0.000    0.000 threading.py:429(__init__)
#        20    0.000    0.000    0.000    0.000 threading.py:1501(enumerate)
#         8    0.000    0.000    0.000    0.000 threading.py:562(__init__)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:85(add)
#         8    0.000    0.000    0.000    0.000 threading.py:829(_maintain_shutdown_locks)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.ascontiguousarray}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         8    0.000    0.000    0.000    0.000 weakref.py:427(__setitem__)
#        16    0.000    0.000    0.000    0.000 threading.py:1453(current_thread)
#         8    0.000    0.000    0.000    0.000 threading.py:1324(_make_invoke_excepthook)
#         2    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         2    0.000    0.000    0.000    0.000 threading.py:1192(is_alive)
#         8    0.000    0.000    0.000    0.000 weakref.py:369(remove)
#         8    0.000    0.000    0.000    0.000 threading.py:839(<listcomp>)
#        80    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method faiss._swigfaiss.swig_ptr}
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#        40    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        16    0.000    0.000    0.000    0.000 threading.py:1206(daemon)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         8    0.000    0.000    0.000    0.000 {method 'difference_update' of 'set' objects}
#        18    0.000    0.000    0.000    0.000 threading.py:575(is_set)
#        28    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:643(__enter__)

# %% [markdown]
# # Applying Cython

# %%
# %%cython
# import numpy as np
# cimport numpy as np
#
# def build_playcounts_cy(str filepath):
#     cdef dict counts = {}
#     cdef bytes line
#     with open(filepath, 'rb') as f:
#         for line in f:
#             parts = line.rstrip(b'\n').split(b'\t')
#             counts[(parts[0], parts[3])] = counts.get((parts[0], parts[3]), 0) + 1
#     return counts                                       # Cython: replace pandas groupby
#
# def fill_matrix_cy(dict counts,
#                    np.ndarray[np.float32_t, ndim=2] M,
#                    dict user_to_idx,
#                    dict artist_to_idx):
#     cdef tuple key
#     cdef int u, a, cnt
#     for key, cnt in counts.items():
#         u = user_to_idx[key[0]]
#         a = artist_to_idx[key[1]]
#         M[u, a] += cnt                                    # Cython: replace itertuples loop
# Out:
# Content of stderr:
# In file included from /Users/yujinkim/.cache/ipython/cython/_cython_magic_d39cbee5769cfe17ccdb36f1ac3ec0377793e9d0.c:1250:
# In file included from /Users/yujinkim/Desktop/Efficient MRS/efficient_mrs/.venv/lib/python3.11/site-packages/numpy/_core/include/numpy/arrayobject.h:5:
# In file included from /Users/yujinkim/Desktop/Efficient MRS/efficient_mrs/.venv/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarrayobject.h:12:
# In file included from /Users/yujinkim/Desktop/Efficient MRS/efficient_mrs/.venv/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1913:
# /Users/yujinkim/Desktop/Efficient MRS/efficient_mrs/.venv/lib/python3.11/site-packages/numpy/_core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: "Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d39cbee5769cfe17ccdb36f1ac3ec0377793e9d0.c:7765:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#  7765 |                     CYTHON_FALLTHROUGH;
#       |                     ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d39cbee5769cfe17ccdb36f1ac3ec0377793e9d0.c:567:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#   567 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#       |                                  ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d39cbee5769cfe17ccdb36f1ac3ec0377793e9d0.c:7776:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#  7776 |                     CYTHON_FALLTHROUGH;
#       |                     ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d39cbee5769cfe17ccdb36f1ac3ec0377793e9d0.c:567:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#   567 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#       |                                  ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d39cbee5769cfe17ccdb36f1ac3ec0377793e9d0.c:9087:26: warning: code will never be executed [-Wunreachable-code]
#  9087 |                 module = PyImport_ImportModuleLevelObject(
#       |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 4 warnings generated.

# %%
# Count number of times each user listened to each artist
# playcounts = interactions.groupby(["user_id","artist_name"]).size().reset_index(name="playcount")
counts = build_playcounts_cy(file_path)              # Cython: replace pandas groupby

# Create mappings: user/artist to index
user_id_to_idx     = {u: i for i, u in enumerate({k[0] for k in counts.keys()})}   # Cython: from counts keys
artist_name_to_idx = {a: i for i, a in enumerate({k[1] for k in counts.keys()})}

# Build dense user-artist matrix (playcounts)
n_users   = len(user_id_to_idx)
n_artists = len(artist_name_to_idx)
user_matrix = np.zeros((n_users, n_artists), dtype=np.float32)

# for row in playcounts.itertuples(index=False):
#     user_matrix[row.user_idx, row.artist_idx] += row.playcount
fill_matrix_cy(counts, user_matrix, user_id_to_idx, artist_name_to_idx)  # Cython: replace itertuples loop

# Normalize rows to unit length for cosine similarity
faiss.normalize_L2(user_matrix)

# Create FAISS index for cosine similarity (inner product after normalization)
index = faiss.IndexFlatIP(n_artists)
index.add(user_matrix)  # Add all user vectors

# Reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

def recommend_user(u):
    neighbor_indices = neighbors[u][1:]  # skip self
    neighbor_scores  = distances[u][1:]

    recommended_artists_idx = []
    for neighbor in neighbor_indices:
        neighbor_vector = user_matrix[neighbor]
        recommended_artists_idx.extend(np.where(neighbor_vector > 0)[0])

    known_artists = np.where(user_matrix[u] > 0)[0]
    recommended_artists_idx = list(set(recommended_artists_idx) - set(known_artists))

    if len(recommended_artists_idx) >= K:
        random_indices = random.sample(recommended_artists_idx, K)
    else:
        random_indices = recommended_artists_idx

    return {
        "user": user_ids[u],
        "neighbors": user_ids[neighbor_indices],
        "artist_indices": random_indices,
        "artist_names": [artist_ids[i] for i in random_indices]
    }

def run_recommendations():
    """Run FAISS search and print recommendation results."""
    start_time = time.time()
    global distances, neighbors
    distances, neighbors = index.search(user_matrix, K + 1)

    with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
        results = list(executor.map(recommend_user, range(n_users)))

    for res in results:
        print("Seed user-id:", res["user"])
        print(f"Nearest K={K} neighbors' user-ids:", res["neighbors"])
        print(f"Indices of {len(res['artist_indices'])} recommended artists:", res["artist_indices"])
        print("Recommended artist names:", res["artist_names"])
        print('-' * 80)

    end_time = time.time()
    avg_time = (end_time - start_time) / n_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")

# %%
if __name__ == "__main__":
    run_recommendations()
# Out:
# Seed user-id: b'user_000375'
# Nearest K=5 neighbors' user-ids: [b'user_000959' b'user_000765' b'user_000016' b'user_000975'
#  b'user_000905']
# Indices of 5 recommended artists: [np.int64(28475), np.int64(148163), np.int64(151593), np.int64(106789), np.int64(1029)]
# Recommended artist names: [np.bytes_(b'The Killers'), np.bytes_(b'Drive'), np.bytes_(b'Beyonc\xc3\xa9 & Shakira'), np.bytes_(b'Godsmack'), np.bytes_(b'Rupee')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000942'
# Nearest K=5 neighbors' user-ids: [b'user_000195' b'user_000230' b'user_000431' b'user_000912'
#  b'user_000637']
# Indices of 5 recommended artists: [np.int64(122830), np.int64(134569), np.int64(91377), np.int64(40629), np.int64(8840)]
# Recommended artist names: [np.bytes_(b'Joe Strummer & The Mescaleros'), np.bytes_(b'Vertical Horizon'), np.bytes_(b'Brx'), np.bytes_(b'Total War'), np.bytes_(b'Jmfh')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000670'
# Nearest K=5 neighbors' user-ids: [b'user_000567' b'user_000031' b'user_000345' b'user_000577'
#  b'user_000998']
# Indices of 5 recommended artists: [np.int64(102681), np.int64(115978), np.int64(160669), np.int64(17016), np.int64(56325)]
# Recommended artist names: [np.bytes_(b'Denny Mclain'), np.bytes_(b'The Pierces'), np.bytes_(b'Shanghai Triad'), np.bytes_(b'Novos Baianos'), np.bytes_(b'Bassnectar')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000845'
# Nearest K=5 neighbors' user-ids: [b'user_000957' b'user_000461' b'user_000612' b'user_000453'
#  b'user_000182']
# Indices of 5 recommended artists: [np.int64(165712), np.int64(104974), np.int64(147164), np.int64(86961), np.int64(163042)]
# Recommended artist names: [np.bytes_(b'Shockwave'), np.bytes_(b'Thetaphi'), np.bytes_(b'Black Tartan Clan'), np.bytes_(b'Mika'), np.bytes_(b'Black Sun Empire Ft. Illy Emceeft. Illy Emcee')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000799'
# Nearest K=5 neighbors' user-ids: [b'user_000871' b'user_000205' b'user_000643' b'user_000243'
#  b'user_000894']
# Indices of 5 recommended artists: [np.int64(88615), np.int64(73891), np.int64(103600), np.int64(106185), np.int64(23154)]
# Recommended artist names: [np.bytes_(b'Everclear'), np.bytes_(b'Aleks Syntek Y La Gente Normal'), np.bytes_(b'Medeski Martin And Wood'), np.bytes_(b'Yeah Yeah Yeahs'), np.bytes_(b'Lo Ke Diga El Dedo')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000484'
# Nearest K=5 neighbors' user-ids: [b'user_000634' b'user_000927' b'user_000515' b'user_000503'
#  b'user_000866']
# Indices of 5 recommended artists: [np.int64(123562), np.int64(1181), np.int64(76316), np.int64(11160), np.int64(84314)]
# Recommended artist names: [np.bytes_(b'Fleetwood Mac'), np.bytes_(b'Trio'), np.bytes_(b"Vex'D"), np.bytes_(b'Lighthouse Family'), np.bytes_(b'Loess')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000031'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000513' b'user_000164' b'user_000159'
#  b'user_000242']
# Indices of 5 recommended artists: [np.int64(42154), np.int64(158370), np.int64(166146), np.int64(48596), np.int64(95645)]
# Recommended artist names: [np.bytes_(b'Blectum From Blechdom'), np.bytes_(b'Aldebert'), np.bytes_(b'The Kite-Eating Tree'), np.bytes_(b'The Mendoza Line'), np.bytes_(b'Cachorro Grande')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000406'
# Nearest K=5 neighbors' user-ids: [b'user_000767' b'user_000070' b'user_000600' b'user_000219'
#  b'user_000922']
# Indices of 5 recommended artists: [np.int64(104645), np.int64(162967), np.int64(150126), np.int64(141291), np.int64(145605)]
# Recommended artist names: [np.bytes_(b'Mc Paul Barman'), np.bytes_(b'Gry With Fm Einheit And His Orchestra'), np.bytes_(b'Cartola'), np.bytes_(b'Miranda Lambert'), np.bytes_(b'Scala & Kolacny Brothers')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000502'
# Nearest K=5 neighbors' user-ids: [b'user_000397' b'user_000569' b'user_000795' b'user_000223'
#  b'user_000371']
# Indices of 5 recommended artists: [np.int64(47685), np.int64(129495), np.int64(120381), np.int64(16607), np.int64(8076)]
# Recommended artist names: [np.bytes_(b'Pere Ubu'), np.bytes_(b'Portugal. The Man'), np.bytes_(b'Anathallo'), np.bytes_(b'Black Star'), np.bytes_(b'Mono')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000522'
# Nearest K=5 neighbors' user-ids: [b'user_000838' b'user_000079' b'user_000801' b'user_000074'
#  b'user_000577']
# Indices of 5 recommended artists: [np.int64(164408), np.int64(44507), np.int64(998), np.int64(57793), np.int64(140183)]
# Recommended artist names: [np.bytes_(b'Polmo Polpo'), np.bytes_(b'Tk'), np.bytes_(b'Maria Friedman'), np.bytes_(b'Lady Sovereign'), np.bytes_(b'Farley Jackmaster Funk')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000274'
# Nearest K=5 neighbors' user-ids: [b'user_000753' b'user_000717' b'user_000198' b'user_000582'
#  b'user_000060']
# Indices of 5 recommended artists: [np.int64(28440), np.int64(141622), np.int64(79517), np.int64(12226), np.int64(63202)]
# Recommended artist names: [np.bytes_(b'Benny Benassi'), np.bytes_(b'Anna Domino'), np.bytes_(b'Creed'), np.bytes_(b'Building 6'), np.bytes_(b'Grandmaster Flash & The Furious Five')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000301'
# Nearest K=5 neighbors' user-ids: [b'user_000603' b'user_000960' b'user_000065' b'user_000403'
#  b'user_000505']
# Indices of 5 recommended artists: [np.int64(7406), np.int64(137929), np.int64(36576), np.int64(68305), np.int64(59086)]
# Recommended artist names: [np.bytes_(b'Eagles Of Death Metal'), np.bytes_(b'Milburn'), np.bytes_(b'The Magic Numbers'), np.bytes_(b'Vega 4'), np.bytes_(b'Starsailor')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000583'
# Nearest K=5 neighbors' user-ids: [b'user_000150' b'user_000625' b'user_000553' b'user_000230'
#  b'user_000348']
# Indices of 5 recommended artists: [np.int64(86329), np.int64(99974), np.int64(101960), np.int64(137929), np.int64(109486)]
# Recommended artist names: [np.bytes_(b'Samhain'), np.bytes_(b'Monty Python'), np.bytes_(b'Tapio Rautavaara Ja Reino Helismaa'), np.bytes_(b'Milburn'), np.bytes_(b'Death Angel')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000693'
# Nearest K=5 neighbors' user-ids: [b'user_000397' b'user_000569' b'user_000024' b'user_000279'
#  b'user_000965']
# Indices of 5 recommended artists: [np.int64(119548), np.int64(44549), np.int64(87113), np.int64(133815), np.int64(123732)]
# Recommended artist names: [np.bytes_(b'Thee Oh Sees'), np.bytes_(b'Wilderness Pangs'), np.bytes_(b'The Helio Sequence'), np.bytes_(b'The Righteous Brothers'), np.bytes_(b'Spacehog')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000981'
# Nearest K=5 neighbors' user-ids: [b'user_000010' b'user_000706' b'user_000940' b'user_000208'
#  b'user_000715']
# Indices of 5 recommended artists: [np.int64(36871), np.int64(40812), np.int64(44260), np.int64(92894), np.int64(160056)]
# Recommended artist names: [np.bytes_(b'Uffie'), np.bytes_(b'Michael Garrick Trio'), np.bytes_(b'Zion'), np.bytes_(b'Ronski Speed'), np.bytes_(b'Robin Jones')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000076'
# Nearest K=5 neighbors' user-ids: [b'user_000168' b'user_000792' b'user_000091' b'user_000086'
#  b'user_000210']
# Indices of 5 recommended artists: [np.int64(88191), np.int64(115125), np.int64(120876), np.int64(17958), np.int64(153713)]
# Recommended artist names: [np.bytes_(b'Spacemen 3'), np.bytes_(b'Coparck'), np.bytes_(b'Morcheeba'), np.bytes_(b'The Sound Of Arrows'), np.bytes_(b'Andrew Hockey')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000385'
# Nearest K=5 neighbors' user-ids: [b'user_000993' b'user_000090' b'user_000980' b'user_000376'
#  b'user_000876']
# Indices of 5 recommended artists: [np.int64(151094), np.int64(25817), np.int64(64946), np.int64(147984), np.int64(83587)]
# Recommended artist names: [np.bytes_(b'Ready Fire Aim'), np.bytes_(b'Katie Melua'), np.bytes_(b'Client'), np.bytes_(b'Playgroup'), np.bytes_(b'Paris Combo')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000091'
# Nearest K=5 neighbors' user-ids: [b'user_000675' b'user_000807' b'user_000792' b'user_000074'
#  b'user_000703']
# Indices of 5 recommended artists: [np.int64(114499), np.int64(30667), np.int64(12827), np.int64(61340), np.int64(114326)]
# Recommended artist names: [np.bytes_(b'Fisz'), np.bytes_(b'Rainstick Orchestra'), np.bytes_(b'Marco Codeini'), np.bytes_(b'Don Mclean'), np.bytes_(b'Electric Company')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000212'
# Nearest K=5 neighbors' user-ids: [b'user_000778' b'user_000631' b'user_000829' b'user_000328'
#  b'user_000048']
# Indices of 5 recommended artists: [np.int64(59870), np.int64(11123), np.int64(25940), np.int64(134001), np.int64(93195)]
# Recommended artist names: [np.bytes_(b'Daddy_Yanke'), np.bytes_(b'[Disney]'), np.bytes_(b'Noel Gallagher & Paul Weller'), np.bytes_(b'Baby Rank'), np.bytes_(b'Ville Valo & Agents')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000096'
# Nearest K=5 neighbors' user-ids: [b'user_000653' b'user_000596' b'user_000110' b'user_000829'
#  b'user_000493']
# Indices of 5 recommended artists: [np.int64(12809), np.int64(59536), np.int64(20919), np.int64(98221), np.int64(48469)]
# Recommended artist names: [np.bytes_(b'The Slip'), np.bytes_(b'Those Dancing Days'), np.bytes_(b'Daedelus'), np.bytes_(b'Casiotone For The Painfully Alone'), np.bytes_(b'Cute Is What We Aim For')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000168'
# Nearest K=5 neighbors' user-ids: [b'user_000030' b'user_000753' b'user_000001' b'user_000362'
#  b'user_000076']
# Indices of 5 recommended artists: [np.int64(47105), np.int64(77180), np.int64(145563), np.int64(104954), np.int64(69218)]
# Recommended artist names: [np.bytes_(b'Dizzee Rascal'), np.bytes_(b'Megashira'), np.bytes_(b'Ravi Shankar'), np.bytes_(b'Nebula'), np.bytes_(b'The Unicorns')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000256'
# Nearest K=5 neighbors' user-ids: [b'user_000806' b'user_000383' b'user_000074' b'user_000117'
#  b'user_000024']
# Indices of 5 recommended artists: [np.int64(125280), np.int64(105164), np.int64(53561), np.int64(127630), np.int64(93065)]
# Recommended artist names: [np.bytes_(b'Little Brother'), np.bytes_(b'Future Tech'), np.bytes_(b'The Clientele'), np.bytes_(b'Rakim'), np.bytes_(b'Ceephax')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000408'
# Nearest K=5 neighbors' user-ids: [b'user_000705' b'user_000881' b'user_000417' b'user_000545'
#  b'user_000389']
# Indices of 5 recommended artists: [np.int64(89624), np.int64(3516), np.int64(34837), np.int64(64129), np.int64(24589)]
# Recommended artist names: [np.bytes_(b'John Martyn'), np.bytes_(b'Plbenjaminz'), np.bytes_(b'Bad Religion'), np.bytes_(b'Atomic Rooster'), np.bytes_(b'Barry Mcguire')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000685'
# Nearest K=5 neighbors' user-ids: [b'user_000606' b'user_000945' b'user_000135' b'user_000077'
#  b'user_000763']
# Indices of 5 recommended artists: [np.int64(69477), np.int64(23136), np.int64(55044), np.int64(113117), np.int64(113084)]
# Recommended artist names: [np.bytes_(b'Sporto Kantes'), np.bytes_(b'All Saints'), np.bytes_(b'Paulo Moura'), np.bytes_(b'Sing Sing Penelope'), np.bytes_(b"Society'S Bag")]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000085'
# Nearest K=5 neighbors' user-ids: [b'user_000346' b'user_000579' b'user_000686' b'user_000110'
#  b'user_000676']
# Indices of 5 recommended artists: [np.int64(105215), np.int64(17650), np.int64(133539), np.int64(143746), np.int64(33329)]
# Recommended artist names: [np.bytes_(b'Neda'), np.bytes_(b'No Alternative'), np.bytes_(b'Coldcut'), np.bytes_(b'Bj\xc3\xb6rn Olsson'), np.bytes_(b'Foje')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000625'
# Nearest K=5 neighbors' user-ids: [b'user_000150' b'user_000348' b'user_000583' b'user_000905'
#  b'user_000532']
# Indices of 5 recommended artists: [np.int64(63527), np.int64(2044), np.int64(93454), np.int64(66480), np.int64(167185)]
# Recommended artist names: [np.bytes_(b'Richard Ashcroft'), np.bytes_(b'The Sunshine Underground'), np.bytes_(b'Scientist'), np.bytes_(b'Man Parrish'), np.bytes_(b'The Farm')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000509'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000734' b'user_000304' b'user_000862'
#  b'user_000858']
# Indices of 5 recommended artists: [np.int64(115396), np.int64(69391), np.int64(82553), np.int64(109971), np.int64(172577)]
# Recommended artist names: [np.bytes_(b'Pong'), np.bytes_(b'The Juliana Theory'), np.bytes_(b'The Sounds'), np.bytes_(b'Small Defence'), np.bytes_(b'The Pillows')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000703'
# Nearest K=5 neighbors' user-ids: [b'user_000031' b'user_000024' b'user_000345' b'user_000242'
#  b'user_000159']
# Indices of 5 recommended artists: [np.int64(171216), np.int64(134127), np.int64(18881), np.int64(51831), np.int64(88986)]
# Recommended artist names: [np.bytes_(b'Saxon Shore'), np.bytes_(b'Atb'), np.bytes_(b'Neeme J\xc3\xa4rvi / Gothenburg Symphony Orchestra / Gil Shaham (Vn)'), np.bytes_(b'Bob Wills & His Texas Playboys'), np.bytes_(b'Five Smooth Stones')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000813'
# Nearest K=5 neighbors' user-ids: [b'user_000558' b'user_000392' b'user_000165' b'user_000003'
#  b'user_000737']
# Indices of 5 recommended artists: [np.int64(27692), np.int64(155970), np.int64(67842), np.int64(60156), np.int64(56325)]
# Recommended artist names: [np.bytes_(b'Allez Allez'), np.bytes_(b'Noiz Feat. Yana Kay'), np.bytes_(b"Daddy'S Favourite"), np.bytes_(b'Tom Waits'), np.bytes_(b'Bassnectar')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000844'
# Nearest K=5 neighbors' user-ids: [b'user_000862' b'user_000629' b'user_000114' b'user_000074'
#  b'user_000196']
# Indices of 5 recommended artists: [np.int64(140111), np.int64(52273), np.int64(38551), np.int64(136599), np.int64(90604)]
# Recommended artist names: [np.bytes_(b'Peter Grummich'), np.bytes_(b'Mayra Andrade'), np.bytes_(b'Project Bassline'), np.bytes_(b'Nancy Wallace'), np.bytes_(b'Ivan Smagghe')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000953'
# Nearest K=5 neighbors' user-ids: [b'user_000715' b'user_000741' b'user_000291' b'user_000705'
#  b'user_000637']
# Indices of 5 recommended artists: [np.int64(119134), np.int64(36710), np.int64(64348), np.int64(107957), np.int64(121909)]
# Recommended artist names: [np.bytes_(b'The Trews'), np.bytes_(b'Thelonious Monk'), np.bytes_(b'Alannah Myles'), np.bytes_(b'Leon Jackson'), np.bytes_(b'Pin')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000883'
# Nearest K=5 neighbors' user-ids: [b'user_000328' b'user_000516' b'user_000964' b'user_000153'
#  b'user_000606']
# Indices of 5 recommended artists: [np.int64(51669), np.int64(149962), np.int64(149799), np.int64(30633), np.int64(120018)]
# Recommended artist names: [np.bytes_(b'2Raumwohnung'), np.bytes_(b'Led Zeppelin Jam'), np.bytes_(b'Fr\xc3\xa9d\xc3\xa9ric Chopin'), np.bytes_(b'Indian Ropeman'), np.bytes_(b'Adam Faith')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000921'
# Nearest K=5 neighbors' user-ids: [b'user_000742' b'user_000418' b'user_000650' b'user_000610'
#  b'user_000233']
# Indices of 5 recommended artists: [np.int64(81801), np.int64(56658), np.int64(109251), np.int64(162704), np.int64(117096)]
# Recommended artist names: [np.bytes_(b'Circuit Boy Featuring Alan T'), np.bytes_(b'Nicki Richards'), np.bytes_(b'Dolly Parton'), np.bytes_(b'Toy'), np.bytes_(b'Ono')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000044'
# Nearest K=5 neighbors' user-ids: [b'user_000115' b'user_000435' b'user_000442' b'user_000527'
#  b'user_000473']
# Indices of 5 recommended artists: [np.int64(91977), np.int64(153074), np.int64(26905), np.int64(124185), np.int64(93220)]
# Recommended artist names: [np.bytes_(b'The Yardbirds'), np.bytes_(b'\xe8\x90\xa9\xe7\x94\xb0\xe5\x85\x89\xe9\x9b\x84'), np.bytes_(b'The Prodigy'), np.bytes_(b'Gallows'), np.bytes_(b'Marilyn Monroe')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000975'
# Nearest K=5 neighbors' user-ids: [b'user_000549' b'user_000789' b'user_000497' b'user_000224'
#  b'user_000257']
# Indices of 5 recommended artists: [np.int64(138317), np.int64(88599), np.int64(75937), np.int64(76755), np.int64(90520)]
# Recommended artist names: [np.bytes_(b'Alesha'), np.bytes_(b'Tiffany'), np.bytes_(b'The Love Me Nots'), np.bytes_(b'Mad Caddies'), np.bytes_(b'Mickey 3D')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000343'
# Nearest K=5 neighbors' user-ids: [b'user_000031' b'user_000345' b'user_000159' b'user_000393'
#  b'user_000858']
# Indices of 5 recommended artists: [np.int64(144981), np.int64(75835), np.int64(35010), np.int64(46538), np.int64(129370)]
# Recommended artist names: [np.bytes_(b'Rainer Von Vielen'), np.bytes_(b'Ordo Equilibrio'), np.bytes_(b'A Man Called Adam'), np.bytes_(b'Q-Burns Abstract Message'), np.bytes_(b'Kt Tunstall')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000049'
# Nearest K=5 neighbors' user-ids: [b'user_000126' b'user_000420' b'user_000387' b'user_000668'
#  b'user_000256']
# Indices of 5 recommended artists: [np.int64(48816), np.int64(77074), np.int64(133539), np.int64(4535), np.int64(21888)]
# Recommended artist names: [np.bytes_(b'M.O.P.'), np.bytes_(b'Nosseratu'), np.bytes_(b'Coldcut'), np.bytes_(b'Vhs Or Beta'), np.bytes_(b'Divide & Kreate')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000013'
# Nearest K=5 neighbors' user-ids: [b'user_000161' b'user_000932' b'user_000935' b'user_000927'
#  b'user_000026']
# Indices of 5 recommended artists: [np.int64(68595), np.int64(13022), np.int64(13213), np.int64(102011), np.int64(6617)]
# Recommended artist names: [np.bytes_(b'Frog Eyes'), np.bytes_(b'\xce\x86\xce\xbb\xce\xba\xce\xb7\xcf\x83\xcf\x84\xce\xb9\xcf\x82 \xce\xa0\xcf\x81\xcf\x89\xcf\x84\xce\xbf\xcf\x88\xce\xac\xce\xbb\xcf\x84\xce\xb7'), np.bytes_(b'Hatesphere'), np.bytes_(b'Califone'), np.bytes_(b'Orquesta Estable Del Teatro Colon - Jose Carli')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000139'
# Nearest K=5 neighbors' user-ids: [b'user_000020' b'user_000624' b'user_000683' b'user_000658'
#  b'user_000327']
# Indices of 5 recommended artists: [np.int64(7283), np.int64(138472), np.int64(146716), np.int64(89792), np.int64(166465)]
# Recommended artist names: [np.bytes_(b'Erase Errata'), np.bytes_(b'Trang F\xc3\xb8dsel'), np.bytes_(b'Finger Eleven'), np.bytes_(b'Lamb'), np.bytes_(b'Amy Lee')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000720'
# Nearest K=5 neighbors' user-ids: [b'user_000664' b'user_000405' b'user_000203' b'user_000147'
#  b'user_000483']
# Indices of 5 recommended artists: [np.int64(127809), np.int64(85139), np.int64(163547), np.int64(73902), np.int64(1291)]
# Recommended artist names: [np.bytes_(b'The Anix'), np.bytes_(b'J Rocc Presents'), np.bytes_(b'Fedde Le Grand'), np.bytes_(b'Oblong Boys'), np.bytes_(b'Vision And Loss')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000306'
# Nearest K=5 neighbors' user-ids: [b'user_000344' b'user_000776' b'user_000325' b'user_000395'
#  b'user_000740']
# Indices of 5 recommended artists: [np.int64(110133), np.int64(144823), np.int64(129067), np.int64(32303), np.int64(171159)]
# Recommended artist names: [np.bytes_(b'Pyramaze'), np.bytes_(b'Gravediggaz'), np.bytes_(b'Aretha Franklin'), np.bytes_(b'Saint Seiya'), np.bytes_(b'Dimmu Borgir')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000714'
# Nearest K=5 neighbors' user-ids: [b'user_000205' b'user_000520' b'user_000897' b'user_000610'
#  b'user_000626']
# Indices of 5 recommended artists: [np.int64(60156), np.int64(19013), np.int64(146091), np.int64(103434), np.int64(98099)]
# Recommended artist names: [np.bytes_(b'Tom Waits'), np.bytes_(b'Kaas'), np.bytes_(b'Tortoise'), np.bytes_(b'Lola Beltr\xc3\xa1n'), np.bytes_(b'Howie Day')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000546'
# Nearest K=5 neighbors' user-ids: [b'user_000560' b'user_000606' b'user_000956' b'user_000763'
#  b'user_000584']
# Indices of 5 recommended artists: [np.int64(61861), np.int64(115891), np.int64(133425), np.int64(166841), np.int64(125964)]
# Recommended artist names: [np.bytes_(b'Emerson, Lake & Palmer'), np.bytes_(b'Jaga Jazzist'), np.bytes_(b'Cell'), np.bytes_(b'Connie Price'), np.bytes_(b'Commix')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000695'
# Nearest K=5 neighbors' user-ids: [b'user_000584' b'user_000606' b'user_000822' b'user_000627'
#  b'user_000345']
# Indices of 5 recommended artists: [np.int64(107530), np.int64(49934), np.int64(37530), np.int64(118898), np.int64(171396)]
# Recommended artist names: [np.bytes_(b'Seamus Haji'), np.bytes_(b'Baron Zen'), np.bytes_(b'Enon'), np.bytes_(b'Ludes'), np.bytes_(b'Why?')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000297'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000031' b'user_000858' b'user_000393'
#  b'user_000164']
# Indices of 5 recommended artists: [np.int64(52628), np.int64(22123), np.int64(149799), np.int64(78495), np.int64(127399)]
# Recommended artist names: [np.bytes_(b'Giovanni Battista Pergolesi'), np.bytes_(b'Happy Apple'), np.bytes_(b'Fr\xc3\xa9d\xc3\xa9ric Chopin'), np.bytes_(b'Utopia Carwash'), np.bytes_(b'Hi-Tek')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000123'
# Nearest K=5 neighbors' user-ids: [b'user_000996' b'user_000998' b'user_000018' b'user_000779'
#  b'user_000486']
# Indices of 5 recommended artists: [np.int64(58216), np.int64(45697), np.int64(144947), np.int64(90028), np.int64(171020)]
# Recommended artist names: [np.bytes_(b'Peter Bjorn And John'), np.bytes_(b'The Fallout Trust'), np.bytes_(b'Souls Of Mischief'), np.bytes_(b'Nicole Kidman'), np.bytes_(b'Deal')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000577'
# Nearest K=5 neighbors' user-ids: [b'user_000059' b'user_000031' b'user_000345' b'user_000779'
#  b'user_000089']
# Indices of 5 recommended artists: [np.int64(138783), np.int64(81368), np.int64(23824), np.int64(146603), np.int64(59948)]
# Recommended artist names: [np.bytes_(b'Bryan Ferry'), np.bytes_(b'Shiva In Exile'), np.bytes_(b'Marques Houston'), np.bytes_(b'The Fabulous Thunderbirds'), np.bytes_(b'Amy Marcy Cheney Beach')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000413'
# Nearest K=5 neighbors' user-ids: [b'user_000225' b'user_000535' b'user_000347' b'user_000134'
#  b'user_000198']
# Indices of 5 recommended artists: [np.int64(151473), np.int64(57053), np.int64(113904), np.int64(37973), np.int64(84431)]
# Recommended artist names: [np.bytes_(b'Clarence Carter'), np.bytes_(b'Norrda'), np.bytes_(b'Myl\xc3\xa8ne Farmer'), np.bytes_(b'Lemon Jelly'), np.bytes_(b'Jackal & Hyde')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000252'
# Nearest K=5 neighbors' user-ids: [b'user_000225' b'user_000535' b'user_000347' b'user_000413'
#  b'user_000134']
# Indices of 5 recommended artists: [np.int64(89671), np.int64(48921), np.int64(102371), np.int64(49432), np.int64(162369)]
# Recommended artist names: [np.bytes_(b'Pete Yorn'), np.bytes_(b'Jesper Dahlb\xc3\xa4ck'), np.bytes_(b'Bilal Salaam'), np.bytes_(b'Miss V\xc3\xa9ronika'), np.bytes_(b'Alex Reece')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000814'
# Nearest K=5 neighbors' user-ids: [b'user_000039' b'user_000976' b'user_000285' b'user_000890'
#  b'user_000878']
# Indices of 5 recommended artists: [np.int64(116502), np.int64(59094), np.int64(157580), np.int64(109122), np.int64(123562)]
# Recommended artist names: [np.bytes_(b'Aya'), np.bytes_(b'Dj Sanious'), np.bytes_(b'Venus Hum'), np.bytes_(b'M.O.V.E'), np.bytes_(b'Fleetwood Mac')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000236'
# Nearest K=5 neighbors' user-ids: [b'user_000781' b'user_000765' b'user_000437' b'user_000990'
#  b'user_000959']
# Indices of 5 recommended artists: [np.int64(121066), np.int64(21398), np.int64(43859), np.int64(60238), np.int64(82276)]
# Recommended artist names: [np.bytes_(b'Harry Connick, Jr.'), np.bytes_(b'Yves Deruyter'), np.bytes_(b'Abstrackt Keal Agram'), np.bytes_(b'Courtney Love'), np.bytes_(b'P Diddy Feat. Elephant Man & Nicole Scherzinger')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000267'
# Nearest K=5 neighbors' user-ids: [b'user_000828' b'user_000463' b'user_000116' b'user_000770'
#  b'user_000070']
# Indices of 5 recommended artists: [np.int64(155195), np.int64(39639), np.int64(68714), np.int64(136460), np.int64(149672)]
# Recommended artist names: [np.bytes_(b'Lesbians On Ecstasy'), np.bytes_(b'John Mayall & The Bluesbreakers'), np.bytes_(b'Knockout'), np.bytes_(b'Clawfinger'), np.bytes_(b'Franz Liszt')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000985'
# Nearest K=5 neighbors' user-ids: [b'user_000551' b'user_000902' b'user_000849' b'user_000298'
#  b'user_000039']
# Indices of 5 recommended artists: [np.int64(85841), np.int64(82659), np.int64(66983), np.int64(60946), np.int64(1840)]
# Recommended artist names: [np.bytes_(b'James Dean Bradfield'), np.bytes_(b'Corona'), np.bytes_(b'Escape The Fate'), np.bytes_(b'Stray Cats'), np.bytes_(b'Barry White')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000181'
# Nearest K=5 neighbors' user-ids: [b'user_000261' b'user_000754' b'user_000277' b'user_000393'
#  b'user_000909']
# Indices of 5 recommended artists: [np.int64(140380), np.int64(26998), np.int64(103750), np.int64(58815), np.int64(69065)]
# Recommended artist names: [np.bytes_(b'Landau'), np.bytes_(b'Luke Vibert'), np.bytes_(b'The Human League'), np.bytes_(b'Lia Ices'), np.bytes_(b'Speed Crazy')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000736'
# Nearest K=5 neighbors' user-ids: [b'user_000559' b'user_000610' b'user_000985' b'user_000128'
#  b'user_000027']
# Indices of 5 recommended artists: [np.int64(67986), np.int64(132016), np.int64(4232), np.int64(57364), np.int64(85247)]
# Recommended artist names: [np.bytes_(b'Journey'), np.bytes_(b'Sara Bareilles'), np.bytes_(b'Nick Drake'), np.bytes_(b'Elvis Presley'), np.bytes_(b'Son Volt')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000150'
# Nearest K=5 neighbors' user-ids: [b'user_000625' b'user_000348' b'user_000583' b'user_000861'
#  b'user_000095']
# Indices of 5 recommended artists: [np.int64(108412), np.int64(42899), np.int64(611), np.int64(37949), np.int64(62274)]
# Recommended artist names: [np.bytes_(b'Calexico'), np.bytes_(b'Stu Phillips/Lorne Greene'), np.bytes_(b'Fannypack'), np.bytes_(b'Plus-Tech Squeezebox Featuring Spongebob'), np.bytes_(b'Najoua Belyzel')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000271'
# Nearest K=5 neighbors' user-ids: [b'user_000573' b'user_000656' b'user_000048' b'user_000614'
#  b'user_000255']
# Indices of 5 recommended artists: [np.int64(136522), np.int64(42110), np.int64(9816), np.int64(63148), np.int64(29157)]
# Recommended artist names: [np.bytes_(b'Emmy Rossum & Patrick Wilson'), np.bytes_(b'Eddie Cochran'), np.bytes_(b'Woody Herman'), np.bytes_(b'Eddie Willis'), np.bytes_(b"D'Abruzzo")]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000468'
# Nearest K=5 neighbors' user-ids: [b'user_000816' b'user_000150' b'user_000957' b'user_000625'
#  b'user_000442']
# Indices of 5 recommended artists: [np.int64(112643), np.int64(93492), np.int64(11285), np.int64(90905), np.int64(149737)]
# Recommended artist names: [np.bytes_(b'Malevolent Creation'), np.bytes_(b'Paul Mccartney'), np.bytes_(b'Florian Haidt'), np.bytes_(b'London Mc'), np.bytes_(b'Forever Slave')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000172'
# Nearest K=5 neighbors' user-ids: [b'user_000938' b'user_000996' b'user_000493' b'user_000351'
#  b'user_000653']
# Indices of 5 recommended artists: [np.int64(15398), np.int64(120635), np.int64(57335), np.int64(150171), np.int64(10697)]
# Recommended artist names: [np.bytes_(b'Danielson'), np.bytes_(b'Armor For Sleep'), np.bytes_(b'Kenny Parchman'), np.bytes_(b'Bright Eyes'), np.bytes_(b'Gym Class Heroes')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000609'
# Nearest K=5 neighbors' user-ids: [b'user_000066' b'user_000763' b'user_000584' b'user_000560'
#  b'user_000807']
# Indices of 5 recommended artists: [np.int64(136096), np.int64(95115), np.int64(168519), np.int64(157196), np.int64(150238)]
# Recommended artist names: [np.bytes_(b'World Of Twist'), np.bytes_(b'Echo & The Bunnymen'), np.bytes_(b'The Only Ones'), np.bytes_(b'Kate Bush'), np.bytes_(b'Shapeshifters')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000836'
# Nearest K=5 neighbors' user-ids: [b'user_000456' b'user_000881' b'user_000938' b'user_000172'
#  b'user_000545']
# Indices of 5 recommended artists: [np.int64(103600), np.int64(77992), np.int64(63309), np.int64(111636), np.int64(16356)]
# Recommended artist names: [np.bytes_(b'Medeski Martin And Wood'), np.bytes_(b'Ace Hood'), np.bytes_(b'Phil Moore Iii'), np.bytes_(b'Stiff Little Fingers'), np.bytes_(b'Hardfloor')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000900'
# Nearest K=5 neighbors' user-ids: [b'user_000251' b'user_000319' b'user_000715' b'user_000779'
#  b'user_000706']
# Indices of 5 recommended artists: [np.int64(112922), np.int64(99297), np.int64(10836), np.int64(169806), np.int64(141272)]
# Recommended artist names: [np.bytes_(b'Sonebridge'), np.bytes_(b'Dallas Superstars'), np.bytes_(b'Www.Mzhiphop.Com'), np.bytes_(b'Violins'), np.bytes_(b'Do It Again')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000831'
# Nearest K=5 neighbors' user-ids: [b'user_000912' b'user_000322' b'user_000927' b'user_000041'
#  b'user_000809']
# Indices of 5 recommended artists: [np.int64(53835), np.int64(42722), np.int64(109119), np.int64(106670), np.int64(150539)]
# Recommended artist names: [np.bytes_(b'Mogwai'), np.bytes_(b'Keane'), np.bytes_(b'Ajattara'), np.bytes_(b'Dream Factory & Jessica Palmer'), np.bytes_(b'Alex Megane')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000042'
# Nearest K=5 neighbors' user-ids: [b'user_000117' b'user_000806' b'user_000103' b'user_000383'
#  b'user_000256']
# Indices of 5 recommended artists: [np.int64(105164), np.int64(7744), np.int64(22756), np.int64(31602), np.int64(43852)]
# Recommended artist names: [np.bytes_(b'Future Tech'), np.bytes_(b'\xe9\x95\xb7\xe6\xb2\xbc\xe8\x8b\xb1\xe6\xa8\xb9'), np.bytes_(b'Tgm & Cytech'), np.bytes_(b'Accelera Deck'), np.bytes_(b'Big L')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000612'
# Nearest K=5 neighbors' user-ids: [b'user_000588' b'user_000453' b'user_000052' b'user_000038'
#  b'user_000395']
# Indices of 5 recommended artists: [np.int64(70982), np.int64(95905), np.int64(41773), np.int64(147530), np.int64(120968)]
# Recommended artist names: [np.bytes_(b'Chastain'), np.bytes_(b'Jon Fitz'), np.bytes_(b'Autumn'), np.bytes_(b'Daughters'), np.bytes_(b'Jesu')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000166'
# Nearest K=5 neighbors' user-ids: [b'user_000440' b'user_000465' b'user_000019' b'user_000412'
#  b'user_000596']
# Indices of 5 recommended artists: [np.int64(40517), np.int64(81963), np.int64(167885), np.int64(156896), np.int64(117238)]
# Recommended artist names: [np.bytes_(b'The Mar-Keys'), np.bytes_(b'Lykke Li'), np.bytes_(b"I'M From Barcelona"), np.bytes_(b'Museum'), np.bytes_(b'Bill Evans Trio')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000667'
# Nearest K=5 neighbors' user-ids: [b'user_000886' b'user_000643' b'user_000637' b'user_000070'
#  b'user_000016']
# Indices of 5 recommended artists: [np.int64(128564), np.int64(111457), np.int64(171596), np.int64(49903), np.int64(165543)]
# Recommended artist names: [np.bytes_(b'Little Barrie'), np.bytes_(b'Space'), np.bytes_(b'Soledad Brothers'), np.bytes_(b'Kimberley Locke'), np.bytes_(b'Serj Tankian')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000875'
# Nearest K=5 neighbors' user-ids: [b'user_000993' b'user_000202' b'user_000467' b'user_000620'
#  b'user_000844']
# Indices of 5 recommended artists: [np.int64(135549), np.int64(66377), np.int64(54139), np.int64(11134), np.int64(60478)]
# Recommended artist names: [np.bytes_(b'J\xc3\xbcrgen Paape'), np.bytes_(b'Bert Jansch'), np.bytes_(b'Jackson C. Frank'), np.bytes_(b'Vive La F\xc3\xaate'), np.bytes_(b'Crimetime Orchestra')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000941'
# Nearest K=5 neighbors' user-ids: [b'user_000897' b'user_000791' b'user_000293' b'user_000603'
#  b'user_000626']
# Indices of 5 recommended artists: [np.int64(101797), np.int64(120419), np.int64(127554), np.int64(166702), np.int64(151734)]
# Recommended artist names: [np.bytes_(b'Jamie Scott & The Town'), np.bytes_(b'Chaka Khan'), np.bytes_(b'The January Flake'), np.bytes_(b'Tomaso Giovanni Albinoni'), np.bytes_(b'Jakobinarina')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000093'
# Nearest K=5 neighbors' user-ids: [b'user_000327' b'user_000658' b'user_000891' b'user_000018'
#  b'user_000996']
# Indices of 5 recommended artists: [np.int64(144453), np.int64(4275), np.int64(154287), np.int64(155566), np.int64(62092)]
# Recommended artist names: [np.bytes_(b'50 Cent'), np.bytes_(b'Evanescence'), np.bytes_(b'The Prodigy Vs Eminem'), np.bytes_(b'Winterpills'), np.bytes_(b'The Hush Sound')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000304'
# Nearest K=5 neighbors' user-ids: [b'user_000170' b'user_000277' b'user_000261' b'user_000826'
#  b'user_000159']
# Indices of 5 recommended artists: [np.int64(155727), np.int64(130162), np.int64(165217), np.int64(53632), np.int64(59087)]
# Recommended artist names: [np.bytes_(b'Arthur Argent'), np.bytes_(b'Children Of Bodom'), np.bytes_(b'Curtis Mayfield'), np.bytes_(b'Monty'), np.bytes_(b'David Gilmour')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000635'
# Nearest K=5 neighbors' user-ids: [b'user_000702' b'user_000017' b'user_000408' b'user_000011'
#  b'user_000705']
# Indices of 5 recommended artists: [np.int64(62491), np.int64(142080), np.int64(23616), np.int64(114052), np.int64(12211)]
# Recommended artist names: [np.bytes_(b'David Daniels'), np.bytes_(b'Bill Charlap'), np.bytes_(b'New Order'), np.bytes_(b'Vox Populi!'), np.bytes_(b'Cedar Walton')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000160'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000842' b'user_000059' b'user_000513'
#  b'user_000031']
# Indices of 5 recommended artists: [np.int64(23651), np.int64(160659), np.int64(165452), np.int64(135536), np.int64(38693)]
# Recommended artist names: [np.bytes_(b'Jon Anderson'), np.bytes_(b'David Guetta'), np.bytes_(b'Emmy The Great'), np.bytes_(b'Chaos'), np.bytes_(b'Fabulous Poodles')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000938'
# Nearest K=5 neighbors' user-ids: [b'user_000829' b'user_000653' b'user_000493' b'user_000242'
#  b'user_000261']
# Indices of 5 recommended artists: [np.int64(90735), np.int64(28729), np.int64(150039), np.int64(118582), np.int64(42557)]
# Recommended artist names: [np.bytes_(b'Miss Kittin'), np.bytes_(b'Hunter X Hunter'), np.bytes_(b'Ex Pistols'), np.bytes_(b'Odd Nordstoga'), np.bytes_(b'Brian Reitzell & Roger J. Manning Jr')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000794'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000467' b'user_000584' b'user_000858'
#  b'user_000620']
# Indices of 5 recommended artists: [np.int64(2292), np.int64(94524), np.int64(20693), np.int64(9824), np.int64(121880)]
# Recommended artist names: [np.bytes_(b'Dinosaur Jr.'), np.bytes_(b'Sean Lennon'), np.bytes_(b'The Game'), np.bytes_(b'Arcoiris'), np.bytes_(b'Fern Jones')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000277'
# Nearest K=5 neighbors' user-ids: [b'user_000261' b'user_000170' b'user_000304' b'user_000060'
#  b'user_000159']
# Indices of 5 recommended artists: [np.int64(8287), np.int64(121748), np.int64(170084), np.int64(59107), np.int64(132264)]
# Recommended artist names: [np.bytes_(b'Geneva'), np.bytes_(b'Inspiral Carpets'), np.bytes_(b'Deep Purple'), np.bytes_(b'Towa Tei'), np.bytes_(b'Uncle Tupelo')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000872'
# Nearest K=5 neighbors' user-ids: [b'user_000285' b'user_000434' b'user_000837' b'user_000575'
#  b'user_000501']
# Indices of 5 recommended artists: [np.int64(117497), np.int64(170168), np.int64(69770), np.int64(35044), np.int64(115890)]
# Recommended artist names: [np.bytes_(b'John Travolta & Olivia Newton-John'), np.bytes_(b'Yonder Mountain String Band'), np.bytes_(b'Missy Elliott'), np.bytes_(b'The Cover'), np.bytes_(b'Mr. Big')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000317'
# Nearest K=5 neighbors' user-ids: [b'user_000752' b'user_000444' b'user_000712' b'user_000134'
#  b'user_000225']
# Indices of 5 recommended artists: [np.int64(43104), np.int64(100554), np.int64(137526), np.int64(35848), np.int64(144542)]
# Recommended artist names: [np.bytes_(b'Ultravox'), np.bytes_(b'Sun Electric'), np.bytes_(b'Los Bunkers'), np.bytes_(b'Atrakcyjny Kazimierz'), np.bytes_(b'Fad Gadget')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000585'
# Nearest K=5 neighbors' user-ids: [b'user_000001' b'user_000174' b'user_000368' b'user_000963'
#  b'user_000844']
# Indices of 5 recommended artists: [np.int64(64966), np.int64(80083), np.int64(95031), np.int64(52661), np.int64(99571)]
# Recommended artist names: [np.bytes_(b'Benji Boko'), np.bytes_(b'Puffy'), np.bytes_(b'Starz Beatz'), np.bytes_(b'Britney Spears'), np.bytes_(b'Aaron Lawry')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000415'
# Nearest K=5 neighbors' user-ids: [b'user_000031' b'user_000345' b'user_000703' b'user_000633'
#  b'user_000398']
# Indices of 5 recommended artists: [np.int64(57256), np.int64(171771), np.int64(13316), np.int64(171784), np.int64(46708)]
# Recommended artist names: [np.bytes_(b'Icehouse'), np.bytes_(b'The Village Green'), np.bytes_(b'Chris T-T'), np.bytes_(b'Ricardo Rae'), np.bytes_(b'Larry Darnell')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000825'
# Nearest K=5 neighbors' user-ids: [b'user_000829' b'user_000016' b'user_000261' b'user_000277'
#  b'user_000159']
# Indices of 5 recommended artists: [np.int64(152658), np.int64(173537), np.int64(86816), np.int64(15398), np.int64(22534)]
# Recommended artist names: [np.bytes_(b'Little Boots'), np.bytes_(b'Dubstar'), np.bytes_(b'The Trend'), np.bytes_(b'Danielson'), np.bytes_(b'Eels')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000764'
# Nearest K=5 neighbors' user-ids: [b'user_000960' b'user_000341' b'user_000893' b'user_000603'
#  b'user_000288']
# Indices of 5 recommended artists: [np.int64(36039), np.int64(59555), np.int64(41193), np.int64(57364), np.int64(43932)]
# Recommended artist names: [np.bytes_(b'Lyn Leon'), np.bytes_(b'Zebrahead'), np.bytes_(b'4 Wings'), np.bytes_(b'Elvis Presley'), np.bytes_(b'Band Aid Ii')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000898'
# Nearest K=5 neighbors' user-ids: [b'user_000715' b'user_000766' b'user_000291' b'user_000198'
#  b'user_000779']
# Indices of 5 recommended artists: [np.int64(101074), np.int64(98159), np.int64(106150), np.int64(88615), np.int64(158824)]
# Recommended artist names: [np.bytes_(b'Bernard Herrmann'), np.bytes_(b'Sum 41'), np.bytes_(b'Kc And The Sunshine Band'), np.bytes_(b'Everclear'), np.bytes_(b'Accept')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000929'
# Nearest K=5 neighbors' user-ids: [b'user_000091' b'user_000207' b'user_000467' b'user_000074'
#  b'user_000807']
# Indices of 5 recommended artists: [np.int64(35959), np.int64(153033), np.int64(16114), np.int64(32337), np.int64(115032)]
# Recommended artist names: [np.bytes_(b'Fragra Ce'), np.bytes_(b'Jackie Mclean'), np.bytes_(b'Bob Sinclar'), np.bytes_(b'Border Crossing'), np.bytes_(b'Mats Wester')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000111'
# Nearest K=5 neighbors' user-ids: [b'user_000378' b'user_000047' b'user_000648' b'user_000973'
#  b'user_000868']
# Indices of 5 recommended artists: [np.int64(58769), np.int64(124846), np.int64(67010), np.int64(75385), np.int64(101208)]
# Recommended artist names: [np.bytes_(b'Peggy Lee'), np.bytes_(b'Ludwig Van Beethoven'), np.bytes_(b'David Frizzell & Shelly West'), np.bytes_(b'Derek Donald'), np.bytes_(b'10,000 Hurts')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000768'
# Nearest K=5 neighbors' user-ids: [b'user_000957' b'user_000760' b'user_000487' b'user_000088'
#  b'user_000898']
# Indices of 5 recommended artists: [np.int64(98204), np.int64(18279), np.int64(72832), np.int64(173225), np.int64(130673)]
# Recommended artist names: [np.bytes_(b'D*Note'), np.bytes_(b'Shannon'), np.bytes_(b'The Pretenders'), np.bytes_(b'Die Toten Hosen'), np.bytes_(b'Ap3S')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000282'
# Nearest K=5 neighbors' user-ids: [b'user_000161' b'user_000669' b'user_000705' b'user_000741'
#  b'user_000291']
# Indices of 5 recommended artists: [np.int64(87423), np.int64(88507), np.int64(70657), np.int64(158500), np.int64(63527)]
# Recommended artist names: [np.bytes_(b'Wire'), np.bytes_(b'Radiohead & El Lele'), np.bytes_(b'Godspeed You! Black Emperor'), np.bytes_(b'Musica Antiqua K\xc3\xb6ln'), np.bytes_(b'Richard Ashcroft')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000864'
# Nearest K=5 neighbors' user-ids: [b'user_000008' b'user_000419' b'user_000737' b'user_000187'
#  b'user_000321']
# Indices of 5 recommended artists: [np.int64(28440), np.int64(2345), np.int64(163769), np.int64(85125), np.int64(99542)]
# Recommended artist names: [np.bytes_(b'Benny Benassi'), np.bytes_(b'Dramatikz'), np.bytes_(b'Gheorghe Zamfir'), np.bytes_(b'Ayo'), np.bytes_(b'Kelis Featuring Cee-Lo')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000399'
# Nearest K=5 neighbors' user-ids: [b'user_000195' b'user_000742' b'user_000650' b'user_000395'
#  b'user_000109']
# Indices of 5 recommended artists: [np.int64(7406), np.int64(80228), np.int64(25074), np.int64(170104), np.int64(58251)]
# Recommended artist names: [np.bytes_(b'Eagles Of Death Metal'), np.bytes_(b'Orion Too'), np.bytes_(b'Young Dro'), np.bytes_(b'Billie Piper'), np.bytes_(b'Oceanlab')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000765'
# Nearest K=5 neighbors' user-ids: [b'user_000959' b'user_000233' b'user_000479' b'user_000579'
#  b'user_000781']
# Indices of 5 recommended artists: [np.int64(15827), np.int64(161900), np.int64(48605), np.int64(155132), np.int64(98625)]
# Recommended artist names: [np.bytes_(b'Kermit The Frog'), np.bytes_(b'Soulcatcher Feat. Amanda Wilson'), np.bytes_(b'The Veronicas Vs. Pink'), np.bytes_(b'Evan'), np.bytes_(b'Trinity Featuring Revi')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000023'
# Nearest K=5 neighbors' user-ids: [b'user_000634' b'user_000515' b'user_000927' b'user_000503'
#  b'user_000866']
# Indices of 5 recommended artists: [np.int64(158195), np.int64(106369), np.int64(8297), np.int64(66397), np.int64(62443)]
# Recommended artist names: [np.bytes_(b'Divinyls'), np.bytes_(b'Orli & Martie'), np.bytes_(b'Cybotron'), np.bytes_(b'Marti Webb'), np.bytes_(b'Cotti & Cluekid')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000618'
# Nearest K=5 neighbors' user-ids: [b'user_000296' b'user_000409' b'user_000010' b'user_000208'
#  b'user_000592']
# Indices of 5 recommended artists: [np.int64(112223), np.int64(78968), np.int64(54495), np.int64(71263), np.int64(15928)]
# Recommended artist names: [np.bytes_(b'Afcoskynet'), np.bytes_(b'Sean Paul'), np.bytes_(b'T-Pain'), np.bytes_(b'Guy Gerber'), np.bytes_(b'Split Second')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000920'
# Nearest K=5 neighbors' user-ids: [b'user_000998' b'user_000779' b'user_000116' b'user_000766'
#  b'user_000658']
# Indices of 5 recommended artists: [np.int64(4042), np.int64(56461), np.int64(48358), np.int64(167519), np.int64(115118)]
# ...
#  b'user_000650']
# Indices of 5 recommended artists: [np.int64(69013), np.int64(168563), np.int64(87780), np.int64(40975), np.int64(40206)]
# Recommended artist names: [np.bytes_(b'The Flexican'), np.bytes_(b'Filter'), np.bytes_(b'David Morales'), np.bytes_(b'Grace Jones'), np.bytes_(b'St. Lunatics Feat Nelly And Cedric')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000350'
# Nearest K=5 neighbors' user-ids: [b'user_000658' b'user_000624' b'user_000116' b'user_000020'
#  b'user_000600']
# Indices of 5 recommended artists: [np.int64(22530), np.int64(120455), np.int64(104718), np.int64(105956), np.int64(97171)]
# Recommended artist names: [np.bytes_(b'Runrig'), np.bytes_(b'Lillestr\xc3\xb8m'), np.bytes_(b'The Nova Saints'), np.bytes_(b'The Submarines'), np.bytes_(b'Dust')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000674'
# Nearest K=5 neighbors' user-ids: [b'user_000195' b'user_000742' b'user_000251' b'user_000431'
#  b'user_000650']
# Indices of 5 recommended artists: [np.int64(61881), np.int64(136063), np.int64(119670), np.int64(124540), np.int64(50016)]
# Recommended artist names: [np.bytes_(b'Basic Element'), np.bytes_(b'Westbam'), np.bytes_(b'Sylvia Tosun'), np.bytes_(b'\xe8\x8f\xaf\xe6\x97\x8f'), np.bytes_(b'Self')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000819'
# Nearest K=5 neighbors' user-ids: [b'user_000143' b'user_000513' b'user_000384' b'user_000016'
#  b'user_000215']
# Indices of 5 recommended artists: [np.int64(82659), np.int64(116057), np.int64(44562), np.int64(41162), np.int64(122296)]
# Recommended artist names: [np.bytes_(b'Corona'), np.bytes_(b'Edwin Birdsong'), np.bytes_(b'Yourcodenameis:Milo'), np.bytes_(b"Cassettes Won'T Listen"), np.bytes_(b'Little Thoughts')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000811'
# Nearest K=5 neighbors' user-ids: [b'user_000664' b'user_000187' b'user_000602' b'user_000817'
#  b'user_000479']
# Indices of 5 recommended artists: [np.int64(133367), np.int64(100304), np.int64(114371), np.int64(96120), np.int64(166408)]
# Recommended artist names: [np.bytes_(b'Michael Woods & Judge Jules'), np.bytes_(b'Dirty Electronite'), np.bytes_(b'Whitney Houston & Deborah Cox'), np.bytes_(b'Yelle'), np.bytes_(b'M\xc5\x93nia')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000807'
# Nearest K=5 neighbors' user-ids: [b'user_000584' b'user_000763' b'user_000606' b'user_000560'
#  b'user_000873']
# Indices of 5 recommended artists: [np.int64(42226), np.int64(33048), np.int64(56286), np.int64(28554), np.int64(44483)]
# Recommended artist names: [np.bytes_(b'Apostle Of Hustle'), np.bytes_(b'Dj Kentaro'), np.bytes_(b'Eric Prydz Vs. Floyd'), np.bytes_(b'The Cinematics'), np.bytes_(b'Epmd')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000905'
# Nearest K=5 neighbors' user-ids: [b'user_000859' b'user_000532' b'user_000705' b'user_000083'
#  b'user_000829']
# Indices of 5 recommended artists: [np.int64(63222), np.int64(82238), np.int64(69849), np.int64(127751), np.int64(62985)]
# Recommended artist names: [np.bytes_(b'Joyce Poynter'), np.bytes_(b'Lito Mckcd'), np.bytes_(b'Pulp'), np.bytes_(b'Lifehouse'), np.bytes_(b"Bonnie 'Prince' Billy")]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000665'
# Nearest K=5 neighbors' user-ids: [b'user_000319' b'user_000209' b'user_000089' b'user_000116'
#  b'user_000658']
# Indices of 5 recommended artists: [np.int64(28870), np.int64(3903), np.int64(145580), np.int64(44307), np.int64(70777)]
# Recommended artist names: [np.bytes_(b'Wolfsbane'), np.bytes_(b'Saint Etienne'), np.bytes_(b'The Handsome Family'), np.bytes_(b"Mark 'Oh"), np.bytes_(b'School Of Seven Bells')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000603'
# Nearest K=5 neighbors' user-ids: [b'user_000301' b'user_000803' b'user_000065' b'user_000093'
#  b'user_000575']
# Indices of 5 recommended artists: [np.int64(91725), np.int64(9318), np.int64(42467), np.int64(58449), np.int64(142504)]
# Recommended artist names: [np.bytes_(b'Bob Marley & The Wailers'), np.bytes_(b'The Paper Chase'), np.bytes_(b'Sonic Youth'), np.bytes_(b'Royce Da 5\'9"'), np.bytes_(b'Mutya Buena')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000712'
# Nearest K=5 neighbors' user-ids: [b'user_000605' b'user_000134' b'user_000225' b'user_000535'
#  b'user_000752']
# Indices of 5 recommended artists: [np.int64(144987), np.int64(4646), np.int64(138783), np.int64(43191), np.int64(61932)]
# Recommended artist names: [np.bytes_(b'Craig Armstrong'), np.bytes_(b'Synchronoize'), np.bytes_(b'Bryan Ferry'), np.bytes_(b'Sister Machine Gun'), np.bytes_(b'Ahmet Abi')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000735'
# Nearest K=5 neighbors' user-ids: [b'user_000159' b'user_000151' b'user_000653' b'user_000189'
#  b'user_000870']
# Indices of 5 recommended artists: [np.int64(73577), np.int64(81973), np.int64(70657), np.int64(47558), np.int64(81086)]
# Recommended artist names: [np.bytes_(b'Alias'), np.bytes_(b'Slowdive'), np.bytes_(b'Godspeed You! Black Emperor'), np.bytes_(b'Campbell, Cornell (W. The Brentford Rockers)'), np.bytes_(b'Suzanne Vega')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000994'
# Nearest K=5 neighbors' user-ids: [b'user_000108' b'user_000986' b'user_000565' b'user_000393'
#  b'user_000650']
# Indices of 5 recommended artists: [np.int64(135204), np.int64(47691), np.int64(10657), np.int64(136525), np.int64(99423)]
# Recommended artist names: [np.bytes_(b'John Zorn & Yamatsuke Eye'), np.bytes_(b'Love Inc.'), np.bytes_(b'George Harrison'), np.bytes_(b'B.J. Thomas'), np.bytes_(b'The Flying Burrito Brothers')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000691'
# Nearest K=5 neighbors' user-ids: [b'user_000910' b'user_000345' b'user_000031' b'user_000681'
#  b'user_000249']
# Indices of 5 recommended artists: [np.int64(96473), np.int64(163609), np.int64(58848), np.int64(23120), np.int64(111765)]
# Recommended artist names: [np.bytes_(b'Microstoria'), np.bytes_(b'Master Shake, Meatwad And Carl Brutananadilewski'), np.bytes_(b'Creosote'), np.bytes_(b'Saing Saing Maw'), np.bytes_(b'Boys From Nowhere')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000136'
# Nearest K=5 neighbors' user-ids: [b'user_000995' b'user_000034' b'user_000089' b'user_000910'
#  b'user_000345']
# Indices of 5 recommended artists: [np.int64(97864), np.int64(65143), np.int64(85800), np.int64(142800), np.int64(162956)]
# Recommended artist names: [np.bytes_(b'Global Goon'), np.bytes_(b'Super 400'), np.bytes_(b'The Supremes'), np.bytes_(b'Skates'), np.bytes_(b'Pure Reason Revolution')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000892'
# Nearest K=5 neighbors' user-ids: [b'user_000440' b'user_000331' b'user_000465' b'user_000963'
#  b'user_000412']
# Indices of 5 recommended artists: [np.int64(33379), np.int64(24163), np.int64(173568), np.int64(125622), np.int64(68668)]
# Recommended artist names: [np.bytes_(b'\xc3\x89ric Serra'), np.bytes_(b'Joshua Bell'), np.bytes_(b'Maede Lux Lewis'), np.bytes_(b'Faze Action'), np.bytes_(b'The Pharcyde')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000627'
# Nearest K=5 neighbors' user-ids: [b'user_000560' b'user_000606' b'user_000584' b'user_000873'
#  b'user_000956']
# Indices of 5 recommended artists: [np.int64(168563), np.int64(170213), np.int64(35249), np.int64(134578), np.int64(94315)]
# Recommended artist names: [np.bytes_(b'Filter'), np.bytes_(b'The Dandy Warhols'), np.bytes_(b'Carmina Burana'), np.bytes_(b'Dedou'), np.bytes_(b'Krysten Berg')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000839'
# Nearest K=5 neighbors' user-ids: [b'user_000103' b'user_000161' b'user_000616' b'user_000026'
#  b'user_000188']
# Indices of 5 recommended artists: [np.int64(60262), np.int64(137217), np.int64(110207), np.int64(55813), np.int64(68654)]
# Recommended artist names: [np.bytes_(b'The Who'), np.bytes_(b'U\xc4\x9fur Akdora'), np.bytes_(b'Mirkelam'), np.bytes_(b'David Essex'), np.bytes_(b'Bass Extremes')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000038'
# Nearest K=5 neighbors' user-ids: [b'user_000588' b'user_000612' b'user_000015' b'user_000780'
#  b'user_000056']
# Indices of 5 recommended artists: [np.int64(105833), np.int64(22941), np.int64(75025), np.int64(119847), np.int64(36230)]
# Recommended artist names: [np.bytes_(b'\xc3\x9cberzone'), np.bytes_(b'Pale'), np.bytes_(b'Dyed Emotions'), np.bytes_(b'The Music'), np.bytes_(b'Aleksi Eeben Of Carillon International')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000828'
# Nearest K=5 neighbors' user-ids: [b'user_000770' b'user_000463' b'user_000598' b'user_000070'
#  b'user_000377']
# Indices of 5 recommended artists: [np.int64(8762), np.int64(68563), np.int64(86498), np.int64(155333), np.int64(155848)]
# Recommended artist names: [np.bytes_(b'Foghat'), np.bytes_(b'Crosby, Stills, Nash & Young'), np.bytes_(b'Maroon'), np.bytes_(b'Carlos Pai\xc3\xa3o'), np.bytes_(b'Tristeza')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000286'
# Nearest K=5 neighbors' user-ids: [b'user_000564' b'user_000896' b'user_000157' b'user_000164'
#  b'user_000345']
# Indices of 5 recommended artists: [np.int64(31671), np.int64(92117), np.int64(58889), np.int64(119024), np.int64(74746)]
# Recommended artist names: [np.bytes_(b'Chubby Checker'), np.bytes_(b'The Living End'), np.bytes_(b'Tender Forever'), np.bytes_(b'Dave Clarke'), np.bytes_(b'Jan Wayne')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000401'
# Nearest K=5 neighbors' user-ids: [b'user_000995' b'user_000024' b'user_000345' b'user_000397'
#  b'user_000031']
# Indices of 5 recommended artists: [np.int64(77852), np.int64(10958), np.int64(124363), np.int64(74205), np.int64(18118)]
# Recommended artist names: [np.bytes_(b'Atomic Opera'), np.bytes_(b'St. Vincent'), np.bytes_(b'Thunder In The Valley'), np.bytes_(b'Zolt\xc3\xa1n Kod\xc3\xa1ly'), np.bytes_(b'Vanilla Ice')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000878'
# Nearest K=5 neighbors' user-ids: [b'user_000285' b'user_000575' b'user_000621' b'user_000109'
#  b'user_000145']
# Indices of 5 recommended artists: [np.int64(143680), np.int64(21998), np.int64(113012), np.int64(95786), np.int64(27148)]
# Recommended artist names: [np.bytes_(b'Ozzy Osborne & Madonna'), np.bytes_(b'Lionsgate'), np.bytes_(b'Da Hool'), np.bytes_(b'News'), np.bytes_(b'Hi_Tack')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000554'
# Nearest K=5 neighbors' user-ids: [b'user_000019' b'user_000113' b'user_000372' b'user_000414'
#  b'user_000692']
# Indices of 5 recommended artists: [np.int64(110947), np.int64(120319), np.int64(12316), np.int64(171512), np.int64(49824)]
# Recommended artist names: [np.bytes_(b'Lostgeneration'), np.bytes_(b'Tintinnabulation'), np.bytes_(b'Belle And Sebastian'), np.bytes_(b'Aromabar'), np.bytes_(b'War From A Harlots Mouth')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000448'
# Nearest K=5 neighbors' user-ids: [b'user_000582' b'user_000413' b'user_000198' b'user_000060'
#  b'user_000393']
# Indices of 5 recommended artists: [np.int64(32401), np.int64(110451), np.int64(31717), np.int64(108423), np.int64(161711)]
# Recommended artist names: [np.bytes_(b'Nelly Furtado'), np.bytes_(b'Civils Radio'), np.bytes_(b'Pearl Jam'), np.bytes_(b'[Unknown]'), np.bytes_(b'Lloyd Cole')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000153'
# Nearest K=5 neighbors' user-ids: [b'user_000897' b'user_000714' b'user_000930' b'user_000626'
#  b'user_000328']
# Indices of 5 recommended artists: [np.int64(72851), np.int64(13503), np.int64(10897), np.int64(12299), np.int64(123205)]
# Recommended artist names: [np.bytes_(b'Diomedes D\xc3\xadaz'), np.bytes_(b'Anastasia'), np.bytes_(b'Secede'), np.bytes_(b'D12'), np.bytes_(b'Dashboard Confessional')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000965'
# Nearest K=5 neighbors' user-ids: [b'user_000397' b'user_000569' b'user_000795' b'user_001000'
#  b'user_000628']
# Indices of 5 recommended artists: [np.int64(110489), np.int64(137959), np.int64(122986), np.int64(68599), np.int64(53444)]
# Recommended artist names: [np.bytes_(b'Free The Robots'), np.bytes_(b'Honkeyfinger'), np.bytes_(b'Guitar Vader'), np.bytes_(b'Joe Tex'), np.bytes_(b'Shellac')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000270'
# Nearest K=5 neighbors' user-ids: [b'user_000551' b'user_000330' b'user_000976' b'user_000517'
#  b'user_000849']
# Indices of 5 recommended artists: [np.int64(73869), np.int64(42021), np.int64(31418), np.int64(87753), np.int64(101663)]
# Recommended artist names: [np.bytes_(b'Thin Lizzy'), np.bytes_(b'Van Halen'), np.bytes_(b'U2 And Green Day'), np.bytes_(b'Patti Rothberg'), np.bytes_(b'Fates Warning')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000998'
# Nearest K=5 neighbors' user-ids: [b'user_000201' b'user_000024' b'user_000920' b'user_000996'
#  b'user_000918']
# Indices of 5 recommended artists: [np.int64(144916), np.int64(83742), np.int64(26352), np.int64(29560), np.int64(106706)]
# Recommended artist names: [np.bytes_(b'Robyn'), np.bytes_(b'Big Star'), np.bytes_(b"Herman'S Hermits"), np.bytes_(b'The Goo Goo Dolls'), np.bytes_(b'The Wallflowers')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000144'
# Nearest K=5 neighbors' user-ids: [b'user_000155' b'user_000961' b'user_000190' b'user_000710'
#  b'user_000263']
# Indices of 5 recommended artists: [np.int64(140485), np.int64(94259), np.int64(108077), np.int64(108033), np.int64(75263)]
# Recommended artist names: [np.bytes_(b'Hannaliisa Uusma Feat. Dj Critical'), np.bytes_(b'Kim Wilde'), np.bytes_(b'Cheek'), np.bytes_(b'Da Lata'), np.bytes_(b'Heavy Metal Army')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000319'
# Nearest K=5 neighbors' user-ids: [b'user_000482' b'user_000242' b'user_000345' b'user_000954'
#  b'user_000164']
# Indices of 5 recommended artists: [np.int64(78525), np.int64(132998), np.int64(108751), np.int64(124221), np.int64(125964)]
# Recommended artist names: [np.bytes_(b'Intuit'), np.bytes_(b'Naked Lunch'), np.bytes_(b'Dilated Peoples'), np.bytes_(b'Apparat'), np.bytes_(b'Commix')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000611'
# Nearest K=5 neighbors' user-ids: [b'user_000957' b'user_000173' b'user_000230' b'user_000776'
#  b'user_000407']
# Indices of 5 recommended artists: [np.int64(33377), np.int64(5709), np.int64(126780), np.int64(146319), np.int64(14108)]
# Recommended artist names: [np.bytes_(b'Mattias Ia Eklundh'), np.bytes_(b'At The Drive-In'), np.bytes_(b'Ethan Hawke'), np.bytes_(b'Cheek Feat. J.Ahola'), np.bytes_(b'Mc Jeffsky')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0013 seconds

# %% [markdown]
# After applying cython: 0.0013s
