# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/dingmeiying/miniconda3/envs/mrs/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/dingmeiying/miniconda3/envs/mrs/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/dingmeiying/miniconda3/envs/mrs/lib/python3.10/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/dingmeiying/miniconda3/envs/mrs/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/dingmeiying/miniconda3/envs/mrs/lib/python3.10/site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
from scipy.sparse import csr_matrix
import numpy as np
import random
import time 
from sklearn.preprocessing import normalize

# %%
K = 5

file_path = "lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv"

# Load interaction log
interactions = pd.read_csv(file_path, sep="\t", header=None,
                           names=["user_id", "timestamp", "artist_id", "artist_name", "track_id", "track_name"], on_bad_lines='skip')

# %%
# Count how many times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mapping dictionaries for user/artist to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map user/artist names to indices in the dataframe
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the user-artist matrix (UAM) in sparse format
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# Normalize rows (each row becomes a unit vector for cosine similarity)
UAM = normalize(UAM, norm='l2', axis=1)

# Precompute UAM transpose for efficient cosine similarity calculations
# This avoids repeatedly computing UAM.transpose() within the loop.
UAM_T = UAM.transpose().tocsr()

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

if __name__ == '__main__':
    start_time = time.time()
    num_users = UAM.shape[0]
    
    for u in range(num_users):
        print("Seed user-id:", user_ids[u])
        
        # Retrieve the normalized playcount vector (row) for the current user
        pc_vec = UAM.getrow(u)
        
        # Compute cosine similarity between the seed user and all other users
        # Using the precomputed UAM_T speeds up the dot-product calculation.
        sims = pc_vec.dot(UAM_T)
        
        # Convert the similarity result to COO format to easily access indices and data.
        sims_coo = sims.tocoo()
        
        # Remove self-similarity by filtering out the element where the column index equals the seed user.
        mask = sims_coo.col != u
        neighbor_indices = sims_coo.col[mask]
        neighbor_scores = sims_coo.data[mask]
        
        # Proceed only if there is at least one similar user
        if neighbor_scores.size == 0:
            print("No similar users found for", user_ids[u])
            print('-' * 80)
            continue
        
        # Use argpartition to quickly find indices of top K similarities.
        # For cases where there are fewer than K neighbors, return all.
        if neighbor_scores.size > K:
            top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
            # Sort the top K neighbors in descending order by their similarity scores.
            sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
            top_neighbors = neighbor_indices[top_k_idx][sorted_order]
        else:
            sorted_order = np.argsort(neighbor_scores)[::-1]
            top_neighbors = neighbor_indices[sorted_order]
        
        # Retrieve the actual user IDs for the top K neighbors
        recommended_user_ids = user_ids[top_neighbors]
        print(f"Nearest K={K} neighbors' user-ids:", recommended_user_ids.flatten())
        
        # Get all artist indices listened to by the top K similar users in one vectorized operation.
        # This avoids looping over each neighbor.
        neighbor_rows = UAM[top_neighbors, :]
        neighbor_coo = neighbor_rows.tocoo()
        recommended_artists_idx = np.unique(neighbor_coo.col)
        
        # Remove artists already known to the seed user
        seed_artists = pc_vec.indices
        recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)
        
        # Randomly choose 5 artists (or fewer, if not enough exist) for recommendation
        if recommended_artists_idx.size > 0:
            num_to_select = min(5, recommended_artists_idx.size)
            random_elements = random.sample(list(recommended_artists_idx), num_to_select)
            print(f"Indices of {len(random_elements)} recommended artists:", random_elements)
            rec_artist_names = [artist_ids[i] for i in random_elements]
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
            
        print('-' * 80)
    
    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Indices of 5 recommended artists: [28341, 12357, 5495, 34731, 988]
# Recommended artist names: ['Exile', 'Soul Coughing', 'Little Computer People', 'Wechsel Garland', 'Elbow']
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Indices of 5 recommended artists: [10909, 8624, 51082, 3038, 2906]
# Recommended artist names: ['Sly & The Family Stone', 'Helmet', 'Charley Patton', 'Elastica', 'Chikinki']
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Indices of 5 recommended artists: [59737, 94003, 3224, 7398, 15233]
# Recommended artist names: ['Luke Dzierzek', 'Purple Ribbon All-Stars', 'Iron Maiden', 'Uniting Nations', 'The Outsiders']
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Indices of 5 recommended artists: [19836, 20381, 15, 36706, 25244]
# Recommended artist names: ['Control Machete', 'ポルノグラフィティ', 'Afterlife', 'Nick Cave And Pj Harvey', 'Buddha Brand']
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Indices of 5 recommended artists: [6812, 92725, 14053, 123427, 14461]
# Recommended artist names: ['Apoptygma Berzerk', 'Might Could', 'Jaydee', 'André Campra', 'The Bastard Fairies']
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Indices of 5 recommended artists: [23693, 1634, 2838, 41298, 224]
# Recommended artist names: ['Pato Fu', 'The Band', 'Brazilian Girls', 'Mute', 'Hexstatic']
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Indices of 5 recommended artists: [39366, 1343, 100350, 100148, 18684]
# Recommended artist names: ['Peabo Bryson & Regina Belle', 'Natasha Bedingfield', 'Joshua Bell/The Philharmonia Orchestra', "Beyonce Feat. Lil' Wayne", 'Klint']
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Indices of 5 recommended artists: [59506, 2598, 22587, 3200, 59743]
# Recommended artist names: ['Albin Myers', 'Tiësto & Christian Burns', 'Alex C.', 'Husky Rescue', 'Magnolia']
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Indices of 5 recommended artists: [79227, 156247, 22592, 88493, 145370]
# Recommended artist names: ['Furyo', 'Brenda Wayne', 'All Gone Dead', 'Östro 430', 'Never Crazy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Indices of 5 recommended artists: [585, 63250, 34180, 4575, 63372]
# Recommended artist names: ['Thomas Newman', 'Progadelica Volume 5', 'Daniel Wang', 'Paffendorf', 'Tremor']
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Indices of 5 recommended artists: [6976, 17133, 28547, 12570, 78846]
# Recommended artist names: ['Madina Lake', 'Dab', 'Robert Rich & Steve Roach', 'Triumph', 'Philippe Saisse Trio']
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Indices of 5 recommended artists: [128790, 45918, 45461, 12826, 116433]
# Recommended artist names: ['Gut-Humpe', 'Waltz For Debbie', 'Karen O & The Million Dollar Bashers', 'Javier Solís', 'Jungle Book']
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Indices of 5 recommended artists: [99545, 3010, 92144, 51467, 9678]
# Recommended artist names: ['Moskwa', 'Disturbed', 'Joose Keskitalo', 'Corpse Bride', 'The Specials']
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Indices of 5 recommended artists: [3136, 25934, 13973, 4192, 165169]
# Recommended artist names: ['Glen Hansard', 'Jewell', 'Get Him Eat Him', 'Dave Gahan', 'Tori Amos And Ani Difranco']
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Indices of 5 recommended artists: [1752, 34285, 92153, 17354, 27794]
# Recommended artist names: ['The Postal Service', 'Gultskra Artikler', 'Panic Attack', 'Marc Almond', 'Psychopomps']
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Indices of 5 recommended artists: [996, 662, 6880, 150351, 2559]
# Recommended artist names: ['Elton John', '10Cc', 'Don Henley', 'Smartbox', 'The Guess Who']
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Indices of 5 recommended artists: [2291, 2126, 24683, 22387, 8038]
# Recommended artist names: ['Klaxons', 'Duran Duran', 'Jordan Rudess', 'Oren Lavie', 'Blossom Dearie']
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Indices of 5 recommended artists: [989, 9406, 545, 14995, 2493]
# Recommended artist names: ['Elefant', 'Skalpel', 'Sébastien Tellier', 'Hṛṣṭa', 'Simian Mobile Disco']
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Indices of 5 recommended artists: [13131, 3504, 1368, 1816, 30641]
# Recommended artist names: ['アンティック-珈琲店-', 'Nina Simone', 'Nofx', 'Thirteen Senses', 'Judge Jules']
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Indices of 5 recommended artists: [47674, 10275, 9810, 11303, 126947]
# Recommended artist names: ['Tc', 'E Nomine', 'Visage', 'Blue October', 'Raging Soul']
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Indices of 5 recommended artists: [1011, 131248, 129871, 133321, 10508]
# Recommended artist names: ['Eve 6', 'Top Jimmy & The Rhythm Pigs', 'Elvis Costello & Steve Nieve', 'Howard K. Smith', 'Beth Nielsen Chapman']
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Indices of 5 recommended artists: [17254, 49715, 31372, 1439, 19150]
# Recommended artist names: ['Harvey Williams', 'Die Kreuzen', 'Indian Jewelry', 'Punchline', 'Quallofill']
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Indices of 5 recommended artists: [7291, 99525, 109978, 11944, 110157]
# Recommended artist names: ['Kai Tracid', 'Lighthouse', 'Apm', 'Lordi', 'Ooo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Indices of 5 recommended artists: [2177, 86168, 35398, 17870, 16317]
# Recommended artist names: ['Freezepop', 'Club Killers', 'Joe Gibbs', 'Bang Sugar Bang', 'Woven Hand']
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Indices of 5 recommended artists: [12389, 1711, 87500, 21059, 1363]
# Recommended artist names: ['Stidiek', 'The Kills', 'Ronnie Self', 'Mariah Carey & Boyz Ii Men', 'Nine Black Alps']
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Indices of 5 recommended artists: [79507, 12141, 1669, 11503, 101085]
# Recommended artist names: ['Anúna', 'Oysterband', 'The Datsuns', 'Duman', 'Olivier Derivière']
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Indices of 5 recommended artists: [23938, 71179, 94563, 69611, 79875]
# Recommended artist names: ['Old School 101', 'Sash! Featuring Vanessa Amorosi', 'Dj Sakin', 'Atfc Feat. Inaya Day', 'Dante']
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Indices of 5 recommended artists: [33318, 127861, 145157, 318, 1491]
# Recommended artist names: ['Killarmy', 'Retape', 'J-Zone & Chief Chinchilla', 'Lady Gaga', 'Rooney']
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Indices of 5 recommended artists: [10894, 48716, 22487, 10308, 86446]
# Recommended artist names: ['Shy Child', 'Influx', 'The Five Corners Quintet', 'Jennifer Lopez', 'Sterling Silver']
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Indices of 5 recommended artists: [3400, 8514, 26548, 5956, 7036]
# Recommended artist names: ['Markéta Irglová', 'Françoise Hardy', "Ramblin' Jack Elliott", 'Teddybears', 'Reo Speedwagon']
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Indices of 5 recommended artists: [62107, 16923, 14890, 23705, 472]
# Recommended artist names: ['Riistetyt', 'Pete Rock & C.L. Smooth', 'Busdriver', 'Radical Face', 'Rob Swift']
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Indices of 5 recommended artists: [38726, 23362, 1249, 36730, 2520]
# Recommended artist names: ['David Bowie & Pat Metheny Group', 'Spineshank', 'Leona Naess', 'Because Of Ghosts', 'Sunny Day Real Estate']
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Indices of 5 recommended artists: [107680, 16435, 32306, 16344, 37550]
# Recommended artist names: ['Alien Factory', 'Gojira', 'The Pink Spiders', 'Aerial', 'Włochaty']
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Indices of 5 recommended artists: [19812, 17731, 8322, 11710, 3144]
# Recommended artist names: ['河野みどり', 'A.K.Klosowski/Pyrolator', 'Dimitri From Paris', 'Hood', 'Goodbooks']
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Indices of 5 recommended artists: [106450, 106538, 1394, 1518, 40700]
# Recommended artist names: ['D-Shake', "Est'Elle & Joni Rewind", 'Paolo Nutini', 'Scritti Politti', 'Radioactive Man']
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Indices of 5 recommended artists: [1782, 108511, 12880, 10018, 5882]
# Recommended artist names: ['The Stone Roses', 'Nelio Guerson And Carlos Guerson', 'Peace Orchestra', 'Kittie', 'Social Distortion']
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Indices of 5 recommended artists: [118173, 10549, 118214, 13651, 14173]
# Recommended artist names: ["Caroline'S Spine", 'Catherine Feeny', 'Faded Motorway Cronies', 'Adorable', 'Morgan']
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Indices of 5 recommended artists: [89689, 115634, 4077, 6910, 148712]
# Recommended artist names: ['Abyssic Hate', 'Auļi', 'Ayria', 'Gackt', 'Andaja']
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Indices of 5 recommended artists: [159751, 4481, 1671, 1846, 904]
# Recommended artist names: ['Carrie Akre', 'Matt Nathanson', 'The Dears', 'Turin Brakes', 'Danny Elfman']
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Indices of 5 recommended artists: [3812, 1111, 168, 7994, 2942]
# Recommended artist names: ['The Indelicates', 'Idlewild', 'Elza Soarez', 'Be Your Own Pet', 'Conjure One']
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Indices of 5 recommended artists: [2615, 27498, 27104, 46222, 15634]
# Recommended artist names: ['Télépopmusik', 'Controlled Fusion', 'We Smoke Fags', 'Magical Mystery', 'Friends']
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Indices of 5 recommended artists: [40182, 40196, 2426, 1907, 40203]
# Recommended artist names: ['Lanterns On The Lake', 'Newspox', 'Paul Oakenfold', 'Zero 7', 'Our Brother The Native']
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Indices of 5 recommended artists: [19494, 586, 32731, 86336, 13765]
# Recommended artist names: ['The Godz', 'Tiefschwarz', 'Craig Erickson', 'Mission Control', 'Blitz']
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Indices of 5 recommended artists: [10469, 10018, 6812, 1821, 19913]
# Recommended artist names: ['Alabama 3', 'Kittie', 'Apoptygma Berzerk', 'Timbaland', 'Warlock']
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Indices of 5 recommended artists: [1345, 36023, 19845, 11647, 13062]
# Recommended artist names: ['Ne-Yo', 'The Dying Breed Feat. Tanaka Koyuki', 'Eamon', 'Grave Digger', 'Moptop']
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Indices of 5 recommended artists: [87171, 2359, 10179, 85747, 51597]
# Recommended artist names: ['Badlands', 'Megadeth', 'Xytras', 'Karp', 'Immolation']
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Indices of 5 recommended artists: [107878, 172616, 4723, 31885, 13286]
# Recommended artist names: ['Growing Concern', 'Ricky & Rock-Its', 'Squeeze', 'Queen & Wyclef Jean', 'Ian Dury']
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Indices of 5 recommended artists: [43984, 11823, 24525, 88755, 3094]
# Recommended artist names: ['Maga', 'Joshua Radin', 'Ashes To Ashes', 'River', 'Flowers From The Man Who Shot Your Cousin']
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Indices of 5 recommended artists: [3973, 1080, 16885, 95883, 1394]
# Recommended artist names: ['Yppah', 'Guillemots', 'Medina Green', 'Kamikaze Queens', 'Paolo Nutini']
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Indices of 5 recommended artists: [11333, 13541, 3945, 2989, 86309]
# Recommended artist names: ['Brett Dennen', 'The Ponys', 'White Rose Movement', 'Death In June & Boyd Rice', 'Lisa Haley']
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Indices of 5 recommended artists: [1782, 1615, 9235, 2937, 149560]
# Recommended artist names: ['The Stone Roses', 'Tellison', 'Pony Up', 'Cocteau Twins', 'Tom Jones With Cerys From Catatonia']
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Indices of 5 recommended artists: [23968, 40632, 6697, 10057, 59207]
# Recommended artist names: ['Burst', 'Morrigan', 'Breaking Benjamin', 'My Ruin', 'Naio Ssaion']
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Indices of 5 recommended artists: [1759, 21587, 8362, 35724, 85681]
# Recommended artist names: ['The Rakes', 'Andy Mckee', 'Dj Sneak', 'Freescha', 'Ver Vlads']
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Indices of 5 recommended artists: [116723, 156401, 116663, 48554, 13544]
# Recommended artist names: ['Motorocker', 'Uberfaust', 'Injúria', 'Bluesøsken', 'The Rezillos']
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Indices of 5 recommended artists: [3645, 75715, 1486, 13488, 9200]
# Recommended artist names: ['Sarah Slean', 'Groovelily', 'Rod Stewart', 'The Ethiopians', 'Pelle Carlberg']
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Indices of 5 recommended artists: [2823, 22889, 23009, 82701, 17064]
# Recommended artist names: ['Blue States', 'Endzeit', 'Jones & Stephenson', 'Nvmph', 'Bassbin Twins']
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Indices of 5 recommended artists: [684, 2488, 2367, 5684, 6976]
# Recommended artist names: ['Air', 'Sherwood', 'Michael Gray Vs. Shelly Poole', 'Onyx', 'Madina Lake']
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Indices of 5 recommended artists: [1697, 3910, 19772, 14201, 17695]
# Recommended artist names: ['The Goo Goo Dolls', 'Tunng', 'İlhan Erşahin', 'No Age', 'Suicide']
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Indices of 5 recommended artists: [15119, 25913, 1673, 31509, 15048]
# Recommended artist names: ['Paul Revere And The Raiders', 'Jay Haze', 'The Delgados', 'Leeroy Stagger', 'Krzysztof Penderecki']
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Indices of 5 recommended artists: [19086, 2249, 6001, 19081, 3106]
# Recommended artist names: ['Peaches & Herb', 'Jedi Mind Tricks', 'Thomas Brinkmann', 'Paul Spencer', 'French Kicks']
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Indices of 5 recommended artists: [4635, 5761, 27753, 8333, 2150]
# Recommended artist names: ['Res', 'Queens Of The Stone Age', 'Nicolae Guță', 'Divinyls', 'Everclear']
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Indices of 5 recommended artists: [17232, 19638, 12470, 19438, 18591]
# Recommended artist names: ['George Baker Selection', 'Tony Conrad With Faust', 'The Innocence Mission', 'The Butchies', 'John Hammond']
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Indices of 5 recommended artists: [50675, 662, 137224, 6371, 4592]
# Recommended artist names: ['Beware Of Safety', '10Cc', 'Zakir Hussain;Sultan Khan', 'Craig David', 'Phil Fuldner']
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Indices of 5 recommended artists: [17106, 12995, 2931, 88817, 138753]
# Recommended artist names: ['Cheryl Lynn', 'Codeseven', 'Clor', 'Alarma Man', 'Nesian Mystik']
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Indices of 5 recommended artists: [4293, 21784, 18372, 3167, 12234]
# Recommended artist names: ['Finley Quaye', 'Piers Faccini', 'Gecko Turner', 'Hadouken!', 'Renaud']
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Indices of 5 recommended artists: [21620, 93486, 13635, 46927, 12758]
# Recommended artist names: ['Cliff Martinez', 'Nemesi', '#Poundsign#', 'Audio Deluxe', 'Carl Orff']
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Indices of 5 recommended artists: [15672, 117876, 51015, 145611, 4323]
# Recommended artist names: ['Günther', 'U2 & Bob Dylan', 'The Roaring Twenties', 'Tiėsto Feat. Kirsty Hawkshaw', 'Global Deeyays']
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Indices of 5 recommended artists: [58028, 7204, 32539, 23233, 2632]
# Recommended artist names: ['Duran Duran Duran', 'Deepsky', 'We', 'Praga Khan', 'Way Out West']
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Indices of 5 recommended artists: [2103, 120945, 9191, 428, 47674]
# Recommended artist names: ['Dj Krush', 'Chinesepod.Com', 'Paul Johnson', 'Pendulum', 'Tc']
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Indices of 5 recommended artists: [9698, 12093, 103998, 1869, 37533]
# Recommended artist names: ['The Twelves', 'Neil Young & Pearl Jam', 'Deviot', 'Voxtrot', 'Upside Down']
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Indices of 5 recommended artists: [2231, 2616, 14123, 9142, 44736]
# Recommended artist names: ['Iggy Pop', 'Uffie', 'Longpigs', 'Northcape', 'Iain Matthews']
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Indices of 5 recommended artists: [31293, 8909, 38306, 12304, 2192]
# Recommended artist names: ['Grand Ole Party', 'Lindsay Lohan', 'Five', 'Scott Weiland', 'Goldfrapp']
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Indices of 5 recommended artists: [21890, 36850, 110142, 110114, 109106]
# Recommended artist names: ['Atrocity', 'Esem', 'Mixed By Judge Jules', 'Lollop', 'Along Came Man']
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Indices of 5 recommended artists: [24991, 9014, 19124, 75959, 30716]
# Recommended artist names: ['A Scissors', 'Metricks & Gaiabeat', 'Popol Vuh', 'Without Gravity', 'Christian Castro']
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Indices of 5 recommended artists: [1889, 3125, 4550, 12232, 11620]
# Recommended artist names: ['Wolfgang Amadeus Mozart', 'George Michael', 'Nusrat Fateh Ali Khan', 'Reggae Crusaders', 'Garmarna']
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Indices of 5 recommended artists: [60757, 5003, 64119, 151047, 5186]
# Recommended artist names: ['That Petrol Emotion', 'Basteroid', 'John Cale, Tony Conrad, Angus Maclise, La Monte Young And Marian Zazeela', 'Temp Sound Solutions', 'Dorit Chrysler']
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Indices of 5 recommended artists: [47210, 118753, 47701, 27474, 6425]
# Recommended artist names: ['Helena Vondráčková', 'Psykick Lyrikah', 'The Mighty Diamonds', 'Butch Walker', 'Gil T']
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Indices of 5 recommended artists: [153666, 66963, 153627, 18169, 14804]
# Recommended artist names: ['Siesta', 'Unique 3', 'Headgear', 'Delta 5', 'Graeme Revell']
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Indices of 5 recommended artists: [933, 152689, 33283, 5511, 2739]
# Recommended artist names: ['Detektivbyrån', 'Emak 1', 'Womack & Womack', 'Luis Bacalov', 'Apollo 440']
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Indices of 5 recommended artists: [19398, 12034, 47398, 697, 940]
# Recommended artist names: ['Sylvester', 'Mercedes Sosa', 'Maria Del Mar Bonet', 'Alison Krauss', 'Die Aeronauten']
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Indices of 5 recommended artists: [13777, 82356, 24407, 151454, 2733]
# Recommended artist names: ['Bodies Of Water', 'A Hawk And A Hacksaw And The Hun Hangár Ensemble', 'Steadman', 'Slumdog Millionaire Soundtrack', 'Annie']
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Indices of 5 recommended artists: [2682, 41946, 14225, 2621, 90493]
# Recommended artist names: ['Adele', 'Stunt Monkey', 'Oxford Collapse', 'Unwritten Law', 'Imported']
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Indices of 5 recommended artists: [41983, 11619, 7073, 20493, 41638]
# Recommended artist names: ['The Meads Of Asphodel', 'Garagecorp', 'Symphony X', 'Etta James & Sugar Pie Desanto', 'Eddie Thoneick Feat. Berget Lewis']
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Indices of 5 recommended artists: [856, 105212, 2183, 50653, 4429]
# Recommended artist names: ['Chantal Kreviazuk', 'Disney Channel Circle Of Stars', 'Gadjo', 'Wicked Wisdom', 'Leona Lewis']
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Indices of 5 recommended artists: [9538, 6828, 86534, 706, 42358]
# Recommended artist names: ['Television', 'Bon Jovi', 'Brkovi', 'American Hi-Fi', 'Latisha']
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Indices of 5 recommended artists: [95544, 18378, 37735, 6000, 136931]
# Recommended artist names: ['Hannah Collins', 'Georg Danzer; Ulli Bäer', 'Diana Ross & Lionel Richie', 'Thomas Andersson', 'Hot Chip & Robert Wyatt']
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Indices of 5 recommended artists: [16282, 1309, 96875, 125425, 2079]
# Recommended artist names: ['Veronica Maggio', 'Mia.', 'The Angry String Orchestra', 'Amber Feat. Sweet Rains', 'David Guetta']
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Indices of 5 recommended artists: [6856, 812, 908, 12221, 62266]
# Recommended artist names: ['Daughtry', 'Bob Seger', 'Dashboard Confessional', 'Rainer Maria', 'Faruk Korkmaz']
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Indices of 5 recommended artists: [18538, 3189, 9879, 17388, 11403]
# Recommended artist names: ['James Brown And The Famous Flames', 'High Places', 'Adem', 'Momus', 'Codeine']
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Indices of 5 recommended artists: [10123, 29722, 968, 1786, 23742]
# Recommended artist names: ['Styx', 'Tigercity', 'Dread Zeppelin', 'The Strokes', 'Ttc']
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Indices of 5 recommended artists: [11959, 34387, 150824, 8283, 8586]
# Recommended artist names: ['Luigi Boccherini', 'La Jetee', 'Marek Rybicki', 'David Rubato', 'Grauzone']
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Indices of 5 recommended artists: [79189, 8203, 1443, 63963, 3229]
# Recommended artist names: ['Constantine Soundtrack', 'Color Me Badd', 'Rachael Yamagata', 'Gloria Scott', 'Isobel Campbell & Mark Lanegan']
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Indices of 5 recommended artists: [33437, 4851, 1254, 162691, 720]
# Recommended artist names: ['Articolo 31', 'Zombie Nation', 'Liquido', 'Dj Edo', 'Animal Collective']
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Indices of 5 recommended artists: [107586, 99543, 107472, 99533, 6911]
# Recommended artist names: ['Umar Bin Hassan And Abiodun Oyewole With Pharoah Sanders', 'Mind Necrosis Factor Vs Kenji Siratori', 'Miles Davis, Ornette Coleman, Bill Frisell', 'Mango Maniax', 'Gary Numan']
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Indices of 5 recommended artists: [126231, 13881, 7815, 22578, 13990]
# Recommended artist names: ['Os Cascavelletes', 'Db Boulebard', 'The Troggs', 'Advance Patrol', 'Greg Lake']
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Indices of 5 recommended artists: [30015, 7107, 42330, 39666, 19020]
# Recommended artist names: ['Tomorrow', 'Trivium', 'Joel Rubin Jewish Music Ensemble', 'The Gas Band', 'Nisi Period']
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Indices of 5 recommended artists: [3101, 87923, 171896, 43517, 49707]
# Recommended artist names: ['Franz Ferdinand & Jane Birkin', 'Burton Cummings', 'D.S.', 'Antonio Pinto', 'Crime']
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Indices of 5 recommended artists: [1470, 1552, 1722, 71, 21630]
# Recommended artist names: ['Richmond Fontaine', 'Someone Still Loves You Boris Yeltsin', 'The Long Blondes', 'Bobbi Humphrey', 'Danny']
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Indices of 5 recommended artists: [13280, 8760, 879, 30357, 113046]
# Recommended artist names: ['Horrorpops', 'Jorge Ben', 'Cold War Kids', 'Les Wampas', 'Kekster Dynamics']
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids: ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Indices of 5 recommended artists: [1111, 660, 28727, 1402, 13055]
# Recommended artist names: ['Idlewild', '...And You Will Know Us By The Trail Of Dead', 'Apollo Sunshine', 'Paula Cole', 'Mclusky']
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids: ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Indices of 5 recommended artists: [1802, 2587, 1796, 1236, 7566]
# Recommended artist names: ['The Walkmen', 'Thin Lizzy', 'The Veils', 'Kylie Minogue', 'Gentle Giant']
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids: ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Indices of 5 recommended artists: [7111, 22179, 24275, 12470, 32963]
# Recommended artist names: ['Unter Null', 'Die Raketen', 'Joe Pass', 'The Innocence Mission', 'Lee Morgan']
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids: ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Indices of 5 recommended artists: [122682, 13117, 18868, 95438, 2023]
# Recommended artist names: ['Georgio Schultz', 'The Warlocks', 'Marlena Shaw', 'Peter Liddle', 'Bullet For My Valentine']
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Indices of 5 recommended artists: [24658, 29001, 111044, 15937, 24522]
# Recommended artist names: ['Gorod', 'Holly Morris', 'Menosgada', 'Nifelheim', 'Arise']
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Indices of 5 recommended artists: [999, 845, 1237, 51794, 2739]
# Recommended artist names: ['Elvis Presley', 'Camera Obscura', 'Lagwagon', 'Sabrina Starke', 'Apollo 440']
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Indices of 5 recommended artists: [158700, 44207, 3731, 16710, 95580]
# Recommended artist names: ['The Pakistanettes M/Valentinerne', 'Demon Boyz', 'Syd Matters', 'Bill Hicks', 'Laura Burhenn']
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids: ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Indices of 5 recommended artists: [1527, 87900, 91656, 18074, 122643]
# Recommended artist names: ['Sheryl Crow', 'This Is Hell', 'The Matches & Zebrahead', 'Circle Jerks', 'Björk Guðmundsdóttir & Tríó Guðmundar Ingólfssonar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids: ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Indices of 5 recommended artists: [171950, 87024, 10114, 99519, 7169]
# Recommended artist names: ['Main Finger', 'Queen & Elton John', 'Soilwork', 'Ksu [Pod Prąd', 'Cafe Groove']
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids: ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Indices of 5 recommended artists: [9352, 1924, 6541, 58784, 1316]
# Recommended artist names: ['Scatman John', '65Daysofstatic', 'Monica', 'Britney Spears Vs Linkin Park', 'Milburn']
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Indices of 5 recommended artists: [10588, 2368, 7329, 38277, 85450]
# Recommended artist names: ['Donavon Frankenreiter', 'Mickey Avalon', 'Nelly', 'Beth Hart', '宮内タカユキ']
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Indices of 5 recommended artists: [125299, 6751, 6953, 172448, 1413]
# Recommended artist names: ['Concord Dawn And Ill Skillz', 'Mario Vazquez', 'Kenny G', 'Last In Line', 'Pete Yorn']
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids: ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Indices of 5 recommended artists: [47730, 57506, 13296, 19227, 47457]
# Recommended artist names: ['Traband', 'Bungalove', 'Joe Strummer & The Mescaleros', 'Romashka', 'Musetta']
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids: ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Indices of 5 recommended artists: [6162, 22037, 26459, 24525, 24871]
# Recommended artist names: ['Кино', 'Пикник', 'Paul Ritch', 'Ashes To Ashes', 'Александр Васильев']
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids: ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Indices of 5 recommended artists: [10161, 149825, 158711, 47244, 158516]
# Recommended artist names: ['Tomahawk', 'Crookers Mix', 'Tom Stephan & D.Ramirez', 'Inverso Lagarto', 'Exceptional Records']
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids: ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Indices of 5 recommended artists: [45293, 6193, 1691, 19540, 23905]
# Recommended artist names: ['Smack', 'Мумий Тролль', 'The Fray', 'The Number Twelve Looks Like You', '[Anonymous]']
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids: ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Indices of 5 recommended artists: [12984, 146678, 88865, 4151, 2929]
# Recommended artist names: ['Briskeby', 'Vacum', 'Jonas', 'Claude Challe', 'Clinic']
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids: ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Indices of 5 recommended artists: [18216, 41129, 24777, 23455, 43918]
# Recommended artist names: ['Dr. Octagon', 'Data 80', 'Saltillo', 'Total Eclipse', 'Guy Mitchell']
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids: ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Indices of 5 recommended artists: [126188, 28168, 81565, 1477, 82219]
# Recommended artist names: ['Joe Bennett', 'Moby Grape', 'Dale Hawkins', 'Robbie Williams', 'Ulysses']
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids: ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Indices of 5 recommended artists: [5249, 24857, 3051, 40449, 87762]
# Recommended artist names: ['Fatboy Slim', 'Vision Divine', 'Emilíana Torrini', 'Equilibrium', 'Eventide']
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids: ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Indices of 5 recommended artists: [3875, 1869, 8375, 68345, 147040]
# Recommended artist names: ['The Whip', 'Voxtrot', 'Dntel', 'Idina Menzel & Tracie Thoms', 'Lucas Grabeel']
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids: ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Indices of 5 recommended artists: [2138, 18729, 5393, 12031, 12088]
# Recommended artist names: ['Emerson, Lake & Palmer', 'Lee Hazlewood', 'Johan Skugge', 'Melvins', 'Nanci Griffith']
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Indices of 5 recommended artists: [2397, 8501, 2075, 1241, 17489]
# Recommended artist names: ['Nikka Costa', 'Four Tet', 'Darude', 'Lazlo Bane', 'Seachange']
# --------------------------------------------------------------------------------
# Seed user-id: user_000123
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000998' 'user_000018' 'user_000779' 'user_000486']
# Indices of 5 recommended artists: [17448, 13042, 38423, 9793, 115298]
# ...
# Recommended artist names: ['Christina Vidal', 'The Ananda Project', 'Spektrum', 'Junior Jack', 'Jay-Z And Linkin Park']
# --------------------------------------------------------------------------------
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Indices of 5 recommended artists: [86204, 18669, 839, 28404, 4999]
# Recommended artist names: ['Duane Mccoy Trio', 'Kindred The Family Soul', 'Béla Fleck And The Flecktones', 'K.I.A.', 'Barbara Morgenstern']
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids: ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Indices of 5 recommended artists: [118179, 38511, 38700, 38687, 38077]
# Recommended artist names: ['Clinton', 'B. A. Robertson', 'Dana Glover', 'Coldcut Featuring Yazz & The Plastic Population', 'Richard Rodgers & Oscar Hammerstein Ii']
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids: ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Indices of 5 recommended artists: [14843, 12340, 111866, 10486, 1656]
# Recommended artist names: ['Aceyalone', 'Slayer', 'Museum Pieces', 'Army Navy', 'The Click Five']
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids: ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Indices of 5 recommended artists: [64306, 47380, 15128, 25004, 86127]
# Recommended artist names: ['Marie France', 'Luciano Supervielle', 'Pit Er Pat', 'Abstrackt Keal Agram', 'Autocantantes']
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids: ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Indices of 5 recommended artists: [433, 28508, 23724, 2765, 40685]
# Recommended artist names: ['Pierre Henry', "Pe'Z", 'T.O.K.', 'B.B. King', 'Pink Turns Blue']
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids: ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Indices of 5 recommended artists: [15024, 8909, 93690, 41321, 11935]
# Recommended artist names: ['Joe Anderson', 'Lindsay Lohan', 'Inca Ore', 'Owls', 'Lit']
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids: ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Indices of 5 recommended artists: [2782, 12459, 34379, 81994, 841]
# Recommended artist names: ['Baxter', 'The Funky Lowlives', 'Komet', 'Richard And The Pallbearers', 'Café Del Mar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Indices of 5 recommended artists: [46803, 108573, 26774, 26961, 1559]
# Recommended artist names: ['Nasty Habits', 'Venus In Motion', 'Spooks', 'The Shape Shifters', 'Soundtrack']
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Indices of 5 recommended artists: [319, 24533, 11037, 10198, 12997]
# Recommended artist names: ['Lamb', 'Between The Buried And Me', 'The Needs', 'Morningwood', 'Cotton Candy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Indices of 5 recommended artists: [97629, 6487, 11668, 2649, 19071]
# Recommended artist names: ['Padma Chebrolu', 'Kerri Chandler', 'Gülşen', 'Young Jeezy', 'Papa Wemba']
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Indices of 5 recommended artists: [41766, 145871, 41842, 133666, 60508]
# Recommended artist names: ['La Mazz', 'D-Men', 'Orgy & Korn', 'The Lost Souls', 'Jeff Trott']
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Indices of 5 recommended artists: [123888, 91701, 91499, 91480, 45237]
# Recommended artist names: ['Cry.On.My.Console', 'Tips For Lester', 'Planetstruck', 'No Torso', 'Magrudergrind']
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Indices of 5 recommended artists: [88810, 1016, 91630, 124012, 5415]
# Recommended artist names: ['When Tides Collide', 'Faith No More', 'The Disco Students', 'Soulfire', 'Junior Boys']
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Indices of 5 recommended artists: [6828, 24193, 1134, 12506, 18148]
# Recommended artist names: ['Bon Jovi', 'Smurffit', 'Jamiroquai', 'The Shadows', 'Dave Berry']
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Indices of 5 recommended artists: [10910, 15820, 27412, 10553, 746]
# Recommended artist names: ['Smokey Robinson & The Miracles', 'Liam Lynch', 'Adam Richman', 'Cherry Ghost', 'Ashlee Simpson']
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Indices of 5 recommended artists: [2017, 19635, 2755, 795, 13084]
# Recommended artist names: ['Boys Night Out', 'Tommy Mccook & The Supersonics', 'Au Revoir Simone', 'Big D And The Kids Table', 'R. Stevie Moore']
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Indices of 5 recommended artists: [2547, 16050, 8553, 1086, 45893]
# Recommended artist names: ['The Briggs', 'Rollergirl', 'Georges Bizet', 'Hard-Fi', 'The Martinis']
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Indices of 5 recommended artists: [488, 1750, 3499, 66171, 962]
# Recommended artist names: ['Röyksopp', 'The Police', 'Nightmares On Wax', 'Behind Crimson Eyes', 'Dogs Die In Hot Cars']
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Indices of 5 recommended artists: [38815, 32395, 14318, 29798, 109495]
# Recommended artist names: ['Edgar Winter', 'The Woggles', 'Sambassadeur', 'Xbxrx', 'Locanda Delle Fate']
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Indices of 5 recommended artists: [726, 33075, 46977, 43301, 47227]
# Recommended artist names: ['Annie Lennox', 'Parov Stellar', 'Boban Marković', 'Subsollo', 'Hugo Díaz']
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Indices of 5 recommended artists: [49602, 49170, 66268, 49227, 48915]
# Recommended artist names: ['The Sick Lipstick', 'Gangbangaz', 'Pez', 'Jbag', 'Air Miami']
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Indices of 5 recommended artists: [17052, 2255, 137389, 9988, 1933]
# Recommended artist names: ['Arthur Lyman', 'Jibbs', 'Sonebridge', 'Heimatærde', 'Above & Beyond']
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Indices of 5 recommended artists: [1168, 17560, 2335, 6373, 9965]
# Recommended artist names: ['John Lennon', 'The Irresistible Force', 'Lynyrd Skynyrd', "D'Angelo", 'Filter']
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Indices of 5 recommended artists: [26010, 2231, 781, 7776, 9417]
# Recommended artist names: ['Kero One', 'Iggy Pop', 'Belle And Sebastian', 'Steinski', 'Slowdive']
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Indices of 5 recommended artists: [2059, 157937, 157816, 8760, 2444]
# Recommended artist names: ['Crystal Castles', 'University Of California, Los Angeles Random Voices', 'Brown Jabberwocks', 'Jorge Ben', 'Punks Jump Up']
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Indices of 5 recommended artists: [1324, 1144, 2968, 18644, 11067]
# Recommended artist names: ['Morrissey', 'Jeff Buckley', 'Daniel Licht', 'Katharine Mcphee', 'The Surfaris']
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Indices of 5 recommended artists: [16304, 13324, 95422, 71745, 12612]
# Recommended artist names: ['White Lion', 'Loretta Lynn', 'Willis', 'Heligoland', 'W.A.S.P.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Indices of 5 recommended artists: [462, 16, 100, 45689, 5538]
# Recommended artist names: ['Rei Harakami', 'Afx', "Christian Prommer'S Drumlesson", 'Eli "Paperboy" Reed & The True Loves', 'Marek Bois']
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Indices of 5 recommended artists: [118683, 12203, 11111, 17305, 22706]
# Recommended artist names: ['Tír Na Nóg', 'Pride & Glory', 'Van Mccoy & The Soul City Symphony', 'Katerine', 'Champion']
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Indices of 5 recommended artists: [40007, 2767, 15225, 9399, 28589]
# Recommended artist names: ['Minty Fresh Beats', 'Bachman-Turner Overdrive', 'The Mccoys', 'Silver Jews', 'Steve Forbert']
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Indices of 5 recommended artists: [10001, 60132, 3898, 38423, 47397]
# Recommended artist names: ['Indukti', 'Tuomari Nurmio & Korkein Oikeus', 'Tortoise', 'Viikate', 'Mari Boine']
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Indices of 5 recommended artists: [21603, 1565, 12474, 2389, 1092]
# Recommended artist names: ['Bobby Helms', 'Spoon', 'The Jon Spencer Blues Explosion', 'My Bloody Valentine', 'Hoobastank']
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Indices of 5 recommended artists: [9852, 18839, 1045, 18362, 7909]
# Recommended artist names: ['Young Marble Giants', 'Malik', 'Fred Astaire', 'Galliano', 'Albert Ayler']
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Indices of 5 recommended artists: [41708, 41800, 2127, 79507, 44897]
# Recommended artist names: ['Hedley', 'Mark Knight (Feat. The B.B.N.)', 'Dusty Kid', 'Anúna', 'David Morales']
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Indices of 5 recommended artists: [161691, 12730, 102204, 11658, 2555]
# Recommended artist names: ['The Gaylads (B. Seaton)', 'Anton Bruckner', 'Square One', 'Grobschnitt', 'The Good Life']
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Indices of 5 recommended artists: [8710, 37267, 10812, 894, 1508]
# Recommended artist names: ['Jean Michel Jarre', 'Bill Bailey', 'Newton Faulkner', 'Crosby, Stills, Nash & Young', 'Santana']
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Indices of 5 recommended artists: [29263, 1827, 14087, 36542, 3234]
# Recommended artist names: ['Rheingold', 'Tokyo Police Club', 'Kitchens Of Distinction', 'Klingonz', 'Jacob Miller']
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Indices of 5 recommended artists: [15222, 996, 15093, 2563, 3273]
# Recommended artist names: ['The Hush Now', 'Elton John', 'Mozella', 'The Juliana Theory', 'Junior Senior']
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Indices of 5 recommended artists: [3282, 110203, 1585, 4142, 11211]
# Recommended artist names: ['Kate Bush', 'Sikora', 'Straylight Run', 'Chris Brown', 'Anthrax']
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Indices of 5 recommended artists: [851, 15121, 745, 18717, 9677]
# Recommended artist names: ['Cary Brothers', 'Pela', 'Ash', 'Last Days Of April', 'The Slickers']
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0013 seconds
