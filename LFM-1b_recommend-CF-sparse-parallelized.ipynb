# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
import pandas as pd
from scipy.sparse import csr_matrix
import numpy as np
import random
import time 
from sklearn.preprocessing import normalize
from multiprocessing import Pool, cpu_count

# %%
K = 5

file_path = r'C:\MRS\lastfm-dataset-1K\lastfm-dataset-1K\userid-timestamp-artid-artname-traid-traname.tsv'

# Load interaction log
interactions = pd.read_csv(file_path, sep="\t", header=None,
                           names=["user_id", "timestamp", "artist_id", "artist_name", "track_id", "track_name"], on_bad_lines='skip')

# %%
# Count number of times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mappings: user/artist to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map to index
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the sparse matrix (UAM)
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# normalize rows (for cosine similarity)

UAM = normalize(UAM, norm='l2', axis=1)

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))


if __name__ == '__main__':
    start_time = time.time()
    for u in range(0, UAM.shape[0]):
        print("Seed user-id: " + str(user_ids[u]))

        # Get normalized playcount vector for current user
        pc_vec = UAM.getrow(u)

        # Compute cosine similarity between this user and all users
        uU_sim = pc_vec.dot(UAM.transpose()).tocoo()
        uU_user_idx = uU_sim.col
        uU_data = uU_sim.data

        # Remove self-similarity
        uU_data[uU_user_idx == u] = 0

        # Eliminate zeros
        uU_sim.data = uU_data
        uU_sim = uU_sim.tocsr()
        uU_sim.eliminate_zeros()
        uU_sim = uU_sim.tocoo()

        # Re-assign user indices and scores
        uU_user_idx = uU_sim.col
        uU_data = uU_sim.data

        # Sort by similarity score
        sort_index = np.argsort(uU_data)

        # Select top-K nearest neighbors
        # Note that uU_user_idx indeed provides the indices for users in UAM
        recommended_user_idx = uU_user_idx[sort_index[-K:]]
        # Get user_ids corresponding to nearest neighbors
        recommended_user_ids = user_ids[recommended_user_idx]
        # Get similarity score for nearest neighbors
        recommended_user_scores = uU_data[sort_index[-K:]]

        print("Nearest K=" + str(K) + " neighbors' user-ids: ", recommended_user_ids.flatten())

        # Get all artists these similar users have listened to
        recommended_artists_idx = []
        for u_idx in recommended_user_idx:
            recommended_artists_idx.extend(list(UAM.getrow(u_idx).indices))

        # Remove duplicates and sort
        recommended_artists_idx = sorted(set(recommended_artists_idx))

        # Remove artists already known to seed user
        recommended_artists_idx = np.setdiff1d(recommended_artists_idx, pc_vec.indices)

        # Narrow down to random 5 artist out of all artists that similar users listen to for illustration purpose
        random_indices = random.sample(range(len(recommended_artists_idx)), 5)
        random_elements = [recommended_artists_idx[i] for i in random_indices]

        print("Indices of " + str(len(random_elements)) + " recommended artists: ", random_elements)
        print("Recommended artist names:", [artist_ids[i] for i in random_elements])
        print('-' * 80)

    end_time = time.time()
    total_users = UAM.shape[0]
    avg_time = (end_time - start_time) / total_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids:  ['user_000168' 'user_000844' 'user_000862' 'user_000629' 'user_000074']
# Indices of 5 recommended artists:  [160722, 9537, 33476, 3107, 8724]
# Recommended artist names: ['Silvia Aprile', 'Telefuzz', 'Bryn Christopher', 'Frida Hyvönen', "Jim O'Rourke"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids:  ['user_000513' 'user_000726' 'user_000143' 'user_000238' 'user_000673']
# Indices of 5 recommended artists:  [18821, 61158, 9651, 23604, 62401]
# Recommended artist names: ['Maceo & The Macks', 'La Polla Records', 'The Mountain Goats', 'Chiara Mastroianni & Benjamin Biolay', 'La Quinta Estación']
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids:  ['user_000392' 'user_000741' 'user_000400' 'user_000558' 'user_000813']
# Indices of 5 recommended artists:  [7024, 28425, 4432, 115296, 19033]
# Recommended artist names: ['Peter Gabriel', 'Laurent Wolf', 'Lifelike & Kris Menace', 'Schwarzkopf', 'Numbers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids:  ['user_000703' 'user_000998' 'user_000089' 'user_000779' 'user_000996']
# Indices of 5 recommended artists:  [7967, 8698, 53749, 4723, 11308]
# Recommended artist names: ['Asian Dub Foundation', "Jane'S Addiction", 'Mr. Lee', 'Squeeze', 'Boa']
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids:  ['user_000627' 'user_000807' 'user_000560' 'user_000584' 'user_000307']
# Indices of 5 recommended artists:  [107730, 13816, 19888, 103699, 22774]
# Recommended artist names: ['Jupiter Ace', 'Camper Van Beethoven', 'Safri Duo', 'Kazantip', 'Dcx']
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids:  ['user_000675' 'user_000415' 'user_000885' 'user_000766' 'user_000116']
# Indices of 5 recommended artists:  [3788, 19468, 14866, 77553, 18985]
# Recommended artist names: ['The Divine Comedy', 'The Egyptian Lover', 'Badmarsh & Shri', 'Kevin Smith And Scott Mosier', 'Napalm Death']
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids:  ['user_000437' 'user_000781' 'user_000402' 'user_000236' 'user_000765']
# Indices of 5 recommended artists:  [29978, 100085, 66782, 32430, 26860]
# Recommended artist names: ['Poloroid', '10 Minutes Chrono', 'Dj Ace', 'Toby Lightman', 'Teairra Mari']
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids:  ['user_000123' 'user_000187' 'user_000737' 'user_000419' 'user_000864']
# Indices of 5 recommended artists:  [2613, 59776, 1759, 59672, 13490]
# Recommended artist names: ['Twista', 'Myon & Shane 54 (Feat. Carrie Skipper)', 'The Rakes', 'Herve Feat. Plastic Little', 'The Evens']
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids:  ['user_000833' 'user_000115' 'user_000473' 'user_000758' 'user_000357']
# Indices of 5 recommended artists:  [12782, 16334, 59920, 19947, 10008]
# Recommended artist names: ['Dick Dale', '下村陽子', 'Aleister Einstein', 'Asian Kung-Fu Generation', 'Julee Cruise']
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids:  ['user_000813' 'user_000379' 'user_000329' 'user_000981' 'user_000208']
# Indices of 5 recommended artists:  [173149, 14004, 63172, 43893, 90841]
# Recommended artist names: ['Josipa Lisac', 'Harlem Shakes', 'Last Rhythm', 'Fashionless', 'Benji B']
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids:  ['user_000953' 'user_000715' 'user_000291' 'user_000417' 'user_000705']
# Indices of 5 recommended artists:  [72103, 6729, 71566, 137115, 2700]
# Recommended artist names: ['Delirious', 'Harry Gregson-Williams', 'Willa Ford', "Fou Ts'Ong", 'Alphawezen']
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids:  ['user_000203' 'user_000564' 'user_000703' 'user_000698' 'user_000689']
# Indices of 5 recommended artists:  [46570, 938, 115464, 36756, 132724]
# Recommended artist names: ['Lidell Townsell', 'Diana Ross & The Supremes And The Temptations', 'Haywood', 'Japancakes', 'Hugh Moore']
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids:  ['user_000026' 'user_000927' 'user_000935' 'user_000932' 'user_000161']
# Indices of 5 recommended artists:  [42778, 11657, 7259, 13858, 51855]
# Recommended artist names: ['Dj Rodriguez', 'Grinspoon', 'Godsmack', 'Cosmo Jones Beat Machine', 'Timo Maas Fest Brian Molko']
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids:  ['user_000129' 'user_000443' 'user_000920' 'user_000257' 'user_000497']
# Indices of 5 recommended artists:  [1781, 66681, 11767, 680, 17847]
# Recommended artist names: ['The Stills', 'No-Fi Soul Rebellion', 'Jenny Owen Youngs', 'Adam Green', 'Au Pairs']
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids:  ['user_000503' 'user_000515' 'user_000634' 'user_000532' 'user_000927']
# Indices of 5 recommended artists:  [10587, 25545, 4030, 74121, 13280]
# Recommended artist names: ['Don Byron', 'Dosh', 'Airbase', 'Dierks Bentley', 'Horrorpops']
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids:  ['user_000328' 'user_000048' 'user_000897' 'user_000293' 'user_000791']
# Indices of 5 recommended artists:  [35707, 16633, 67, 34261, 1971]
# Recommended artist names: ['The Puppini Sisters', 'Madison Avenue', 'Blockhead', 'Gaelle', 'Armor For Sleep']
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids:  ['user_000705' 'user_000075' 'user_000937' 'user_000731' 'user_000905']
# Indices of 5 recommended artists:  [38809, 30595, 75759, 34848, 137126]
# Recommended artist names: ['Dylan Singh', 'Chris Botti', 'Jon Lord', 'Henri Wieniavsky', 'Howard Shore;G.E. Smith;Sharon Isbin']
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids:  ['user_000123' 'user_000486' 'user_000998' 'user_000093' 'user_000996']
# Indices of 5 recommended artists:  [101947, 29977, 1384, 18240, 229]
# Recommended artist names: ['Mat Weddle', 'Polmo Polpo', 'Olspur', 'Ekkehard Ehlers', 'Holy Fuck']
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids:  ['user_000020' 'user_000565' 'user_000554' 'user_000139' 'user_000440']
# Indices of 5 recommended artists:  [13089, 36168, 40820, 48849, 115733]
# Recommended artist names: ['Sansui Rocknroll', 'Miranda!', 'Unto Ashes', 'The Casualties', 'Karnataka']
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids:  ['user_000658' 'user_000139' 'user_000327' 'user_000683' 'user_000624']
# Indices of 5 recommended artists:  [126938, 11884, 21534, 48139, 1058]
# Recommended artist names: ['Hillary & The Democrats', 'Kristin Hersh', 'Molotov', 'Stiff Kittens', 'Gary Jules']
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids:  ['user_000681' 'user_000691' 'user_000673' 'user_000617' 'user_000882']
# Indices of 5 recommended artists:  [1860, 129545, 14404, 13125, 108081]
# Recommended artist names: ['Vast', 'Auntie Vegetable', 'Stump', 'X', "Ne'Er-Do-Wells"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids:  ['user_000858' 'user_000249' 'user_000534' 'user_000564' 'user_000690']
# Indices of 5 recommended artists:  [2230, 115488, 19073, 99754, 73224]
# Recommended artist names: ['Ice Cube', 'King Kong', 'Pat Boone', 'Twist', 'Frog Holler']
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids:  ['user_000866' 'user_000503' 'user_000927' 'user_000515' 'user_000634']
# Indices of 5 recommended artists:  [99591, 2333, 5712, 19295, 4068]
# Recommended artist names: ['Starcraft Soundtrack', 'Lupe Fiasco', 'Paul Kalkbrenner', 'Sex Gang Children', 'Audio Bullys']
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids:  ['user_000371' 'user_000998' 'user_000493' 'user_000031' 'user_000345']
# Indices of 5 recommended artists:  [60660, 17873, 13728, 12383, 18074]
# Recommended artist names: ['Push Kings', 'Bantam Rooster', 'Baskervilles', 'Steve Morse Band', 'Circle Jerks']
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids:  ['user_000476' 'user_000096' 'user_000151' 'user_000118' 'user_000653']
# Indices of 5 recommended artists:  [1129, 8207, 126155, 1802, 7852]
# Recommended artist names: ['Jacques Brel', 'Common', 'Dickie Mcbride', 'The Walkmen', 'Zen Café']
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids:  ['user_000565' 'user_000839' 'user_000188' 'user_000833' 'user_000161']
# Indices of 5 recommended artists:  [101078, 60023, 11358, 40820, 1025]
# Recommended artist names: ['Dismal Euphony', 'Klaha', 'Cathedral', 'Unto Ashes', 'Fettes Brot']
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids:  ['user_000651' 'user_000205' 'user_000124' 'user_000233' 'user_000714']
# Indices of 5 recommended artists:  [7203, 70414, 19408, 18574, 2108]
# Recommended artist names: ['Deep.Spirit', 'Johnson', 'Tami Chynn', 'Joachim Witt', 'Dj Mystik']
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids:  ['user_000485' 'user_000373' 'user_000756' 'user_000069' 'user_000661']
# Indices of 5 recommended artists:  [72578, 12374, 19142, 35399, 8828]
# Recommended artist names: ['Private Eleanor', 'Steely Dan', 'Q Project', 'John B', 'Klein & M.B.O.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000826' 'user_000513' 'user_000703' 'user_000024']
# Indices of 5 recommended artists:  [49142, 18409, 23606, 10747, 40304]
# Recommended artist names: ['Elektrik Dred', 'Gorgoroth', 'Christian Walz', 'Kubichek!', 'Arcturus']
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids:  ['user_000858' 'user_000753' 'user_000703' 'user_000031' 'user_000564']
# Indices of 5 recommended artists:  [5931, 11857, 18038, 115431, 970]
# Recommended artist names: ['Superpitcher', 'Kathryn Tickell', 'Chavez', 'El Jezel', 'Dropkick Murphys']
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids:  ['user_000242' 'user_000159' 'user_000164' 'user_000513' 'user_000345']
# Indices of 5 recommended artists:  [14855, 50934, 4635, 15186, 713]
# Recommended artist names: ['American Football', 'Broadway Project Feat. Jeb Loy Nichols', 'Res', 'Steven Stark', 'Andrew Lloyd Webber']
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids:  ['user_000206' 'user_000115' 'user_000442' 'user_000727' 'user_000692']
# Indices of 5 recommended artists:  [9444, 23471, 4347, 134040, 18433]
# Recommended artist names: ['Spandau Ballet', 'Uniklubi', 'I Monster', 'Freiburger Spielleyt', 'György Ligeti']
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids:  ['user_000991' 'user_000999' 'user_000588' 'user_000188' 'user_000758']
# Indices of 5 recommended artists:  [92413, 6837, 2845, 30040, 50667]
# Recommended artist names: ['Suzy Q', 'Canoply Games', 'Britney Spears', 'Akurat', 'Amplifier Machine']
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids:  ['user_000280' 'user_000086' 'user_000031' 'user_000164' 'user_000345']
# Indices of 5 recommended artists:  [19517, 19190, 8079, 17827, 11094]
# Recommended artist names: ['The Kingstonians', 'Reverend Deadeye', 'Brian Bennett', 'Arovane', 'Toots & The Maytals']
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids:  ['user_000415' 'user_000023' 'user_000483' 'user_000664' 'user_000720']
# Indices of 5 recommended artists:  [101445, 1141, 107191, 35034, 17843]
# Recommended artist names: ['2 Am/Fm', 'Japanther', 'William Becton', 'Domenico + 2', 'Atom And His Package']
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids:  ['user_000086' 'user_000770' 'user_000495' 'user_000992' 'user_000499']
# Indices of 5 recommended artists:  [3469, 18216, 2121, 15213, 57623]
# Recommended artist names: ['Myslovitz', 'Dr. Octagon', 'Dr. Dre', 'The Format', 'Lulu Santos']
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids:  ['user_000062' 'user_000304' 'user_000294' 'user_000862' 'user_000577']
# Indices of 5 recommended artists:  [732, 14649, 118360, 79228, 13774]
# Recommended artist names: ['Antonio Vivaldi', 'The Salteens', 'Ruja', 'Gary Allan', 'Bobby Hebb']
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids:  ['user_000056' 'user_000780' 'user_000015' 'user_000612' 'user_000588']
# Indices of 5 recommended artists:  [27559, 2047, 10318, 10435, 10297]
# Recommended artist names: ['Effect', 'Chromeo', 'Latexxx Teens', 'Von Thronstahl', 'Gothminister']
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids:  ['user_000603' 'user_000551' 'user_000985' 'user_000849' 'user_000814']
# Indices of 5 recommended artists:  [7564, 2625, 4142, 1303, 6864]
# Recommended artist names: ['Gary Moore', 'Vengaboys', 'Chris Brown', 'Mazzy Star', 'Deftones']
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids:  ['user_000624' 'user_000658' 'user_000093' 'user_000327' 'user_000020']
# Indices of 5 recommended artists:  [1313, 1366, 3262, 2422, 13034]
# Recommended artist names: ['Michael Jackson', 'No Doubt', 'Joanna Newsom', 'Paramore', 'Instant Wilkie']
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids:  ['user_000615' 'user_000831' 'user_000444' 'user_000134' 'user_000132']
# Indices of 5 recommended artists:  [3099, 46005, 9053, 46294, 89126]
# Recommended artist names: ['France Gall', 'Charlene Duncan', 'Mohammed Rafi', 'Randy Rathbun Nv0U', 'Matt Darey & Marcella Woods']
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids:  ['user_000256' 'user_000383' 'user_000103' 'user_000806' 'user_000117']
# Indices of 5 recommended artists:  [53782, 91864, 7083, 9428, 304]
# Recommended artist names: ['Rhythim Is Rhythim', 'S.A. Smash', 'The Ghost That Walks', 'Sofa', 'Kid Koala']
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000143' 'user_000513' 'user_000345' 'user_000031']
# Indices of 5 recommended artists:  [54814, 17798, 17843, 2485, 86396]
# Recommended artist names: ['Damon Aaron', 'Andreas Dorau', 'Atom And His Package', 'Shakira', 'Portable Sunsets']
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids:  ['user_000473' 'user_000527' 'user_000442' 'user_000435' 'user_000115']
# Indices of 5 recommended artists:  [44367, 1755, 919, 2670, 43712]
# Recommended artist names: ['Cadaveria', 'The Proclaimers', 'Death Cab For Cutie', 'A Flock Of Seagulls', 'Devanic']
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids:  ['user_000346' 'user_000457' 'user_000289' 'user_000527' 'user_000442']
# Indices of 5 recommended artists:  [37785, 3682, 3994, 16530, 992]
# Recommended artist names: ['Ewan Mcgregor Jose Feliciano', 'Skunk Anansie', '増田俊郎', 'Shadow Gallery', 'Ella Fitzgerald']
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids:  ['user_000013' 'user_000537' 'user_000783' 'user_000912' 'user_000354']
# Indices of 5 recommended artists:  [15559, 999, 3453, 7073, 9952]
# Recommended artist names: ['E-Type', 'Elvis Presley', 'Morcheeba', 'Symphony X', 'Electric Brother']
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids:  ['user_000354' 'user_000761' 'user_000260' 'user_000973' 'user_000378']
# Indices of 5 recommended artists:  [9196, 146416, 2827, 11494, 132423]
# Recommended artist names: ['Paula Abdul', 'Voidsettler', 'Bobby Darin', 'Dozer', 'Warren G, Sissel']
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids:  ['user_000847' 'user_000328' 'user_000631' 'user_000791' 'user_000769']
# Indices of 5 recommended artists:  [2942, 119282, 9074, 45838, 38673]
# Recommended artist names: ['Conjure One', 'Starrfadu', 'Muke', 'Robbie Williams & Kylie Minogue', 'Cliff Richard & The Shadows']
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids:  ['user_000256' 'user_000668' 'user_000387' 'user_000420' 'user_000126']
# Indices of 5 recommended artists:  [92220, 1877, 9214, 43323, 250]
# Recommended artist names: ['Clarence Foster & The Internal Revenue', 'Weezer', 'Peter Murphy', 'The All Seeing I', 'James Brown']
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids:  ['user_000467' 'user_000511' 'user_000620' 'user_000336' 'user_000345']
# Indices of 5 recommended artists:  [9848, 18986, 86388, 12911, 9949]
# Recommended artist names: ['Yacht', 'Nara Leão', 'Pina', 'Stillwater', 'Efterklang']
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids:  ['user_000478' 'user_000803' 'user_000977' 'user_000089' 'user_000215']
# Indices of 5 recommended artists:  [3090, 21676, 64812, 161, 32928]
# Recommended artist names: ["Five O'Clock Heroes", 'Iningrid Michaelson', 'The Hair', 'Earth, Wind & Fire', 'Johnny Cash & June Carter Cash']
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids:  ['user_000247' 'user_000173' 'user_000115' 'user_000182' 'user_000113']
# Indices of 5 recommended artists:  [59176, 25720, 59179, 1663, 43457]
# Recommended artist names: ['Luna Spice', 'Gallows', 'Løveblod', 'The Cranberries', 'Crucified Barbara']
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids:  ['user_000773' 'user_000606' 'user_000756' 'user_000241' 'user_000373']
# Indices of 5 recommended artists:  [57373, 72562, 54815, 145117, 810]
# Recommended artist names: ['Zo! & Tigallo', 'Ocaixi', 'Damu The Fudgemunk', 'Dj Overdose', 'Blur']
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids:  ['user_000570' 'user_000835' 'user_000142' 'user_000776' 'user_000912']
# Indices of 5 recommended artists:  [116813, 83639, 61778, 16272, 12061]
# Recommended artist names: ['Steel Warrior', 'Kotipelto', 'Malefactor', 'U96', 'Modena City Ramblers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids:  ['user_000763' 'user_000591' 'user_000577' 'user_000579' 'user_000894']
# Indices of 5 recommended artists:  [3586, 15070, 93877, 40400, 1672]
# Recommended artist names: ['Q And Not U', 'Martin Luther', 'Julia Darling', 'Dj Ernesto', 'The Decemberists']
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids:  ['user_000043' 'user_000132' 'user_000134' 'user_000700' 'user_000041']
# Indices of 5 recommended artists:  [3610, 19263, 23144, 23462, 23276]
# Recommended artist names: ['Rhapsody Of Fire', 'Sanseverino', 'Mindless Faith', 'Trippa', 'Rick Dees & His Cast Of Idiots']
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids:  ['user_000557' 'user_000742' 'user_000551' 'user_000650' 'user_000902']
# Indices of 5 recommended artists:  [122069, 1827, 1713, 1230, 105987]
# Recommended artist names: ['Kirsty Hawkshaw Vs. Kinky Rowland', 'Tokyo Police Club', 'The Knife', 'Kings Of Leon', 'Peter Presta Feat. Bonse']
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids:  ['user_000070' 'user_000598' 'user_000463' 'user_000828' 'user_000770']
# Indices of 5 recommended artists:  [705, 14414, 101540, 9417, 1364]
# Recommended artist names: ['Ambulance Ltd', 'Sweet Jane', 'Black Moth Super Rainbow + The Octopus Project', 'Slowdive', 'Nine Inch Nails']
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids:  ['user_000024' 'user_000837' 'user_000763' 'user_000584' 'user_000345']
# Indices of 5 recommended artists:  [104119, 3654, 13746, 7970, 11718]
# Recommended artist names: ['David Lynch', 'Scout Niblett', 'Big Bill Broonzy', 'Atjazz', 'Humble Pie']
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids:  ['user_000633' 'user_000448' 'user_000031' 'user_000170' 'user_000582']
# Indices of 5 recommended artists:  [10781, 18857, 9600, 18942, 19636]
# Recommended artist names: ['Manitoba', 'Maria Solheim', 'The Electric Hellfire Club', 'Mombasa', 'Toni L']
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids:  ['user_000479' 'user_000579' 'user_000959' 'user_000233' 'user_000765']
# Indices of 5 recommended artists:  [149035, 70231, 118579, 69575, 2032]
# Recommended artist names: ['Megan Rochell', 'Gina Glocksen', 'Milky Lasers', 'Angelica De No', "Cam'Ron"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids:  ['user_000159' 'user_000345' 'user_000031' 'user_000304' 'user_000170']
# Indices of 5 recommended artists:  [2165, 18107, 13096, 40531, 19373]
# Recommended artist names: ['Fleetwood Mac', 'Cop Shoot Cop', 'Spacemen 3', 'Justice Vs. Gambit', 'Stigmato Inc.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids:  ['user_000188' 'user_000705' 'user_000338' 'user_000305' 'user_000431']
# Indices of 5 recommended artists:  [13069, 8555, 99411, 550, 63590]
# Recommended artist names: ['No-Man', 'Gerry Rafferty', 'Atmosphere X', 'Talvin Singh', 'Blind Blake']
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids:  ['user_000853' 'user_000832' 'user_000970' 'user_000360' 'user_000495']
# Indices of 5 recommended artists:  [47397, 1684, 46539, 4631, 3439]
# Recommended artist names: ['Mari Boine', 'The Feeling', 'Jacuzzi Boys', 'Rednex', 'Missy Higgins']
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids:  ['user_000803' 'user_000603' 'user_000960' 'user_000403' 'user_000467']
# Indices of 5 recommended artists:  [3800, 2849, 1079, 2969, 685]
# Recommended artist names: ['The Frames', 'Buffalo Springfield', 'Guided By Voices', 'Danielson', 'Air Traffic']
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids:  ['user_000396' 'user_000392' 'user_000586' 'user_000418' 'user_000609']
# Indices of 5 recommended artists:  [18335, 93474, 3475, 93495, 4400]
# Recommended artist names: ['Francis Poulenc', 'Michelle Walker', 'Múm', 'Opihi Pickers', 'Kelly Rowland']
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids:  ['user_000020' 'user_000122' 'user_000624' 'user_000760' 'user_000658']
# Indices of 5 recommended artists:  [16553, 15928, 22506, 145531, 4109]
# Recommended artist names: ['The Boondock Saints', 'Nasa', 'These New Puritans', 'Loto Feat. Aiga', 'Blue Foundation']
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids:  ['user_000753' 'user_000898' 'user_000343' 'user_000735' 'user_000159']
# Indices of 5 recommended artists:  [15036, 13469, 39502, 1224, 50952]
# Recommended artist names: ['Kelli Ali', 'The Bones', 'Shakatak', 'Kent', 'Fotheringay']
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids:  ['user_000707' 'user_000756' 'user_000273' 'user_000661' 'user_000028']
# Indices of 5 recommended artists:  [90635, 127853, 23698, 2020, 6337]
# Recommended artist names: ['Sukia', 'R.Kelly Feat. Wisin & Yandell', 'Plastic Little', 'Broken Social Scene', 'Bun B']
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids:  ['user_000600' 'user_000598' 'user_000770' 'user_000463' 'user_000828']
# Indices of 5 recommended artists:  [10193, 12305, 120305, 13489, 12903]
# Recommended artist names: ['Gomez', 'Screaming Trees', '100 Monkeys', 'The Evaporators', 'Soda Stereo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000512' 'user_000513' 'user_000448' 'user_000209']
# Indices of 5 recommended artists:  [8654, 3202, 4767, 1133, 10594]
# Recommended artist names: ['Howard Jones', "I'M From Barcelona", 'Terror Squad', 'Jamie T', 'Duke Special']
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids:  ['user_000520' 'user_000018' 'user_000837' 'user_000668' 'user_000367']
# Indices of 5 recommended artists:  [128290, 82239, 49583, 1678, 2291]
# Recommended artist names: ['The Beatle Barkers', 'We Are Telephone', 'The Federation', 'The Early November', 'Klaxons']
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids:  ['user_000515' 'user_000935' 'user_000503' 'user_000634' 'user_000927']
# Indices of 5 recommended artists:  [1896, 110040, 1534, 59039, 74813]
# Recommended artist names: ['Yann Tiersen', 'Ekon', 'Sigur Rós', 'Carved In Stone', 'Gayla Peevey']
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids:  ['user_000844' 'user_000577' 'user_000807' 'user_000079' 'user_000838']
# Indices of 5 recommended artists:  [158464, 7029, 54060, 2315, 20646]
# Recommended artist names: ['Astrud Gilberto With Stanley Turrentine', 'Plumb', 'Darkmateria', 'Lindstrøm', 'Blu Mar Ten']
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids:  ['user_000905' 'user_000083' 'user_000017' 'user_000859' 'user_000937']
# Indices of 5 recommended artists:  [11213, 1649, 318, 15450, 2016]
# Recommended artist names: ['Anto Drennan; Ciaran Toorish; Clannad; Ian Melrose; Ian Parker; Paul Moran', 'The Cardigans', 'Lady Gaga', 'Bobby Mcferrin', 'Boys Like Girls']
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids:  ['user_000210' 'user_000086' 'user_000091' 'user_000792' 'user_000168']
# Indices of 5 recommended artists:  [1126, 26391, 923, 20944, 150712]
# Recommended artist names: ['Jack Peñate', 'Non', 'Deichkind', 'Jeff Mills & Montpellier Philarmonic Orchestra', 'Indopepsychics And Jan Jelinek']
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids:  ['user_000606' 'user_000807' 'user_000584' 'user_000135' 'user_000763']
# Indices of 5 recommended artists:  [47811, 2925, 43128, 27348, 2937]
# Recommended artist names: ['温力铭', 'Claudio Villa', 'Ollano', 'N.O.H.A.', 'Cocteau Twins']
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids:  ['user_000763' 'user_000606' 'user_000560' 'user_000807' 'user_000584']
# Indices of 5 recommended artists:  [5556, 24509, 1246, 10025, 33631]
# Recommended artist names: ['Masha Qrella', 'Amen', 'Leftöver Crack', "L'Altra", 'Jon Hopkins']
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids:  ['user_000862' 'user_000074' 'user_000801' 'user_000522' 'user_000838']
# Indices of 5 recommended artists:  [10574, 34719, 34693, 18895, 12466]
# Recommended artist names: ['Data Panik', 'Universal Constructors', 'The Trio Bulgarka', 'Men Without Hats', 'The Guggenheim Grotto']
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids:  ['user_000031' 'user_000242' 'user_000273' 'user_000870' 'user_000315']
# Indices of 5 recommended artists:  [6431, 431, 18983, 5566, 161684]
# Recommended artist names: ['Groove Theory', 'Pharoah Sanders', 'Nadezhda Kuular & The Tuvan State Ensemble Sayani', 'Matthew Dear', 'Take 5 Feat. Kyla']
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids:  ['user_000569' 'user_000983' 'user_000960' 'user_000511' 'user_000795']
# Indices of 5 recommended artists:  [17450, 26977, 2387, 34625, 7791]
# Recommended artist names: ['Quatuor Ysaÿe', 'The Young Jazz Rebels', 'Mstrkrft', 'Shipping News', 'Tech N9Ne']
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids:  ['user_000993' 'user_000617' 'user_000838' 'user_000376' 'user_000577']
# Indices of 5 recommended artists:  [1884, 11070, 197, 36853, 43059]
# Recommended artist names: ['Wilco', 'The Tears', 'Gemini', 'Fenin', 'Michel Colombier']
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids:  ['user_000075' 'user_000108' 'user_000905' 'user_000937' 'user_000859']
# Indices of 5 recommended artists:  [41885, 1080, 1130, 6433, 1650]
# Recommended artist names: ['Relapsed', 'Guillemots', 'James Blunt', 'Hed Kandi', 'The Cat Empire']
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids:  ['user_000342' 'user_000894' 'user_000610' 'user_000771' 'user_000155']
# Indices of 5 recommended artists:  [1767, 3638, 21776, 50647, 1318]
# Recommended artist names: ['The Rolling Stones', 'Santogold', 'Patrick L', 'Todosantos', 'Millencolin']
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids:  ['user_000676' 'user_000110' 'user_000686' 'user_000579' 'user_000346']
# Indices of 5 recommended artists:  [23964, 18698, 118532, 9731, 2022]
# Recommended artist names: ['As Blood Runs Black', 'Kultur Shock', 'Dainos Teatras', 'Throwing Muses', 'Bt']
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids:  ['user_000703' 'user_000415' 'user_000345' 'user_000031' 'user_000034']
# Indices of 5 recommended artists:  [1538, 19793, 29390, 4381, 19334]
# Recommended artist names: ['Simon & Garfunkel', 'Николай Римский-Корсаков', 'Subway Sect', 'John Digweed', 'Slovak Philharmonic Chorus/Csr So/Dohnányi']
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids:  ['user_000173' 'user_000776' 'user_000426' 'user_000650' 'user_000607']
# Indices of 5 recommended artists:  [1354, 2386, 59235, 10417, 833]
# Recommended artist names: ['Nickelback', 'Mr. Vegas', 'Onkel Tom Angelripper', 'The Pointer Sisters', 'Buddy Holly']
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids:  ['user_000897' 'user_000626' 'user_000706' 'user_000204' 'user_000577']
# Indices of 5 recommended artists:  [1808, 32184, 3570, 82190, 12954]
# Recommended artist names: ['The Wombats', 'The Day After', 'Pram', 'The World Without Magic', 'Игорь Фёдорович Стравинский']
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids:  ['user_000403' 'user_000467' 'user_000131' 'user_000031' 'user_000345']
# Indices of 5 recommended artists:  [19632, 522, 2716, 3227, 11097]
# Recommended artist names: ['Tomaso Giovanni Albinoni', 'Soundgarden', 'Anathema', 'Isis', 'Transglobal Underground']
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids:  ['user_000238' 'user_000361' 'user_000333' 'user_000385' 'user_000993']
# Indices of 5 recommended artists:  [9767, 1779, 12636, 72340, 1237]
# Recommended artist names: ['Touch And Go', 'The Sounds', 'Wolfstone', 'Nelly Fertado Ft. Chris Martin From Coldplay', 'Lagwagon']
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids:  ['user_000703' 'user_000074' 'user_000792' 'user_000807' 'user_000675']
# Indices of 5 recommended artists:  [128845, 151138, 67187, 3954, 977]
# Recommended artist names: ['Mamelo Sound System', 'Èglantine Gouzy & Landini', 'Nico And The Invisible Girls', 'Within Temptation', 'E-Z Rollers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids:  ['user_000294' 'user_000687' 'user_000284' 'user_000860' 'user_000326']
# Indices of 5 recommended artists:  [3636, 37671, 12511, 77858, 2455]
# Recommended artist names: ['Sakin', 'Catherine Zeta-Jones', 'The Swinging Blue Jeans', 'David Herzhaft', 'Ricky Nelson']
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000018' 'user_000891' 'user_000658' 'user_000327']
# Indices of 5 recommended artists:  [4232, 105501, 24382, 13842, 3954]
# Recommended artist names: ['Dj Hype', 'Universal Hall Pass', 'Kay Kay & His Weathered Underground', 'Cocoanut Groove', 'Within Temptation']
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000179' 'user_000484' 'user_000927' 'user_000431']
# Indices of 5 recommended artists:  [75698, 6893, 18792, 3561, 1338]
# Recommended artist names: ['Feng Shui', "Evil'S Toy", 'Lost Sounds', 'Pin Me Down', 'Nancy Sinatra']
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids:  ['user_000482' 'user_000596' 'user_000705' 'user_000096' 'user_000653']
# Indices of 5 recommended artists:  [12761, 10588, 12445, 97317, 11246]
# Recommended artist names: ['Chico Buarque', 'Donavon Frankenreiter', 'The Coasters', 'J.B. Hutto & The Hawks', 'Babyface']
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids:  ['user_000493' 'user_000829' 'user_000110' 'user_000596' 'user_000653']
# Indices of 5 recommended artists:  [9868, 1363, 116825, 2403, 6966]
# Recommended artist names: ['近藤浩治', 'Nine Black Alps', 'Tequila Baby', 'O-Zone', 'Lamb Of God']
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids:  ['user_000970' 'user_000989' 'user_000753' 'user_000294' 'user_000709']
# Indices of 5 recommended artists:  [12277, 68358, 22845, 8519, 72413]
# Recommended artist names: ['Sacred Spirit', 'Mike Garlington & The Mishap Crew', 'Download', 'Free Kitten', 'Support Lesbiens']
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids:  ['user_000328' 'user_000476' 'user_000002' 'user_000631' 'user_000778']
# Indices of 5 recommended artists:  [1890, 675, 1188, 1483, 1003]
# Recommended artist names: ['Wolfgang Petry', 'Abba', 'Joseph Arthur', 'Robert Randolph & The Family Band', 'Eric Clapton']
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids:  ['user_000217' 'user_000360' 'user_000238' 'user_000543' 'user_000906']
# Indices of 5 recommended artists:  [1002, 85135, 1238, 12691, 21664]
# Recommended artist names: ['Erasure', 'Potentia Animi', 'Larrikin Love', 'Antony', 'Gabriel Yared']
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids:  ['user_000390' 'user_000371' 'user_000913' 'user_000234' 'user_000918']
# Indices of 5 recommended artists:  [14857, 3659, 1533, 8390, 6979]
# Recommended artist names: ['Anathallo', 'Semisonic', 'Shout Out Louds', 'Dressy Bessy', 'Marilyn Manson & The Spooky Kids']
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids:  ['user_000654' 'user_000637' 'user_000667' 'user_000643' 'user_000886']
# Indices of 5 recommended artists:  [1042, 21384, 785, 124627, 11670]
# Recommended artist names: ['Frank Zappa', 'Wang Chung', 'Ben Harper', 'Ewan Mcgregor & Jacek Koman', 'H-Blockx']
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids:  ['user_000274' 'user_000704' 'user_000582' 'user_000031' 'user_000753']
# Indices of 5 recommended artists:  [17951, 9455, 17966, 18045, 944]
# Recommended artist names: ['Bobby Bare', 'Spy Machine 16', 'Bossa Nostra', 'Cheb Tarik', 'Die Kassierer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids:  ['user_000513' 'user_000567' 'user_000414' 'user_000616' 'user_000839']
# Indices of 5 recommended artists:  [40747, 95439, 46737, 1654, 3329]
# Recommended artist names: ['Solefald', 'Poppadoms', 'Chrome', 'The Cinematics', 'Lenny Kravitz']
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids:  ['user_000032' 'user_000523' 'user_000853' 'user_000594' 'user_000442']
# Indices of 5 recommended artists:  [59075, 1067, 10366, 98680, 111153]
# Recommended artist names: ['Disillusion', 'Goldfinger', 'Qntal', 'Powerwolf', 'Vrankenvorde']
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids:  ['user_000093' 'user_000018' 'user_000779' 'user_000161' 'user_000996']
# Indices of 5 recommended artists:  [965, 3341, 17062, 51510, 1011]
# Recommended artist names: ['Doris Day', 'Lily Allen', 'Barry Manilow', 'Elixir', 'Eve 6']
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids:  ['user_000629' 'user_000074' 'user_000992' 'user_000844' 'user_000499']
# Indices of 5 recommended artists:  [1025, 20228, 28402, 3492, 24252]
# Recommended artist names: ['Fettes Brot', 'Snorkel', 'Julien Neto', 'Neon Neon', 'Chris Clark']
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids:  ['user_000616' 'user_000729' 'user_000976' 'user_000890' 'user_000382']
# Indices of 5 recommended artists:  [10189, 769, 66300, 13375, 1192]
# Recommended artist names: ['Damone', 'Band Of Horses', 'The Ghost Frequency', 'Paint It Black', 'José González']
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids:  ['user_000431' 'user_000650' 'user_000970' 'user_000912' 'user_000393']
# Indices of 5 recommended artists:  [8698, 12745, 4445, 24501, 11809]
# Recommended artist names: ["Jane'S Addiction", 'Bebe', 'Los Del Río', 'Ajattara', 'Johnny Winter']
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids:  ['user_000603' 'user_000501' 'user_000434' 'user_000741' 'user_000878']
# Indices of 5 recommended artists:  [46451, 1840, 10048, 11754, 14415]
# Recommended artist names: ['20 Fingers', 'Trans-Siberian Orchestra', 'Ministry', 'Jann Arden', 'Symposium']
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids:  ['user_000493' 'user_000169' 'user_000596' 'user_000096' 'user_000653']
# Indices of 5 recommended artists:  [8454, 4660, 11141, 10708, 10]
# Recommended artist names: ['Erase Errata', 'Rza', '*Nsync', 'John Lee Hooker, Jr.', 'A. R. Rahman']
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids:  ['user_000868' 'user_000973' 'user_000648' 'user_000047' 'user_000378']
# Indices of 5 recommended artists:  [24120, 172501, 1773, 172659, 172331]
# Recommended artist names: ['Denison Witmer', 'Mr. & Mrs. J.W. Baker', 'The Shins', 'Singerclub Ernesto Che Guevara', 'Front Range']
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids:  ['user_000933' 'user_000358' 'user_000177' 'user_000945' 'user_000135']
# Indices of 5 recommended artists:  [149579, 12789, 166063, 8761, 33116]
# Recommended artist names: ['Crystin', 'Dragon Ash', 'Alen Ramic', 'Jorge Ben Jor', 'Red Garland']
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids:  ['user_000247' 'user_000676' 'user_000395' 'user_000115' 'user_000052']
# Indices of 5 recommended artists:  [24698, 24500, 24956, 24756, 5951]
# Recommended artist names: ['Libido Airbag', 'Agonizer', 'Шевчук', 'Paracoccidioidomicosisproctitissarcomucosis', 'T.A.T.U.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids:  ['user_000196' 'user_000584' 'user_000844' 'user_000862' 'user_000629']
# Indices of 5 recommended artists:  [7422, 123781, 37022, 12577, 72242]
# Recommended artist names: ['Anekdoten', 'Obituary Mambo', 'Donatella Rettore', 'Twisted Sister', 'Speech Debelle']
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids:  ['user_000798' 'user_000802' 'user_000113' 'user_000052' 'user_000044']
# Indices of 5 recommended artists:  [44409, 12419, 8008, 24767, 1202]
# Recommended artist names: ['Gloomy Grim', 'Tarot', 'Berlin', 'Ram-Zet', 'Kaiser Chiefs']
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids:  ['user_000920' 'user_000350' 'user_000658' 'user_000624' 'user_000766']
# Indices of 5 recommended artists:  [970, 97610, 712, 48549, 6794]
# Recommended artist names: ['Dropkick Murphys', 'Nucleus', 'Andrew Bird', 'Asta Kask', 'Accessory']
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids:  ['user_000368' 'user_000807' 'user_000256' 'user_000383' 'user_000806']
# Indices of 5 recommended artists:  [4655, 8673, 1042, 1453, 153603]
# Recommended artist names: ['Royal Gigolos', 'Ilkae', 'Frank Zappa', 'Ray Charles', 'Dave Pemberton']
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids:  ['user_000096' 'user_000493' 'user_000653' 'user_000837' 'user_000626']
# Indices of 5 recommended artists:  [126151, 126203, 2389, 934, 101240]
# Recommended artist names: ['Cornel Gunter & The Flairs', 'Kidou Keiji Jiban    ¡Yujo!', 'My Bloody Valentine', 'Devendra Banhart', 'Ashley Ballard']
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids:  ['user_000173' 'user_000594' 'user_000453' 'user_000182' 'user_000395']
# Indices of 5 recommended artists:  [102481, 6972, 3610, 40900, 4435]
# Recommended artist names: ['Mundanus Imperium', 'Live', 'Rhapsody Of Fire', 'Construcdead', 'Lionel Richie']
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids:  ['user_000224' 'user_000837' 'user_000575' 'user_000890' 'user_000285']
# Indices of 5 recommended artists:  [2380, 7106, 86517, 999, 6760]
# Recommended artist names: ['Misfits', 'Train', 'Zed', 'Elvis Presley', 'Ray J']
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids:  ['user_000493' 'user_000202' 'user_000851' 'user_000345' 'user_000277']
# Indices of 5 recommended artists:  [238, 3589, 9971, 1092, 63883]
# Recommended artist names: ['Incognito', 'Radio 4', 'Fu Manchu', 'Hoobastank', 'Experimental Audio Research']
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids:  ['user_000118' 'user_000525' 'user_000714' 'user_000048' 'user_000837']
# Indices of 5 recommended artists:  [15163, 24404, 41216, 38767, 1357]
# ...
# --------------------------------------------------------------------------------
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids:  ['user_000403' 'user_000698' 'user_000024' 'user_000511' 'user_000345']
# Indices of 5 recommended artists:  [54406, 15229, 15169, 843, 2854]
# Recommended artist names: ['Beathoven', 'The Mundanes', 'Sightings', 'Calexico', 'Butterfly Boucher']
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids:  ['user_000294' 'user_000097' 'user_000753' 'user_000709' 'user_000591']
# Indices of 5 recommended artists:  [16206, 28808, 2929, 54034, 144782]
# Recommended artist names: ['The Penguins', 'Captain Sensible', 'Clinic', 'Atom Heart', 'Bio Ninja Circus']
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids:  ['user_000910' 'user_000031' 'user_000970' 'user_000705' 'user_000691']
# Indices of 5 recommended artists:  [8175, 8015, 8085, 11588, 17967]
# Recommended artist names: ['Christopher Cross', 'Bill Evans', 'Brigitte Bardot', 'Fionn Regan', 'Botch']
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids:  ['user_000412' 'user_000345' 'user_000794' 'user_000691' 'user_000210']
# Indices of 5 recommended artists:  [10659, 60474, 64018, 10543, 3774]
# Recommended artist names: ['Griffin House', 'Guided By Voices & Airport 5', 'Howard Keel & Kathryn Grayson', 'Carpark North', 'The Clientele']
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000716' 'user_000268' 'user_000059' 'user_000721']
# Indices of 5 recommended artists:  [55730, 2733, 12947, 90701, 17185]
# Recommended artist names: ['Kill Memory Crash', 'Annie', 'Yodashe', 'António Variações', 'Earthling']
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids:  ['user_000628' 'user_001000' 'user_000795' 'user_000569' 'user_000397']
# Indices of 5 recommended artists:  [2517, 23610, 12946, 810, 9643]
# Recommended artist names: ['Sugar Ray', 'Copy', 'X-Ray Dog', 'Blur', "The Lovin' Spoonful"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids:  ['user_000397' 'user_000143' 'user_000345' 'user_000043' 'user_000574']
# Indices of 5 recommended artists:  [12750, 12341, 5398, 3967, 93629]
# Recommended artist names: ['Boban Marković Orkestar', 'Sleep', 'John Tejada', 'Yndi Halda', 'Borbetomagus']
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids:  ['user_000243' 'user_000135' 'user_000606' 'user_000585' 'user_000945']
# Indices of 5 recommended artists:  [35707, 10445, 6593, 8712, 72725]
# Recommended artist names: ['The Puppini Sisters', 'Zbigniew Preisner', 'Ramsey Lewis', 'Jean-Jacques Perrey', 'Peter Gelderblom; Renea Amesz; Wally Lopez']
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids:  ['user_000789' 'user_000784' 'user_000376' 'user_000562' 'user_000824']
# Indices of 5 recommended artists:  [3228, 66205, 18707, 46600, 64171]
# Recommended artist names: ['Isobel Campbell', 'Esser', 'Ladyfuzz', 'Nazz', 'Kathy Diamond']
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids:  ['user_000140' 'user_000485' 'user_000295' 'user_000427' 'user_000750']
# Indices of 5 recommended artists:  [1070, 73793, 97902, 6925, 143204]
# Recommended artist names: ['Gorillaz', 'Kora', 'Tspear', 'Heart', 'Dr. Calypso']
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids:  ['user_000761' 'user_000108' 'user_000691' 'user_000393' 'user_000731']
# Indices of 5 recommended artists:  [1994, 142572, 3205, 82201, 49672]
# Recommended artist names: ['Benny Benassi', 'Dj Niel', 'Iced Earth', 'Tom Leach', 'Yip-Yip']
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids:  ['user_000630' 'user_000382' 'user_000491' 'user_000434' 'user_000575']
# Indices of 5 recommended artists:  [91594, 24344, 1092, 49344, 91513]
# Recommended artist names: ['Sub Rosa', 'Between Home And Serenity', 'Hoobastank', 'Michoacan', 'Retardos Le La Mour']
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids:  ['user_000893' 'user_000852' 'user_000382' 'user_000630' 'user_000259']
# Indices of 5 recommended artists:  [106458, 17070, 91616, 3097, 1672]
# Recommended artist names: ['Dakota', 'Benzos', 'The Backup Plan', 'Fountains Of Wayne', 'The Decemberists']
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids:  ['user_000111' 'user_000054' 'user_000047' 'user_000276' 'user_000378']
# Indices of 5 recommended artists:  [30234, 24120, 8574, 7799, 11480]
# Recommended artist names: ['Demis Roussos', 'Denison Witmer', 'Gloria Estefan', 'The Hellacopters', 'Dokken']
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids:  ['user_000575' 'user_000120' 'user_000285' 'user_000729' 'user_000890']
# Indices of 5 recommended artists:  [78407, 101427, 902, 44577, 1345]
# Recommended artist names: ["Punk Goes 90'S", 'Recover', 'Daniel Bedingfield', 'Jake Wilson Featuring Natalie Weiss', 'Ne-Yo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids:  ['user_000257' 'user_000224' 'user_000497' 'user_000789' 'user_000549']
# Indices of 5 recommended artists:  [10218, 33536, 3148, 1747, 24153]
# Recommended artist names: ['Aly & Aj', 'Dj Vini', 'Gotan Project', 'The Pigeon Detectives', 'John Travolta']
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids:  ['user_000729' 'user_000330' 'user_000814' 'user_000145' 'user_000890']
# Indices of 5 recommended artists:  [24247, 4114, 22055, 48733, 154474]
# Recommended artist names: ['Bump Of Chicken', "Bomfunk Mc'S", 'Fightstar', 'A Bird A Sparrow', 'Beverly']
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids:  ['user_000457' 'user_000093' 'user_000051' 'user_000478' 'user_000215']
# Indices of 5 recommended artists:  [13183, 2050, 1537, 13062, 15289]
# Recommended artist names: ['Born Ruffians', 'Cky', 'Silversun Pickups', 'Moptop', '菅野よう子']
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids:  ['user_000702' 'user_000901' 'user_000440' 'user_000381' 'user_000284']
# Indices of 5 recommended artists:  [12176, 164427, 1748, 118306, 132710]
# Recommended artist names: ['Peter Kater', 'Hiro My Hero Feat. Moã\x83Â¯Ra', 'The Pipettes', 'Miraflores', 'Gameface']
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids:  ['user_000873' 'user_000135' 'user_000806' 'user_000077' 'user_000807']
# Indices of 5 recommended artists:  [11774, 3040, 3541, 74181, 1712]
# Recommended artist names: ['Jesse Cook', 'Electric Six', 'Pati Yang', 'Universal Indicator', 'The Kinks']
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids:  ['user_000977' 'user_000897' 'user_000438' 'user_000215' 'user_000147']
# Indices of 5 recommended artists:  [802, 4731, 34133, 7008, 43492]
# Recommended artist names: ['Bing Crosby', 'Steve Lawler', 'Black Affair', 'New Radicals', 'Silver Ginger 5']
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids:  ['user_000715' 'user_000208' 'user_000940' 'user_000706' 'user_000010']
# Indices of 5 recommended artists:  [3474, 1272, 137245, 2309, 137271]
# Recommended artist names: ['Mötley Crüe', 'Madeleine Peyroux', 'Atb Ft. George Acosta', 'Legowelt', 'Cristian Vasile']
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids:  ['user_000606' 'user_000956' 'user_000560' 'user_000873' 'user_000584']
# Indices of 5 recommended artists:  [8566, 6320, 8000, 100257, 161855]
# Recommended artist names: ['Glass Candy', 'Barrington Levy', 'Bedrock', 'Dual Sessions', 'Dj Spooky & Blue Series Continuum']
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids:  ['user_000475' 'user_001000' 'user_000414' 'user_000596' 'user_000993']
# Indices of 5 recommended artists:  [12147, 36675, 76260, 14840, 76275]
# Recommended artist names: ['Paloma', 'Dave Sitek', 'Super Mash Bros.', '500Won Project', 'Wiz Khalifa']
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids:  ['user_000837' 'user_000373' 'user_000351' 'user_000118' 'user_000731']
# Indices of 5 recommended artists:  [10898, 22950, 15113, 7539, 28169]
# Recommended artist names: ['Simple Kid', 'Gravity Kills', 'Ooioo', 'El-P', 'Natalie Cole']
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids:  ['user_000039' 'user_000298' 'user_000849' 'user_000902' 'user_000551']
# Indices of 5 recommended artists:  [164530, 856, 80138, 2670, 1675]
# Recommended artist names: ['Spin.Com And Pete Wentz', 'Chantal Kreviazuk', 'Wyclef Jean Ft. Akon Lil Wayne And Introducing Niia', 'A Flock Of Seagulls', 'The Doors']
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000774' 'user_000229' 'user_000140' 'user_000909']
# Indices of 5 recommended artists:  [35223, 14745, 95177, 109073, 40235]
# Recommended artist names: ['Tim Berne', 'Unkle Bob', 'Eddie The Rat', 'The Almighty Trigger Happy', 'Strategy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids:  ['user_000572' 'user_000454' 'user_000910' 'user_000451' 'user_000249']
# Indices of 5 recommended artists:  [25785, 34586, 45, 10629, 1157]
# Recommended artist names: ['Guido Schneider', 'Richard Devine', 'Barry White', 'Free', 'Jimi Hendrix']
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids:  ['user_000097' 'user_000545' 'user_000294' 'user_000854' 'user_000581']
# Indices of 5 recommended artists:  [39524, 33027, 30238, 12388, 38964]
# Recommended artist names: ['Sir Harry Lauder', 'Mfsb', 'Diana King', 'Stevie Ray Vaughan And Double Trouble', 'Horace Faith']
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids:  ['user_000791' 'user_000520' 'user_000059' 'user_000606' 'user_000837']
# Indices of 5 recommended artists:  [92005, 8909, 106566, 4393, 16636]
# Recommended artist names: ['Llama Farmers', 'Lindsay Lohan', 'Fmb', 'Junior Jack', 'Murray Head']
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000927' 'user_000524' 'user_000188' 'user_000452']
# Indices of 5 recommended artists:  [10120, 2816, 59986, 59984, 1230]
# Recommended artist names: ['Strangers Die Every Day', 'Blonde Redhead', 'Gackt & Chachamaru', 'From Now On', 'Kings Of Leon']
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids:  ['user_000106' 'user_000796' 'user_000036' 'user_000654' 'user_000499']
# Indices of 5 recommended artists:  [93222, 1726, 108534, 6740, 10198]
# Recommended artist names: ["Rin'", 'The Magnetic Fields', 'Robin Mark', 'Johann Pachelbel', 'Morningwood']
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids:  ['user_000361' 'user_000089' 'user_000467' 'user_000345' 'user_000620']
# Indices of 5 recommended artists:  [3797, 1758, 1625, 14689, 11518]
# Recommended artist names: ['The Field Mice', 'The Pussycat Dolls', 'The All-American Rejects', 'The The', 'Eddie Vedder']
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids:  ['user_000650' 'user_000393' 'user_000565' 'user_000986' 'user_000108']
# Indices of 5 recommended artists:  [123613, 11389, 916, 2739, 1231]
# Recommended artist names: ['_Algol_', 'Christian Kjellvander', 'David Kitt', 'Apollo 440', 'Klee']
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids:  ['user_000136' 'user_000870' 'user_000593' 'user_000914' 'user_000704']
# Indices of 5 recommended artists:  [117143, 23723, 19523, 123805, 807]
# Recommended artist names: ['Langhorns', 'Symarip', 'The Lounge Lizards', 'Solar X', 'Blues Traveler']
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids:  ['user_000093' 'user_000998' 'user_000779' 'user_000123' 'user_000018']
# Indices of 5 recommended artists:  [17361, 9992, 148627, 44851, 14983]
# Recommended artist names: ['Mark Mothersbaugh', 'His Name Is Alive', 'Queensland Symphony Orchestra', 'The Special Goodness', 'Harry Belafonte']
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids:  ['user_000060' 'user_000345' 'user_000371' 'user_000467' 'user_000086']
# Indices of 5 recommended artists:  [12088, 1072, 773, 2660, 7174]
# Recommended artist names: ['Nanci Griffith', 'Grace Potter And The Nocturnals', 'Bay City Rollers', '!!!', 'Celldweller']
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids:  ['user_000918' 'user_000996' 'user_000920' 'user_000024' 'user_000201']
# Indices of 5 recommended artists:  [14935, 14888, 12094, 8683, 1743]
# Recommended artist names: ['Djet', 'Buggles', 'Nena', 'Isaac Hayes', 'The Perishers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids:  ['user_000866' 'user_000515' 'user_000927' 'user_000503' 'user_000634']
# Indices of 5 recommended artists:  [16181, 8085, 920, 110090, 2378]
# Recommended artist names: ['The Dixie Cups', 'Brigitte Bardot', 'Death From Above 1979', 'Joel Tammik', 'Mirah']
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids:  ['user_000371' 'user_000795' 'user_000628' 'user_000345' 'user_000024']
# Indices of 5 recommended artists:  [76504, 123636, 36925, 86135, 14041]
# Recommended artist names: ['John Foxx And Louis Gordon', 'Hrej!', 'Twerk', 'Beese & Brtschitsch', 'Ivy']
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0081 seconds

# %%
# Count how many times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mapping dictionaries for user/artist to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map user/artist names to indices in the dataframe
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the user-artist matrix (UAM) in sparse format
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# Normalize rows (each row becomes a unit vector for cosine similarity)
UAM = normalize(UAM, norm='l2', axis=1)

# Precompute UAM transpose for efficient cosine similarity calculations
# This avoids repeatedly computing UAM.transpose() within the loop.
UAM_T = UAM.transpose().tocsr()

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

if __name__ == '__main__':
    start_time = time.time()
    num_users = UAM.shape[0]
    
    for u in range(num_users):
        print("Seed user-id:", user_ids[u])
        
        # Retrieve the normalized playcount vector (row) for the current user
        pc_vec = UAM.getrow(u)
        
        # Compute cosine similarity between the seed user and all other users
        # Using the precomputed UAM_T speeds up the dot-product calculation.
        sims = pc_vec.dot(UAM_T)
        
        # Convert the similarity result to COO format to easily access indices and data.
        sims_coo = sims.tocoo()
        
        # Remove self-similarity by filtering out the element where the column index equals the seed user.
        mask = sims_coo.col != u
        neighbor_indices = sims_coo.col[mask]
        neighbor_scores = sims_coo.data[mask]
        
        # Proceed only if there is at least one similar user
        if neighbor_scores.size == 0:
            print("No similar users found for", user_ids[u])
            print('-' * 80)
            continue
        
        # Use argpartition to quickly find indices of top K similarities.
        # For cases where there are fewer than K neighbors, return all.
        if neighbor_scores.size > K:
            top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
            # Sort the top K neighbors in descending order by their similarity scores.
            sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
            top_neighbors = neighbor_indices[top_k_idx][sorted_order]
        else:
            sorted_order = np.argsort(neighbor_scores)[::-1]
            top_neighbors = neighbor_indices[sorted_order]
        
        # Retrieve the actual user IDs for the top K neighbors
        recommended_user_ids = user_ids[top_neighbors]
        print(f"Nearest K={K} neighbors' user-ids:", recommended_user_ids.flatten())
        
        # Get all artist indices listened to by the top K similar users in one vectorized operation.
        # This avoids looping over each neighbor.
        neighbor_rows = UAM[top_neighbors, :]
        neighbor_coo = neighbor_rows.tocoo()
        recommended_artists_idx = np.unique(neighbor_coo.col)
        
        # Remove artists already known to the seed user
        seed_artists = pc_vec.indices
        recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)
        
        # Randomly choose 5 artists (or fewer, if not enough exist) for recommendation
        if recommended_artists_idx.size > 0:
            num_to_select = min(5, recommended_artists_idx.size)
            random_elements = random.sample(list(recommended_artists_idx), num_to_select)
            print(f"Indices of {len(random_elements)} recommended artists:", random_elements)
            rec_artist_names = [artist_ids[i] for i in random_elements]
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
            
        print('-' * 80)
    
    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Indices of 5 recommended artists: [5826, 72140, 50044, 9633, 160647]
# Recommended artist names: ['Sami Koivikko', 'Houdini', 'Александр Ляпин', 'The Karminsky Experience Inc.', 'Giuann Shadai, Daker, Ill Mario']
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Indices of 5 recommended artists: [2447, 6940, 63, 36736, 3369]
# Recommended artist names: ['Quiet Riot', 'Jack Off Jill', 'Björk', 'Cdoass', 'Lush']
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Indices of 5 recommended artists: [1414, 93138, 11969, 93202, 115126]
# Recommended artist names: ['Peter Bjorn And John', 'Antonio De Lucena', 'Macy Gray', 'Maya Filipič', 'A.S.H.A. Vs. Love Decade']
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Indices of 5 recommended artists: [674, 9205, 5362, 43388, 136926]
# Recommended artist names: ['Aaliyah', 'Pet Shop Boys', 'Isolée', 'Trio Mocotó', 'Gucci Soundsystem']
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Indices of 5 recommended artists: [251, 17064, 54034, 38210, 17285]
# Recommended artist names: ['Jamie Lidell', 'Bassbin Twins', 'Atom Heart', 'The Tremeloes', 'Jay Lumen']
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Indices of 5 recommended artists: [696, 2685, 8363, 233, 44036]
# Recommended artist names: ['Alien Ant Farm', 'Afterhours', 'Dj Spooky', 'I Am Robot And Proud', 'Pereza']
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Indices of 5 recommended artists: [2351, 777, 2012, 2459, 3655]
# Recommended artist names: ['Maroon', 'Beginner', 'Bone Thugs-N-Harmony', 'Robyn', "Screamin' Jay Hawkins"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Indices of 5 recommended artists: [17727, 25586, 44784, 775, 5212]
# Recommended artist names: ['A Split-Second', 'Ed Banger Records', 'Compass', 'Beck', 'Ellen Allien']
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Indices of 5 recommended artists: [88144, 59222, 57952, 88349, 3203]
# Recommended artist names: ['Alert', 'Nomans Land', 'Cristina', 'Nikki Sudden & Rowland S. Howard', 'Iamx']
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Indices of 5 recommended artists: [84352, 205, 1675, 90889, 2235]
# Recommended artist names: ['Grems', 'Goldie', 'The Doors', 'Ges-E & Visionary Underground', 'Infected Mushroom']
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Indices of 5 recommended artists: [138668, 2803, 37101, 138631, 138705]
# Recommended artist names: ['Le Quattro Stagioni - Summer, Allegro Non Molto', 'Billy Idol', 'Karen Ramirez', 'Chopin - Complete Edition', 'Spawn']
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Indices of 5 recommended artists: [5037, 130340, 72475, 18660, 5248]
# Recommended artist names: ['Broke', 'Mark Hosler, Steve Fisk & Bob Basanich', 'Csr', 'Khonnor', 'Farben']
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Indices of 5 recommended artists: [37891, 459, 51907, 2489, 15962]
# Recommended artist names: ['John Murphy & David Hughes', 'Red Hot Chili Peppers', 'Xhol Caravan', 'Shiny Toy Guns', 'Ost']
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Indices of 5 recommended artists: [8012, 1414, 45493, 19684, 9413]
# Recommended artist names: ['Best Friends Forever', 'Peter Bjorn And John', 'The Sound Explosion', 'Vanishing', 'Sleeper']
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Indices of 5 recommended artists: [27476, 986, 99529, 12065, 15061]
# Recommended artist names: ['C-Tec', 'Eels', 'Lonnie Youngblood', 'Monster Magnet', 'Lunatic Calm']
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Indices of 5 recommended artists: [936, 15797, 150218, 6991, 14720]
# Recommended artist names: ['Diana Krall', 'Kylie Minogue & Jason Donovan', 'Hello Nurse', 'Mindi Abair', 'Tiny Dancers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Indices of 5 recommended artists: [2209, 14446, 20528, 2969, 166725]
# Recommended artist names: ['Handsome Boy Modeling School', 'The Amps', 'Positive K', 'Danielson', 'Ai Yamamoto']
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Indices of 5 recommended artists: [4051, 3610, 6831, 3200, 173808]
# Recommended artist names: ['Antoine Clamaran', 'Rhapsody Of Fire', 'Bruce Springsteen', 'Husky Rescue', 'Brian Jeffries']
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Indices of 5 recommended artists: [3671, 115810, 804, 11670, 3018]
# Recommended artist names: ['Shearwater', 'Sava', 'Blackmail', 'H-Blockx', 'Dot Allison']
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Indices of 5 recommended artists: [7058, 61176, 5274, 3330, 9171]
# Recommended artist names: ['Skinny Puppy', 'Misanthrop', 'Frédéric Chopin', 'Leonard Cohen', 'Our Lady Peace']
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Indices of 5 recommended artists: [12004, 129935, 122826, 22485, 61496]
# Recommended artist names: ['Martin Simpson', 'Freddi-Henchi & The Soul Setters', 'Custom', 'The Dynamics', 'Bandits Of The Acoustic Revolution']
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Indices of 5 recommended artists: [9990, 111853, 8724, 133012, 17029]
# Recommended artist names: ['Henry Rollins', 'Kristofer Åström & Ronny Eriksson', "Jim O'Rourke", 'Lou Barlow & Rudy Trouve', 'Adrian Orange']
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Indices of 5 recommended artists: [15352, 109983, 110146, 109131, 7010]
# Recommended artist names: ['Amon Amarth', 'Benni Hemm Hemm & Jens Lekman', 'Nacht Plank', 'Eddie Vedder & Cat Power', 'Nightwish']
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Indices of 5 recommended artists: [19315, 10670, 19480, 14318, 9314]
# Recommended artist names: ['Silver Apples', 'Holopaw', 'The Finn Brothers', 'Sambassadeur', 'Rockers Hi-Fi']
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Indices of 5 recommended artists: [19667, 38426, 9002, 26082, 2031]
# Recommended artist names: ['Tweet', 'Wintersun', 'Mel Tormé', 'Lee Dorsey', 'Calvin Harris']
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Indices of 5 recommended artists: [51365, 115719, 685, 51414, 59922]
# Recommended artist names: ['Alonso De Córdoba', 'In The Wake', 'Air Traffic', 'Bertan Karaimer', 'Andy Irvine']
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Indices of 5 recommended artists: [45016, 85872, 70422, 69577, 11507]
# Recommended artist names: ['Steve Schalchlin Demo', 'Coco Bongo', 'Jonathan Peters Ft. Sylver Logan Sharp', 'Angelo Venuto', 'E-Rotic']
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Indices of 5 recommended artists: [90230, 18874, 743, 127643, 2542]
# Recommended artist names: ['Japhia Life', 'Marvin Gaye & Tammi Terrell', 'Art Blakey & James Moody', 'Danger 1Nze', 'The Basement Khemist']
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Indices of 5 recommended artists: [16843, 86423, 86169, 10620, 15127]
# Recommended artist names: ['Jean Grae', 'Rykarda Parasol', 'Cmp Ler 3000 Series', 'Fine Young Cannibals', "Pickin' On Modest Mouse"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Indices of 5 recommended artists: [1723, 16923, 18517, 18214, 3317]
# Recommended artist names: ['The Long Winters', 'Pete Rock & C.L. Smooth', 'Islaja', 'Dr. Kunnakudi Vaidhyanathan', 'Lacuna Coil']
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Indices of 5 recommended artists: [86386, 7577, 63840, 34376, 36737]
# Recommended artist names: ['Pierref', 'Gravediggaz', 'Edith Frost', 'Kippi Kaninus', 'Charalambides']
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Indices of 5 recommended artists: [23976, 133895, 133766, 134456, 3465]
# Recommended artist names: ['Far', 'Chocolat Soundtrack', 'A.T.B. & Wild Strawbbery', '×Åõîâà Êàòÿ', 'My Morning Jacket']
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Indices of 5 recommended artists: [23687, 35799, 173852, 119301, 1003]
# Recommended artist names: ['O.S.T.R.', 'Masala', 'Golden Rock Ballads', 'Hummingbird', 'Eric Clapton']
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Indices of 5 recommended artists: [732, 10093, 36257, 7989, 23423]
# Recommended artist names: ['Antonio Vivaldi', 'Revolting Cocks', 'Intensity', 'Bananarama', 'The Mavericks']
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Indices of 5 recommended artists: [9615, 24815, 15063, 3262, 33664]
# Recommended artist names: ['The Gift Of Gab', 'Technical Itch', 'Maceo Parker', 'Joanna Newsom', 'Litfiba']
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Indices of 5 recommended artists: [1717, 5244, 5079, 682, 3666]
# Recommended artist names: ['The Lemonheads', 'Fairmont', 'Christopher & Raphael Just', 'Aerosmith', 'Shannon Wright']
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Indices of 5 recommended artists: [118400, 763, 75819, 10759, 12783]
# Recommended artist names: ['The Enfields', 'Bad Astronaut', "Mary Lee'S Corvette", 'Levy', 'Dick Dale And His Del-Tones']
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Indices of 5 recommended artists: [148801, 10303, 148766, 10010, 4416]
# Recommended artist names: ['Frailty', 'Hot Rain', 'Detenzya', 'Juliette And The Licks', 'Kyau & Albert']
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Indices of 5 recommended artists: [6955, 78397, 2819, 3425, 154529]
# Recommended artist names: ['Kevin Bloody Wilson', 'Day At The Fair', 'Blood Red Shoes', 'Metallica', 'With Hearts Of Heroes']
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Indices of 5 recommended artists: [13111, 123374, 1343, 13109, 1488]
# Recommended artist names: ['The Mock Turtles', 'Tsjaikovskij', 'Natasha Bedingfield', 'The Mary Onettes', 'Rogue Wave']
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Indices of 5 recommended artists: [122492, 62622, 2544, 3208, 122613]
# Recommended artist names: ['Pitchers', 'Elegy', 'The Black Ghosts', 'Ilya', 'W.O.S.P.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Indices of 5 recommended artists: [17491, 229, 36704, 74186, 28714]
# Recommended artist names: ['Seefeel', 'Holy Fuck', 'Miranda Lee Richards', '䐀攀愀琀栀\u2000昀爀漀洀\u2000䄀戀漀瘀攀\u2000\u3100㤀㜀㤀', 'Ambulance']
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Indices of 5 recommended artists: [19766, 287, 22467, 12031, 929]
# Recommended artist names: ['Zeze', 'Johnny Foreigner', 'Sylvain Chauveau', 'Melvins', 'Der Junge Mit Der Gitarre']
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Indices of 5 recommended artists: [21522, 24685, 17778, 43761, 2836]
# Recommended artist names: ['Madonna Ft. Justin & Timbaland', 'Kalmah', 'Alien Sex Fiend', 'Yearning', 'Brainstorm']
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Indices of 5 recommended artists: [43482, 62716, 677, 111199, 54173]
# Recommended artist names: ['Nightrage', 'Masterplan', 'Ac/Dc', 'Belinda - Utopía - 12', 'Nanowar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Indices of 5 recommended artists: [149227, 59187, 41590, 2190, 43482]
# Recommended artist names: ['Hostility', 'Melechesh', 'Day Of Fire', 'Global Deejays', 'Nightrage']
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Indices of 5 recommended artists: [23986, 11630, 83635, 112243, 172869]
# Recommended artist names: ['Kreator', 'Gillian Welch', 'Khanate', 'Sojorn', 'Wolfbrigade (Ex-Wolfpack)']
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Indices of 5 recommended artists: [10803, 6623, 66234, 31849, 37564]
# Recommended artist names: ['Mr Hudson & The Library', 'Spiller', 'Kids In Glass Houses', 'Pinstripe', 'Acker Bilk']
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Indices of 5 recommended artists: [74143, 29625, 757, 33105, 8182]
# Recommended artist names: ['????? ???? ???? ??????? ????????', 'The Republic Tigers', 'Augustana', 'Quiet Village', 'Ciccone Youth']
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Indices of 5 recommended artists: [8245, 12984, 19435, 21830, 8040]
# Recommended artist names: ['Culture Beat', 'Briskeby', 'The Boomtown Rats', 'The Morning Benders', 'Blue Six']
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Indices of 5 recommended artists: [15245, 1249, 3247, 66219, 2320]
# Recommended artist names: ['The Victorian English Gentlemens Club', 'Leona Naess', 'Jay-Z', 'Haunts', 'Liz Phair']
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Indices of 5 recommended artists: [23534, 1758, 45531, 59184, 2364]
# Recommended artist names: ['Zebrahead', 'The Pussycat Dolls', 'Dissection', 'Maladaptive', 'Mew']
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Indices of 5 recommended artists: [72597, 145159, 90223, 77230, 145209]
# Recommended artist names: ['Shotgun Start', 'James Purify', 'Frank Marino', 'Demon', 'Nitebreed']
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Indices of 5 recommended artists: [54180, 668, 73963, 62557, 4763]
# Recommended artist names: ['Sud Sound System', '4 Non Blondes', 'Lemmy, Slim Jim & Danny B', 'Byzantine', 'Tears For Fears']
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Indices of 5 recommended artists: [853, 706, 24253, 21644, 1250]
# Recommended artist names: ['Cat Stevens', 'American Hi-Fi', 'Chris Martin Of Coldplay', 'Dj Format', 'Less Than Jake']
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Indices of 5 recommended artists: [22925, 4642, 1326, 12025, 7045]
# Recommended artist names: ['Freaking', 'Rmb', 'Mott The Hoople', 'Mediæval Bæbes', 'Samael']
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Indices of 5 recommended artists: [69444, 1015, 115106, 22055, 6607]
# Recommended artist names: ['Jessica Mauboy', 'Face To Face', 'Dino Velvet', 'Fightstar', 'Sammie']
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Indices of 5 recommended artists: [155971, 104006, 2937, 33352, 1305]
# Recommended artist names: ['Cortez', 'Noel Gallagher, Gem Archer & Stereophonics', 'Cocteau Twins', 'Christophe Beck', 'Megapuss']
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Indices of 5 recommended artists: [26668, 17729, 15551, 86497, 1329]
# Recommended artist names: ['Sense', 'A.B.Perspectives', 'Don Davis', 'Tim Kearne', 'Murder By Death']
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Indices of 5 recommended artists: [19328, 17760, 19689, 18597, 840]
# Recommended artist names: ["Skip Jensen & His Shakin' Feet", 'Al Foul', 'Vegan Reich', 'John Scofield', 'Caesars']
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Indices of 5 recommended artists: [106067, 71168, 70666, 31205, 169323]
# Recommended artist names: ['Streetplayer Feat Raychel', 'Sanober Kabir', 'M1M1', 'Erin Mccarley', '2Pac Ft. Clay Aiken, Rl, Foxy Brown, Joe Budden & Mr. Mister']
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Indices of 5 recommended artists: [1695, 9260, 1830, 19903, 24258]
# Recommended artist names: ['The Get Up Kids', 'Pérez Prado', 'Tom Petty And The Heartbreakers', 'Therion', 'Divinity']
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Indices of 5 recommended artists: [31619, 59369, 99429, 60092, 11804]
# Recommended artist names: ['Maya Azucena', 'Bagman', 'Buckethead / George S. Clinton', 'Sixto Sounds & Zircon', 'John Renbourn']
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Indices of 5 recommended artists: [36359, 38588, 1499, 3573, 8698]
# Recommended artist names: ['Humanwine', 'Boz Scaggs', 'Ryan Adams', 'Primal Scream', "Jane'S Addiction"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Indices of 5 recommended artists: [719, 104231, 55576, 42988, 1950]
# Recommended artist names: ['Ani Difranco', 'Joe Mason', 'Jerry Beeks', 'Latin Lounge', 'Alice Deejay']
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Indices of 5 recommended artists: [120914, 1032, 121013, 121275, 40808]
# Recommended artist names: ['Beatforge Presents', 'Foo Fighters', 'Dj_Bg', 'Ues', 'Tri-Star']
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Indices of 5 recommended artists: [10562, 145562, 664, 145493, 145448]
# Recommended artist names: ['Cold', 'Party Pimpz Feat Mc Miker G & Dj Sven', '3 Doors Down', 'Gadjo Feat Alexandra Prince', 'Dj Tatana Feat Morris']
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Indices of 5 recommended artists: [767, 164132, 1097, 11226, 2429]
# Recommended artist names: ['Badly Drawn Boy', 'To Be Able To Love', 'Hot Club De Paris', 'Asia', 'Peaches']
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Indices of 5 recommended artists: [153, 54507, 17952, 9367, 23362]
# Recommended artist names: ['Donny Hathaway', 'Bonnie And Sheila', 'Bobby Byrd', 'Secret Machines', 'Spineshank']
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Indices of 5 recommended artists: [4969, 23900, 632, 2983, 36692]
# Recommended artist names: ['Arab Strap', 'Voice', '[Unknown]', 'Dead Can Dance', 'Karen O']
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Indices of 5 recommended artists: [14041, 7115, 1306, 2150, 10912]
# Recommended artist names: ['Ivy', 'Vnv Nation', 'Meredith Brooks', 'Everclear', 'Sons And Daughters']
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Indices of 5 recommended artists: [1251, 99727, 89627, 12710, 10417]
# Recommended artist names: ['Lez Zeppelin', 'Emmy Rossum', 'Japanese Flute', 'Raudive', 'The Pointer Sisters']
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Indices of 5 recommended artists: [19783, 7272, 106776, 22124, 99385]
# Recommended artist names: ['Буготак', 'Hyper', 'Luke Envoy', 'Bright Eyes/Neva Dinova', '8 Mile Soundtrack - 50 Cent']
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Indices of 5 recommended artists: [19372, 152, 35568, 95416, 11630]
# Recommended artist names: ['Steve Wynn', 'Donald Byrd', 'Anita Harris', 'Vincent Knobil', 'Gillian Welch']
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Indices of 5 recommended artists: [11978, 11259, 2359, 3567, 11145]
# Recommended artist names: ['Majesty', 'Barry Dransfield', 'Megadeth', 'Poe', '2002']
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Indices of 5 recommended artists: [73906, 1131, 2370, 150666, 24022]
# Recommended artist names: ['Veer', 'Jamie Cullum', 'Midnight Juggernauts', 'Free Fall', 'The Whites']
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Indices of 5 recommended artists: [686, 35715, 18985, 7322, 11929]
# Recommended artist names: ['Al Green', 'Bazaar', 'Napalm Death', 'Mos Def', 'Lisa Gerrard']
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Indices of 5 recommended artists: [6723, 2133, 17196, 1101, 28230]
# Recommended artist names: ['Flipsyde', 'Eiffel 65', 'Elite Force', 'Howie Day', 'Aromabar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Indices of 5 recommended artists: [160737, 12903, 19813, 68176, 124273]
# Recommended artist names: ['Tim Armstrong + Asia Argento', 'Soda Stereo', '王菲', 'Vegas', 'Altro']
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Indices of 5 recommended artists: [18094, 25075, 6998, 1236, 10748]
# Recommended artist names: ['Cobra Killer', 'Andreas Ammer & F.M. Einheit', 'Mudvayne', 'Kylie Minogue', 'Kula Shaker']
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Indices of 5 recommended artists: [1510, 2177, 38450, 1081, 3247]
# Recommended artist names: ['Sarah Mclachlan', 'Freezepop', 'Aimee Mann & Michael Penn', 'Guster', 'Jay-Z']
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Indices of 5 recommended artists: [7995, 118370, 36584, 39346, 10962]
# Recommended artist names: ['Beach House', 'Simon Paul', 'The 4-Skins', 'Paper Dolls', 'The Blood Arm']
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Indices of 5 recommended artists: [12846, 17372, 34892, 10912, 24270]
# Recommended artist names: ['Lauryn Hill', 'Mellowdrone', 'Reid Paley', 'Sons And Daughters', 'I:Cube']
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Indices of 5 recommended artists: [301, 10544, 20396, 3895, 47687]
# Recommended artist names: ['Kelis', 'Carrie Underwood', '佐藤直紀', 'Tori Amos', 'The Cookies']
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Indices of 5 recommended artists: [18213, 2716, 118570, 3094, 118557]
# Recommended artist names: ['Dr. Alimantado', 'Anathema', "Lightnin' Rod", 'Flowers From The Man Who Shot Your Cousin', 'Ilona']
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Indices of 5 recommended artists: [86254, 717, 17786, 68539, 5443]
# Recommended artist names: ['Homer & Jethro', 'Angels & Airwaves', 'Amherst Saxophone Quartet', 'Dj6', 'Kiki']
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Indices of 5 recommended artists: [120838, 7231, 15484, 12268, 10472]
# Recommended artist names: ['Ebbe Nilsson', 'Dragonforce', 'Celtic Frost', 'Running Wild', 'Alex Party']
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Indices of 5 recommended artists: [2778, 1968, 94863, 137404, 28441]
# Recommended artist names: ['Barış Manço', 'Anti-Flag', 'Sinebag', 'The Thomas Crown Affair', 'Lunascape']
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Indices of 5 recommended artists: [24241, 8312, 42987, 19318, 18275]
# Recommended artist names: ['B12', 'Detroit Grand Pubahs', 'Lassigue Bendthaus', 'Sinsemilia', 'Eva Ayllón']
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Indices of 5 recommended artists: [11857, 19915, 786, 1000, 3565]
# Recommended artist names: ['Kathryn Tickell', 'X Japan', 'Ben Kweller', 'Embrace', 'Pj Harvey']
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Indices of 5 recommended artists: [11464, 150660, 13175, 115385, 135291]
# Recommended artist names: ['Diana Ross', 'Fraet', 'Black Flag', 'Balsam', 'Andrzej Kurylewicz']
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Indices of 5 recommended artists: [14468, 83943, 78353, 913, 3819]
# Recommended artist names: ['The Billie Burke Estate', 'Cihan Akerson', 'Wc And The Maad Circle', 'David Ford', 'The Lightning Seeds']
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Indices of 5 recommended artists: [22377, 3492, 6735, 727, 28229]
# Recommended artist names: ['No Kids', 'Neon Neon', 'Jack White & Alicia Keys', 'Antonio Banderas', 'Army Of Me']
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Indices of 5 recommended artists: [6306, 10166, 66055, 99592, 10018]
# Recommended artist names: ['Alicia Keys', 'Ulver', 'Vvaa', 'Sunna', 'Kittie']
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Indices of 5 recommended artists: [27391, 7473, 3638, 43769, 87693]
# Recommended artist names: ['3Oh!3', 'Caravan', 'Santogold', 'Adrian Belew', 'Belle Ame']
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Indices of 5 recommended artists: [42383, 11938, 3597, 30154, 9554]
# Recommended artist names: ["Monty Python'S Spamalot", 'Little Willie John', 'Rammstein', 'Żywiołak', 'The Andrews Sisters']
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Indices of 5 recommended artists: [6494, 25243, 21147, 138200, 79163]
# Recommended artist names: ['Koffi Olomidé', 'Buckshot Lefonque', 'Paradise', 'Various - Classic Rock, Mains', 'Beaut']
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Indices of 5 recommended artists: [761, 1412, 1489, 661, 992]
# Recommended artist names: ['Babyshambles', 'Pete Townshend', 'Ron Sexsmith', '...But Alive', 'Ella Fitzgerald']
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Indices of 5 recommended artists: [66703, 3315, 46839, 1290, 804]
# Recommended artist names: ['The Power-Chords', 'Laakso', 'The Kid', 'Maroon 5', 'Blackmail']
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids: ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Indices of 5 recommended artists: [14795, 3810, 4354, 8207, 1058]
# Recommended artist names: ['Butterfly Boucher & David Bowie', 'The Hidden Cameras', 'India.Arie', 'Common', 'Gary Jules']
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids: ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Indices of 5 recommended artists: [1394, 2606, 767, 898, 12840]
# Recommended artist names: ['Paolo Nutini', 'Tool', 'Badly Drawn Boy', 'Cyndi Lauper', 'Juno Reactor']
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids: ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Indices of 5 recommended artists: [11145, 12308, 18130, 19354, 723]
# Recommended artist names: ['2002', 'Secret Garden', "D'Angelo, Femi Kuti + Macy Gray", 'Sort Sol', 'Anna Ternheim']
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids: ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Indices of 5 recommended artists: [919, 1939, 7989, 1069, 14417]
# Recommended artist names: ['Death Cab For Cutie', 'Afi', 'Bananarama', 'Good Shoes', 'Tales Of Jenny']
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Indices of 5 recommended artists: [12067, 1288, 1033, 59139, 15352]
# Recommended artist names: ['Mor Ve Ötesi', 'Mark Knopfler', "Fool'S Garden", 'Ikuinen Kaamos', 'Amon Amarth']
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Indices of 5 recommended artists: [36643, 47452, 51746, 3185, 16594]
# Recommended artist names: ['Nev', 'Moviola', 'Pedro Laurenz', 'Her Space Holiday', 'Cleptomaniacs & Bryan Chambers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Indices of 5 recommended artists: [17331, 34536, 3941, 36841, 34343]
# Recommended artist names: ['Lole Y Manuel', 'Phil Ranelin', 'Wax Poetic', 'Ctrlaltdelete', 'Jme']
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids: ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Indices of 5 recommended artists: [91631, 16365, 162666, 91545, 3372]
# Recommended artist names: ['The Distance', 'Bettie Serveert', 'Thomas T.', 'Seasick', 'M83']
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids: ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Indices of 5 recommended artists: [95562, 15170, 7038, 6331, 1384]
# Recommended artist names: ['Joegh9', 'Silverstein', 'Rick Astley', 'Boney James', 'Olspur']
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids: ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Indices of 5 recommended artists: [16669, 1062, 31717, 1594, 61]
# Recommended artist names: ['We The Kings', 'Get Cape. Wear Cape. Fly', 'National Pornographic', 'Supergrass', 'Billy Joel']
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Indices of 5 recommended artists: [26126, 3797, 12868, 31662, 9671]
# Recommended artist names: ['Looptroop Rockers', 'The Field Mice', 'Missy Elliott', 'Misha', 'The Replacements']
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Indices of 5 recommended artists: [94795, 32983, 165387, 172780, 2316]
# Recommended artist names: ['Oil', 'Living Blues', 'The Woodbox Gang', 'The Riot Rockers', 'Link Wray']
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids: ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Indices of 5 recommended artists: [99711, 12955, 17584, 88610, 17370]
# Recommended artist names: ['Toka Project', 'Кочани Оркестар', 'The Sound', 'Universal Trilogy', 'Medicine']
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids: ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Indices of 5 recommended artists: [24956, 24716, 684, 23880, 24841]
# Recommended artist names: ['Шевчук', 'Mendeed', 'Air', 'Tarja Turunen', 'The Watchmen (Ost)']
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids: ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Indices of 5 recommended artists: [7163, 12459, 123775, 567, 9066]
# Recommended artist names: ['Black Sun Empire', 'The Funky Lowlives', 'Myslowitz & Robert Gawliñski', 'The Isley Brothers', 'Moving Fusion']
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids: ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Indices of 5 recommended artists: [24862, 16518, 11935, 6844, 23798]
# Recommended artist names: ['Working Man', 'Roadrunner United', 'Lit', 'Collective Soul', 'Filthy Kids']
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids: ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Indices of 5 recommended artists: [12941, 40486, 3839, 128785, 6902]
# Recommended artist names: ["Void'S Anatomy", 'Har-El', 'The Radio Dept.', 'Gareth Clarke', 'Flesh Field']
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids: ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Indices of 5 recommended artists: [17855, 9978, 349, 12340, 65136]
# Recommended artist names: ['Avail', 'Golden Death Music', 'Lusine Icl', 'Slayer', 'Chaos A.D.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids: ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Indices of 5 recommended artists: [1555, 33573, 91569, 4654, 10198]
# Recommended artist names: ['Sophie B. Hawkins', 'Gabriele Monici', 'Skeptics', 'Roxette', 'Morningwood']
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids: ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Indices of 5 recommended artists: [2475, 59021, 686, 28880, 2003]
# Recommended artist names: ['Sean Paul', 'Berliner Philharmoniker & Karl Böhm', 'Al Green', 'Decadence', 'Black Sabbath']
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids: ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Indices of 5 recommended artists: [162663, 27843, 36033, 3683, 5527]
# Recommended artist names: ['The Specs', 'Sandy', 'The Working Title', 'Sleater-Kinney', 'Magnet']
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids: ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Indices of 5 recommended artists: [1167, 19709, 19065, 46736, 1913]
# Recommended artist names: ['John Legend', 'Wall Of Voodoo', 'Ozomatli', 'Celebrate The Nun', 'Émilie Simon']
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Indices of 5 recommended artists: [8376, 157917, 8375, 12607, 2334]
# Recommended artist names: ['Do Make Say Think', 'Superman Revenge Squad', 'Dntel', 'Vienna Teng', 'Lykke Li']
# --------------------------------------------------------------------------------
# Seed user-id: user_000123
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000998' 'user_000018' 'user_000779' 'user_000486']
# Indices of 5 recommended artists: [47175, 8002, 2088, 148455, 1032]
# ...
# Recommended artist names: ['Mateo', 'Amanaska', 'Brother Ali', 'Willie Dixon', 'Chenoa']
# --------------------------------------------------------------------------------
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Indices of 5 recommended artists: [1199, 27215, 28453, 15179, 64574]
# Recommended artist names: ['Justin Timberlake', 'D!O', 'Marumari', 'Spaceways Inc. [Vandermark - Mcbride - Drake]', 'Richard Chartier']
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids: ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Indices of 5 recommended artists: [79285, 34972, 26121, 11914, 137781]
# Recommended artist names: ['Luydmilla Zukena; Marc Almond', 'Anthony Braxton', 'London Philharmonic Orchestra', 'Leo Kottke', 'Glen Velez & Javier Paxariño']
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids: ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Indices of 5 recommended artists: [18407, 17755, 12031, 125053, 13083]
# Recommended artist names: ['Good Noise Bad Noise', 'Airiel', 'Melvins', 'Mark Ronson Feat. The Daptone Horns', 'Portugal. The Man']
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids: ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Indices of 5 recommended artists: [10804, 2315, 63659, 79765, 8091]
# Recommended artist names: ['Mr.S', 'Lindstrøm', 'Chalk', 'Tracy Vierra', 'Broken Social Scene Presents: Brendan Canning']
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids: ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Indices of 5 recommended artists: [21368, 10842, 12079, 32746, 6694]
# Recommended artist names: ['Underground Resistance', 'Planet Bliss', 'Music From The World Of Osho', 'Dave Dobbyn', 'Birdy Nam Nam']
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids: ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Indices of 5 recommended artists: [891, 8207, 2816, 1166, 1009]
# Recommended artist names: ['Creedence Clearwater Revisited', 'Common', 'Blonde Redhead', 'John Frusciante', 'Eva Cassidy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids: ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Indices of 5 recommended artists: [15162, 16503, 48716, 10328, 35464]
# Recommended artist names: ['Scumbo', 'Pat Metheny', 'Influx', 'Maria Peszek', 'Papa M']
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Indices of 5 recommended artists: [7084, 47480, 1455, 47582, 23676]
# Recommended artist names: ['The Human League', 'Nik Carlson', 'Ray Lamontagne', 'Rrr', 'Mc Solaar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Indices of 5 recommended artists: [13866, 36685, 1277, 149667, 1320]
# Recommended artist names: ['Crocodiles', 'Grizzly Bear + Feist', 'Mando Diao', 'Cops And Robbers', 'Modest Mouse']
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Indices of 5 recommended artists: [56114, 97604, 2846, 124109, 18093]
# Recommended artist names: ['Monty Alexander', 'Nizag Chag', 'Broadcast', 'Ekho', 'Cls & Wax']
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Indices of 5 recommended artists: [145957, 29431, 813, 41684, 10713]
# Recommended artist names: ['Dj_Dano_&_Liza_N_Eliaz', 'The Braves', 'Bobby Hutcherson', 'Gain Fast', 'Johnny Kidd & The Pirates']
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Indices of 5 recommended artists: [53286, 10563, 11097, 91459, 9803]
# Recommended artist names: ['Goldblade', 'Comets On Fire', 'Transglobal Underground', 'Moros Eros', 'Vcr']
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Indices of 5 recommended artists: [7088, 61963, 33272, 13407, 2422]
# Recommended artist names: ['The Outfield', 'The Brokedowns', 'Voicst', "Ryan'S Hope", 'Paramore']
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Indices of 5 recommended artists: [42554, 6569, 22846, 48885, 78180]
# Recommended artist names: ['Partisans', 'P. Diddy', 'Dr. Hook', 'Musica Antiqua', 'P.J. Proby']
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Indices of 5 recommended artists: [44623, 2058, 2487, 1076, 162659]
# Recommended artist names: ['Paris Green', 'Cream', 'Shaun Baker', 'Green Day', 'Score By Bill Conti']
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Indices of 5 recommended artists: [5798, 1690, 3825, 3858, 993]
# Recommended artist names: ['Ricky Martin', 'The Fratellis', 'The Monkees', 'The Ting Tings', 'Ella Fitzgerald & Louis Armstrong']
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Indices of 5 recommended artists: [8925, 10095, 104801, 38961, 1603]
# Recommended artist names: ['Longwave', 'Robert Schumann', 'Nujabes Feat. Five Deez', 'Holly Palmer', 'T. Rex']
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Indices of 5 recommended artists: [1081, 20426, 25290, 250, 2418]
# Recommended artist names: ['Guster', '朝倉紀行', "Cassettes Won'T Listen", 'James Brown', 'Panic! At The Disco']
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Indices of 5 recommended artists: [82184, 77475, 60160, 15286, 17907]
# Recommended artist names: ['The Waifs', 'Willie Nelson & Wynton Marsalis', 'Natalia Y La Forquetina', 'Արամ Խաչատրյան', 'Betty Wright']
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Indices of 5 recommended artists: [103399, 47369, 78, 10170, 540]
# Recommended artist names: ['Terra Nine', 'Lord Runningclam', 'Boom Boom Satellites', 'Urban Myth Club', 'Sun Ra']
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Indices of 5 recommended artists: [10007, 1366, 3609, 1994, 45726]
# Recommended artist names: ['Jon Brion', 'No Doubt', 'Rex The Dog', 'Benny Benassi', 'Grouper']
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Indices of 5 recommended artists: [63380, 7383, 17934, 14967, 3726]
# Recommended artist names: ['Umberloid', 'Svenson & Gielen', 'Blake Baxter', 'Gia Farrell', 'Suzanne Vega']
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Indices of 5 recommended artists: [3452, 63438, 1349, 118762, 7424]
# Recommended artist names: ['Moonspell', 'Accidental Heroes', 'Nelly Furtado', 'Sound Foundation', 'Anton Maiden']
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Indices of 5 recommended artists: [1773, 32285, 40750, 13889, 105051]
# Recommended artist names: ['The Shins', 'The Muslims', 'Soul Avengerz', 'Department Of Eagles', 'Frank Sticks']
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Indices of 5 recommended artists: [1242, 11679, 978, 25620, 25187]
# Recommended artist names: ['Lcd Soundsystem', 'Hans Zimmer', 'Eagle-Eye Cherry', 'Elzhi', 'Black Milk']
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Indices of 5 recommended artists: [79935, 4648, 3731, 3038, 1323]
# Recommended artist names: ['Jarabe De Palo Y Jorge Drexler', 'Roll Deep', 'Syd Matters', 'Elastica', 'Moloko']
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Indices of 5 recommended artists: [35171, 9285, 41587, 38962, 7275]
# Recommended artist names: ['Pierre Schaeffer', 'Real Life', 'Dave Navarro', 'Hollywood Porn Stars', 'Infernal']
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Indices of 5 recommended artists: [4168, 18074, 20541, 26097, 101929]
# Recommended artist names: ['Culture Club', 'Circle Jerks', 'Subway', 'Lightheaded', 'Manuvers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Indices of 5 recommended artists: [39164, 60117, 12248, 79183, 2991]
# Recommended artist names: ['Linda Carr & The Love Squad', 'The Boondock Saints Soundtrack', 'Robert Cray', 'Chimeres', 'Del Amitri']
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Indices of 5 recommended artists: [1708, 19115, 9144, 17115, 13929]
# Recommended artist names: ['The Jesus And Mary Chain', 'Planet Of The Stereos', 'Npr', 'Cirrus', 'Eugenius']
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Indices of 5 recommended artists: [30573, 12686, 99372, 565, 14929]
# Recommended artist names: ['Yö', '浜崎あゆみ', '! Www.Polskie-Mp3.Tk ! Sweet N', 'The Herbaliser', 'Dirty Three']
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Indices of 5 recommended artists: [108382, 11784, 126286, 9793, 8605]
# Recommended artist names: ['A Winters Tale', 'Joan Osborne', 'Carlin', 'Ulrich Schnauss', 'Harold Faltermeyer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Indices of 5 recommended artists: [53269, 19572, 7513, 4309, 1142]
# Recommended artist names: ['Fonda 500', 'The Soft Pink Truth', 'Dead Prez', 'Front Line Assembly', 'Jason Mraz']
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Indices of 5 recommended artists: [41835, 173335, 1832, 1552, 1352]
# Recommended artist names: ['Nomataras', 'Spirallianz', 'Tom Waits', 'Someone Still Loves You Boris Yeltsin', 'New Found Glory']
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Indices of 5 recommended artists: [11692, 21603, 18141, 19456, 161555]
# Recommended artist names: ['Hawkwind', 'Bobby Helms', 'Daniel Johnston', 'The Dave Brubeck Quartet', 'Jay-Z Feat Mary J Blige']
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Indices of 5 recommended artists: [11212, 173808, 1436, 2741, 686]
# Recommended artist names: ['Antiloop', 'Brian Jeffries', 'Portishead & Moloko', 'Apparat', 'Al Green']
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Indices of 5 recommended artists: [11997, 12179, 1250, 9593, 18759]
# Recommended artist names: ['Maria Mena', 'Peter Von Poehl', 'Less Than Jake', 'The Ditty Bops', 'Liliput']
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Indices of 5 recommended artists: [15222, 3227, 9007, 2903, 4435]
# Recommended artist names: ['The Hush Now', 'Isis', 'Men At Work', 'Cher', 'Lionel Richie']
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Indices of 5 recommended artists: [1980, 23725, 2931, 23816, 99591]
# Recommended artist names: ['Avenged Sevenfold', 'Tapping The Vein', 'Clor', 'Il Divo', 'Starcraft Soundtrack']
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Indices of 5 recommended artists: [8913, 8120, 10008, 12953, 11334]
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0008 seconds

# %%
#Batch Version
from concurrent.futures import ThreadPoolExecutor, as_completed
BATCH_SIZE = 8 
# Build User-Artist Matrix (UAM)
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

UAM = normalize(UAM, norm='l2', axis=1)

user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

UAM_T = UAM.transpose().tocsr()

num_users = UAM.shape[0]

# --- Function to process a single batch ---
def process_batch(batch_start, batch_end):
    batch_users = np.arange(batch_start, batch_end)

    pc_mat = UAM[batch_users, :]
    sim_mat = pc_mat.dot(UAM_T).toarray()

    batch_results = []

    for idx_in_batch, u in enumerate(batch_users):
        sim_vec = sim_mat[idx_in_batch]
        sim_vec[u] = 0  # Remove self-similarity

        neighbor_indices = np.where(sim_vec > 0)[0]
        neighbor_scores = sim_vec[neighbor_indices]

        if neighbor_scores.size == 0:
            batch_results.append((user_ids[u], None, None))
            continue

        if neighbor_scores.size > K:
            top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
            sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
            top_neighbors = neighbor_indices[top_k_idx][sorted_order]
        else:
            sorted_order = np.argsort(neighbor_scores)[::-1]
            top_neighbors = neighbor_indices[sorted_order]

        recommended_user_ids = user_ids[top_neighbors]

        neighbor_rows = UAM[top_neighbors, :]
        neighbor_coo = neighbor_rows.tocoo()
        recommended_artists_idx = np.unique(neighbor_coo.col)

        seed_artists = UAM.getrow(u).indices
        recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)

        if recommended_artists_idx.size > 0:
            num_to_select = min(5, recommended_artists_idx.size)
            random_elements = random.sample(list(recommended_artists_idx), num_to_select)
            rec_artist_names = [artist_ids[i] for i in random_elements]
            batch_results.append((user_ids[u], recommended_user_ids, rec_artist_names))
        else:
            batch_results.append((user_ids[u], recommended_user_ids, None))

    return batch_results

# --- Main Program ---
if __name__ == '__main__':
    start_time = time.time()

    # Create batches
    batches = [(i, min(i+BATCH_SIZE, num_users)) for i in range(0, num_users, BATCH_SIZE)]

    all_results = []

    # Sequentially process each batch
    for batch_start, batch_end in batches:
        batch_result = process_batch(batch_start, batch_end)
        all_results.extend(batch_result)

    # Print results
    for res in all_results:
        seed_user, neighbors, rec_artists = res
        print("Seed user-id:", seed_user)
        if neighbors is None:
            print("No similar users found for", seed_user)
            print('-' * 80)
            continue
        print(f"Nearest K={K} neighbors' user-ids:", neighbors.flatten())
        if rec_artists is not None:
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
        print('-' * 80)

    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids: ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids: ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids: ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids: ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids: ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids: ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids: ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids: ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids: ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids: ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids: ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids: ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids: ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids: ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids: ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids: ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids: ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000123
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000998' 'user_000018' 'user_000779' 'user_000486']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000124
# Nearest K=5 neighbors' user-ids: ['user_000233' 'user_000479' 'user_000610' 'user_000765' 'user_000613']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000125
# Nearest K=5 neighbors' user-ids: ['user_000771' 'user_000405' 'user_000482' 'user_000665' 'user_000040']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000126
# Nearest K=5 neighbors' user-ids: ['user_000420' 'user_000668' 'user_000058' 'user_000665' 'user_000120']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000127
# Nearest K=5 neighbors' user-ids: ['user_000774' 'user_000510' 'user_000341' 'user_000595' 'user_000886']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000128
# Nearest K=5 neighbors' user-ids: ['user_000856' 'user_000622' 'user_000421' 'user_000336' 'user_000131']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000129
# Nearest K=5 neighbors' user-ids: ['user_000948' 'user_000336' 'user_000497' 'user_000918' 'user_000234']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000130
# Nearest K=5 neighbors' user-ids: ['user_000305' 'user_000594' 'user_000222' 'user_000607' 'user_000783']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000131
# Nearest K=5 neighbors' user-ids: ['user_000089' 'user_000336' 'user_000467' 'user_000345' 'user_000856']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000132
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000134' 'user_000056' 'user_000225' 'user_000535']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000133
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000233' 'user_000467' 'user_000050' 'user_000124']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000134
# Nearest K=5 neighbors' user-ids: ['user_000225' 'user_000535' 'user_000198' 'user_000413' 'user_000347']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000135
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000077' 'user_000177' 'user_000763' 'user_000584']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000136
# Nearest K=5 neighbors' user-ids: ['user_000995' 'user_000034' 'user_000089' 'user_000910' 'user_000345']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000137
# Nearest K=5 neighbors' user-ids: ['user_000263' 'user_000018' 'user_000093' 'user_000658' 'user_000996']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000138
# Nearest K=5 neighbors' user-ids: ['user_000227' 'user_000013' 'user_000348' 'user_000188' 'user_000341']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000139
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000624' 'user_000683' 'user_000658' 'user_000327']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000140
# Nearest K=5 neighbors' user-ids: ['user_000986' 'user_000995' 'user_000083' 'user_000017' 'user_000393']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000141
# Nearest K=5 neighbors' user-ids: ['user_000852' 'user_000216' 'user_000458' 'user_000984' 'user_000916']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000142
# Nearest K=5 neighbors' user-ids: ['user_000507' 'user_000173' 'user_000776' 'user_000354' 'user_000426']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000143
# Nearest K=5 neighbors' user-ids: ['user_000513' 'user_000345' 'user_000384' 'user_000031' 'user_000726']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000144
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000961' 'user_000190' 'user_000710' 'user_000263']
# ...
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000953
# Nearest K=5 neighbors' user-ids: ['user_000715' 'user_000741' 'user_000291' 'user_000705' 'user_000637']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000954
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000319' 'user_000242' 'user_000403' 'user_000024']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000955
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000529' 'user_000031' 'user_000242']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000956
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000560' 'user_000606' 'user_000584' 'user_000078']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000957
# Nearest K=5 neighbors' user-ids: ['user_000611' 'user_000173' 'user_000442' 'user_000395' 'user_000230']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000958
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000393' 'user_000274' 'user_000490' 'user_000753']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000959
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000342' 'user_000613' 'user_000437' 'user_000771']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids: ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids: ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids: ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids: ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids: ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids: ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0006 seconds

# %%
#Thread
from concurrent.futures import ThreadPoolExecutor, as_completed
MAX_WORKERS = 8
# Build User-Artist Matrix (UAM)
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

UAM = normalize(UAM, norm='l2', axis=1)

user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

UAM_T = UAM.transpose().tocsr()

num_users = UAM.shape[0]

# --- Define function to process a single user ---
def process_single_user(u):
    pc_vec = UAM.getrow(u)
    sims = pc_vec.dot(UAM_T)
    sims_coo = sims.tocoo()
    
    mask = sims_coo.col != u
    neighbor_indices = sims_coo.col[mask]
    neighbor_scores = sims_coo.data[mask]
    
    if neighbor_scores.size == 0:
        return (user_ids[u], None, None)

    if neighbor_scores.size > K:
        top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
        sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
        top_neighbors = neighbor_indices[top_k_idx][sorted_order]
    else:
        sorted_order = np.argsort(neighbor_scores)[::-1]
        top_neighbors = neighbor_indices[sorted_order]

    recommended_user_ids = user_ids[top_neighbors]

    neighbor_rows = UAM[top_neighbors, :]
    neighbor_coo = neighbor_rows.tocoo()
    recommended_artists_idx = np.unique(neighbor_coo.col)

    seed_artists = UAM.getrow(u).indices
    recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)

    if recommended_artists_idx.size > 0:
        num_to_select = min(5, recommended_artists_idx.size)
        random_elements = random.sample(list(recommended_artists_idx), num_to_select)
        rec_artist_names = [artist_ids[i] for i in random_elements]
        return (user_ids[u], recommended_user_ids, rec_artist_names)
    else:
        return (user_ids[u], recommended_user_ids, None)

# --- Main Program ---
if __name__ == '__main__':
    start_time = time.time()

    all_results = []

    # Use ThreadPoolExecutor to process all users in parallel
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(process_single_user, u) for u in range(num_users)]
        for future in as_completed(futures):
            res = future.result()
            all_results.append(res)

    # Print all results
    for res in all_results:
        seed_user, neighbors, rec_artists = res
        print("Seed user-id:", seed_user)
        if neighbors is None:
            print("No similar users found for", seed_user)
            print('-' * 80)
            continue
        print(f"Nearest K={K} neighbors' user-ids:", neighbors.flatten())
        if rec_artists is not None:
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
        print('-' * 80)

    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids: ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids: ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids: ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids: ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids: ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids: ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids: ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids: ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids: ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids: ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids: ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids: ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids: ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids: ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids: ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids: ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids: ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000124
# Nearest K=5 neighbors' user-ids: ['user_000233' 'user_000479' 'user_000610' 'user_000765' 'user_000613']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000123
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000998' 'user_000018' 'user_000779' 'user_000486']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000125
# Nearest K=5 neighbors' user-ids: ['user_000771' 'user_000405' 'user_000482' 'user_000665' 'user_000040']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000126
# Nearest K=5 neighbors' user-ids: ['user_000420' 'user_000668' 'user_000058' 'user_000665' 'user_000120']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000128
# Nearest K=5 neighbors' user-ids: ['user_000856' 'user_000622' 'user_000421' 'user_000336' 'user_000131']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000127
# Nearest K=5 neighbors' user-ids: ['user_000774' 'user_000510' 'user_000341' 'user_000595' 'user_000886']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000129
# Nearest K=5 neighbors' user-ids: ['user_000948' 'user_000336' 'user_000497' 'user_000918' 'user_000234']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000130
# Nearest K=5 neighbors' user-ids: ['user_000305' 'user_000594' 'user_000222' 'user_000607' 'user_000783']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000132
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000134' 'user_000056' 'user_000225' 'user_000535']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000131
# Nearest K=5 neighbors' user-ids: ['user_000089' 'user_000336' 'user_000467' 'user_000345' 'user_000856']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000133
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000233' 'user_000467' 'user_000050' 'user_000124']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000134
# Nearest K=5 neighbors' user-ids: ['user_000225' 'user_000535' 'user_000198' 'user_000413' 'user_000347']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000135
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000077' 'user_000177' 'user_000763' 'user_000584']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000136
# Nearest K=5 neighbors' user-ids: ['user_000995' 'user_000034' 'user_000089' 'user_000910' 'user_000345']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000137
# Nearest K=5 neighbors' user-ids: ['user_000263' 'user_000018' 'user_000093' 'user_000658' 'user_000996']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000139
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000624' 'user_000683' 'user_000658' 'user_000327']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000138
# Nearest K=5 neighbors' user-ids: ['user_000227' 'user_000013' 'user_000348' 'user_000188' 'user_000341']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000141
# Nearest K=5 neighbors' user-ids: ['user_000852' 'user_000216' 'user_000458' 'user_000984' 'user_000916']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000142
# Nearest K=5 neighbors' user-ids: ['user_000507' 'user_000173' 'user_000776' 'user_000354' 'user_000426']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000144
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000961' 'user_000190' 'user_000710' 'user_000263']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000140
# Nearest K=5 neighbors' user-ids: ['user_000986' 'user_000995' 'user_000083' 'user_000017' 'user_000393']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000143
# Nearest K=5 neighbors' user-ids: ['user_000513' 'user_000345' 'user_000384' 'user_000031' 'user_000726']
# ...
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000952
# Nearest K=5 neighbors' user-ids: ['user_000498' 'user_000453' 'user_000780' 'user_000711' 'user_000291']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000954
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000319' 'user_000242' 'user_000403' 'user_000024']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000955
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000529' 'user_000031' 'user_000242']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000956
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000560' 'user_000606' 'user_000584' 'user_000078']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000958
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000393' 'user_000274' 'user_000490' 'user_000753']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000957
# Nearest K=5 neighbors' user-ids: ['user_000611' 'user_000173' 'user_000442' 'user_000395' 'user_000230']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000959
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000342' 'user_000613' 'user_000437' 'user_000771']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids: ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids: ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids: ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids: ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids: ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids: ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Recommended artist names: ['Lionel Hampton', 'Cal Tjader', 'Julee Cruise', 'Владимир Давидович Ашкенази', 'Brian Setzer']
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0008 seconds
