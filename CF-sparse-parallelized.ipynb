# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/dingmeiying/miniconda3/envs/mrs/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.15.2-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: joblib>=1.2.0 in /Users/dingmeiying/miniconda3/envs/mrs/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl (11.1 MB)
# Using cached scipy-1.15.2-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Successfully installed scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0

# %%
import pandas as pd
from scipy.sparse import csr_matrix
import numpy as np
import random
import time 
from sklearn.preprocessing import normalize
from multiprocessing import Pool, cpu_count

# %%
K = 5

file_path = "lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv"

# Load interaction log
interactions = pd.read_csv(file_path, sep="\t", header=None,
                           names=["user_id", "timestamp", "artist_id", "artist_name", "track_id", "track_name"], on_bad_lines='skip')

# %%
# Count how many times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mapping dictionaries for user/artist to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map user/artist names to indices in the dataframe
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the user-artist matrix (UAM) in sparse format
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# Normalize rows (each row becomes a unit vector for cosine similarity)
UAM = normalize(UAM, norm='l2', axis=1)

# Precompute UAM transpose for efficient cosine similarity calculations
# This avoids repeatedly computing UAM.transpose() within the loop.
UAM_T = UAM.transpose().tocsr()

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

if __name__ == '__main__':
    start_time = time.time()
    num_users = UAM.shape[0]
    
    for u in range(num_users):
        print("Seed user-id:", user_ids[u])
        
        # Retrieve the normalized playcount vector (row) for the current user
        pc_vec = UAM.getrow(u)
        
        # Compute cosine similarity between the seed user and all other users
        # Using the precomputed UAM_T speeds up the dot-product calculation.
        sims = pc_vec.dot(UAM_T)
        
        # Convert the similarity result to COO format to easily access indices and data.
        sims_coo = sims.tocoo()
        
        # Remove self-similarity by filtering out the element where the column index equals the seed user.
        mask = sims_coo.col != u
        neighbor_indices = sims_coo.col[mask]
        neighbor_scores = sims_coo.data[mask]
        
        # Proceed only if there is at least one similar user
        if neighbor_scores.size == 0:
            print("No similar users found for", user_ids[u])
            print('-' * 80)
            continue
        
        # Use argpartition to quickly find indices of top K similarities.
        # For cases where there are fewer than K neighbors, return all.
        if neighbor_scores.size > K:
            top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
            # Sort the top K neighbors in descending order by their similarity scores.
            sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
            top_neighbors = neighbor_indices[top_k_idx][sorted_order]
        else:
            sorted_order = np.argsort(neighbor_scores)[::-1]
            top_neighbors = neighbor_indices[sorted_order]
        
        # Retrieve the actual user IDs for the top K neighbors
        recommended_user_ids = user_ids[top_neighbors]
        print(f"Nearest K={K} neighbors' user-ids:", recommended_user_ids.flatten())
        
        # Get all artist indices listened to by the top K similar users in one vectorized operation.
        # This avoids looping over each neighbor.
        neighbor_rows = UAM[top_neighbors, :]
        neighbor_coo = neighbor_rows.tocoo()
        recommended_artists_idx = np.unique(neighbor_coo.col)
        
        # Remove artists already known to the seed user
        seed_artists = pc_vec.indices
        recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)
        
        # Randomly choose 5 artists (or fewer, if not enough exist) for recommendation
        if recommended_artists_idx.size > 0:
            num_to_select = min(5, recommended_artists_idx.size)
            random_elements = random.sample(list(recommended_artists_idx), num_to_select)
            print(f"Indices of {len(random_elements)} recommended artists:", random_elements)
            rec_artist_names = [artist_ids[i] for i in random_elements]
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
            
        print('-' * 80)
    
    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Indices of 5 recommended artists: [5607, 14960, 9597, 6915, 17584]
# Recommended artist names: ['Mitchell Akiyama', 'Fridge', 'The Dust Brothers', 'Girls Under Glass', 'The Sound']
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Indices of 5 recommended artists: [217, 122063, 6856, 72335, 13541]
# Recommended artist names: ['Hefner', 'Ida Corr Vs Fedde Le Grand + Camilla Jones Vs Fedde Le Grand', 'Daughtry', 'Larrinkin Love', 'The Ponys']
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Indices of 5 recommended artists: [115222, 50403, 115189, 1313, 3990]
# Recommended artist names: ['Hi Jack', 'The Potbelleez', 'Dj Self & Puerta-Rock', 'Michael Jackson', 'いきものがかり']
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Indices of 5 recommended artists: [14960, 12926, 5600, 95464, 95528]
# Recommended artist names: ['Fridge', 'The Temptations', 'Ministry Of Sound', 'Aste-Maan', 'Fab G.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Indices of 5 recommended artists: [1608, 24315, 38162, 25289, 120887]
# Recommended artist names: ["Tapes 'N Tapes", 'Symbion Project', 'The Brian Setzer Orchestra', 'Cass Elliot', 'Aly-Us']
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Indices of 5 recommended artists: [1239, 21333, 1311, 23722, 17535]
# Recommended artist names: ['Lars Winnerbäck', 'The Eternals', 'Michael Cera & Ellen Page', 'Suprême Ntm', 'Tanga']
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Indices of 5 recommended artists: [10089, 1767, 26782, 46105, 45009]
# Recommended artist names: ['Rasputina', 'The Rolling Stones', 'Statik Selektah', 'Hannah Montana', 'Scent']
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Indices of 5 recommended artists: [59583, 90513, 59772, 17337, 3672]
# Recommended artist names: ['Cosmic Gate Feat. Roxanne Emery', 'Jence', 'Mr. Pit Feat. Vicky Fee', 'Los Lobos', 'Shitdisco']
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Indices of 5 recommended artists: [43751, 43707, 17977, 88490, 31975]
# Recommended artist names: ['The Dreamside', 'Dakrua', 'Brian Eno & David Byrne', 'Zsd', 'Sanctus Real']
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Indices of 5 recommended artists: [90851, 2296, 145487, 84505, 39552]
# Recommended artist names: ['Burufunk', 'Krazy Baldhead', 'Evolve', 'True Faith', 'Steam']
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Indices of 5 recommended artists: [2467, 138614, 12800, 78845, 51893]
# Recommended artist names: ['Sasha', 'Aks', 'Fc Kahuna', 'Orient Team', 'Vidna Obmana']
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Indices of 5 recommended artists: [17985, 14395, 50856, 19605, 115577]
# Recommended artist names: ['Bud Powell', 'Stephen Malkmus And The Jicks', 'Birdie', 'The Young Gods', 'The Cannanes With Steward']
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Indices of 5 recommended artists: [16456, 51393, 19632, 193, 13054]
# Recommended artist names: ['Klaus Schulze', 'Ayni Mahallenin Cocuklari', 'Tomaso Giovanni Albinoni', 'Gabin', 'Mazhar Alanson']
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Indices of 5 recommended artists: [165159, 101094, 8290, 12481, 1098]
# Recommended artist names: ['Major Parkinson', 'Belasana', 'Dead Or Alive', 'The New Amsterdams', 'Hot Hot Heat']
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Indices of 5 recommended artists: [59869, 58543, 36051, 3504, 17408]
# Recommended artist names: ['The Doppler Effect', 'Stranger & Patsy', 'Zeropage', 'Nina Simone', 'Noir']
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Indices of 5 recommended artists: [21683, 3619, 6031, 3474, 19682]
# Recommended artist names: ['Jennifer Rush', 'Robin Thicke', 'Tonic', 'Mötley Crüe', 'Vanessa Paradis']
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Indices of 5 recommended artists: [137136, 34943, 137083, 13296, 1109]
# Recommended artist names: ['Javed Ali & Sonu Nigam', 'Wild T And The Spirit', 'Bony Chakravarthy', 'Joe Strummer & The Mescaleros', 'Ian Brown']
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Indices of 5 recommended artists: [776, 3806, 13185, 14720, 1752]
# Recommended artist names: ['Bedouin Soundclash', 'The Grates', 'Brian Reitzell & Roger J. Manning Jr', 'Tiny Dancers', 'The Postal Service']
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Indices of 5 recommended artists: [12205, 1120, 12101, 100829, 100862]
# Recommended artist names: ['Primal Fear', 'Islands', 'Nick Cave And Warren Ellis', 'Andy Morris', 'Jacqueline Du Pré']
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Indices of 5 recommended artists: [13253, 8008, 15935, 16585, 2446]
# Recommended artist names: ['Franklin', 'Berlin', 'Nickel Eye', 'Aqua', 'Queen']
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Indices of 5 recommended artists: [13653, 133326, 129725, 124965, 130648]
# Recommended artist names: ['Aerospace', 'In The 11Th House', 'Chubby Parker & His Old Time Banjo', 'Fiebre', 'Rickolus']
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Indices of 5 recommended artists: [45829, 17254, 115396, 7473, 4282]
# Recommended artist names: ['Pre', 'Harvey Williams', 'Blast Off Country Style', 'Caravan', 'Europe']
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Indices of 5 recommended artists: [9106, 88899, 1628, 15425, 26475]
# Recommended artist names: ['Neneh Cherry', 'Penny Lan Band', 'The Ark', 'Billy Ocean', 'Pete Namlook']
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Indices of 5 recommended artists: [10858, 839, 77578, 1061, 3231]
# Recommended artist names: ['Recliner', 'Béla Fleck And The Flecktones', 'Outcasts', 'Georgie Fame', 'J Dilla']
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Indices of 5 recommended artists: [38336, 57581, 1092, 1698, 2813]
# Recommended artist names: ['Kaija Koo', 'Ian Carey', 'Hoobastank', 'The Good, The Bad & The Queen', 'Blackalicious']
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Indices of 5 recommended artists: [26299, 3275, 60007, 1647, 51685]
# Recommended artist names: ['Minsk', 'Kaki King', 'Intronaut', 'The Breeders', 'Mert Icgören']
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Indices of 5 recommended artists: [9760, 22584, 125900, 69909, 16322]
# Recommended artist names: ['Tony Bennett', 'Ago', 'Saxsymbol Feat. Lex Express', 'Dario Nunez & David Vio Featuring Stella', 'Yvonne Elliman']
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Indices of 5 recommended artists: [1134, 127564, 6870, 127565, 59543]
# Recommended artist names: ['Jamiroquai', '50 Cent W/ Diddy & Jay-Z', 'Dimmu Borgir', '57Th St. Rdvs', 'Balearic Bill']
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Indices of 5 recommended artists: [42810, 12407, 136880, 51846, 15851]
# Recommended artist names: ['Eliades Ochoa', 'T-Bone Walker Quintet', 'Antlerland', 'The Butterfly Effect', 'Luther Vandross']
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Indices of 5 recommended artists: [12676, 90513, 95666, 2005, 19187]
# Recommended artist names: ['Дмитрий Дмитриевич Шостакович', 'Jence', 'Scorp', 'Bloodhound Gang', 'Renft']
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Indices of 5 recommended artists: [20182, 86117, 42702, 3719, 43001]
# Recommended artist names: ['Nick Cave & Pj Harvey', 'Anis', 'Burnt Friedman & Jaki Liebezeit', 'Sugababes', 'Lisa Ono']
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Indices of 5 recommended artists: [3849, 20704, 10107, 62573, 1086]
# Recommended artist names: ['The Spinto Band', 'Cyrus', 'Scarling.', 'Claudio Cordero', 'Hard-Fi']
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Indices of 5 recommended artists: [60124, 10436, 1727, 60014, 3051]
# Recommended artist names: ['Tides', 'White Zombie', 'The Mars Volta', 'Jorg', 'Emilíana Torrini']
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Indices of 5 recommended artists: [17227, 11195, 19800, 1016, 18609]
# Recommended artist names: ['Gal Costa', 'Amethystium', 'Цезарь Антонович Кюи', 'Faith No More', 'Jon Marsh']
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Indices of 5 recommended artists: [55885, 5146, 42764, 3186, 3753]
# Recommended artist names: ['London Posse', 'Delon & Dalcan', 'Decoder', 'Hercules And Love Affair', 'The Baby Namboos']
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Indices of 5 recommended artists: [14191, 17687, 1565, 27117, 1068]
# Recommended artist names: ['My Latest Novel', 'Prince Jazzbo', 'Spoon', 'Will.I.Am', 'Good Charlotte']
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Indices of 5 recommended artists: [62716, 28152, 51010, 19831, 41845]
# Recommended artist names: ['Masterplan', 'Eric Burdon And The Animals', 'The Fucking Champs', 'Briskey', 'Owsley']
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Indices of 5 recommended artists: [148921, 1127, 3331, 148936, 27552]
# Recommended artist names: ['Sheezzanova Feat. Mc Messiah', "Jack'S Mannequin", 'Les Savy Fav', 'Streicher', 'Dust Of Basement - Gift']
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Indices of 5 recommended artists: [2403, 1303, 11128, 1672, 12335]
# Recommended artist names: ['O-Zone', 'Mazzy Star', 'Whitley', 'The Decemberists', 'Skid Row']
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Indices of 5 recommended artists: [11488, 11893, 34724, 11025, 14720]
# Recommended artist names: ['Dorian', "L'Arc~En~Ciel", 'Venus Hum', 'The Lucksmiths', 'Tiny Dancers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Indices of 5 recommended artists: [18345, 122217, 85499, 122436, 2797]
# Recommended artist names: ['Fred Frith', 'B. Connor', 'Cycle Sphere', 'Matthew Dekay Band', 'Beth Orton']
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Indices of 5 recommended artists: [123029, 58083, 1378, 7658, 15258]
# Recommended artist names: ['The Beatnigs', 'Fukkk Offf', 'Of Montreal', 'Looptroop', 'Ugly Casanova']
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Indices of 5 recommended artists: [37163, 86228, 18148, 74603, 3699]
# Recommended artist names: ['Nil', 'Funky 4 + 1', 'Dave Berry', 'Dream Forest', 'Sparklehorse']
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Indices of 5 recommended artists: [170, 75597, 24857, 7259, 17817]
# Recommended artist names: ['Ennio Morricone', 'Bandas Sonoras', 'Vision Divine', 'Godsmack', 'Antiworld']
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Indices of 5 recommended artists: [4608, 28666, 6828, 1221, 11617]
# Recommended artist names: ['Prince', 'Will Young', 'Bon Jovi', 'Kelly Clarkson', 'G3']
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Indices of 5 recommended artists: [33365, 8030, 11226, 37355, 104474]
# Recommended artist names: ['Hair Police', 'Black Mountain', 'Asia', 'Deadlock', 'Gpkism']
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Indices of 5 recommended artists: [15470, 123887, 37875, 172442, 146137]
# Recommended artist names: ['Burning Witch', 'Crumbsuckers', 'Jimmie Davis', 'Kyle Wooten', 'Loveparade 2008']
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Indices of 5 recommended artists: [12926, 9169, 9636, 60444, 9171]
# Recommended artist names: ['The Temptations', 'Oscar Peterson', 'The Klf', 'Fat And Frantic', 'Our Lady Peace']
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Indices of 5 recommended artists: [381, 3231, 19705, 10596, 3493]
# Recommended artist names: ['Mika', 'J Dilla', 'Von Iva', 'Earl Grant', 'New Order']
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Indices of 5 recommended artists: [22457, 11710, 19605, 8562, 6308]
# Recommended artist names: ['Spillsbury', 'Hood', 'The Young Gods', 'Gilberto Gil', 'Amel Larrieux']
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Indices of 5 recommended artists: [19515, 3245, 34572, 11126, 10451]
# Recommended artist names: ['The Juliana Hatfield Three', 'Jay Reatard', 'Radioclit', 'White Denim', '1990S']
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Indices of 5 recommended artists: [46810, 12577, 59299, 1605, 12806]
# Recommended artist names: ['Operation Phoenix', 'Twisted Sister', 'The Great Kat', 'Taking Back Sunday', 'Georg Friedrich Händel']
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Indices of 5 recommended artists: [33337, 80497, 291, 34506, 49180]
# Recommended artist names: ['Shyne', 'Leisure-B & The Hidden Master', 'José Padilla', 'Ochre', 'Greg Street']
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Indices of 5 recommended artists: [33283, 16401, 10584, 3472, 3128]
# Recommended artist names: ['Womack & Womack', 'Demons & Wizards', 'Dizzee Rascal', 'Mägo De Oz', 'Ghostface Killah']
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Indices of 5 recommended artists: [27085, 10083, 33055, 11143, 45722]
# Recommended artist names: ['Vikter Duplaix', 'Prong', 'Nrbq', '10,000 Maniacs', 'Graham Parker']
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Indices of 5 recommended artists: [221, 46187, 22559, 22921, 23680]
# Recommended artist names: ['Henry Mancini', 'Karoline Krüger', '1200 Micrograms', 'For Love Not Lisa', 'Moby & Public Enemy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Indices of 5 recommended artists: [24602, 1941, 1889, 45019, 7209]
# Recommended artist names: ['Die Apokalyptischen Reiter', 'Against Me!', 'Wolfgang Amadeus Mozart', 'Sunfreakz Feat. Andrea Britton', 'Disco Blu']
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Indices of 5 recommended artists: [1308, 146952, 25129, 18717, 2452]
# Recommended artist names: ['Mgmt', 'Bright Eyes Britt Daniel', 'Autor', 'Last Days Of April', 'Ravi Shankar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Indices of 5 recommended artists: [4162, 21689, 157879, 10158, 10056]
# Recommended artist names: ['Cosmic Gate', 'Jorge Drexler', 'Jude Law', 'This Will Destroy You', 'My Life With The Thrill Kill Kult']
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Indices of 5 recommended artists: [4668, 19284, 19186, 5851, 2016]
# Recommended artist names: ['Sarah Brightman', 'Sema', 'Renato Carosone', 'Señor Coconut', 'Boys Like Girls']
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Indices of 5 recommended artists: [301, 50548, 48029, 69644, 2414]
# Recommended artist names: ['Kelis', 'Franco De Vita', 'Álex Ubago', 'Bad Yard Club', 'Ozzy Osbourne']
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Indices of 5 recommended artists: [19635, 86182, 18593, 1322, 18438]
# Recommended artist names: ['Tommy Mccook & The Supersonics', 'Dave Blackledge', 'John Mclaughlin Trio', 'Mojave 3', 'Hans Albers & Heinz Rühmann']
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Indices of 5 recommended artists: [137106, 40329, 3042, 1329, 17157]
# Recommended artist names: ['Elder Charles Beck', 'Borknagar', 'Elisa', 'Murder By Death', 'Dilatazione']
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Indices of 5 recommended artists: [28989, 44681, 8831, 1570, 57499]
# Recommended artist names: ['Haysi Fantayzee', 'Judee Sill', 'Komeda', 'Stacie Orrico', 'Billy May & His Orchestra']
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Indices of 5 recommended artists: [811, 42621, 94130, 3944, 9632]
# Recommended artist names: ['Bob Dylan', 'Alexis Weissenberg', 'David Morales & Lea-Lorién', 'White Magic', 'The Juan Maclean']
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Indices of 5 recommended artists: [120929, 93474, 1722, 47553, 4059]
# Recommended artist names: ['Boozoo Bajou Featuring Wayne Martin', 'Michelle Walker', 'The Long Blondes', 'Raiden', 'Armand Van Helden']
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Indices of 5 recommended artists: [145531, 44747, 69412, 126955, 145532]
# Recommended artist names: ['Loto Feat. Aiga', 'Notch Feat. Pitbull', 'The Roc Project Feat. Tina Area', 'Провода', 'Love Sensualty Devotion- The G']
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Indices of 5 recommended artists: [13102, 585, 18924, 3597, 163703]
# Recommended artist names: ['The Brian Jonestown Massacre', 'Thomas Newman', 'Minimal Compact', 'Rammstein', 'Beyonce Vs Dsico']
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Indices of 5 recommended artists: [76255, 11362, 62185, 6933, 4454]
# Recommended artist names: ['Shawn Wigs & Ghostface Killah', 'Cee-Lo', 'The Opposites', 'In Strict Confidence', 'Madcon']
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Indices of 5 recommended artists: [120475, 444, 1202, 18135, 156005]
# Recommended artist names: ['The Nova Saints', 'Pop Levi', 'Kaiser Chiefs', 'Dahmane El Harrachi', 'Tiny Masters Of Today (Css Remix)']
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Indices of 5 recommended artists: [109890, 2472, 59399, 93259, 5516]
# Recommended artist names: ['No Doubt, Reel Big Fish And Save Ferris', 'Scooter', 'Rihanna Ft. Chris Brown', 'Rodan', 'Luomo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Indices of 5 recommended artists: [2259, 30712, 8511, 738, 1424]
# Recommended artist names: ['Johann Sebastian Bach', 'Belinda', 'Frankmusik', 'Arcade Fire', 'Phoenix']
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Indices of 5 recommended artists: [19960, 577, 36305, 23699, 16193]
# Recommended artist names: ['Blood', 'The Underwolves', 'Baby Dee', 'Pmmp', 'The Hooters']
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Indices of 5 recommended artists: [75069, 2048, 7853, 19171, 30623]
# Recommended artist names: ['Breeder', 'Circa Survive', 'Zircon', 'Rapeman', 'I Am Jen']
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Indices of 5 recommended artists: [959, 10772, 10627, 24083, 4669]
# Recommended artist names: ['Dispatch', 'Lucie Silvas', 'Frankie Lymon & The Teenagers', 'Behemoth', 'Sarah Vaughan']
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Indices of 5 recommended artists: [123661, 2797, 1773, 63858, 150823]
# Recommended artist names: ['Načeva', 'Beth Orton', 'The Shins', 'Eno - Moebius - Roedelius - Plank', 'Marcin Nowakowski']
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Indices of 5 recommended artists: [24320, 15218, 15254, 19706, 1889]
# Recommended artist names: ['Transparent Sound', 'The High Llamas', 'Trespassers William', 'Voo Voo', 'Wolfgang Amadeus Mozart']
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Indices of 5 recommended artists: [12809, 1337, 12665, 9295, 23642]
# Recommended artist names: ['Gustav Holst', 'Naked Raygun', 'Zwan', 'Richard "Groove" Holmes', 'Izrael']
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Indices of 5 recommended artists: [66859, 34082, 34058, 26408, 12332]
# Recommended artist names: ['Koninklijk Concertgebouworkest', 'Airlock', '24.Umek', 'Oddisee', 'Simone White']
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Indices of 5 recommended artists: [948, 16800, 87740, 19660, 9236]
# Recommended artist names: ['Die Toten Hosen', 'Fabolous', 'Criminal Class', 'Tryo', 'Pop Will Eat Itself']
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Indices of 5 recommended artists: [11472, 1435, 12177, 103506, 15121]
# Recommended artist names: ['Dion', 'Portishead', 'Peter Sarstedt', 'Avatar', 'Pela']
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Indices of 5 recommended artists: [7424, 118271, 11582, 8288, 7756]
# Recommended artist names: ['Anton Maiden', 'Konflit Dramatik', 'Fela Kuti', 'De-Phazz', 'Sepultura']
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Indices of 5 recommended artists: [1259, 10654, 1294, 41995, 5956]
# Recommended artist names: ['Living Things', 'Goldspot', 'Mat Kearney', 'The Star Aliance Feat. Shiela Ferguson', 'Teddybears']
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Indices of 5 recommended artists: [1929, 1316, 1010, 13027, 43852]
# Recommended artist names: ['A Static Lullaby', 'Milburn', 'Evanescence', 'High And Mighty Color', 'David Tort']
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Indices of 5 recommended artists: [42462, 2683, 1879, 2140, 6891]
# Recommended artist names: ['Usta Bilizowane', 'Adult.', 'Wham!', 'Eminem', 'Evans Blue']
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Indices of 5 recommended artists: [65606, 8006, 10752, 86136, 15581]
# Recommended artist names: ['The Cosmic Jokers', 'Benny Goodman', 'Layo & Bushwacka!', 'Behrouz', 'Envy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Indices of 5 recommended artists: [6948, 7658, 2737, 96888, 42059]
# Recommended artist names: ['Journey', 'Looptroop', 'Antique', 'Windham Hill Artists - Best Of Carols Of Christmas 1', 'Akon & Eminem']
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Indices of 5 recommended artists: [18653, 10604, 66015, 11285, 15561]
# Recommended artist names: ['Keshco', 'Elvis Costello & The Attractions', 'The Moving Sidewalks', 'Billy May', 'East 17']
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Indices of 5 recommended artists: [10885, 17305, 31625, 15158, 18328]
# Recommended artist names: ['Scott Matthews', 'Katerine', 'Meiko', 'Scientist', 'Foltin']
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Indices of 5 recommended artists: [64361, 8615, 1296, 996, 2323]
# Recommended artist names: ['Miracle Fortress', 'Headman', 'Matisyahu', 'Elton John', 'Lo-Fi-Fnk']
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Indices of 5 recommended artists: [16066, 34080, 34297, 151020, 34587]
# Recommended artist names: ['Sammy Davis Jr.', 'Aguayo/Rossknecht', 'Hello Eskimo Or Polyhedric Mu', 'Storm And Stress', 'Richard Dworsky']
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Indices of 5 recommended artists: [132489, 1589, 14508, 15033, 2624]
# Recommended artist names: ['Ex Reverie', 'Sufjan Stevens', 'The Electric Pop Group', 'Jurassic 5', 'Ustad Sultan Khan']
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Indices of 5 recommended artists: [12691, 8082, 824, 1473, 14041]
# Recommended artist names: ['Antony', 'Brian Eno', 'Brenda Lee', 'Rilo Kiley', 'Ivy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Indices of 5 recommended artists: [15962, 2071, 74241, 1631, 23976]
# Recommended artist names: ['Ost', 'Danzel', 'Dandy', 'The Ataris', 'Far']
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Indices of 5 recommended artists: [11907, 137061, 18687, 550, 38350]
# Recommended artist names: ['Lead Belly', 'Ali Leroi', 'Kohai', 'Talvin Singh', 'Lisa "Left Eye" Lopes']
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Indices of 5 recommended artists: [30624, 107948, 12629, 18601, 42461]
# Recommended artist names: ['Ill Mitch', 'Dan Gardopee', 'Willie Nelson', 'Johnny Clarke', 'Tryp']
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Indices of 5 recommended artists: [79303, 8977, 11180, 137988, 124719]
# Recommended artist names: ['New Order & Pet Shop Boys', 'Martin Denny', 'Albert King', 'Ortiga', 'Coverville']
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Indices of 5 recommended artists: [1134, 1036, 976, 2675, 1586]
# Recommended artist names: ['Jamiroquai', 'Fotos', 'Dynamite Deluxe', 'A-Ha', 'Streetlight Manifesto']
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Indices of 5 recommended artists: [1250, 10866, 3010, 113148, 7755]
# Recommended artist names: ['Less Than Jake', 'Robert Palmer', 'Disturbed', "The Arre Panda'S", 'Sentenced']
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids: ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Indices of 5 recommended artists: [39659, 49943, 4176, 17659, 90069]
# Recommended artist names: ['The Floaters', 'Strangers With Candy', 'D12', 'Here We Go Magic', 'John Mcmartin, Company']
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids: ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Indices of 5 recommended artists: [75440, 9254, 10941, 2765, 34408]
# Recommended artist names: ['Dave Grohl', 'Propellerheads', 'Terry Callier', 'B.B. King', 'Machine Drum']
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids: ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Indices of 5 recommended artists: [11076, 3124, 1334, 14576, 11029]
# Recommended artist names: ['The Upsetters', 'Georg Philipp Telemann', 'Mystery Jets', 'The Litter', 'The Milestone Corporation']
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids: ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Indices of 5 recommended artists: [17546, 15647, 6645, 15842, 767]
# Recommended artist names: ['The Clean', 'Giovanni Battista Pergolesi', 'The Notorious B.I.G.', 'Lou Bega', 'Badly Drawn Boy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Indices of 5 recommended artists: [59331, 1777, 111076, 24512, 59288]
# Recommended artist names: ['Vreid', 'The Smiths', 'Paghania', 'An Albatross', 'Tarabas']
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Indices of 5 recommended artists: [21857, 3730, 12065, 12455, 57455]
# Recommended artist names: ['Yoav', 'Switches', 'Monster Magnet', 'The Elders', 'Ricardo Arjona']
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Indices of 5 recommended artists: [158559, 3130, 1394, 22639, 29828]
# Recommended artist names: ['James M', 'Ghosts', 'Paolo Nutini', 'Barbra Streisand', 'Audio Lotion']
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids: ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Indices of 5 recommended artists: [8082, 91502, 79094, 91440, 61702]
# Recommended artist names: ['Brian Eno', 'Praise Of Folly', 'The Sunstreak', 'Man Alive', 'Hit The Switch']
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids: ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Indices of 5 recommended artists: [37413, 6823, 122536, 8281, 9051]
# Recommended artist names: ['Kazik Na Żywo', 'Black Lung', "Scape Feat. D'Empress", 'David Lindup', 'Mobius Band']
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids: ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Indices of 5 recommended artists: [11156, 10667, 2025, 892, 1511]
# Recommended artist names: ['Abra Moore', 'Hell Is For Heroes', 'Butthole Surfers', 'Creedence Clearwater Revival', 'Savage Garden']
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Indices of 5 recommended artists: [9661, 765, 38333, 3273, 12877]
# Recommended artist names: ['The Olivia Tremor Control', 'Bad Religion', 'Joh N Legend', 'Junior Senior', 'Nuspirit Helsinki']
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Indices of 5 recommended artists: [11224, 800, 12244, 2380, 74863]
# Recommended artist names: ['Arthur Brown', 'Billie Holiday', 'Ritchie Valens', 'Misfits', 'Les Paul & Mary Ford']
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids: ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Indices of 5 recommended artists: [86267, 1303, 221, 166419, 19151]
# Recommended artist names: ['In Vitro', 'Mazzy Star', 'Henry Mancini', 'Phutura', 'Quarteto Em Cy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids: ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Indices of 5 recommended artists: [6909, 43729, 18503, 24533, 24496]
# Recommended artist names: ['Funker Vogt', 'May I Cry', 'Icehouse', 'Between The Buried And Me', 'Abeyance']
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids: ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Indices of 5 recommended artists: [7431, 3521, 16435, 118716, 158555]
# Recommended artist names: ['Arsonists', 'Onerepublic', 'Gojira', 'Bill Bourne & Shannon Johnson', 'Inputjunkie/Catfactory']
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids: ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Indices of 5 recommended artists: [24770, 22037, 12665, 24548, 1365]
# Recommended artist names: ['Rfe/Rl Inc.', 'Пикник', 'Zwan', 'Budapest Symphony Orchestra', 'Nirvana']
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids: ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Indices of 5 recommended artists: [92158, 13223, 1423, 28229, 2233]
# Recommended artist names: ['The Burning Paris', 'Dead To Me', 'Phish', 'Army Of Me', 'Iio']
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids: ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Indices of 5 recommended artists: [97878, 891, 46816, 91853, 1336]
# Recommended artist names: ['Thomas Mapfumo', 'Creedence Clearwater Revisited', 'Point 7', 'Pedrito', 'Nada Surf']
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids: ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Indices of 5 recommended artists: [126199, 10838, 8084, 775, 37143]
# Recommended artist names: ['Kage', 'Pete Murray', 'Brian Wilson', 'Beck', 'N.A.S.A.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids: ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Indices of 5 recommended artists: [19823, 24560, 2999, 10856, 59265]
# Recommended artist names: ['Altaria', 'Cephalic Carnage', 'Deus', 'Racoon', 'Shieldwall']
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids: ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Indices of 5 recommended artists: [2942, 32482, 2268, 78983, 11412]
# Recommended artist names: ['Conjure One', 'Ultimate Fakebook', 'June', 'Kate Earl', 'Course Of Nature']
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids: ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Indices of 5 recommended artists: [7019, 11906, 44109, 973, 3194]
# Recommended artist names: ['Overlap', "Le Peuple De L'Herbe", 'The Alarmists', 'Dustin Kensrue', 'Hooverphonic']
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Indices of 5 recommended artists: [1667, 970, 111184, 79875, 44334]
# Recommended artist names: ['The Dandy Warhols', 'Dropkick Murphys', 'Burns And Smithers', 'Dante', 'Matt Pless']
# --------------------------------------------------------------------------------
# Seed user-id: user_000123
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000998' 'user_000018' 'user_000779' 'user_000486']
# Indices of 5 recommended artists: [643, 3862, 30667, 148598, 3877]
# ...
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Indices of 5 recommended artists: [8274, 3677, 15273, 86149, 13584]
# Recommended artist names: ['David Axelrod', 'Simian', 'Wilderness', 'Borneo & Sporenburg', 'The Vibrators']
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids: ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Indices of 5 recommended artists: [137564, 39722, 19042, 4347, 137563]
# Recommended artist names: ['Andrew Powell-Andrew Powell And The Philharmonia Orchestra Play The Best Of Alan Parsons Project', 'The Rainbow Harmony Project', 'Ohm', 'I Monster', 'Andrew Playfoot']
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids: ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Indices of 5 recommended artists: [85567, 126346, 17871, 17973, 89176]
# Recommended artist names: ['Latin Playboys', 'Aki Tsuyuko', 'Bangkok Impact', 'Bratsch', 'Skip Raiders']
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids: ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Indices of 5 recommended artists: [43185, 21671, 89324, 22205, 63543]
# Recommended artist names: ['Prince Alla', 'Headless Heroes', 'Woody Shaw', 'Electronicat', 'Bang On A Can All-Stars']
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids: ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Indices of 5 recommended artists: [9820, 26296, 11323, 15901, 10854]
# Recommended artist names: ['Weather Report', 'Mind Da Gap', 'Boubacar Traoré', 'Midnight Oil', 'Qpe']
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids: ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Indices of 5 recommended artists: [116442, 19602, 1177, 1098, 12873]
# Recommended artist names: ['Lancelot', 'The Willowz', 'Johnny Cash', 'Hot Hot Heat', 'Mxpx']
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids: ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Indices of 5 recommended artists: [64574, 9521, 36870, 8882, 36864]
# Recommended artist names: ['Richard Chartier', 'Talk Talk', 'Kit Clayton', 'Leftfield', 'James Hook']
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Indices of 5 recommended artists: [3969, 8594, 47761, 42912, 118791]
# Recommended artist names: ['Yoko Ono', 'Guy Lombardo', 'Vinicio Capossela', 'Irakere', 'Anne Garner']
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Indices of 5 recommended artists: [10307, 19488, 4647, 45717, 10765]
# Recommended artist names: ['Jamelia', 'The Fuzztones', 'Rogue Traders', 'Gavin Rossdale', 'Loney, Dear']
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Indices of 5 recommended artists: [4610, 9999, 42910, 18401, 787]
# Recommended artist names: ['Prodigy', 'Implicit Audio Frequency', 'Intuit', 'Goapele', 'Ben Lee']
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Indices of 5 recommended artists: [2996, 9417, 133399, 39402, 145975]
# Recommended artist names: ['Dengue Fever', 'Slowdive', 'Little Brother, Median & Symbolyc One & Illlmind', 'Pluto Shervington', 'E6']
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Indices of 5 recommended artists: [10300, 18216, 91724, 91478, 91692]
# Recommended artist names: ['Hilltop Hoods', 'Dr. Octagon', 'Wasted Sunday', 'No Risk', 'The Vestals']
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Indices of 5 recommended artists: [18322, 23326, 6982, 60640, 91681]
# Recommended artist names: ['Flipper', 'Showbread', 'Matchbox Twenty', 'Paula Kelley', 'The Starrs']
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Indices of 5 recommended artists: [18456, 76911, 8750, 42560, 3399]
# Recommended artist names: ['Helen Shapiro', 'Claude King', 'Johnny Hates Jazz', 'Riot Squad', 'Mark Ronson']
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Indices of 5 recommended artists: [13218, 44640, 162670, 20134, 78419]
# Recommended artist names: ['Darkest Hour', 'Shelley Campbell', 'Victory Records', 'Little By Little', 'Wheatus Live']
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Indices of 5 recommended artists: [58828, 4014, 14014, 23022, 14258]
# Recommended artist names: ['Freeloaders Feat. The Real Thing', '2-4 Grooves', 'Hip Parade', 'Kate Ryan', 'Pocketbooks']
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Indices of 5 recommended artists: [162664, 1430, 32790, 1832, 40633]
# Recommended artist names: ['The Spiders From Mars', 'Pixies', 'Dritte Wahl', 'Tom Waits', 'Morris']
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Indices of 5 recommended artists: [1711, 66195, 37274, 24455, 31780]
# Recommended artist names: ['The Kills', 'Diskokaine', 'Family Guy', 'Joe Anderson Feat Salma Hayek', 'Operahouse']
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Indices of 5 recommended artists: [98511, 86330, 30915, 164422, 120446]
# Recommended artist names: ['Les Brown And His Orchestra', 'Melvins & Lustmord', 'Billy Sheehan', 'Groove Da Praya', 'Tony Macalpine']
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Indices of 5 recommended artists: [153602, 15062, 35265, 47468, 11931]
# Recommended artist names: ['Dabrye 73.3', 'Lyrics Born', 'Dexter Freebish', 'Needs', 'Lisa Loeb']
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Indices of 5 recommended artists: [1086, 14147, 3444, 1590, 301]
# Recommended artist names: ['Hard-Fi', 'Masters Of The Hemisphere', 'Mogwai', 'Sugarplum Fairy', 'Kelis']
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Indices of 5 recommended artists: [1953, 8769, 7408, 53364, 137320]
# Recommended artist names: ['Alter Ego', 'Judas Priest', 'Yarabi', 'Monk & Canatella', 'Jasefos Ft. Claire Van Der Boom']
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Indices of 5 recommended artists: [12459, 6694, 2743, 16658, 2271]
# Recommended artist names: ['The Funky Lowlives', 'Birdy Nam Nam', 'Aqualung', 'Tamia', 'Justice Vs. Simian']
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Indices of 5 recommended artists: [5052, 1698, 15561, 1612, 15023]
# Recommended artist names: ['Buzzcocks', 'The Good, The Bad & The Queen', 'East 17', 'Teenage Fanclub', 'Joaquín Rodrigo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Indices of 5 recommended artists: [15196, 39351, 38815, 12926, 90248]
# Recommended artist names: ['Terrestrial Tones', 'Patrick Doyle', 'Edgar Winter', 'The Temptations', 'Patti Labelle & The Bluebelles']
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Indices of 5 recommended artists: [12058, 43130, 20512, 159784, 1243]
# Recommended artist names: ['Miossec', 'Orlando "Cachaito" López', 'Kenny Loggins', 'Rhianna Feat. Jay-Z', 'Leann Rimes']
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Indices of 5 recommended artists: [1832, 104506, 164692, 34539, 11769]
# Recommended artist names: ['Tom Waits', 'Michale Graves', 'Mf Doom Ft. Monster Island Czars', 'Phonem', 'Jerry Lee Lewis']
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Indices of 5 recommended artists: [25565, 201, 9764, 60818, 1134]
# Recommended artist names: ['Duane Eddy', 'Gilles Peterson', 'Tosca', 'The Del-Vetts', 'Jamiroquai']
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Indices of 5 recommended artists: [10492, 3544, 39659, 15831, 76461]
# Recommended artist names: ['Average White Band', 'Patsy Cline', 'The Floaters', 'Living In A Box', 'George Clinton & Parliament - Funkadelic']
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Indices of 5 recommended artists: [1025, 9950, 17977, 9171, 8990]
# Recommended artist names: ['Fettes Brot', 'Einstürzende Neubauten', 'Brian Eno & David Byrne', 'Our Lady Peace', 'Matthew Good']
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Indices of 5 recommended artists: [10152, 13113, 18792, 89889, 1889]
# Recommended artist names: ['The Shy Trafficker', 'The Pineapple Thief', 'Lost Sounds', 'Mz.412', 'Wolfgang Amadeus Mozart']
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Indices of 5 recommended artists: [8928, 11230, 21804, 6910, 3761]
# Recommended artist names: ['Lords Of Acid', 'Atlanta Rhythm Section', 'Shawn Hlookoff', 'Gackt', 'The Black Keys']
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Indices of 5 recommended artists: [2998, 1341, 12354, 14620, 2004]
# Recommended artist names: ['Destroyer', 'Nat King Cole', 'Sonny Boy Williamson', 'The Owls', 'Blank & Jones']
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Indices of 5 recommended artists: [13057, 35462, 14658, 152, 3952]
# Recommended artist names: ['Mice Parade', 'Pablo Moses', 'The Sea And Cake', 'Donald Byrd', 'Wintersleep']
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Indices of 5 recommended artists: [40078, 11303, 86397, 8179, 161664]
# Recommended artist names: ['Susie Van Der Meer', 'Blue October', 'Postmen', 'Chron Gen', 'Softland']
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Indices of 5 recommended artists: [1364, 50371, 12328, 84959, 1596]
# Recommended artist names: ['Nine Inch Nails', 'Party Ben - Green Day Vs. Oasis Vs. Travis Vs. Eminem & Aerosmith', 'Sigur Rós & Hilmar Örn Hilmarsson', 'Dj Gt', 'Supreme Beings Of Leisure']
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Indices of 5 recommended artists: [14150, 15254, 1815, 19734, 86207]
# Recommended artist names: ['Mauro Picotto', 'Trespassers William', 'Third Eye Blind', 'William Shatner', 'Ebn']
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Indices of 5 recommended artists: [1743, 9007, 15107, 14856, 14870]
# Recommended artist names: ['The Perishers', 'Men At Work', 'Nyles Lannon', 'Amina', 'Barrett Strong']
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Indices of 5 recommended artists: [28808, 110267, 3683, 88625, 15928]
# Recommended artist names: ['Captain Sensible', 'X-Asp', 'Sleater-Kinney', 'Andrei Krylov', 'Nasa']
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Indices of 5 recommended artists: [6739, 18627, 10862, 1998, 16717]
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0016 seconds

# %%
#Thread
from concurrent.futures import ThreadPoolExecutor, as_completed
MAX_WORKERS = 8
# Build User-Artist Matrix (UAM)
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

UAM = normalize(UAM, norm='l2', axis=1)

user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

UAM_T = UAM.transpose().tocsr()

num_users = UAM.shape[0]

# --- Define function to process a single user ---
def process_single_user(u):
    pc_vec = UAM.getrow(u)
    sims = pc_vec.dot(UAM_T)
    sims_coo = sims.tocoo()
    
    mask = sims_coo.col != u
    neighbor_indices = sims_coo.col[mask]
    neighbor_scores = sims_coo.data[mask]
    
    if neighbor_scores.size == 0:
        return (user_ids[u], None, None)

    if neighbor_scores.size > K:
        top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
        sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
        top_neighbors = neighbor_indices[top_k_idx][sorted_order]
    else:
        sorted_order = np.argsort(neighbor_scores)[::-1]
        top_neighbors = neighbor_indices[sorted_order]

    recommended_user_ids = user_ids[top_neighbors]

    neighbor_rows = UAM[top_neighbors, :]
    neighbor_coo = neighbor_rows.tocoo()
    recommended_artists_idx = np.unique(neighbor_coo.col)

    seed_artists = UAM.getrow(u).indices
    recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)

    if recommended_artists_idx.size > 0:
        num_to_select = min(5, recommended_artists_idx.size)
        random_elements = random.sample(list(recommended_artists_idx), num_to_select)
        rec_artist_names = [artist_ids[i] for i in random_elements]
        return (user_ids[u], recommended_user_ids, rec_artist_names)
    else:
        return (user_ids[u], recommended_user_ids, None)

# --- Main Program ---
if __name__ == '__main__':
    start_time = time.time()

    all_results = []

    # Use ThreadPoolExecutor to process all users in parallel
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(process_single_user, u) for u in range(num_users)]
        for future in as_completed(futures):
            res = future.result()
            all_results.append(res)

    # Print all results
    for res in all_results:
        seed_user, neighbors, rec_artists = res
        print("Seed user-id:", seed_user)
        if neighbors is None:
            print("No similar users found for", seed_user)
            print('-' * 80)
            continue
        print(f"Nearest K={K} neighbors' user-ids:", neighbors.flatten())
        if rec_artists is not None:
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
        print('-' * 80)

    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids: ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids: ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids: ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids: ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids: ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids: ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids: ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids: ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids: ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids: ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids: ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids: ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids: ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids: ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids: ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids: ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000126
# Nearest K=5 neighbors' user-ids: ['user_000420' 'user_000668' 'user_000058' 'user_000665' 'user_000120']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids: ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000124
# Nearest K=5 neighbors' user-ids: ['user_000233' 'user_000479' 'user_000610' 'user_000765' 'user_000613']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000123
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000998' 'user_000018' 'user_000779' 'user_000486']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000125
# Nearest K=5 neighbors' user-ids: ['user_000771' 'user_000405' 'user_000482' 'user_000665' 'user_000040']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000129
# Nearest K=5 neighbors' user-ids: ['user_000948' 'user_000336' 'user_000497' 'user_000918' 'user_000234']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000127
# Nearest K=5 neighbors' user-ids: ['user_000774' 'user_000510' 'user_000341' 'user_000595' 'user_000886']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000130
# Nearest K=5 neighbors' user-ids: ['user_000305' 'user_000594' 'user_000222' 'user_000607' 'user_000783']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000131
# Nearest K=5 neighbors' user-ids: ['user_000089' 'user_000336' 'user_000467' 'user_000345' 'user_000856']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000136
# Nearest K=5 neighbors' user-ids: ['user_000995' 'user_000034' 'user_000089' 'user_000910' 'user_000345']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000128
# Nearest K=5 neighbors' user-ids: ['user_000856' 'user_000622' 'user_000421' 'user_000336' 'user_000131']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000135
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000077' 'user_000177' 'user_000763' 'user_000584']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000134
# Nearest K=5 neighbors' user-ids: ['user_000225' 'user_000535' 'user_000198' 'user_000413' 'user_000347']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000132
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000134' 'user_000056' 'user_000225' 'user_000535']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000137
# Nearest K=5 neighbors' user-ids: ['user_000263' 'user_000018' 'user_000093' 'user_000658' 'user_000996']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000133
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000233' 'user_000467' 'user_000050' 'user_000124']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000139
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000624' 'user_000683' 'user_000658' 'user_000327']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000141
# Nearest K=5 neighbors' user-ids: ['user_000852' 'user_000216' 'user_000458' 'user_000984' 'user_000916']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000142
# Nearest K=5 neighbors' user-ids: ['user_000507' 'user_000173' 'user_000776' 'user_000354' 'user_000426']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000140
# Nearest K=5 neighbors' user-ids: ['user_000986' 'user_000995' 'user_000083' 'user_000017' 'user_000393']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000144
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000961' 'user_000190' 'user_000710' 'user_000263']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000146
# Nearest K=5 neighbors' user-ids: ['user_000636' 'user_000553' 'user_000934' 'user_000182' 'user_000333']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000138
# Nearest K=5 neighbors' user-ids: ['user_000227' 'user_000013' 'user_000348' 'user_000188' 'user_000341']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000143
# Nearest K=5 neighbors' user-ids: ['user_000513' 'user_000345' 'user_000384' 'user_000031' 'user_000726']
# ...
# Seed user-id: user_000954
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000319' 'user_000242' 'user_000403' 'user_000024']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000949
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000569' 'user_000701' 'user_000364' 'user_000837']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000953
# Nearest K=5 neighbors' user-ids: ['user_000715' 'user_000741' 'user_000291' 'user_000705' 'user_000637']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000955
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000529' 'user_000031' 'user_000242']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000958
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000393' 'user_000274' 'user_000490' 'user_000753']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000959
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000342' 'user_000613' 'user_000437' 'user_000771']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000957
# Nearest K=5 neighbors' user-ids: ['user_000611' 'user_000173' 'user_000442' 'user_000395' 'user_000230']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000956
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000560' 'user_000606' 'user_000584' 'user_000078']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids: ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids: ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids: ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids: ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids: ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids: ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Recommended artist names: ['Jewel', 'Julieta Venegas', 'Reverend Horton Heat', 'Big & Rich', 'Boogie Down Productions']
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0012 seconds
