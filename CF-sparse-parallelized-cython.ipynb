# %%
import pandas as pd
from scipy.sparse import csr_matrix
import numpy as np
import random
import time 
import cProfile
import cython
from sklearn.preprocessing import normalize
from multiprocessing import Pool, cpu_count

# %%
K = 5

file_path = "lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv"

# Load interaction log
interactions = pd.read_csv(file_path, sep="\t", header=None,
                           names=["user_id", "timestamp", "artist_id", "artist_name", "track_id", "track_name"], on_bad_lines='skip')

# %%
# Count number of times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mappings: user/artist to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map to index
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the sparse matrix (UAM)
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# normalize rows (for cosine similarity)

UAM = normalize(UAM, norm='l2', axis=1)

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))


if __name__ == '__main__':
    start_time = time.time()
    for u in range(0, UAM.shape[0]):
        print("Seed user-id: " + str(user_ids[u]))

        # Get normalized playcount vector for current user
        pc_vec = UAM.getrow(u)

        # Compute cosine similarity between this user and all users
        uU_sim = pc_vec.dot(UAM.transpose()).tocoo()
        uU_user_idx = uU_sim.col
        uU_data = uU_sim.data

        # Remove self-similarity
        uU_data[uU_user_idx == u] = 0

        # Eliminate zeros
        uU_sim.data = uU_data
        uU_sim = uU_sim.tocsr()
        uU_sim.eliminate_zeros()
        uU_sim = uU_sim.tocoo()

        # Re-assign user indices and scores
        uU_user_idx = uU_sim.col
        uU_data = uU_sim.data

        # Sort by similarity score
        sort_index = np.argsort(uU_data)

        # Select top-K nearest neighbors
        # Note that uU_user_idx indeed provides the indices for users in UAM
        recommended_user_idx = uU_user_idx[sort_index[-K:]]
        # Get user_ids corresponding to nearest neighbors
        recommended_user_ids = user_ids[recommended_user_idx]
        # Get similarity score for nearest neighbors
        recommended_user_scores = uU_data[sort_index[-K:]]

        print("Nearest K=" + str(K) + " neighbors' user-ids: ", recommended_user_ids.flatten())

        # Get all artists these similar users have listened to
        recommended_artists_idx = []
        for u_idx in recommended_user_idx:
            recommended_artists_idx.extend(list(UAM.getrow(u_idx).indices))

        # Remove duplicates and sort
        recommended_artists_idx = sorted(set(recommended_artists_idx))

        # Remove artists already known to seed user
        recommended_artists_idx = np.setdiff1d(recommended_artists_idx, pc_vec.indices)

        # Narrow down to random 5 artist out of all artists that similar users listen to for illustration purpose
        random_indices = random.sample(range(len(recommended_artists_idx)), 5)
        random_elements = [recommended_artists_idx[i] for i in random_indices]

        print("Indices of " + str(len(random_elements)) + " recommended artists: ", random_elements)
        print("Recommended artist names:", [artist_ids[i] for i in random_elements])
        print('-' * 80)

    end_time = time.time()
    total_users = UAM.shape[0]
    avg_time = (end_time - start_time) / total_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids:  ['user_000168' 'user_000844' 'user_000862' 'user_000629' 'user_000074']
# Indices of 5 recommended artists:  [np.int32(17530), np.int32(6951), np.int32(8550), np.int32(14092), np.int32(34080)]
# Recommended artist names: [np.str_('Superchunk'), np.str_('Kansas'), np.str_('George Shearing'), np.str_('Kukl'), np.str_('Aguayo/Rossknecht')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids:  ['user_000513' 'user_000726' 'user_000143' 'user_000238' 'user_000673']
# Indices of 5 recommended artists:  [np.int32(2180), np.int32(3247), np.int32(12868), np.int32(10678), np.int32(2535)]
# Recommended artist names: [np.str_('Funeral For A Friend'), np.str_('Jay-Z'), np.str_('Missy Elliott'), np.str_('Hundred Reasons'), np.str_('Ten Years After')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids:  ['user_000392' 'user_000741' 'user_000400' 'user_000558' 'user_000813']
# Indices of 5 recommended artists:  [np.int32(41553), np.int32(52315), np.int32(11740), np.int32(115188), np.int32(52527)]
# Recommended artist names: [np.str_('Byron Stingily'), np.str_('Atfc'), np.str_('Jackson Browne'), np.str_('Dj Nekbath'), np.str_('Neophyte')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids:  ['user_000703' 'user_000998' 'user_000089' 'user_000779' 'user_000996']
# Indices of 5 recommended artists:  [np.int32(35774), np.int32(64951), np.int32(45849), np.int32(77424), np.int32(24487)]
# Recommended artist names: [np.str_('Faith & Disease'), np.str_('Val Bennett'), np.str_('Science For Girls'), np.str_('Qypthone'), np.str_('8 Bit Weapon')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids:  ['user_000627' 'user_000807' 'user_000560' 'user_000584' 'user_000307']
# Indices of 5 recommended artists:  [np.int32(7322), np.int32(11539), np.int32(9477), np.int32(8109), np.int32(153580)]
# Recommended artist names: [np.str_('Mos Def'), np.str_('Elmore James'), np.str_('Stereo Mcs'), np.str_('Buena Vista Social Club'), np.str_('Aladdin And The King Of Thieves')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids:  ['user_000675' 'user_000415' 'user_000885' 'user_000766' 'user_000116']
# Indices of 5 recommended artists:  [np.int32(6822), np.int32(16464), np.int32(12665), np.int32(1546), np.int32(104814)]
# Recommended artist names: [np.str_('Big Country'), np.str_('Lithium Dawn'), np.str_('Zwan'), np.str_('Smog'), np.str_('Patrice Scott')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids:  ['user_000437' 'user_000781' 'user_000402' 'user_000236' 'user_000765']
# Indices of 5 recommended artists:  [np.int32(44879), np.int32(57203), np.int32(100241), np.int32(6873), np.int32(148991)]
# Recommended artist names: [np.str_('Bon Garçon'), np.str_('Tsutchie'), np.str_('Dj Kechup'), np.str_('Dishwalla'), np.str_('Cree Summer')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids:  ['user_000123' 'user_000187' 'user_000737' 'user_000419' 'user_000864']
# Indices of 5 recommended artists:  [np.int32(7024), np.int32(4579), np.int32(27051), np.int32(95842), np.int32(2381)]
# Recommended artist names: [np.str_('Peter Gabriel'), np.str_('Panjabi Mc'), np.str_('Underground Kingz'), np.str_('Eve; Missy Elliott'), np.str_('Missing Persons')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids:  ['user_000833' 'user_000115' 'user_000473' 'user_000758' 'user_000357']
# Indices of 5 recommended artists:  [np.int32(23174), np.int32(20007), np.int32(3224), np.int32(88224), np.int32(156250)]
# Recommended artist names: [np.str_('Neuroactive'), np.str_("D'Espairsray"), np.str_('Iron Maiden'), np.str_('Dinah Cancer And The Graverobbers'), np.str_('Cath Young')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids:  ['user_000813' 'user_000379' 'user_000329' 'user_000981' 'user_000208']
# Indices of 5 recommended artists:  [np.int32(12076), np.int32(5222), np.int32(84381), np.int32(121075), np.int32(90891)]
# Recommended artist names: [np.str_('Mud'), np.str_('Era'), np.str_('Klub Des Loosers'), np.str_('Jack Rokka Vs. Betty Boo'), np.str_('Grant Nelson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids:  ['user_000953' 'user_000715' 'user_000291' 'user_000417' 'user_000705']
# Indices of 5 recommended artists:  [np.int32(23043), np.int32(1295), np.int32(138700), np.int32(2048), np.int32(8725)]
# Recommended artist names: [np.str_('Koxbox'), np.str_('Mateo Messina'), np.str_('Ruk Jana O Jana'), np.str_('Circa Survive'), np.str_('Jimmy Cliff')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids:  ['user_000203' 'user_000564' 'user_000703' 'user_000698' 'user_000689']
# Indices of 5 recommended artists:  [np.int32(27089), np.int32(21486), np.int32(3717), np.int32(15695), np.int32(52249)]
# Recommended artist names: [np.str_('Voigt & Voigt'), np.str_('Darker My Love'), np.str_('Styrofoam'), np.str_('Håkan Hellström'), np.str_('The Tubes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids:  ['user_000026' 'user_000927' 'user_000935' 'user_000932' 'user_000161']
# Indices of 5 recommended artists:  [np.int32(51767), np.int32(8392), np.int32(16710), np.int32(28420), np.int32(51533)]
# Recommended artist names: [np.str_('Quinteto Nuevo Tango'), np.str_('Drop The Lime'), np.str_('Bill Hicks'), np.str_('Laika'), np.str_('Fellsilent')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids:  ['user_000129' 'user_000443' 'user_000920' 'user_000257' 'user_000497']
# Indices of 5 recommended artists:  [np.int32(1698), np.int32(8501), np.int32(3551), np.int32(1116), np.int32(6703)]
# Recommended artist names: [np.str_('The Good, The Bad & The Queen'), np.str_('Four Tet'), np.str_('Pearl Jam'), np.str_('Ingrid Michaelson'), np.str_('Chevelle')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids:  ['user_000503' 'user_000515' 'user_000634' 'user_000532' 'user_000927']
# Indices of 5 recommended artists:  [np.int32(17950), np.int32(87491), np.int32(36869), np.int32(774), np.int32(20121)]
# Recommended artist names: [np.str_('Bobby "Blue" Bland'), np.str_('Robert Cocksey'), np.str_('Kim Hiorthøy'), np.str_('Beatsteaks'), np.str_('Kury')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids:  ['user_000328' 'user_000048' 'user_000897' 'user_000293' 'user_000791']
# Indices of 5 recommended artists:  [np.int32(14757), np.int32(39733), np.int32(3149), np.int32(72995), np.int32(35450)]
# Recommended artist names: [np.str_('Vincent Vincent And The Villains'), np.str_('The Sand Band'), np.str_('Grace Jones'), np.str_('The Scarlet Tuesday'), np.str_('Nardis')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids:  ['user_000705' 'user_000075' 'user_000937' 'user_000731' 'user_000905']
# Indices of 5 recommended artists:  [np.int32(30), np.int32(9053), np.int32(164565), np.int32(42431), np.int32(112520)]
# Recommended artist names: [np.str_('Aphex Twin'), np.str_('Mohammed Rafi'), np.str_('Randy Lane'), np.str_('Spacemonkeyz Vs. Gorillaz'), np.str_('Kalimoto')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids:  ['user_000123' 'user_000486' 'user_000998' 'user_000093' 'user_000996']
# Indices of 5 recommended artists:  [np.int32(1775), np.int32(53538), np.int32(22055), np.int32(9015), np.int32(3398)]
# Recommended artist names: [np.str_('The Slip'), np.str_('The Scare'), np.str_('Fightstar'), np.str_('Metronomy'), np.str_('Marilyn Manson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids:  ['user_000020' 'user_000565' 'user_000554' 'user_000139' 'user_000440']
# Indices of 5 recommended artists:  [np.int32(10194), np.int32(3719), np.int32(33093), np.int32(2305), np.int32(18574)]
# Recommended artist names: [np.str_("K'S Choice"), np.str_('Sugababes'), np.str_('Peter Fox'), np.str_('Late Of The Pier'), np.str_('Joachim Witt')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids:  ['user_000658' 'user_000139' 'user_000327' 'user_000683' 'user_000624']
# Indices of 5 recommended artists:  [np.int32(12550), np.int32(38178), np.int32(43827), np.int32(14559), np.int32(27348)]
# Recommended artist names: [np.str_('Tonino Carotone'), np.str_('The Fireman'), np.str_('Carlos Jean'), np.str_('The Just Joans'), np.str_('N.O.H.A.')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids:  ['user_000681' 'user_000691' 'user_000673' 'user_000617' 'user_000882']
# Indices of 5 recommended artists:  [np.int32(4084), np.int32(4852), np.int32(9946), np.int32(87350), np.int32(1205)]
# Recommended artist names: [np.str_('Bangles'), np.str_('Άννα Βίσση'), np.str_('Doomriders'), np.str_('Joe Hill Louis'), np.str_('Kanye West')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids:  ['user_000858' 'user_000249' 'user_000534' 'user_000564' 'user_000690']
# Indices of 5 recommended artists:  [np.int32(9273), np.int32(1889), np.int32(60305), np.int32(60543), np.int32(60713)]
# Recommended artist names: [np.str_('Rahsaan Roland Kirk'), np.str_('Wolfgang Amadeus Mozart'), np.str_('Big Gun'), np.str_('Laugh'), np.str_('Someloves')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids:  ['user_000866' 'user_000503' 'user_000927' 'user_000515' 'user_000634']
# Indices of 5 recommended artists:  [np.int32(3955), np.int32(7587), np.int32(2161), np.int32(247), np.int32(90977)]
# Recommended artist names: [np.str_('Wolf Parade'), np.str_('Hatebreed'), np.str_('Ferry Corsten'), np.str_('Jackson And His Computer Band'), np.str_('The Goodfellas')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids:  ['user_000371' 'user_000998' 'user_000493' 'user_000031' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(17749), np.int32(18900), np.int32(1539), np.int32(17372), np.int32(19351)]
# Recommended artist names: [np.str_('Agnieszka Osiecka'), np.str_('Meshell Ndegeocello & Yerba Buena'), np.str_('Simple Plan'), np.str_('Mellowdrone'), np.str_('Someone Else')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids:  ['user_000476' 'user_000096' 'user_000151' 'user_000118' 'user_000653']
# Indices of 5 recommended artists:  [np.int32(38381), np.int32(87500), np.int32(38405), np.int32(48393), np.int32(38324)]
# Recommended artist names: [np.str_('Roger Daltrey'), np.str_('Ronnie Self'), np.str_('The Power Station'), np.str_('The Yellow Monkey'), np.str_('Ison & Fille')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids:  ['user_000565' 'user_000839' 'user_000188' 'user_000833' 'user_000161']
# Indices of 5 recommended artists:  [np.int32(1378), np.int32(1115), np.int32(112524), np.int32(21789), np.int32(10121)]
# Recommended artist names: [np.str_('Of Montreal'), np.str_('Indochine'), np.str_('Kehlvin'), np.str_('Red'), np.str_('Strapping Young Lad')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids:  ['user_000651' 'user_000205' 'user_000124' 'user_000233' 'user_000714']
# Indices of 5 recommended artists:  [np.int32(4800), np.int32(125979), np.int32(138599), np.int32(70156), np.int32(740)]
# Recommended artist names: [np.str_('Tom Novy Feat. Michael Marshall'), np.str_('Www.Fivemp3.Com'), np.str_('The Ting Tings (Reinzidencia.Blogspot.Com)'), np.str_('First Base'), np.str_('Arctic Monkeys')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids:  ['user_000485' 'user_000373' 'user_000756' 'user_000069' 'user_000661']
# Indices of 5 recommended artists:  [np.int32(41765), np.int32(18999), np.int32(15352), np.int32(32724), np.int32(1378)]
# Recommended artist names: [np.str_('Kutless'), np.str_('Neverending White Lights'), np.str_('Amon Amarth'), np.str_('Con Funk Shun'), np.str_('Of Montreal')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000826' 'user_000513' 'user_000703' 'user_000024']
# Indices of 5 recommended artists:  [np.int32(19724), np.int32(29165), np.int32(86139), np.int32(19904), np.int32(691)]
# Recommended artist names: [np.str_('Whiskeytown'), np.str_('New Age Steepers'), np.str_('Benny Golson'), np.str_('Tiamat'), np.str_('Albert Hammond, Jr.')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids:  ['user_000858' 'user_000753' 'user_000703' 'user_000031' 'user_000564']
# Indices of 5 recommended artists:  [np.int32(18909), np.int32(144898), np.int32(42975), np.int32(51027), np.int32(10262)]
# Recommended artist names: [np.str_('Michael Stearns'), np.str_('Wir'), np.str_('Klanguage'), np.str_('Thom Yorke & My Bloody Valentine'), np.str_('Die Form')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids:  ['user_000242' 'user_000159' 'user_000164' 'user_000513' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(5556), np.int32(224), np.int32(24340), np.int32(49987), np.int32(12380)]
# Recommended artist names: [np.str_('Masha Qrella'), np.str_('Hexstatic'), np.str_('Beans'), np.str_('Distant Fires Burning'), np.str_('Steve Hackett')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids:  ['user_000206' 'user_000115' 'user_000442' 'user_000727' 'user_000692']
# Indices of 5 recommended artists:  [np.int32(62775), np.int32(10146), np.int32(27651), np.int32(62553), np.int32(20704)]
# Recommended artist names: [np.str_('Rock The Nations 2004'), np.str_('The Hold Steady'), np.str_('J.B.O.'), np.str_('Brutality'), np.str_('Cyrus')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids:  ['user_000991' 'user_000999' 'user_000588' 'user_000188' 'user_000758']
# Indices of 5 recommended artists:  [np.int32(7032), np.int32(960), np.int32(12094), np.int32(119322), np.int32(668)]
# Recommended artist names: [np.str_('Project Pitchfork'), np.str_('Dizzy Gillespie'), np.str_('Nena'), np.str_('Xbox World 360'), np.str_('4 Non Blondes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids:  ['user_000280' 'user_000086' 'user_000031' 'user_000164' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(33164), np.int32(86483), np.int32(19071), np.int32(3708), np.int32(19704)]
# Recommended artist names: [np.str_('Skeletons And The Kings Of All Cities'), np.str_('The Spaceshots'), np.str_('Papa Wemba'), np.str_('Stervhïa'), np.str_('Voltaire')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids:  ['user_000415' 'user_000023' 'user_000483' 'user_000664' 'user_000720']
# Indices of 5 recommended artists:  [np.int32(9960), np.int32(28203), np.int32(95513), np.int32(7386), np.int32(3948)]
# Recommended artist names: [np.str_('Fear Factory'), np.str_('A Girl Called Eddy'), np.str_('Drama Society'), np.str_('The Disco Boys'), np.str_('Whitey')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids:  ['user_000086' 'user_000770' 'user_000495' 'user_000992' 'user_000499']
# Indices of 5 recommended artists:  [np.int32(1400), np.int32(36336), np.int32(108579), np.int32(3734), np.int32(13095)]
# Recommended artist names: [np.str_('Paul Simon'), np.str_('Dr. Kirsten Sanford Science Media'), np.str_('É O Tchan'), np.str_('Talking Heads'), np.str_('Souad Massi')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids:  ['user_000062' 'user_000304' 'user_000294' 'user_000862' 'user_000577']
# Indices of 5 recommended artists:  [np.int32(79141), np.int32(30342), np.int32(34373), np.int32(29946), np.int32(79349)]
# Recommended artist names: [np.str_('007'), np.str_('Kim Carnes'), np.str_('Kiln'), np.str_('Leyla Va Dayirman'), np.str_('Salma Hayek & Los Vega')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids:  ['user_000056' 'user_000780' 'user_000015' 'user_000612' 'user_000588']
# Indices of 5 recommended artists:  [np.int32(16339), np.int32(27757), np.int32(15152), np.int32(1066), np.int32(148715)]
# Recommended artist names: [np.str_('日比野則彦'), np.str_('No Comment'), np.str_('Russian Circles'), np.str_('Gnarls Barkley'), np.str_('Antaneliai')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids:  ['user_000603' 'user_000551' 'user_000985' 'user_000849' 'user_000814']
# Indices of 5 recommended artists:  [np.int32(2587), np.int32(985), np.int32(1253), np.int32(16829), np.int32(12493)]
# Recommended artist names: [np.str_('Thin Lizzy'), np.str_('Edwin Mccain'), np.str_('Lighthouse Family'), np.str_('High Contrast'), np.str_('The Pogues')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids:  ['user_000624' 'user_000658' 'user_000093' 'user_000327' 'user_000020']
# Indices of 5 recommended artists:  [np.int32(3291), np.int32(3341), np.int32(1725), np.int32(123348), np.int32(5052)]
# Recommended artist names: [np.str_('Keren Ann'), np.str_('Lily Allen'), np.str_('The Magic Numbers'), np.str_('Astrids BäSta'), np.str_('Buzzcocks')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids:  ['user_000615' 'user_000831' 'user_000444' 'user_000134' 'user_000132']
# Indices of 5 recommended artists:  [np.int32(2460), np.int32(18290), np.int32(3527), np.int32(45946), np.int32(46198)]
# Recommended artist names: [np.str_('Roger Sanchez'), np.str_('Fad Gadget'), np.str_('Orphaned Land'), np.str_('Allen Layman'), np.str_('Kristian Larsen')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids:  ['user_000256' 'user_000383' 'user_000103' 'user_000806' 'user_000117']
# Indices of 5 recommended artists:  [np.int32(91766), np.int32(44291), np.int32(5761), np.int32(90222), np.int32(34602)]
# Recommended artist names: [np.str_('Autopsy Protocol'), np.str_('Tappi Tíkarrass'), np.str_('Queens Of The Stone Age'), np.str_('Fat Ray & Black Milk'), np.str_('Ryoji Ikeda')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000143' 'user_000513' 'user_000345' 'user_000031']
# Indices of 5 recommended artists:  [np.int32(86353), np.int32(18904), np.int32(14377), np.int32(7911), np.int32(15851)]
# Recommended artist names: [np.str_('Ncqtl'), np.str_('Michael Franti & Spearhead (Featuring John Butler)'), np.str_('South Ambulance'), np.str_('Alex Reece'), np.str_('Luther Vandross')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids:  ['user_000473' 'user_000527' 'user_000442' 'user_000435' 'user_000115']
# Indices of 5 recommended artists:  [np.int32(43728), np.int32(50548), np.int32(38274), np.int32(40500), np.int32(93951)]
# Recommended artist names: [np.str_('Marilyn Monroe And Jane Russell'), np.str_('Franco De Vita'), np.str_('Axenstar'), np.str_('Imperia'), np.str_('Bobby Creekwater')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids:  ['user_000346' 'user_000457' 'user_000289' 'user_000527' 'user_000442']
# Indices of 5 recommended artists:  [np.int32(1980), np.int32(101092), np.int32(3398), np.int32(24187), np.int32(48467)]
# Recommended artist names: [np.str_('Avenged Sevenfold'), np.str_('Virtuocity'), np.str_('Marilyn Manson'), np.str_('Samantha Jade'), np.str_('影山ヒロノブ')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids:  ['user_000013' 'user_000537' 'user_000783' 'user_000912' 'user_000354']
# Indices of 5 recommended artists:  [np.int32(10109), np.int32(4189), np.int32(6853), np.int32(26299), np.int32(149175)]
# Recommended artist names: [np.str_('Secret Chiefs 3'), np.str_('Dangerdoom'), np.str_('Cutting Crew'), np.str_('Minsk'), np.str_('Burn It Down')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids:  ['user_000354' 'user_000761' 'user_000260' 'user_000973' 'user_000378']
# Indices of 5 recommended artists:  [np.int32(4412), np.int32(15302), np.int32(172354), np.int32(36273), np.int32(145781)]
# Recommended artist names: [np.str_('Kosheen'), np.str_("5Ive'S Continuum Research Project"), np.str_('Guiding Line'), np.str_('Obrint Pas'), np.str_('B2 Trancetrutje')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids:  ['user_000847' 'user_000328' 'user_000631' 'user_000791' 'user_000769']
# Indices of 5 recommended artists:  [np.int32(1096), np.int32(1242), np.int32(1706), np.int32(1334), np.int32(9937)]
# Recommended artist names: [np.str_('Hot Chocolate'), np.str_('Lcd Soundsystem'), np.str_('The Jackson 5'), np.str_('Mystery Jets'), np.str_('Deepspace')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids:  ['user_000256' 'user_000668' 'user_000387' 'user_000420' 'user_000126']
# Indices of 5 recommended artists:  [np.int32(54679), np.int32(7815), np.int32(43909), np.int32(2998), np.int32(1848)]
# Recommended artist names: [np.str_('Chocolate Star'), np.str_('The Troggs'), np.str_('Gary Wilson'), np.str_('Destroyer'), np.str_('Two Gallants')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids:  ['user_000467' 'user_000511' 'user_000620' 'user_000336' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(3699), np.int32(26395), np.int32(86317), np.int32(23730), np.int32(13096)]
# Recommended artist names: [np.str_('Sparklehorse'), np.str_('Nostalgia 77'), np.str_('Magenta Skycode'), np.str_('The Go Find'), np.str_('Spacemen 3')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids:  ['user_000478' 'user_000803' 'user_000977' 'user_000089' 'user_000215']
# Indices of 5 recommended artists:  [np.int32(11864), np.int32(66283), np.int32(3417), np.int32(26934), np.int32(9697)]
# Recommended artist names: [np.str_('Kenny Rogers'), np.str_('Snob Scrilla'), np.str_('Melody Gardot'), np.str_('The King Blues'), np.str_('The Trashmen')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids:  ['user_000247' 'user_000173' 'user_000115' 'user_000182' 'user_000113']
# Indices of 5 recommended artists:  [np.int32(59310), np.int32(3078), np.int32(59313), np.int32(43495), np.int32(1786)]
# Recommended artist names: [np.str_('Thiasos Dionysos'), np.str_('Faithless'), np.str_('Tim "Ripper" Owens'), np.str_('Suburban Tribe'), np.str_('The Strokes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids:  ['user_000773' 'user_000606' 'user_000756' 'user_000241' 'user_000373']
# Indices of 5 recommended artists:  [np.int32(68095), np.int32(6279), np.int32(7329), np.int32(145209), np.int32(7090)]
# Recommended artist names: [np.str_('Sleepy Hallowtips'), np.str_('112'), np.str_('Nelly'), np.str_('Nitebreed'), np.str_('The Script')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids:  ['user_000570' 'user_000835' 'user_000142' 'user_000776' 'user_000912']
# Indices of 5 recommended artists:  [np.int32(9333), np.int32(38575), np.int32(68972), np.int32(104368), np.int32(164817)]
# Recommended artist names: [np.str_('Rx'), np.str_('Bob Marley Vs Funkstar De Luxe Remix'), np.str_('Bonded By Blood'), np.str_('Oficina G3'), np.str_('Multi Purpose Chemical')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids:  ['user_000763' 'user_000591' 'user_000577' 'user_000579' 'user_000894']
# Indices of 5 recommended artists:  [np.int32(11140), np.int32(82190), np.int32(3302), np.int32(118349), np.int32(163351)]
# Recommended artist names: [np.str_('谭盾'), np.str_('The World Without Magic'), np.str_('Kinnie Starr'), np.str_('Randy Bettis'), np.str_('Queer As Folk Cast')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids:  ['user_000043' 'user_000132' 'user_000134' 'user_000700' 'user_000041']
# Indices of 5 recommended artists:  [np.int32(46216), np.int32(10020), np.int32(937), np.int32(781), np.int32(3444)]
# Recommended artist names: [np.str_('Los Paraguayos'), np.str_('Klimt 1918'), np.str_('Diana Ross & The Supremes'), np.str_('Belle And Sebastian'), np.str_('Mogwai')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids:  ['user_000557' 'user_000742' 'user_000551' 'user_000650' 'user_000902']
# Indices of 5 recommended artists:  [np.int32(12891), np.int32(2427), np.int32(8916), np.int32(7375), np.int32(4310)]
# Recommended artist names: [np.str_('Refused'), np.str_('Paul Van Dyk'), np.str_('Lisa Stansfield'), np.str_('Stonebridge'), np.str_('Funkagenda')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids:  ['user_000070' 'user_000598' 'user_000463' 'user_000828' 'user_000770']
# Indices of 5 recommended artists:  [np.int32(1086), np.int32(14062), np.int32(15190), np.int32(14695), np.int32(13843)]
# Recommended artist names: [np.str_('Hard-Fi'), np.str_('Jj72'), np.str_('Sun City Girls'), np.str_('The Tyde'), np.str_('Coconut Records')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids:  ['user_000024' 'user_000837' 'user_000763' 'user_000584' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(86302), np.int32(157892), np.int32(814), np.int32(14062), np.int32(16414)]
# Recommended artist names: [np.str_('Lawrence Arabia'), np.str_("My Best Friend'S Wedding"), np.str_('Bon Iver'), np.str_('Jj72'), np.str_('Emperor')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids:  ['user_000633' 'user_000448' 'user_000031' 'user_000170' 'user_000582']
# Indices of 5 recommended artists:  [np.int32(18314), np.int32(17600), np.int32(798), np.int32(5851), np.int32(9)]
# Recommended artist names: [np.str_('First Choice'), np.str_('Tommy Tutone'), np.str_('Bill Withers'), np.str_('Señor Coconut'), np.str_('A Tribe Called Quest')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids:  ['user_000479' 'user_000579' 'user_000959' 'user_000233' 'user_000765']
# Indices of 5 recommended artists:  [np.int32(7354), np.int32(4469), np.int32(3696), np.int32(9114), np.int32(105956)]
# Recommended artist names: [np.str_('Rank 1'), np.str_('Martijn Ten Velden'), np.str_('Soul Asylum'), np.str_('New Musik'), np.str_('Natasha Bedingfield & Adam Levine')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids:  ['user_000159' 'user_000345' 'user_000031' 'user_000304' 'user_000170']
# Indices of 5 recommended artists:  [np.int32(11352), np.int32(18977), np.int32(18218), np.int32(50926), np.int32(11312)]
# Recommended artist names: [np.str_('Capsule'), np.str_('My Little Funhouse'), np.str_('Drexciya'), np.str_('Animal Collective (Feat. Vashti Bunyan)'), np.str_('Bob Log Iii')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids:  ['user_000188' 'user_000705' 'user_000338' 'user_000305' 'user_000431']
# Indices of 5 recommended artists:  [np.int32(59933), np.int32(137201), np.int32(92549), np.int32(9885), np.int32(21616)]
# Recommended artist names: [np.str_('Big Giant Circles'), np.str_('Sting & Edin Karamazov'), np.str_('David Daniels'), np.str_('Andrew W.K.'), np.str_('Chris Garneau')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids:  ['user_000853' 'user_000832' 'user_000970' 'user_000360' 'user_000495']
# Indices of 5 recommended artists:  [np.int32(156225), np.int32(88935), np.int32(4684), np.int32(1633), np.int32(82908)]
# Recommended artist names: [np.str_('Kaiser Chiefs, Editors, The Young Knives'), np.str_('The Mo & Kris Le Mans'), np.str_('Shakedown'), np.str_("The B-52'S"), np.str_('Johan Johansson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids:  ['user_000803' 'user_000603' 'user_000960' 'user_000403' 'user_000467']
# Indices of 5 recommended artists:  [np.int32(104322), np.int32(17922), np.int32(81412), np.int32(4189), np.int32(10538)]
# Recommended artist names: [np.str_('Whipping Cats'), np.str_('Billie Jo Spears'), np.str_('Aaron Tippin'), np.str_('Dangerdoom'), np.str_('Cajun Dance Party')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids:  ['user_000396' 'user_000392' 'user_000586' 'user_000418' 'user_000609']
# Indices of 5 recommended artists:  [np.int32(1342), np.int32(93538), np.int32(35438), np.int32(121101), np.int32(6460)]
# Recommended artist names: [np.str_('Natalie Imbruglia'), np.str_("Twins, 梁洛施, Boy'Z, 關智斌, 鄭希怡 & Hanjin"), np.str_('Mind To Mind'), np.str_('Lacarno'), np.str_('Jill Scott')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids:  ['user_000020' 'user_000122' 'user_000624' 'user_000760' 'user_000658']
# Indices of 5 recommended artists:  [np.int32(4276), np.int32(12995), np.int32(22718), np.int32(39428), np.int32(3638)]
# Recommended artist names: [np.str_('Enrique Iglesias'), np.str_('Codeseven'), np.str_('Clokx'), np.str_('Ray Stevens'), np.str_('Santogold')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids:  ['user_000753' 'user_000898' 'user_000343' 'user_000735' 'user_000159']
# Indices of 5 recommended artists:  [np.int32(9311), np.int32(12731), np.int32(127383), np.int32(164173), np.int32(94862)]
# Recommended artist names: [np.str_('Robin S.'), np.str_('Antonín Dvořák'), np.str_("Red Hot 'N' Blue"), np.str_("You'Re The One"), np.str_('Silent Harmony')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids:  ['user_000707' 'user_000756' 'user_000273' 'user_000661' 'user_000028']
# Indices of 5 recommended artists:  [np.int32(145070), np.int32(16958), np.int32(127656), np.int32(38613), np.int32(5061)]
# Recommended artist names: [np.str_('Almight Rso'), np.str_('Saigon'), np.str_('Dj Hype Feat. Stieber Twins &'), np.str_('Byron Lee & The Dragonaires'), np.str_('Castor')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids:  ['user_000600' 'user_000598' 'user_000770' 'user_000463' 'user_000828']
# Indices of 5 recommended artists:  [np.int32(744), np.int32(12093), np.int32(66904), np.int32(1700), np.int32(3560)]
# Recommended artist names: [np.str_('Art Brut'), np.str_('Neil Young & Pearl Jam'), np.str_("Rhea'S Obsession"), np.str_('The Hives'), np.str_('Piano Magic')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000512' 'user_000513' 'user_000448' 'user_000209']
# Indices of 5 recommended artists:  [np.int32(5884), np.int32(142), np.int32(11533), np.int32(1830), np.int32(15650)]
# Recommended artist names: [np.str_('Soft Cell'), np.str_('Diplo'), np.str_('Electric Light Orchestra Part Ii'), np.str_('Tom Petty And The Heartbreakers'), np.str_('Glen Campbell')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids:  ['user_000520' 'user_000018' 'user_000837' 'user_000668' 'user_000367']
# Indices of 5 recommended artists:  [np.int32(14130), np.int32(31117), np.int32(2834), np.int32(157861), np.int32(44969)]
# Recommended artist names: [np.str_('Love Is All'), np.str_('Dolorean'), np.str_('Boy Kill Boy'), np.str_('Howard Shore & Ben Del Maestro'), np.str_('Madonna Feat. Justin Timberlake')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids:  ['user_000515' 'user_000935' 'user_000503' 'user_000634' 'user_000927']
# Indices of 5 recommended artists:  [np.int32(6997), np.int32(17438), np.int32(4796), np.int32(7045), np.int32(24471)]
# Recommended artist names: [np.str_('Mr. Mister'), np.str_('Pole'), np.str_('Timo Maas'), np.str_('Samael'), np.str_('The Swell Season')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids:  ['user_000844' 'user_000577' 'user_000807' 'user_000079' 'user_000838']
# Indices of 5 recommended artists:  [np.int32(147024), np.int32(3676), np.int32(78771), np.int32(64766), np.int32(3048)]
# Recommended artist names: [np.str_('Jordan Pruitt'), np.str_('Sibongile Khumalo'), np.str_('The Jim Yoshii Pile-Up'), np.str_('The Autumn Defense'), np.str_('Emilie Autumn')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids:  ['user_000905' 'user_000083' 'user_000017' 'user_000859' 'user_000937']
# Indices of 5 recommended artists:  [np.int32(11764), np.int32(1939), np.int32(12513), np.int32(6812), np.int32(13298)]
# Recommended artist names: [np.str_('Jennifer Brown'), np.str_('Afi'), np.str_('The Taliesin Orchestra'), np.str_('Apoptygma Berzerk'), np.str_('Joey Ramone')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids:  ['user_000210' 'user_000086' 'user_000091' 'user_000792' 'user_000168']
# Indices of 5 recommended artists:  [np.int32(17251), np.int32(12431), np.int32(41896), np.int32(10650), np.int32(64388)]
# Recommended artist names: [np.str_('Harold Melvin & The Blue Notes'), np.str_('Terra Naomi'), np.str_('Rosie Gaines'), np.str_('Gillan'), np.str_('Mystic Circle')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids:  ['user_000606' 'user_000807' 'user_000584' 'user_000135' 'user_000763']
# Indices of 5 recommended artists:  [np.int32(28567), np.int32(19401), np.int32(13175), np.int32(136658), np.int32(47492)]
# Recommended artist names: [np.str_('Shapeshifter'), np.str_('T.S.O.L.'), np.str_('Black Flag'), np.str_('Teague Cullen'), np.str_('Nu:Logic')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids:  ['user_000763' 'user_000606' 'user_000560' 'user_000807' 'user_000584']
# Indices of 5 recommended artists:  [np.int32(1567), np.int32(3955), np.int32(6293), np.int32(977), np.int32(1998)]
# Recommended artist names: [np.str_('Sportfreunde Stiller'), np.str_('Wolf Parade'), np.str_('Aisha Duo'), np.str_('E-Z Rollers'), np.str_('Big & Rich')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids:  ['user_000862' 'user_000074' 'user_000801' 'user_000522' 'user_000838']
# Indices of 5 recommended artists:  [np.int32(152768), np.int32(5473), np.int32(32968), np.int32(110583), np.int32(26121)]
# Recommended artist names: [np.str_('Tõnu Õnnepalu'), np.str_('Lawrence'), np.str_('Leon Jackson'), np.str_('Aimless'), np.str_('London Philharmonic Orchestra')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids:  ['user_000031' 'user_000242' 'user_000273' 'user_000870' 'user_000315']
# Indices of 5 recommended artists:  [np.int32(18723), np.int32(31381), np.int32(6847), np.int32(3463), np.int32(18636)]
# Recommended artist names: [np.str_('Laurie Anderson'), np.str_('Issa Bagayogo'), np.str_('Cradle Of Filth'), np.str_('My Favorite'), np.str_('Kadda Cherif Hadria')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids:  ['user_000569' 'user_000983' 'user_000960' 'user_000511' 'user_000795']
# Indices of 5 recommended artists:  [np.int32(73206), np.int32(35434), np.int32(14714), np.int32(11767), np.int32(34133)]
# Recommended artist names: [np.str_('Dan Friel'), np.str_('Michael Jackson & Janet Jackson'), np.str_('Throw Me The Statue'), np.str_('Jenny Owen Youngs'), np.str_('Black Affair')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids:  ['user_000993' 'user_000617' 'user_000838' 'user_000376' 'user_000577']
# Indices of 5 recommended artists:  [np.int32(5963), np.int32(66363), np.int32(122858), np.int32(1735), np.int32(19299)]
# Recommended artist names: [np.str_('Terranova'), np.str_('Burnside Project'), np.str_('Dgeneration'), np.str_('The Music'), np.str_('Shalamar')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids:  ['user_000075' 'user_000108' 'user_000905' 'user_000937' 'user_000859']
# Indices of 5 recommended artists:  [np.int32(41671), np.int32(41946), np.int32(12453), np.int32(3808), np.int32(5878)]
# Recommended artist names: [np.str_('Felikss & Livi'), np.str_('Stunt Monkey'), np.str_('The Edgar Winter Group'), np.str_('The Gutter Twins'), np.str_('Slipknot')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids:  ['user_000342' 'user_000894' 'user_000610' 'user_000771' 'user_000155']
# Indices of 5 recommended artists:  [np.int32(11078), np.int32(52771), np.int32(7424), np.int32(147003), np.int32(29627)]
# Recommended artist names: [np.str_('The Wannadies'), np.str_('Dan Gagnon Vs. Kmn'), np.str_('Anton Maiden'), np.str_('Girls Aloud Vs Sugababes'), np.str_('The Romantics')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids:  ['user_000676' 'user_000110' 'user_000686' 'user_000579' 'user_000346']
# Indices of 5 recommended artists:  [np.int32(23724), np.int32(14092), np.int32(42337), np.int32(11796), np.int32(1058)]
# Recommended artist names: [np.str_('T.O.K.'), np.str_('Kukl'), np.str_('Junior Reid'), np.str_('John Fahey'), np.str_('Gary Jules')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids:  ['user_000703' 'user_000415' 'user_000345' 'user_000031' 'user_000034']
# Indices of 5 recommended artists:  [np.int32(11910), np.int32(5964), np.int32(9699), np.int32(26235), np.int32(86317)]
# Recommended artist names: [np.str_('Lee "Scratch" Perry'), np.str_('Terre Thaemlitz'), np.str_('The Undertones'), np.str_('Metropolitan Jazz Affair'), np.str_('Magenta Skycode')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids:  ['user_000173' 'user_000776' 'user_000426' 'user_000650' 'user_000607']
# Indices of 5 recommended artists:  [np.int32(1083), np.int32(96789), np.int32(7066), np.int32(43913), np.int32(53873)]
# Recommended artist names: [np.str_('Hall & Oates'), np.str_('Ground Control'), np.str_('Still Remains'), np.str_('Ghost Machine'), np.str_('Farewell To Freeway')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids:  ['user_000897' 'user_000626' 'user_000706' 'user_000204' 'user_000577']
# Indices of 5 recommended artists:  [np.int32(17527), np.int32(1734), np.int32(4849), np.int32(1309), np.int32(57473)]
# Recommended artist names: [np.str_('Steven Wright'), np.str_('The Moldy Peaches'), np.str_("Youssou N'Dour & Neneh Cherry"), np.str_('Mia.'), np.str_('Almamegretta')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids:  ['user_000403' 'user_000467' 'user_000131' 'user_000031' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(18864), np.int32(8818), np.int32(5856), np.int32(45915), np.int32(89629)]
# Recommended artist names: [np.str_('Mariza'), np.str_('King Khan & The Shrines'), np.str_('Shellac'), np.str_('Uzi & Ari'), np.str_('Julien Clerc')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids:  ['user_000238' 'user_000361' 'user_000333' 'user_000385' 'user_000993']
# Indices of 5 recommended artists:  [np.int32(12196), np.int32(92125), np.int32(8882), np.int32(38367), np.int32(72330)]
# Recommended artist names: [np.str_('Poets Of The Fall'), np.str_('After The Ice'), np.str_('Leftfield'), np.str_('Olavi Uusivirta'), np.str_('Jerome Patrick Holan/Chuck Ber')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids:  ['user_000703' 'user_000074' 'user_000792' 'user_000807' 'user_000675']
# Indices of 5 recommended artists:  [np.int32(2810), np.int32(6752), np.int32(9551), np.int32(1596), np.int32(338)]
# Recommended artist names: [np.str_('Black Kids'), np.str_('Mattafix'), np.str_('The 5Th Dimension'), np.str_('Supreme Beings Of Leisure'), np.str_('Losoul')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids:  ['user_000294' 'user_000687' 'user_000284' 'user_000860' 'user_000326']
# Indices of 5 recommended artists:  [np.int32(84066), np.int32(5990), np.int32(77952), np.int32(84223), np.int32(61190)]
# Recommended artist names: [np.str_('Midnight Cocktail'), np.str_('The Stranglers'), np.str_('Green Hill Instrumental'), np.str_('Катя Chilly'), np.str_('Rita Pavone')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000018' 'user_000891' 'user_000658' 'user_000327']
# Indices of 5 recommended artists:  [np.int32(162677), np.int32(42185), np.int32(6856), np.int32(33838), np.int32(2992)]
# Recommended artist names: [np.str_('Anti_Anti Feat. Super Elastic Bubble Plastic'), np.str_('Raja Ram'), np.str_('Daughtry'), np.str_('Tre Allegri Ragazzi Morti'), np.str_('Delays')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000179' 'user_000484' 'user_000927' 'user_000431']
# Indices of 5 recommended artists:  [np.int32(4654), np.int32(99385), np.int32(2518), np.int32(26422), np.int32(107229)]
# Recommended artist names: [np.str_('Roxette'), np.str_('8 Mile Soundtrack - 50 Cent'), np.str_('Sugarcult'), np.str_('One-T + Cool-T'), np.str_('Aa.Vv Www.Cdonline.It')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids:  ['user_000482' 'user_000596' 'user_000705' 'user_000096' 'user_000653']
# Indices of 5 recommended artists:  [np.int32(8084), np.int32(6350), np.int32(60310), np.int32(16710), np.int32(89080)]
# Recommended artist names: [np.str_('Brian Wilson'), np.str_('Cassie'), np.str_('Billy Lee Riley'), np.str_('Bill Hicks'), np.str_('Gf')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids:  ['user_000493' 'user_000829' 'user_000110' 'user_000596' 'user_000653']
# Indices of 5 recommended artists:  [np.int32(8867), np.int32(10578), np.int32(829), np.int32(8722), np.int32(11767)]
# Recommended artist names: [np.str_('Lali Puna'), np.str_('Desmond Dekker'), np.str_('British Sea Power'), np.str_('Jim Gaffigan'), np.str_('Jenny Owen Youngs')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids:  ['user_000970' 'user_000989' 'user_000753' 'user_000294' 'user_000709']
# Indices of 5 recommended artists:  [np.int32(30962), np.int32(6308), np.int32(32668), np.int32(12498), np.int32(52133)]
# Recommended artist names: [np.str_('Brian Ibbott'), np.str_('Amel Larrieux'), np.str_('Ben Selvin And His Orchestra'), np.str_('The Ray Bryant Trio'), np.str_('Mark Knopfler & Emmylou Harris')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids:  ['user_000328' 'user_000476' 'user_000002' 'user_000631' 'user_000778']
# Indices of 5 recommended artists:  [np.int32(1486), np.int32(3659), np.int32(105112), np.int32(4723), np.int32(1559)]
# ...
# Indices of 5 recommended artists:  [np.int32(11649), np.int32(154361), np.int32(32963), np.int32(3782), np.int32(5370)]
# Recommended artist names: [np.str_('Great Big Sea'), np.str_('Gaynor Elien'), np.str_('Lee Morgan'), np.str_('The Coup'), np.str_('Jahcoozi')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids:  ['user_000789' 'user_000784' 'user_000376' 'user_000562' 'user_000824']
# Indices of 5 recommended artists:  [np.int32(19008), np.int32(12493), np.int32(63), np.int32(25565), np.int32(2126)]
# Recommended artist names: [np.str_('Niccokick'), np.str_('The Pogues'), np.str_('Björk'), np.str_('Duane Eddy'), np.str_('Duran Duran')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids:  ['user_000140' 'user_000485' 'user_000295' 'user_000427' 'user_000750']
# Indices of 5 recommended artists:  [np.int32(18243), np.int32(97524), np.int32(35491), np.int32(67698), np.int32(1613)]
# Recommended artist names: [np.str_('El Pali'), np.str_('Matondoni Wedding'), np.str_('Rupee'), np.str_('Cobra'), np.str_('Tegan And Sara')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids:  ['user_000761' 'user_000108' 'user_000691' 'user_000393' 'user_000731']
# Indices of 5 recommended artists:  [np.int32(17361), np.int32(51964), np.int32(1651), np.int32(12782), np.int32(86499)]
# Recommended artist names: [np.str_('Mark Mothersbaugh'), np.str_('Baz Luhrmann'), np.str_('The Chalets'), np.str_('Dick Dale'), np.str_('Tom Verlaine & The Million Dollar Bashers')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids:  ['user_000630' 'user_000382' 'user_000491' 'user_000434' 'user_000575']
# Indices of 5 recommended artists:  [np.int32(51216), np.int32(29715), np.int32(1718), np.int32(60124), np.int32(81649)]
# Recommended artist names: [np.str_('No Warning'), np.str_('Thee More Shallows'), np.str_('The Libertines'), np.str_('Tides'), np.str_('Fitzgerald')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids:  ['user_000893' 'user_000852' 'user_000382' 'user_000630' 'user_000259']
# Indices of 5 recommended artists:  [np.int32(83635), np.int32(91425), np.int32(807), np.int32(2083), np.int32(10785)]
# Recommended artist names: [np.str_('Khanate'), np.str_('Livitz Livitz'), np.str_('Blues Traveler'), np.str_('Days Away'), np.str_('Maria Taylor')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids:  ['user_000111' 'user_000054' 'user_000047' 'user_000276' 'user_000378']
# Indices of 5 recommended artists:  [np.int32(38461), np.int32(27215), np.int32(1441), np.int32(3341), np.int32(4084)]
# Recommended artist names: [np.str_("Alisha'S Attic"), np.str_('D!O'), np.str_('R. Kelly'), np.str_('Lily Allen'), np.str_('Bangles')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids:  ['user_000575' 'user_000120' 'user_000285' 'user_000729' 'user_000890']
# Indices of 5 recommended artists:  [np.int32(1797), np.int32(37309), np.int32(11769), np.int32(118083), np.int32(22636)]
# Recommended artist names: [np.str_('The Velvet Underground'), np.str_('Aidan Hawken'), np.str_('Jerry Lee Lewis'), np.str_('Jaffa Rose'), np.str_('Bamboo')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids:  ['user_000257' 'user_000224' 'user_000497' 'user_000789' 'user_000549']
# Indices of 5 recommended artists:  [np.int32(8577), np.int32(2998), np.int32(710), np.int32(9660), np.int32(114411)]
# Recommended artist names: [np.str_('Golden Silvers'), np.str_('Destroyer'), np.str_('Anajo'), np.str_('The Octopus Project'), np.str_('American Juniors Top 10')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids:  ['user_000729' 'user_000330' 'user_000814' 'user_000145' 'user_000890']
# Indices of 5 recommended artists:  [np.int32(1863), np.int32(1198), np.int32(154518), np.int32(81099), np.int32(7482)]
# Recommended artist names: [np.str_('Village People'), np.str_('Junesex'), np.str_('The Glorious Unseen'), np.str_('The Arrogant Sons Of Bitches'), np.str_('Children Of Bodom')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids:  ['user_000457' 'user_000093' 'user_000051' 'user_000478' 'user_000215']
# Indices of 5 recommended artists:  [np.int32(712), np.int32(892), np.int32(3251), np.int32(66205), np.int32(66225)]
# Recommended artist names: [np.str_('Andrew Bird'), np.str_('Creedence Clearwater Revival'), np.str_('Jenny Lewis'), np.str_('Esser'), np.str_('I Love Space')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids:  ['user_000702' 'user_000901' 'user_000440' 'user_000381' 'user_000284']
# Indices of 5 recommended artists:  [np.int32(135568), np.int32(62502), np.int32(136334), np.int32(135261), np.int32(62095)]
# Recommended artist names: [np.str_('Conjunto Rumbavana'), np.str_('悠織'), np.str_('Nabyla Maan'), np.str_('Ail Fionn'), np.str_('At The Lake')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids:  ['user_000873' 'user_000135' 'user_000806' 'user_000077' 'user_000807']
# Indices of 5 recommended artists:  [np.int32(3464), np.int32(14019), np.int32(46956), np.int32(153679), np.int32(1928)]
# Recommended artist names: [np.str_('My Little Airport'), np.str_('Honeybus'), np.str_('Benny Page'), np.str_('The Swanee Quintet'), np.str_('A Guy Called Gerald')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids:  ['user_000977' 'user_000897' 'user_000438' 'user_000215' 'user_000147']
# Indices of 5 recommended artists:  [np.int32(2753), np.int32(1092), np.int32(3135), np.int32(49307), np.int32(19277)]
# Recommended artist names: [np.str_('Atlas Sound'), np.str_('Hoobastank'), np.str_('Glasvegas'), np.str_('Lovemakers Vs 50 Cent'), np.str_('Scream Club')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids:  ['user_000715' 'user_000208' 'user_000940' 'user_000706' 'user_000010']
# Indices of 5 recommended artists:  [np.int32(1935), np.int32(6803), np.int32(1684), np.int32(53805), np.int32(1303)]
# Recommended artist names: [np.str_('Ace Of Base'), np.str_('Anatomist'), np.str_('The Feeling'), np.str_('Sparky Lightbourne'), np.str_('Mazzy Star')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids:  ['user_000606' 'user_000956' 'user_000560' 'user_000873' 'user_000584']
# Indices of 5 recommended artists:  [np.int32(584), np.int32(3683), np.int32(35442), np.int32(15214), np.int32(9623)]
# Recommended artist names: [np.str_('Thom Yorke'), np.str_('Sleater-Kinney'), np.str_('Morgan Heritage'), np.str_('The Foundations'), np.str_('The Hollies')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids:  ['user_000475' 'user_001000' 'user_000414' 'user_000596' 'user_000993']
# Indices of 5 recommended artists:  [np.int32(2378), np.int32(18164), np.int32(979), np.int32(4733), np.int32(50809)]
# Recommended artist names: [np.str_('Mirah'), np.str_('Deep Puddle Dynamics'), np.str_('Eagles Of Death Metal'), np.str_('Sting'), np.str_('Tunturia')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids:  ['user_000837' 'user_000373' 'user_000351' 'user_000118' 'user_000731']
# Indices of 5 recommended artists:  [np.int32(157799), np.int32(8131), np.int32(6913), np.int32(11533), np.int32(10711)]
# Recommended artist names: [np.str_('Alberto Lizzio; Philharmonia Slavonica'), np.str_('Caribou'), np.str_('Gin Blossoms'), np.str_('Electric Light Orchestra Part Ii'), np.str_('Johnny Cash & June Carter')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids:  ['user_000039' 'user_000298' 'user_000849' 'user_000902' 'user_000551']
# Indices of 5 recommended artists:  [np.int32(2412), np.int32(73240), np.int32(102700), np.int32(3840), np.int32(7275)]
# Recommended artist names: [np.str_('Outkast'), np.str_('Lauren Hoffman'), np.str_('Ac-Dc, Def Leppard, Bon Jovi,'), np.str_('The Rentals'), np.str_('Infernal')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000774' 'user_000229' 'user_000140' 'user_000909']
# Indices of 5 recommended artists:  [np.int32(6319), np.int32(63591), np.int32(59929), np.int32(44052), np.int32(147851)]
# Recommended artist names: [np.str_('Bah Samba'), np.str_('Blind Idiot God'), np.str_('Back When'), np.str_('Reeves Gabrels'), np.str_('Malibu')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids:  ['user_000572' 'user_000454' 'user_000910' 'user_000451' 'user_000249']
# Indices of 5 recommended artists:  [np.int32(29597), np.int32(29880), np.int32(49952), np.int32(2143), np.int32(43639)]
# Recommended artist names: [np.str_('The Passions'), np.str_('Erkin Koray'), np.str_('The Jerky Boys'), np.str_('Eric Prydz'), np.str_('Roland Vincent')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids:  ['user_000097' 'user_000545' 'user_000294' 'user_000854' 'user_000581']
# Indices of 5 recommended artists:  [np.int32(17922), np.int32(37352), np.int32(30812), np.int32(13477), np.int32(38860)]
# Recommended artist names: [np.str_('Billie Jo Spears'), np.str_('Dave Dee, Dozy, Beaky, Mick & Tich'), np.str_('Alex Skolnick Trio'), np.str_('The Damned'), np.str_('Floyd Robinson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids:  ['user_000791' 'user_000520' 'user_000059' 'user_000606' 'user_000837']
# Indices of 5 recommended artists:  [np.int32(6717), np.int32(1647), np.int32(139793), np.int32(90302), np.int32(100538)]
# Recommended artist names: [np.str_('Eric Carmen'), np.str_('The Breeders'), np.str_('The Cheers'), np.str_('Parva'), np.str_('Richard Fleeshman')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000927' 'user_000524' 'user_000188' 'user_000452']
# Indices of 5 recommended artists:  [np.int32(43089), np.int32(6998), np.int32(21049), np.int32(13280), np.int32(20376)]
# Recommended artist names: [np.str_('Mt.'), np.str_('Mudvayne'), np.str_('Mannequin'), np.str_('Horrorpops'), np.str_('ドレミ團')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids:  ['user_000106' 'user_000796' 'user_000036' 'user_000654' 'user_000499']
# Indices of 5 recommended artists:  [np.int32(108392), np.int32(12569), np.int32(108535), np.int32(7870), np.int32(769)]
# Recommended artist names: [np.str_("Baby, It'S Cold Outside"), np.str_('Tristan Prettyman'), np.str_('Sarah Vaughan & Gotan Project'), np.str_('808 State'), np.str_('Band Of Horses')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids:  ['user_000361' 'user_000089' 'user_000467' 'user_000345' 'user_000620']
# Indices of 5 recommended artists:  [np.int32(5725), np.int32(2563), np.int32(86305), np.int32(86218), np.int32(39547)]
# Recommended artist names: [np.str_('Philippe Cam'), np.str_('The Juliana Theory'), np.str_('Less'), np.str_('Faca'), np.str_('Starland Vocal Band')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids:  ['user_000650' 'user_000393' 'user_000565' 'user_000986' 'user_000108']
# Indices of 5 recommended artists:  [np.int32(41526), np.int32(1935), np.int32(804), np.int32(1660), np.int32(1595)]
# Recommended artist names: [np.str_('Bing Day'), np.str_('Ace Of Base'), np.str_('Blackmail'), np.str_('The Coral'), np.str_('Superpunk')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids:  ['user_000136' 'user_000870' 'user_000593' 'user_000914' 'user_000704']
# Indices of 5 recommended artists:  [np.int32(17546), np.int32(36394), np.int32(3328), np.int32(6804), np.int32(10987)]
# Recommended artist names: [np.str_('The Clean'), np.str_('Mira Billotte'), np.str_('Lemon Jelly'), np.str_('And One'), np.str_('The Dissociatives')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids:  ['user_000093' 'user_000998' 'user_000779' 'user_000123' 'user_000018']
# Indices of 5 recommended artists:  [np.int32(15517), np.int32(9791), np.int32(22506), np.int32(2058), np.int32(15555)]
# Recommended artist names: [np.str_('Daddy Dj'), np.str_('Tycho'), np.str_('These New Puritans'), np.str_('Cream'), np.str_('Dr. Bombay')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids:  ['user_000060' 'user_000345' 'user_000371' 'user_000467' 'user_000086']
# Indices of 5 recommended artists:  [np.int32(29005), np.int32(17084), np.int32(9264), np.int32(19562), np.int32(29648)]
# Recommended artist names: [np.str_('Hoover'), np.str_('Blue Swede'), np.str_('Queensrÿche'), np.str_('The Ruts'), np.str_('The Southland')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids:  ['user_000918' 'user_000996' 'user_000920' 'user_000024' 'user_000201']
# Indices of 5 recommended artists:  [np.int32(6703), np.int32(1416), np.int32(165131), np.int32(2584), np.int32(2231)]
# Recommended artist names: [np.str_('Chevelle'), np.str_('Peter Doherty'), np.str_('Rap On Dat Rock'), np.str_('The Used'), np.str_('Iggy Pop')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids:  ['user_000866' 'user_000515' 'user_000927' 'user_000503' 'user_000634']
# Indices of 5 recommended artists:  [np.int32(36951), np.int32(6940), np.int32(2793), np.int32(9166), np.int32(22263)]
# Recommended artist names: [np.str_('Aril Brikha'), np.str_('Jack Off Jill'), np.str_('Ben E. King'), np.str_('Orchestral Manoeuvres In The Dark'), np.str_('Home Of The Lame')]
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids:  ['user_000371' 'user_000795' 'user_000628' 'user_000345' 'user_000024']
# Indices of 5 recommended artists:  [np.int32(974), np.int32(1873), np.int32(10833), np.int32(44885), np.int32(12519)]
# Recommended artist names: [np.str_('Dusty Springfield'), np.str_('Waylon Jennings'), np.str_('P:Ano'), np.str_('Carole Shelley, Idina Menzel'), np.str_('The Yardbirds')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0053 seconds

# %%
# Count how many times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mapping dictionaries for user/artist to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map user/artist names to indices in the dataframe
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the user-artist matrix (UAM) in sparse format
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# Normalize rows (each row becomes a unit vector for cosine similarity)
UAM = normalize(UAM, norm='l2', axis=1)

# Precompute UAM transpose for efficient cosine similarity calculations
# This avoids repeatedly computing UAM.transpose() within the loop.
UAM_T = UAM.transpose().tocsr()

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

if __name__ == '__main__':
    start_time = time.time()
    num_users = UAM.shape[0]
    
    for u in range(num_users):
        print("Seed user-id:", user_ids[u])
        
        # Retrieve the normalized playcount vector (row) for the current user
        pc_vec = UAM.getrow(u)
        
        # Compute cosine similarity between the seed user and all other users
        # Using the precomputed UAM_T speeds up the dot-product calculation.
        sims = pc_vec.dot(UAM_T)
        
        # Convert the similarity result to COO format to easily access indices and data.
        sims_coo = sims.tocoo()
        
        # Remove self-similarity by filtering out the element where the column index equals the seed user.
        mask = sims_coo.col != u
        neighbor_indices = sims_coo.col[mask]
        neighbor_scores = sims_coo.data[mask]
        
        # Proceed only if there is at least one similar user
        if neighbor_scores.size == 0:
            print("No similar users found for", user_ids[u])
            print('-' * 80)
            continue
        
        # Use argpartition to quickly find indices of top K similarities.
        # For cases where there are fewer than K neighbors, return all.
        if neighbor_scores.size > K:
            top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
            # Sort the top K neighbors in descending order by their similarity scores.
            sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
            top_neighbors = neighbor_indices[top_k_idx][sorted_order]
        else:
            sorted_order = np.argsort(neighbor_scores)[::-1]
            top_neighbors = neighbor_indices[sorted_order]
        
        # Retrieve the actual user IDs for the top K neighbors
        recommended_user_ids = user_ids[top_neighbors]
        print(f"Nearest K={K} neighbors' user-ids:", recommended_user_ids.flatten())
        
        # Get all artist indices listened to by the top K similar users in one vectorized operation.
        # This avoids looping over each neighbor.
        neighbor_rows = UAM[top_neighbors, :]
        neighbor_coo = neighbor_rows.tocoo()
        recommended_artists_idx = np.unique(neighbor_coo.col)
        
        # Remove artists already known to the seed user
        seed_artists = pc_vec.indices
        recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)
        
        # Randomly choose 5 artists (or fewer, if not enough exist) for recommendation
        if recommended_artists_idx.size > 0:
            num_to_select = min(5, recommended_artists_idx.size)
            random_elements = random.sample(list(recommended_artists_idx), num_to_select)
            print(f"Indices of {len(random_elements)} recommended artists:", random_elements)
            rec_artist_names = [artist_ids[i] for i in random_elements]
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
            
        print('-' * 80)
    
    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Indices of 5 recommended artists: [np.int32(33819), np.int32(11275), np.int32(35833), np.int32(85196), np.int32(34275)]
# Recommended artist names: [np.str_('The Amalgamation Of Soundz'), np.str_('Beth Gibbons'), np.str_('Łona'), np.str_('Sweep - Favourite Song (Remixed)'), np.str_('Ginormous')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Indices of 5 recommended artists: [np.int32(10598), np.int32(140032), np.int32(3330), np.int32(17998), np.int32(8698)]
# Recommended artist names: [np.str_('Eddy Grant'), np.str_('Hurry Up'), np.str_('Leonard Cohen'), np.str_('Caifanes'), np.str_("Jane'S Addiction")]
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Indices of 5 recommended artists: [np.int32(50403), np.int32(22410), np.int32(92384), np.int32(6896), np.int32(59757)]
# Recommended artist names: [np.str_('The Potbelleez'), np.str_('Prinzhorn Dance School'), np.str_('Rekid'), np.str_('Fastball'), np.str_('Mashup')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Indices of 5 recommended artists: [np.int32(148615), np.int32(37380), np.int32(148443), np.int32(11431), np.int32(12607)]
# Recommended artist names: [np.str_('Paria'), np.str_('Fight Club'), np.str_('A Tribute To Radiohead'), np.str_('Dan Bern'), np.str_('Vienna Teng')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Indices of 5 recommended artists: [np.int32(2691), np.int32(43383), np.int32(995), np.int32(11518), np.int32(16694)]
# Recommended artist names: [np.str_('Akira Yamaoka'), np.str_('Torpedo Boyz'), np.str_('Elliott Smith'), np.str_('Eddie Vedder'), np.str_('Bally Sagoo')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Indices of 5 recommended artists: [np.int32(3040), np.int32(43978), np.int32(2838), np.int32(62233), np.int32(4684)]
# Recommended artist names: [np.str_('Electric Six'), np.str_('Love Shop'), np.str_('Brazilian Girls'), np.str_('Leroy Hanghofer'), np.str_('Shakedown')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Indices of 5 recommended artists: [np.int32(10669), np.int32(100467), np.int32(100258), np.int32(2577), np.int32(4340)]
# Recommended artist names: [np.str_('Hinder'), np.str_('Nate Dogg/The Game'), np.str_('Dubinc'), np.str_('The Seven Laws Of Woo'), np.str_('Hilary Duff')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Indices of 5 recommended artists: [np.int32(59704), np.int32(2223), np.int32(30390), np.int32(2755), np.int32(33270)]
# Recommended artist names: [np.str_('Kim Fai'), np.str_('Hot Chip'), np.str_('Michael Sembello'), np.str_('Au Revoir Simone'), np.str_('Vince Guaraldi')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Indices of 5 recommended artists: [np.int32(28522), np.int32(16293), np.int32(18300), np.int32(23959), np.int32(6709)]
# Recommended artist names: [np.str_('Pitch Black'), np.str_('Warrant'), np.str_('Fear'), np.str_('3 Inches Of Blood'), np.str_('Dead Kennedys')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Indices of 5 recommended artists: [np.int32(23896), np.int32(3359), np.int32(84272), np.int32(17084), np.int32(154444)]
# Recommended artist names: [np.str_('Turisas'), np.str_('Louis Armstrong'), np.str_('Benny Page & Mc Spyda'), np.str_('Blue Swede'), np.str_('Pitch Dark & Sgt. Slick')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Indices of 5 recommended artists: [np.int32(4668), np.int32(9752), np.int32(19700), np.int32(97328), np.int32(6853)]
# Recommended artist names: [np.str_('Sarah Brightman'), np.str_('Tom Tom Club'), np.str_('Violet Indiana'), np.str_('Jagjit Singh & Chitra Singh'), np.str_('Cutting Crew')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Indices of 5 recommended artists: [np.int32(19315), np.int32(24381), np.int32(10681), np.int32(19385), np.int32(77312)]
# Recommended artist names: [np.str_('Silver Apples'), np.str_('Jupiter One'), np.str_('I Was A Cub Scout'), np.str_('Subtle'), np.str_('The Intelligence')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Indices of 5 recommended artists: [np.int32(51658), np.int32(10781), np.int32(1477), np.int32(99618), np.int32(38401)]
# Recommended artist names: [np.str_('M0Rtis'), np.str_('Manitoba'), np.str_('Robbie Williams'), np.str_('Wolfpack'), np.str_('The Junior Revolution')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Indices of 5 recommended artists: [np.int32(2108), np.int32(72056), np.int32(3793), np.int32(3223), np.int32(2259)]
# Recommended artist names: [np.str_('Dj Mystik'), np.str_('Avey Tare'), np.str_('The Elected'), np.str_('Iron & Wine And Calexico'), np.str_('Johann Sebastian Bach')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Indices of 5 recommended artists: [np.int32(20646), np.int32(22405), np.int32(12829), np.int32(20720), np.int32(110019)]
# Recommended artist names: [np.str_('Blu Mar Ten'), np.str_('Polarkreis 18'), np.str_('Jimi Tenor'), np.str_('Dannii Minogue'), np.str_('Dicte & Dub Tractor')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Indices of 5 recommended artists: [np.int32(12046), np.int32(150304), np.int32(7450), np.int32(36357), np.int32(32306)]
# Recommended artist names: [np.str_('Michael Nyman'), np.str_('Palomine'), np.str_('Blind Faith'), np.str_('He Said'), np.str_('The Pink Spiders')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Indices of 5 recommended artists: [np.int32(34904), np.int32(5894), np.int32(33219), np.int32(38357), np.int32(70414)]
# Recommended artist names: [np.str_('Sivert Høyem'), np.str_('South Park'), np.str_('The Paul Butterfield Blues Band'), np.str_('Mick Jagger'), np.str_('Johnson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Indices of 5 recommended artists: [np.int32(11198), np.int32(3941), np.int32(10852), np.int32(9050), np.int32(3371)]
# Recommended artist names: [np.str_('Amy Millan'), np.str_('Wax Poetic'), np.str_('Pure Reason Revolution'), np.str_("Mo' Horizons"), np.str_('M. Ward')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Indices of 5 recommended artists: [np.int32(716), np.int32(8614), np.int32(7918), np.int32(12430), np.int32(2944)]
# Recommended artist names: [np.str_('Angelika Express'), np.str_('Hayden'), np.str_('Alphabeat'), np.str_('Terje Rypdal'), np.str_('Constantines')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Indices of 5 recommended artists: [np.int32(16905), np.int32(18925), np.int32(2051), np.int32(45103), np.int32(123364)]
# Recommended artist names: [np.str_('Olivia'), np.str_('Minor Majority'), np.str_('Clint Mansell'), np.str_('Dana Fuchs, Evan Rachel Wood, Jim Sturgess, Joe Anderson & T.V. Carpio'), np.str_("Mr. Milo. Lil' Danny & Friend")]
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Indices of 5 recommended artists: [np.int32(32482), np.int32(129721), np.int32(106834), np.int32(131218), np.int32(2058)]
# Recommended artist names: [np.str_('Ultimate Fakebook'), np.str_('Christa Deerynn'), np.str_('Money Addict Feat Pluck'), np.str_('The X-Certs'), np.str_('Cream')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Indices of 5 recommended artists: [np.int32(7787), np.int32(1587), np.int32(1366), np.int32(31101), np.int32(45868)]
# Recommended artist names: [np.str_('Talib Kweli & Hi-Tek'), np.str_('Sublime'), np.str_('No Doubt'), np.str_('Die! Die! Die!'), np.str_('Thao With The Get Down Stay Down')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Indices of 5 recommended artists: [np.int32(3202), np.int32(35208), np.int32(1114), np.int32(35740), np.int32(17662)]
# Recommended artist names: [np.str_("I'M From Barcelona"), np.str_('Taylor Deupree'), np.str_('Incubus'), np.str_('Syntaks'), np.str_('Isan')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Indices of 5 recommended artists: [np.int32(7710), np.int32(1406), np.int32(24299), np.int32(8068), np.int32(18523)]
# Recommended artist names: [np.str_('Paradise Lost'), np.str_('Peggy Lee'), np.str_('Populous'), np.str_('Bow Wow Wow'), np.str_('J.B. Lenoir')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Indices of 5 recommended artists: [np.int32(6737), np.int32(126217), np.int32(44326), np.int32(126146), np.int32(38477)]
# Recommended artist names: [np.str_('Jay-Z And Linkin Park'), np.str_('Miyauti Takayki'), np.str_('Clivillés & Cole'), np.str_('Chico Buarque & Francis Hime'), np.str_('Aneka')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Indices of 5 recommended artists: [np.int32(7653), np.int32(18867), np.int32(490), np.int32(48787), np.int32(2778)]
# Recommended artist names: [np.str_('Leevi And The Leavings'), np.str_('Mark Kozelek'), np.str_('Sade'), np.str_('Giants'), np.str_('Barış Manço')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Indices of 5 recommended artists: [np.int32(69699), np.int32(50560), np.int32(70618), np.int32(125738), np.int32(4379)]
# Recommended artist names: [np.str_('Blaze Feat. Ultra Naté'), np.str_('Hombres G'), np.str_('Lisa Frazier'), np.str_('John Legend (Feat. Andre 3000)'), np.str_('John Dahlbäck')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Indices of 5 recommended artists: [np.int32(145123), np.int32(50863), np.int32(56052), np.int32(127935), np.int32(6330)]
# Recommended artist names: [np.str_('Dred Scott'), np.str_('Espiritu'), np.str_('Menahan Street Band'), np.str_('Www.Mp3Il.Net'), np.str_('Bobby Valentino')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Indices of 5 recommended artists: [np.int32(38704), np.int32(68347), np.int32(2271), np.int32(115279), np.int32(2359)]
# Recommended artist names: [np.str_('Danny & The Juniors'), np.str_('Javelins'), np.str_('Justice Vs. Simian'), np.str_('Poxymusic'), np.str_('Megadeth')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Indices of 5 recommended artists: [np.int32(127383), np.int32(18435), np.int32(144793), np.int32(19358), np.int32(2430)]
# Recommended artist names: [np.str_("Red Hot 'N' Blue"), np.str_('Hamid Baroudi'), np.str_('Dc Deepressed'), np.str_('Sphincters Working Overtime'), np.str_('Peeping Tom')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Indices of 5 recommended artists: [np.int32(8016), np.int32(50928), np.int32(22621), np.int32(1078), np.int32(41004)]
# Recommended artist names: [np.str_('Bill Laswell'), np.str_('Avey Tare & Kría Brekkan'), np.str_('Aswad'), np.str_('Gruff Rhys'), np.str_('Ernest Ranglin')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Indices of 5 recommended artists: [np.int32(9444), np.int32(134306), np.int32(75334), np.int32(40110), np.int32(9265)]
# Recommended artist names: [np.str_('Spandau Ballet'), np.str_('Serge Rachmaninnoff'), np.str_('Simon Break'), np.str_('Vaughan Penn'), np.str_('Quincy Jones')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Indices of 5 recommended artists: [np.int32(60075), np.int32(30093), np.int32(6902), np.int32(51763), np.int32(60146)]
# Recommended artist names: [np.str_('Regression'), np.str_('Lao Che'), np.str_('Flesh Field'), np.str_('Psychotic Waltz'), np.str_('Zaum')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Indices of 5 recommended artists: [np.int32(86122), np.int32(86224), np.int32(4192), np.int32(18678), np.int32(9799)]
# Recommended artist names: [np.str_('Aqualise'), np.str_('Flash Hawk Parlor Ensemble'), np.str_('Dave Gahan'), np.str_('Kittu'), np.str_('Utah Saints')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Indices of 5 recommended artists: [np.int32(23999), np.int32(106583), np.int32(35176), np.int32(106357), np.int32(3403)]
# Recommended artist names: [np.str_('S.O.D.'), np.str_('Gang Starr Featuring Inspectah Deck'), np.str_('Pornoheft'), np.str_('Big L Feat. Royal Flush'), np.str_('Martha Wainwright')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Indices of 5 recommended artists: [np.int32(108112), np.int32(10466), np.int32(1432), np.int32(1742), np.int32(2382)]
# Recommended artist names: [np.str_('Tony Pilley'), np.str_('Airbourne'), np.str_("Plain White T'S"), np.str_('The Paddingtons'), np.str_('Modeselektor')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Indices of 5 recommended artists: [np.int32(25436), np.int32(50271), np.int32(3444), np.int32(79369), np.int32(58543)]
# Recommended artist names: [np.str_('Dean Martin, Frank Sinatra & Sammy Davis Jr.'), np.str_('Bill Murray'), np.str_('Mogwai'), np.str_('Tourbus Tales'), np.str_('Stranger & Patsy')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Indices of 5 recommended artists: [np.int32(23589), np.int32(1236), np.int32(2493), np.int32(1352), np.int32(148977)]
# Recommended artist names: [np.str_('Abney Park'), np.str_('Kylie Minogue'), np.str_('Simian Mobile Disco'), np.str_('New Found Glory'), np.str_('Смарагд')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Indices of 5 recommended artists: [np.int32(10505), np.int32(10621), np.int32(11670), np.int32(1198), np.int32(1133)]
# Recommended artist names: [np.str_("Ben'S Brother"), np.str_('Flobots'), np.str_('H-Blockx'), np.str_('Junesex'), np.str_('Jamie T')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Indices of 5 recommended artists: [np.int32(123349), np.int32(13855), np.int32(6910), np.int32(13123), np.int32(13023)]
# Recommended artist names: [np.str_('Barne Tv/Fragglene'), np.str_('Corduroy'), np.str_('Gackt'), np.str_('Westwood One'), np.str_('Göksel')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Indices of 5 recommended artists: [np.int32(46050), np.int32(7203), np.int32(9889), np.int32(27336), np.int32(27924)]
# Recommended artist names: [np.str_('Edgar Aichinger'), np.str_('Deep.Spirit'), np.str_('Arvo Pärt'), np.str_('Juliet'), np.str_('The O-Zone')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Indices of 5 recommended artists: [np.int32(4406), np.int32(11306), np.int32(44309), np.int32(2813), np.int32(44202)]
# Recommended artist names: [np.str_('King Britt'), np.str_('Blues Explosion'), np.str_('Tinypixel'), np.str_('Blackalicious'), np.str_('D Fast')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Indices of 5 recommended artists: [np.int32(17933), np.int32(9438), np.int32(18564), np.int32(14741), np.int32(11210)]
# Recommended artist names: [np.str_('Black Uhuru'), np.str_('Soulive'), np.str_('Jellyfish'), np.str_('Ultra Vivid Scene'), np.str_('Anouk')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Indices of 5 recommended artists: [np.int32(43714), np.int32(9943), np.int32(12912), np.int32(12036), np.int32(10045)]
# Recommended artist names: [np.str_('Embraze'), np.str_('Diva Destruction'), np.str_('Tesla'), np.str_('Metal Church'), np.str_('Meshuggah')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Indices of 5 recommended artists: [np.int32(85450), np.int32(111203), np.int32(44515), np.int32(21522), np.int32(24190)]
# Recommended artist names: [np.str_('宮内タカユキ'), np.str_('Dj Plead'), np.str_('Alejandra Guzmán'), np.str_('Madonna Ft. Justin & Timbaland'), np.str_('Severina')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Indices of 5 recommended artists: [np.int32(8555), np.int32(61434), np.int32(12840), np.int32(11352), np.int32(10162)]
# Recommended artist names: [np.str_('Gerry Rafferty'), np.str_('Mikromusic'), np.str_('Juno Reactor'), np.str_('Capsule'), np.str_('Trent Reznor And Peter Murphy')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Indices of 5 recommended artists: [np.int32(24476), np.int32(36260), np.int32(32867), np.int32(4129), np.int32(9521)]
# Recommended artist names: [np.str_('William Devaughn'), np.str_('Judge Dread'), np.str_('Hank Snow'), np.str_('Cassius'), np.str_('Talk Talk')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Indices of 5 recommended artists: [np.int32(150368), np.int32(54497), np.int32(8454), np.int32(1277), np.int32(80270)]
# Recommended artist names: [np.str_('Tbwnn'), np.str_('Bobby Caldwell'), np.str_('Erase Errata'), np.str_('Mando Diao'), np.str_('Kristin Hersh & Michael Stipe')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Indices of 5 recommended artists: [np.int32(10706), np.int32(2271), np.int32(10752), np.int32(12307), np.int32(1079)]
# Recommended artist names: [np.str_('John Fogerty'), np.str_('Justice Vs. Simian'), np.str_('Layo & Bushwacka!'), np.str_('Secondhand Serenade'), np.str_('Guided By Voices')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Indices of 5 recommended artists: [np.int32(25762), np.int32(9669), np.int32(10454), np.int32(1288), np.int32(3390)]
# Recommended artist names: [np.str_('Goodie Mob'), np.str_('The Quantic Soul Orchestra'), np.str_('3 Colours Red'), np.str_('Mark Knopfler'), np.str_('Mara Carlyle')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Indices of 5 recommended artists: [np.int32(66172), np.int32(1787), np.int32(147161), np.int32(66326), np.int32(10621)]
# Recommended artist names: [np.str_('Ben Mono Feat. Killa Kella'), np.str_('The Submarines'), np.str_('Bo Burnham'), np.str_('Tmvr'), np.str_('Flobots')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Indices of 5 recommended artists: [np.int32(34307), np.int32(48570), np.int32(59095), np.int32(1020), np.int32(1003)]
# Recommended artist names: [np.str_('Holly Vallanee'), np.str_('Dark Age'), np.str_('Elfonía Feat. Arjen Lucassen'), np.str_('Feeder'), np.str_('Eric Clapton')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Indices of 5 recommended artists: [np.int32(1974), np.int32(54740), np.int32(2022), np.int32(11868), np.int32(1159)]
# Recommended artist names: [np.str_('Atb'), np.str_('Cold Grits'), np.str_('Bt'), np.str_('Khadja Nin'), np.str_('Jimmy Eat World')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Indices of 5 recommended artists: [np.int32(19734), np.int32(116855), np.int32(2577), np.int32(24025), np.int32(13108)]
# Recommended artist names: [np.str_('William Shatner'), np.str_('Wardeath'), np.str_('The Seven Laws Of Woo'), np.str_('Unearth'), np.str_('The Living End')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Indices of 5 recommended artists: [np.int32(91388), np.int32(66775), np.int32(25833), np.int32(783), np.int32(22051)]
# Recommended artist names: [np.str_('Inkwell'), np.str_('David Guetta & Chris Willis Vs. Tocadisco'), np.str_('Hillsong'), np.str_('Ben Folds Five'), np.str_('Charlotte Church')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Indices of 5 recommended artists: [np.int32(12013), np.int32(2327), np.int32(18749), np.int32(15842), np.int32(7713)]
# Recommended artist names: [np.str_('Masters Of Reality'), np.str_('Lost Witness'), np.str_('Les Ogres De Barback'), np.str_('Lou Bega'), np.str_('Peanut Butter Wolf')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Indices of 5 recommended artists: [np.int32(1145), np.int32(5684), np.int32(3855), np.int32(42095), np.int32(3224)]
# Recommended artist names: [np.str_('Jefferson Airplane'), np.str_('Onyx'), np.str_('The Teenagers'), np.str_('Dj Inphinity'), np.str_('Iron Maiden')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Indices of 5 recommended artists: [np.int32(1773), np.int32(2016), np.int32(1792), np.int32(1426), np.int32(7815)]
# Recommended artist names: [np.str_('The Shins'), np.str_('Boys Like Girls'), np.str_('The Thrills'), np.str_('Pinback'), np.str_('The Troggs')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Indices of 5 recommended artists: [np.int32(1922), np.int32(19093), np.int32(999), np.int32(14953), np.int32(6651)]
# Recommended artist names: [np.str_('50 Cent'), np.str_('Peter Thomas'), np.str_('Elvis Presley'), np.str_('Fairview'), np.str_('Tlc')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Indices of 5 recommended artists: [np.int32(13035), np.int32(19037), np.int32(3692), np.int32(17875), np.int32(988)]
# Recommended artist names: [np.str_('Isolation Years'), np.str_('O.T. Quartet'), np.str_('Sondre Lerche'), np.str_('Barbara'), np.str_('Elbow')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Indices of 5 recommended artists: [np.int32(71213), np.int32(79518), np.int32(10305), np.int32(70036), np.int32(70447)]
# Recommended artist names: [np.str_('Shana Vanguarde'), np.str_('Bass-T Vs. Rocco'), np.str_('Ill Niño'), np.str_('Dj Paulo Featuring Pp'), np.str_('Junot Joyner')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Indices of 5 recommended artists: [np.int32(50989), np.int32(3261), np.int32(18034), np.int32(15058), np.int32(86204)]
# Recommended artist names: [np.str_('Rev. Columbus Mann'), np.str_('Joan Baez'), np.str_('Charles Sanford Skilton'), np.str_('Logh'), np.str_('Duane Mccoy Trio')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Indices of 5 recommended artists: [np.int32(20437), np.int32(99542), np.int32(7058), np.int32(78131), np.int32(60057)]
# Recommended artist names: [np.str_('梶浦由記'), np.str_("Millan & D'Attis"), np.str_('Skinny Puppy'), np.str_('Milla Jovovich & The Mdh Band'), np.str_('Papojka')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Indices of 5 recommended artists: [np.int32(9885), np.int32(1467), np.int32(108055), np.int32(19008), np.int32(15826)]
# Recommended artist names: [np.str_('Andrew W.K.'), np.str_('Richard Cheese'), np.str_('Ben Elton'), np.str_('Niccokick'), np.str_('Linda Ronstadt & James Ingram')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Indices of 5 recommended artists: [np.int32(1140), np.int32(18322), np.int32(9935), np.int32(14609), np.int32(10308)]
# Recommended artist names: [np.str_('Janove Ottesen'), np.str_('Flipper'), np.str_('David Vandervelde'), np.str_('The Move'), np.str_('Jennifer Lopez')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Indices of 5 recommended artists: [np.int32(17999), np.int32(2009), np.int32(121120), np.int32(9), np.int32(25091)]
# Recommended artist names: [np.str_('Calibre'), np.str_('Bob Sinclar'), np.str_('Matthias Heilbronn'), np.str_('A Tribe Called Quest'), np.str_('Anton Webern')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Indices of 5 recommended artists: [np.int32(9904), np.int32(10), np.int32(145579), np.int32(1540), np.int32(1221)]
# Recommended artist names: [np.str_('Bruno Sanfilippo'), np.str_('A. R. Rahman'), np.str_('Rule & Asta'), np.str_("Sinéad O'Connor"), np.str_('Kelly Clarkson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Indices of 5 recommended artists: [np.int32(34444), np.int32(5589), np.int32(1652), np.int32(15068), np.int32(2672)]
# Recommended artist names: [np.str_('Minizza'), np.str_('Mighty Math'), np.str_('The Charlatans'), np.str_('Marcus Miller'), np.str_('A Place To Bury Strangers')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Indices of 5 recommended artists: [np.int32(127879), np.int32(145157), np.int32(93946), np.int32(127869), np.int32(1077)]
# Recommended artist names: [np.str_('Scott Mills'), np.str_('J-Zone & Chief Chinchilla'), np.str_("Ak'Sent"), np.str_('Roxy'), np.str_('Grizzly Bear')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Indices of 5 recommended artists: [np.int32(3862), np.int32(3106), np.int32(32467), np.int32(84695), np.int32(1445)]
# Recommended artist names: [np.str_('The Twilight Singers'), np.str_('French Kicks'), np.str_('Turbo Fruits'), np.str_('Koala'), np.str_('Radio Birdman')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Indices of 5 recommended artists: [np.int32(29454), np.int32(1622), np.int32(7060), np.int32(9236), np.int32(109929)]
# Recommended artist names: [np.str_('The Cops'), np.str_('The Academy Is...'), np.str_('Sonique'), np.str_('Pop Will Eat Itself'), np.str_("D'Malicious")]
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Indices of 5 recommended artists: [np.int32(157953), np.int32(71059), np.int32(1895), np.int32(11377), np.int32(30712)]
# Recommended artist names: [np.str_('Usaf Heritage Of America Band'), np.str_('Raven-Symoné'), np.str_('Xavier Rudd'), np.str_('Charlotte Martin'), np.str_('Belinda')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Indices of 5 recommended artists: [np.int32(741), np.int32(354), np.int32(83550), np.int32(103406), np.int32(23580)]
# Recommended artist names: [np.str_('Aretha Franklin'), np.str_('Manual'), np.str_('Base Attack'), np.str_('Vesna'), np.str_('Tripswitch')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Indices of 5 recommended artists: [np.int32(30329), np.int32(158705), np.int32(18388), np.int32(135032), np.int32(17995)]
# Recommended artist names: [np.str_('Judie Tzuke'), np.str_('The Winchester Club'), np.str_('Giorgio Moroder'), np.str_('Ytcracker'), np.str_('Bush Tetras')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Indices of 5 recommended artists: [np.int32(32510), np.int32(11343), np.int32(12469), np.int32(11556), np.int32(5330)]
# Recommended artist names: [np.str_('Victor Wooten'), np.str_('Buffy Sainte-Marie'), np.str_('The Indulgers'), np.str_('Eros Ramazzotti & Anastacia'), np.str_('High Tone')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Indices of 5 recommended artists: [np.int32(28666), np.int32(131357), np.int32(1000), np.int32(64149), np.int32(150454)]
# Recommended artist names: [np.str_('Will Young'), np.str_('Yoshimi & Yuka'), np.str_('Embrace'), np.str_('Jozef Van Wissem'), np.str_('-Ed')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Indices of 5 recommended artists: [np.int32(20202), np.int32(143403), np.int32(32998), np.int32(15116), np.int32(12611)]
# Recommended artist names: [np.str_('Puffy'), np.str_('Solea Amphibia'), np.str_('Magnus'), np.str_('Owen'), np.str_('Värttinä')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Indices of 5 recommended artists: [np.int32(2656), np.int32(43299), np.int32(1916), np.int32(21), np.int32(1658)]
# Recommended artist names: [np.str_('Özgür Can'), np.str_('Studio Apartment'), np.str_('東京スカパラダイスオーケストラ'), np.str_('Alva Noto'), np.str_('The Cooper Temple Clause')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Indices of 5 recommended artists: [np.int32(21579), np.int32(2203), np.int32(6646), np.int32(95074), np.int32(4558)]
# Recommended artist names: [np.str_('A Secret Sense'), np.str_('Groove Coverage'), np.str_("The O'Jays"), np.str_('Addison Groove Project'), np.str_('Olive')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Indices of 5 recommended artists: [np.int32(5856), np.int32(19349), np.int32(64959), np.int32(11732), np.int32(10065)]
# Recommended artist names: [np.str_('Shellac'), np.str_('Solomon Schwartz'), np.str_('Victoria Hume'), np.str_('Iration Steppas'), np.str_('Norma Jean')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Indices of 5 recommended artists: [np.int32(823), np.int32(103506), np.int32(1098), np.int32(3380), np.int32(1250)]
# Recommended artist names: [np.str_('Brand New'), np.str_('Avatar'), np.str_('Hot Hot Heat'), np.str_('Magneta Lane'), np.str_('Less Than Jake')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Indices of 5 recommended artists: [np.int32(5234), np.int32(34844), np.int32(1911), np.int32(3371), np.int32(10761)]
# Recommended artist names: [np.str_('Evermore'), np.str_('Greg Dulli'), np.str_('¡Forward, Russia!'), np.str_('M. Ward'), np.str_('Linda Ronstadt')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Indices of 5 recommended artists: [np.int32(34855), np.int32(2137), np.int32(2320), np.int32(965), np.int32(19871)]
# Recommended artist names: [np.str_('Janusz Olejniczak'), np.str_('Emanuel'), np.str_('Liz Phair'), np.str_('Doris Day'), np.str_('Lunatica')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Indices of 5 recommended artists: [np.int32(71437), np.int32(79988), np.int32(76339), np.int32(121347), np.int32(13492)]
# Recommended artist names: [np.str_('Tiffany Evans'), np.str_('Man Of The Year'), np.str_('Bluefish'), np.str_('Adam Shaw'), np.str_('The Exploited')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Indices of 5 recommended artists: [np.int32(15531), np.int32(6709), np.int32(1443), np.int32(42458), np.int32(7259)]
# Recommended artist names: [np.str_('Derrick Harriott'), np.str_('Dead Kennedys'), np.str_('Rachael Yamagata'), np.str_('Tin Machine'), np.str_('Godsmack')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Indices of 5 recommended artists: [np.int32(8720), np.int32(15901), np.int32(6315), np.int32(19566), np.int32(18656)]
# Recommended artist names: [np.str_('Jesus Jones'), np.str_('Midnight Oil'), np.str_('Baaba Maal'), np.str_('The Shaggs'), np.str_('Kevin Coyne')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Indices of 5 recommended artists: [np.int32(23964), np.int32(2434), np.int32(16304), np.int32(1591), np.int32(4670)]
# Recommended artist names: [np.str_('As Blood Runs Black'), np.str_('Petter'), np.str_('White Lion'), np.str_('Sum 41'), np.str_('Sash!')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Indices of 5 recommended artists: [np.int32(118330), np.int32(38709), np.int32(5950), np.int32(9094), np.int32(58356)]
# Recommended artist names: [np.str_('On The Speakers'), np.str_('Darlene Love'), np.str_('Sébastien Schuller'), np.str_('Nancy Sinatra & Lee Hazlewood'), np.str_('Mystro')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Indices of 5 recommended artists: [np.int32(28097), np.int32(72452), np.int32(86489), np.int32(2315), np.int32(2765)]
# Recommended artist names: [np.str_('安室奈美恵'), np.str_('Axiotronic'), np.str_('The Video Age'), np.str_('Lindstrøm'), np.str_('B.B. King')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Indices of 5 recommended artists: [np.int32(40750), np.int32(8344), np.int32(173597), np.int32(77), np.int32(139)]
# Recommended artist names: [np.str_('Soul Avengerz'), np.str_('Dj Food'), np.str_('Digitalism Vs B.O.B.'), np.str_('Bonobo'), np.str_('Dido')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Indices of 5 recommended artists: [np.int32(1517), np.int32(150960), np.int32(80765), np.int32(150888), np.int32(150807)]
# Recommended artist names: [np.str_('Screeching Weasel'), np.str_('Right Thing'), np.str_('The Oxfam Glamour Models'), np.str_('Oleś/Trzaska/Oleś & Jean Luc Cappozzo'), np.str_('Lukasz Jaszak')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Indices of 5 recommended artists: [np.int32(12810), np.int32(3039), np.int32(21117), np.int32(1144), np.int32(77796)]
# Recommended artist names: [np.str_('Gustav Mahler'), np.str_('Electrelane'), np.str_('Naked Music'), np.str_('Jeff Buckley'), np.str_('Brian Connelly Formerly Of Sweet')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Indices of 5 recommended artists: [np.int32(34336), np.int32(84228), np.int32(3849), np.int32(878), np.int32(87577)]
# Recommended artist names: [np.str_('Jazzamor'), np.str_('Potter Puppet Pals'), np.str_('The Spinto Band'), np.str_('Colbie Caillat'), np.str_('Zidane')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Indices of 5 recommended artists: [np.int32(21380), np.int32(107332), np.int32(2492), np.int32(99545), np.int32(52710)]
# Recommended artist names: [np.str_('W.I.T.'), np.str_('Dj Ben'), np.str_('Shpongle'), np.str_('Moskwa'), np.str_('Africanism')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Indices of 5 recommended artists: [np.int32(15116), np.int32(1120), np.int32(1762), np.int32(4062), np.int32(28162)]
# Recommended artist names: [np.str_('Owen'), np.str_('Islands'), np.str_('The Real Tuesday Weld'), np.str_('Ashanti'), np.str_('Kris Kristofferson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Indices of 5 recommended artists: [np.int32(2270), np.int32(42102), np.int32(78561), np.int32(42380), np.int32(2535)]
# Recommended artist names: [np.str_('Justice'), np.str_('Dr. Evil'), np.str_('張學友'), np.str_('Ming Tea (Featuring Austin Powers)'), np.str_('Ten Years After')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Indices of 5 recommended artists: [np.int32(2989), np.int32(64532), np.int32(41717), np.int32(22512), np.int32(79247)]
# Recommended artist names: [np.str_('Death In June & Boyd Rice'), np.str_('Puppy'), np.str_('I Mother Earth'), np.str_('Tnt Jackson'), np.str_('James Harries')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Indices of 5 recommended artists: [np.int32(1578), np.int32(898), np.int32(1085), np.int32(781), np.int32(1014)]
# Recommended artist names: [np.str_('Stereo Total'), np.str_('Cyndi Lauper'), np.str_('Hansen Band'), np.str_('Belle And Sebastian'), np.str_('Ezio')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Indices of 5 recommended artists: [np.int32(1777), np.int32(2803), np.int32(15809), np.int32(1302), np.int32(5270)]
# ...
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Indices of 5 recommended artists: [np.int32(47751), np.int32(32896), np.int32(20429), np.int32(7457), np.int32(42415)]
# Recommended artist names: [np.str_('Vaisha'), np.str_('Ive Mendes'), np.str_('東京事変'), np.str_('Brand Nubian'), np.str_('Rotfront')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Indices of 5 recommended artists: [np.int32(9230), np.int32(90376), np.int32(3651), np.int32(9128), np.int32(10027)]
# Recommended artist names: [np.str_('Pnau'), np.str_('Barbara Carlotti'), np.str_('School Of Seven Bells'), np.str_('Nino Ferrer'), np.str_('Lady & Bird')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Indices of 5 recommended artists: [np.int32(1069), np.int32(86397), np.int32(97111), np.int32(97281), np.int32(35466)]
# Recommended artist names: [np.str_('Good Shoes'), np.str_('Postmen'), np.str_('Cultural Roots'), np.str_('Hiru Truku'), np.str_('Parachute')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Indices of 5 recommended artists: [np.int32(41484), np.int32(737), np.int32(133466), np.int32(8160), np.int32(41603)]
# Recommended artist names: [np.str_('Ak69'), np.str_('Aqueduct'), np.str_('Neilson Hubbard'), np.str_('Chick Corea'), np.str_('Depressive Age')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Indices of 5 recommended artists: [np.int32(41219), np.int32(1130), np.int32(3456), np.int32(91318), np.int32(5761)]
# Recommended artist names: [np.str_('I Hate Myself'), np.str_('James Blunt'), np.str_('Moving Units'), np.str_('Everlovely Lightningheart'), np.str_('Queens Of The Stone Age')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Indices of 5 recommended artists: [np.int32(19586), np.int32(124055), np.int32(51101), np.int32(123903), np.int32(1499)]
# Recommended artist names: [np.str_('The Time'), np.str_('Yukmouth & C-Bo (As Thug Lordz)'), np.str_('Dead Stop'), np.str_('Eras'), np.str_('Ryan Adams')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Indices of 5 recommended artists: [np.int32(14945), np.int32(76929), np.int32(71377), np.int32(24083), np.int32(27213)]
# Recommended artist names: [np.str_('Emma Bunton'), np.str_('Dinamit'), np.str_('The Beginerz'), np.str_('Behemoth'), np.str_('Combo De La Muerte')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Indices of 5 recommended artists: [np.int32(44610), np.int32(78980), np.int32(29330), np.int32(30943), np.int32(7008)]
# Recommended artist names: [np.str_('Ll Cool J & The Dream'), np.str_('Josh Hoge'), np.str_('Simon Dawes'), np.str_('Bonk'), np.str_('New Radicals')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Indices of 5 recommended artists: [np.int32(3420), np.int32(19448), np.int32(1884), np.int32(1028), np.int32(4769)]
# Recommended artist names: [np.str_('Menomena'), np.str_('The Comsat Angels'), np.str_('Wilco'), np.str_('Firefox Ak'), np.str_('The Byrds')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Indices of 5 recommended artists: [np.int32(40395), np.int32(900), np.int32(7010), np.int32(2446), np.int32(140672)]
# Recommended artist names: [np.str_('Digital Planet'), np.str_('Damien Rice'), np.str_('Nightwish'), np.str_('Queen'), np.str_('Michael Feerick')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Indices of 5 recommended artists: [np.int32(53334), np.int32(11818), np.int32(13050), np.int32(3170), np.int32(9255)]
# Recommended artist names: [np.str_('Kotki Dwa'), np.str_('Jonny Lang'), np.str_('Los Hermanos'), np.str_('Halou'), np.str_('Proxy')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Indices of 5 recommended artists: [np.int32(77692), np.int32(77235), np.int32(136485), np.int32(49970), np.int32(164436)]
# Recommended artist names: [np.str_('Mynta'), np.str_('Dutch Swing College Band'), np.str_('Rare Earth Feat.Peter Rivera'), np.str_('Enchant'), np.str_('Kacey Jones')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Indices of 5 recommended artists: [np.int32(36266), np.int32(13038), np.int32(4450), np.int32(47334), np.int32(17036)]
# Recommended artist names: [np.str_('La Ruda'), np.str_('Juanes'), np.str_('Lustral'), np.str_('Konsta'), np.str_('Aldo Bender')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Indices of 5 recommended artists: [np.int32(2528), np.int32(7727), np.int32(58839), np.int32(46218), np.int32(19672)]
# Recommended artist names: [np.str_('T.I.'), np.str_('Prince Paul'), np.str_("Hear'Say"), np.str_('Lunabee'), np.str_('Undershakers')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Indices of 5 recommended artists: [np.int32(138432), np.int32(666), np.int32(63059), np.int32(4344), np.int32(63321)]
# Recommended artist names: [np.str_('Veil Of Maya'), np.str_('311'), np.str_('Eastern Rebellion'), np.str_('House Of Pain'), np.str_('Tastexperience')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Indices of 5 recommended artists: [np.int32(10707), np.int32(2067), np.int32(56801), np.int32(7118), np.int32(1682)]
# Recommended artist names: [np.str_('John Lee Hooker'), np.str_('Daft Punk'), np.str_('Sunshine Anderson'), np.str_('Weird Al Yankovic'), np.str_('The Faint')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Indices of 5 recommended artists: [np.int32(35790), np.int32(3200), np.int32(5006), np.int32(1295), np.int32(2526)]
# Recommended artist names: [np.str_('Justyna Steczkowska'), np.str_('Husky Rescue'), np.str_('Beastie Boys'), np.str_('Mateo Messina'), np.str_('Surkin')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Indices of 5 recommended artists: [np.int32(141149), np.int32(90200), np.int32(90228), np.int32(141147), np.int32(7665)]
# Recommended artist names: [np.str_('Happy Drivers'), np.str_('Bilal/Common/Mc Lyte'), np.str_('Haole'), np.str_('Beat Down Sound'), np.str_('Madvillain')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Indices of 5 recommended artists: [np.int32(30390), np.int32(159752), np.int32(21534), np.int32(79884), np.int32(31470)]
# Recommended artist names: [np.str_('Michael Sembello'), np.str_('Chorus; Paul Kandel'), np.str_('Molotov'), np.str_('Denise Murz'), np.str_('Katie Herzig')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Indices of 5 recommended artists: [np.int32(14623), np.int32(112105), np.int32(14993), np.int32(60620), np.int32(34112)]
# Recommended artist names: [np.str_('The Pastels'), np.str_('James White'), np.str_('Hyride'), np.str_('Obi'), np.str_('Balanescu Quartet')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Indices of 5 recommended artists: [np.int32(54007), np.int32(43043), np.int32(102288), np.int32(101628), np.int32(11895)]
# Recommended artist names: [np.str_('Basic Channel'), np.str_('Marvin Sease'), np.str_('The Rainbows'), np.str_('Daso And Pawas Gupta'), np.str_('L7')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Indices of 5 recommended artists: [np.int32(59094), np.int32(2943), np.int32(19104), np.int32(39626), np.int32(576)]
# Recommended artist names: [np.str_('Elexorien'), np.str_('Connie Francis'), np.str_('Phyllis Nelson'), np.str_('The Blessing'), np.str_('The Sugarhill Gang')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Indices of 5 recommended artists: [np.int32(21666), np.int32(28662), np.int32(150323), np.int32(28237), np.int32(19457)]
# Recommended artist names: [np.str_('George Michael & Queen & Lisa Stansfield'), np.str_('Volunteer'), np.str_('Rayzyn'), np.str_('Bail Out!'), np.str_('The Dave Clark Five')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Indices of 5 recommended artists: [np.int32(19985), np.int32(21358), np.int32(1294), np.int32(60026), np.int32(4733)]
# Recommended artist names: [np.str_('Buck-Tick'), np.str_('Trenthian'), np.str_('Mat Kearney'), np.str_('Kumikameli'), np.str_('Sting')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Indices of 5 recommended artists: [np.int32(41014), np.int32(1750), np.int32(70019), np.int32(4614), np.int32(32866)]
# Recommended artist names: [np.str_('Spleen United'), np.str_('The Police'), np.str_('Dj Dero'), np.str_('Quantic'), np.str_('Hacienda')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Indices of 5 recommended artists: [np.int32(12756), np.int32(1425), np.int32(86430), np.int32(23606), np.int32(10596)]
# Recommended artist names: [np.str_('Café Tacvba'), np.str_('Piebald'), np.str_('Seclusion'), np.str_('Christian Walz'), np.str_('Earl Grant')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Indices of 5 recommended artists: [np.int32(4668), np.int32(8027), np.int32(115637), np.int32(173285), np.int32(24083)]
# Recommended artist names: [np.str_('Sarah Brightman'), np.str_('Black Box'), np.str_('Beloved Enemy'), np.str_('Downstream'), np.str_('Behemoth')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Indices of 5 recommended artists: [np.int32(9526), np.int32(50807), np.int32(148316), np.int32(15448), np.int32(31085)]
# Recommended artist names: [np.str_('Tarkan'), np.str_('This Is The Kit'), np.str_('Winston Prince'), np.str_('Bob Geldof'), np.str_('Deana Carter')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Indices of 5 recommended artists: [np.int32(10890), np.int32(47027), np.int32(2813), np.int32(10316), np.int32(1696)]
# Recommended artist names: [np.str_('Seth Lakeman'), np.str_('Clipz'), np.str_('Blackalicious'), np.str_('Lacrimosa'), np.str_('The Go! Team')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Indices of 5 recommended artists: [np.int32(3090), np.int32(86216), np.int32(18721), np.int32(86485), np.int32(1851)]
# Recommended artist names: [np.str_("Five O'Clock Heroes"), np.str_('Eureka!'), np.str_('Laura Nyro'), np.str_('The Subversives'), np.str_("Umphrey'S Mcgee")]
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Indices of 5 recommended artists: [np.int32(12509), np.int32(2057), np.int32(5069), np.int32(10610), np.int32(1877)]
# Recommended artist names: [np.str_('The Sun'), np.str_('Covenant'), np.str_('Chicks On Speed'), np.str_('Estelle'), np.str_('Weezer')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Indices of 5 recommended artists: [np.int32(42621), np.int32(37495), np.int32(85926), np.int32(5558), np.int32(4435)]
# Recommended artist names: [np.str_('Alexis Weissenberg'), np.str_('Sophia George'), np.str_('Floor Thirteen'), np.str_('Master Blaster'), np.str_('Lionel Richie')]
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Indices of 5 recommended artists: [np.int32(86301), np.int32(86388), np.int32(11196), np.int32(35266), np.int32(36868)]
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0011 seconds

# %%
#Thread
from concurrent.futures import ThreadPoolExecutor, as_completed
MAX_WORKERS = 8
# Build User-Artist Matrix (UAM)
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

UAM = normalize(UAM, norm='l2', axis=1)

user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

UAM_T = UAM.transpose().tocsr()

num_users = UAM.shape[0]

# --- Define function to process a single user ---
def process_single_user(u):
    pc_vec = UAM.getrow(u)
    sims = pc_vec.dot(UAM_T)
    sims_coo = sims.tocoo()
    
    mask = sims_coo.col != u
    neighbor_indices = sims_coo.col[mask]
    neighbor_scores = sims_coo.data[mask]
    
    if neighbor_scores.size == 0:
        return (user_ids[u], None, None)

    if neighbor_scores.size > K:
        top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
        sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
        top_neighbors = neighbor_indices[top_k_idx][sorted_order]
    else:
        sorted_order = np.argsort(neighbor_scores)[::-1]
        top_neighbors = neighbor_indices[sorted_order]

    recommended_user_ids = user_ids[top_neighbors]

    neighbor_rows = UAM[top_neighbors, :]
    neighbor_coo = neighbor_rows.tocoo()
    recommended_artists_idx = np.unique(neighbor_coo.col)

    seed_artists = UAM.getrow(u).indices
    recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)

    if recommended_artists_idx.size > 0:
        num_to_select = min(5, recommended_artists_idx.size)
        random_elements = random.sample(list(recommended_artists_idx), num_to_select)
        rec_artist_names = [artist_ids[i] for i in random_elements]
        return (user_ids[u], recommended_user_ids, rec_artist_names)
    else:
        return (user_ids[u], recommended_user_ids, None)

# --- Main Program ---
if __name__ == '__main__':
    start_time = time.time()

    all_results = []

    # Use ThreadPoolExecutor to process all users in parallel
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(process_single_user, u) for u in range(num_users)]
        for future in as_completed(futures):
            res = future.result()
            all_results.append(res)

    # Print all results
    for res in all_results:
        seed_user, neighbors, rec_artists = res
        print("Seed user-id:", seed_user)
        if neighbors is None:
            print("No similar users found for", seed_user)
            print('-' * 80)
            continue
        print(f"Nearest K={K} neighbors' user-ids:", neighbors.flatten())
        if rec_artists is not None:
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
        print('-' * 80)

    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids: ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids: ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids: ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids: ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids: ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids: ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids: ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids: ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids: ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids: ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids: ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids: ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids: ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids: ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids: ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids: ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids: ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000126
# Nearest K=5 neighbors' user-ids: ['user_000420' 'user_000668' 'user_000058' 'user_000665' 'user_000120']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000125
# Nearest K=5 neighbors' user-ids: ['user_000771' 'user_000405' 'user_000482' 'user_000665' 'user_000040']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000128
# Nearest K=5 neighbors' user-ids: ['user_000856' 'user_000622' 'user_000421' 'user_000336' 'user_000131']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000123
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000998' 'user_000018' 'user_000779' 'user_000486']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000124
# Nearest K=5 neighbors' user-ids: ['user_000233' 'user_000479' 'user_000610' 'user_000765' 'user_000613']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000127
# Nearest K=5 neighbors' user-ids: ['user_000774' 'user_000510' 'user_000341' 'user_000595' 'user_000886']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000130
# Nearest K=5 neighbors' user-ids: ['user_000305' 'user_000594' 'user_000222' 'user_000607' 'user_000783']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000129
# Nearest K=5 neighbors' user-ids: ['user_000948' 'user_000336' 'user_000497' 'user_000918' 'user_000234']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000134
# Nearest K=5 neighbors' user-ids: ['user_000225' 'user_000535' 'user_000198' 'user_000413' 'user_000347']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000133
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000233' 'user_000467' 'user_000050' 'user_000124']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# ...
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000956
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000560' 'user_000606' 'user_000584' 'user_000078']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000959
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000342' 'user_000613' 'user_000437' 'user_000771']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000958
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000393' 'user_000274' 'user_000490' 'user_000753']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids: ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids: ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids: ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids: ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids: ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids: ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0009 seconds

# %%
# cprofile
from concurrent.futures import ThreadPoolExecutor, as_completed
MAX_WORKERS = 8
# Build User-Artist Matrix (UAM)
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

UAM = normalize(UAM, norm='l2', axis=1)

user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

UAM_T = UAM.transpose().tocsr()

num_users = UAM.shape[0]

# --- Define function to process a single user ---
def process_single_user(u):
    pc_vec = UAM.getrow(u)
    sims = pc_vec.dot(UAM_T)
    sims_coo = sims.tocoo()
    
    mask = sims_coo.col != u
    neighbor_indices = sims_coo.col[mask]
    neighbor_scores = sims_coo.data[mask]
    
    if neighbor_scores.size == 0:
        return (user_ids[u], None, None)

    if neighbor_scores.size > K:
        top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
        sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
        top_neighbors = neighbor_indices[top_k_idx][sorted_order]
    else:
        sorted_order = np.argsort(neighbor_scores)[::-1]
        top_neighbors = neighbor_indices[sorted_order]

    recommended_user_ids = user_ids[top_neighbors]

    neighbor_rows = UAM[top_neighbors, :]
    neighbor_coo = neighbor_rows.tocoo()
    recommended_artists_idx = np.unique(neighbor_coo.col)

    seed_artists = UAM.getrow(u).indices
    recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)

    if recommended_artists_idx.size > 0:
        num_to_select = min(5, recommended_artists_idx.size)
        random_elements = random.sample(list(recommended_artists_idx), num_to_select)
        rec_artist_names = [artist_ids[i] for i in random_elements]
        return (user_ids[u], recommended_user_ids, rec_artist_names)
    else:
        return (user_ids[u], recommended_user_ids, None)

# --- Main Program ---
def main():
    start_time = time.time()

    all_results = []

    # Use ThreadPoolExecutor to process all users in parallel
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(process_single_user, u) for u in range(num_users)]
        for future in as_completed(futures):
            res = future.result()
            all_results.append(res)

    # Print all results
    for res in all_results:
        seed_user, neighbors, rec_artists = res
        print("Seed user-id:", seed_user)
        if neighbors is None:
            print("No similar users found for", seed_user)
            print('-' * 80)
            continue
        print(f"Nearest K={K} neighbors' user-ids:", neighbors.flatten())
        if rec_artists is not None:
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
        print('-' * 80)

    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")

if __name__ == '__main__':
    main()
# Out:
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids: ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids: ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids: ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids: ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids: ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids: ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids: ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids: ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids: ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids: ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids: ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids: ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids: ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids: ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids: ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids: ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000123
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000998' 'user_000018' 'user_000779' 'user_000486']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids: ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000126
# Nearest K=5 neighbors' user-ids: ['user_000420' 'user_000668' 'user_000058' 'user_000665' 'user_000120']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000125
# Nearest K=5 neighbors' user-ids: ['user_000771' 'user_000405' 'user_000482' 'user_000665' 'user_000040']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000124
# Nearest K=5 neighbors' user-ids: ['user_000233' 'user_000479' 'user_000610' 'user_000765' 'user_000613']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000129
# Nearest K=5 neighbors' user-ids: ['user_000948' 'user_000336' 'user_000497' 'user_000918' 'user_000234']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000130
# Nearest K=5 neighbors' user-ids: ['user_000305' 'user_000594' 'user_000222' 'user_000607' 'user_000783']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000128
# Nearest K=5 neighbors' user-ids: ['user_000856' 'user_000622' 'user_000421' 'user_000336' 'user_000131']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000127
# Nearest K=5 neighbors' user-ids: ['user_000774' 'user_000510' 'user_000341' 'user_000595' 'user_000886']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000134
# Nearest K=5 neighbors' user-ids: ['user_000225' 'user_000535' 'user_000198' 'user_000413' 'user_000347']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000133
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000233' 'user_000467' 'user_000050' 'user_000124']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# ...
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000959
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000342' 'user_000613' 'user_000437' 'user_000771']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000957
# Nearest K=5 neighbors' user-ids: ['user_000611' 'user_000173' 'user_000442' 'user_000395' 'user_000230']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000958
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000393' 'user_000274' 'user_000490' 'user_000753']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids: ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids: ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids: ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids: ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids: ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids: ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0009 seconds

# %% [markdown]
# # cprofile

# %%
# %prun -s cumulative main()
# Out:
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids: ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids: ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids: ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids: ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids: ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids: ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids: ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids: ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids: ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids: ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids: ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids: ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids: ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids: ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids: ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids: ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids: ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000125
# Nearest K=5 neighbors' user-ids: ['user_000771' 'user_000405' 'user_000482' 'user_000665' 'user_000040']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids: ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000124
# Nearest K=5 neighbors' user-ids: ['user_000233' 'user_000479' 'user_000610' 'user_000765' 'user_000613']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000126
# Nearest K=5 neighbors' user-ids: ['user_000420' 'user_000668' 'user_000058' 'user_000665' 'user_000120']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000123
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000998' 'user_000018' 'user_000779' 'user_000486']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000128
# Nearest K=5 neighbors' user-ids: ['user_000856' 'user_000622' 'user_000421' 'user_000336' 'user_000131']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000130
# Nearest K=5 neighbors' user-ids: ['user_000305' 'user_000594' 'user_000222' 'user_000607' 'user_000783']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000129
# Nearest K=5 neighbors' user-ids: ['user_000948' 'user_000336' 'user_000497' 'user_000918' 'user_000234']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000132
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000134' 'user_000056' 'user_000225' 'user_000535']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000133
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000233' 'user_000467' 'user_000050' 'user_000124']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000127
# Nearest K=5 neighbors' user-ids: ['user_000774' 'user_000510' 'user_000341' 'user_000595' 'user_000886']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# ...
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Recommended artist names: [np.str_('Lara Martelli'), np.str_('Pina'), np.str_('Amon Düül Ii'), np.str_('Dynamoe'), np.str_('Kammerflimmer Kollektief')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0011 seconds
#          497820 function calls (492860 primitive calls) in 1.120 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.120    1.120 {built-in method builtins.exec}
#         1    0.001    0.001    1.120    1.120 <string>:1(<module>)
#         1    0.002    0.002    1.119    1.119 2635966931.py:65(main)
#       993    0.003    0.000    0.914    0.001 _base.py:199(as_completed)
#      1774    0.003    0.000    0.909    0.001 threading.py:295(wait)
#       782    0.001    0.000    0.909    0.001 threading.py:611(wait)
#      7105    0.904    0.000    0.904    0.000 {method 'acquire' of '_thread.lock' objects}
#      3969    0.005    0.000    0.189    0.000 {built-in method builtins.print}
#     13890    0.089    0.000    0.153    0.000 interactiveshell.py:3025(write)
#     13890    0.027    0.000    0.040    0.000 iostream.py:655(write)
#       992    0.001    0.000    0.030    0.000 arrayprint.py:1685(_array_str_implementation)
#       992    0.001    0.000    0.030    0.000 arrayprint.py:605(array2string)
#       992    0.001    0.000    0.026    0.000 arrayprint.py:550(wrapper)
#       992    0.002    0.000    0.024    0.000 arrayprint.py:567(_array2string)
#     27780    0.010    0.000    0.020    0.000 traitlets.py:676(__get__)
#       992    0.000    0.000    0.019    0.000 arrayprint.py:828(_formatArray)
#  5952/992    0.007    0.000    0.019    0.000 arrayprint.py:837(recurser)
#         1    0.000    0.000    0.012    0.012 2635966931.py:72(<listcomp>)
#       992    0.001    0.000    0.011    0.000 thread.py:161(submit)
#     27780    0.008    0.000    0.009    0.000 traitlets.py:629(get)
#       992    0.000    0.000    0.008    0.000 thread.py:180(_adjust_thread_count)
#      4960    0.002    0.000    0.006    0.000 arrayprint.py:801(_extendLine_pretty)
#      4960    0.002    0.000    0.005    0.000 arrayprint.py:436(repr_format)
#       992    0.002    0.000    0.005    0.000 threading.py:440(acquire)
#     13890    0.003    0.000    0.004    0.000 iostream.py:550(_is_master_process)
#      1767    0.002    0.000    0.004    0.000 _base.py:177(_yield_finished_futures)
#     13890    0.003    0.000    0.003    0.000 iostream.py:505(parent_header)
#      4960    0.002    0.000    0.003    0.000 arrayprint.py:787(_extendLine)
#         8    0.000    0.000    0.003    0.000 threading.py:945(start)
#       992    0.002    0.000    0.003    0.000 arrayprint.py:496(_get_format_function)
#     51587    0.003    0.000    0.003    0.000 {built-in method builtins.len}
#     55560    0.002    0.000    0.002    0.000 typing.py:2287(cast)
#       992    0.001    0.000    0.002    0.000 arrayprint.py:50(_make_options_dict)
#      4960    0.002    0.000    0.002    0.000 {method 'item' of 'numpy.generic' objects}
#       992    0.001    0.000    0.002    0.000 _base.py:428(result)
#      4532    0.001    0.000    0.002    0.000 threading.py:271(__enter__)
#      4532    0.001    0.000    0.001    0.000 threading.py:274(__exit__)
#     13890    0.001    0.000    0.001    0.000 displayhook.py:118(is_active)
#       992    0.000    0.000    0.001    0.000 _base.py:328(__init__)
#     15902    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.RLock' objects}
#     13890    0.001    0.000    0.001    0.000 iostream.py:577(_schedule_flush)
#       774    0.001    0.000    0.001    0.000 threading.py:601(clear)
#     13890    0.001    0.000    0.001    0.000 {built-in method builtins.any}
#     13890    0.001    0.000    0.001    0.000 displaypub.py:150(is_publishing)
#      1002    0.001    0.000    0.001    0.000 threading.py:243(__init__)
#     18890    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#     15874    0.001    0.000    0.001    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#       992    0.001    0.000    0.001    0.000 arrayprint.py:446(_get_formatdict)
#     14882    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#     13890    0.001    0.000    0.001    0.000 {method 'write' of '_io.StringIO' objects}
#     13890    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#      1774    0.000    0.000    0.001    0.000 threading.py:283(_acquire_restore)
#      1774    0.000    0.000    0.001    0.000 threading.py:286(_is_owned)
#       992    0.001    0.000    0.001    0.000 arrayprint.py:59(<dictcomp>)
#      4960    0.001    0.000    0.001    0.000 {built-in method builtins.repr}
#      1774    0.000    0.000    0.000    0.000 threading.py:280(_release_save)
#      1786    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       992    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#      1984    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       992    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#      5315    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:646(__exit__)
#      4960    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 thread.py:216(shutdown)
#         8    0.000    0.000    0.000    0.000 threading.py:1087(join)
#         9    0.000    0.000    0.000    0.000 threading.py:1125(_wait_for_tstate_lock)
#      4960    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#      2548    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       992    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       992    0.000    0.000    0.000    0.000 threading.py:90(RLock)
#      1984    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#        40    0.000    0.000    0.000    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#         1    0.000    0.000    0.000    0.000 _base.py:147(__enter__)
#       992    0.000    0.000    0.000    0.000 thread.py:47(__init__)
#       992    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       992    0.000    0.000    0.000    0.000 _base.py:398(__get_result)
#      1984    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         8    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#         1    0.000    0.000    0.000    0.000 _base.py:155(_create_and_install_waiters)
#      1782    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:151(__exit__)
#      1985    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       992    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#      1775    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:144(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#       992    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#       992    0.000    0.000    0.000    0.000 arrayprint.py:467(<lambda>)
#      1008    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        20    0.000    0.000    0.000    0.000 ipkernel.py:790(<setcomp>)
#       992    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#      1016    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         8    0.000    0.000    0.000    0.000 ipkernel.py:768(init_closure)
#       992    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#      1000    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       992    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       992    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 threading.py:856(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:223(<genexpr>)
#       992    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#       774    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#       993    0.000    0.000    0.000    0.000 {method 'put' of '_queue.SimpleQueue' objects}
#       992    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 socket.py:623(send)
#       992    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         8    0.000    0.000    0.000    0.000 threading.py:1051(_stop)
#        20    0.000    0.000    0.000    0.000 threading.py:1501(enumerate)
#       320    0.000    0.000    0.000    0.000 threading.py:1168(ident)
#         8    0.000    0.000    0.000    0.000 weakref.py:427(__setitem__)
#         9    0.000    0.000    0.000    0.000 threading.py:562(__init__)
#         8    0.000    0.000    0.000    0.000 threading.py:829(_maintain_shutdown_locks)
#         1    0.000    0.000    0.000    0.000 thread.py:123(__init__)
#        16    0.000    0.000    0.000    0.000 threading.py:1453(current_thread)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:85(add)
#         8    0.000    0.000    0.000    0.000 threading.py:839(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _base.py:77(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:429(__init__)
#        80    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 threading.py:1324(_make_invoke_excepthook)
#         1    0.000    0.000    0.000    0.000 _base.py:61(__init__)
#         8    0.000    0.000    0.000    0.000 weakref.py:369(remove)
#        40    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        16    0.000    0.000    0.000    0.000 threading.py:1206(daemon)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#        17    0.000    0.000    0.000    0.000 threading.py:575(is_set)
#         8    0.000    0.000    0.000    0.000 {method 'difference_update' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:1192(is_alive)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#        30    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:643(__enter__)

# %% [markdown]
# # Applying Cython

# %%
# %load_ext cython

# %%
# %%cython
# import numpy as np
# cimport numpy as np
#
# def build_playcounts_cy(str filepath):
#     cdef dict counts = {}
#     cdef bytes line
#     with open(filepath, 'rb') as f:
#         for line in f:
#             parts = line.rstrip(b'\n').split(b'\t')
#             counts[(parts[0], parts[3])] = counts.get((parts[0], parts[3]), 0) + 1
#     return counts
#
# def fill_csr_data_cy(dict counts,
#                      np.ndarray[np.int32_t, ndim=1] data,
#                      np.ndarray[np.int32_t, ndim=1] rows,
#                      np.ndarray[np.int32_t, ndim=1] cols,
#                      dict user_to_idx,
#                      dict artist_to_idx):
#     cdef Py_ssize_t i = 0
#     cdef tuple key
#     cdef int cnt
#     for key, cnt in counts.items():
#         data[i] = cnt
#         rows[i] = user_to_idx[key[0]]
#         cols[i] = artist_to_idx[key[1]]
#         i += 1
# Out:
# Content of stderr:
# In file included from /Users/yujinkim/.cache/ipython/cython/_cython_magic_d8bf18963cbfa55fc94ffc689c3f52d777066b59.c:1250:
# In file included from /Users/yujinkim/Desktop/Efficient MRS/efficient_mrs/.venv/lib/python3.11/site-packages/numpy/_core/include/numpy/arrayobject.h:5:
# In file included from /Users/yujinkim/Desktop/Efficient MRS/efficient_mrs/.venv/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarrayobject.h:12:
# In file included from /Users/yujinkim/Desktop/Efficient MRS/efficient_mrs/.venv/lib/python3.11/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1913:
# /Users/yujinkim/Desktop/Efficient MRS/efficient_mrs/.venv/lib/python3.11/site-packages/numpy/_core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: "Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d8bf18963cbfa55fc94ffc689c3f52d777066b59.c:7864:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#  7864 |                     CYTHON_FALLTHROUGH;
#       |                     ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d8bf18963cbfa55fc94ffc689c3f52d777066b59.c:567:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#   567 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#       |                                  ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d8bf18963cbfa55fc94ffc689c3f52d777066b59.c:7875:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#  7875 |                     CYTHON_FALLTHROUGH;
#       |                     ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d8bf18963cbfa55fc94ffc689c3f52d777066b59.c:567:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#   567 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#       |                                  ^
# /Users/yujinkim/.cache/ipython/cython/_cython_magic_d8bf18963cbfa55fc94ffc689c3f52d777066b59.c:9186:26: warning: code will never be executed [-Wunreachable-code]
#  9186 |                 module = PyImport_ImportModuleLevelObject(
#       |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 4 warnings generated.

# %%
counts = build_playcounts_cy(file_path)        # Cython: replace pandas groupby

# Create mappings: user/artist → index
user_id_to_idx     = {u:i for i,u in enumerate({k[0] for k in counts.keys()})}
artist_name_to_idx = {a:i for i,a in enumerate({k[1] for k in counts.keys()})}

# Build CSR arrays with Cython
n_nnz    = len(counts)
data_arr = np.empty(n_nnz, dtype=np.int32)
row_arr  = np.empty(n_nnz, dtype=np.int32)
col_arr  = np.empty(n_nnz, dtype=np.int32)

fill_csr_data_cy(
    counts,
    data_arr, row_arr, col_arr,
    user_id_to_idx, artist_name_to_idx
)                                              # Cython: replace Python loop

# Assemble sparse matrix exactly like before
UAM = csr_matrix(
    (data_arr, (row_arr, col_arr)),
    shape=(len(user_id_to_idx), len(artist_name_to_idx))
)

UAM = normalize(UAM, norm="l2", axis=1)

user_ids   = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

UAM_T      = UAM.transpose().tocsr()
num_users  = UAM.shape[0]

# — Define function to process a single user —
def process_single_user(u):
    pc_vec    = UAM.getrow(u)
    sims      = pc_vec.dot(UAM_T)
    sims_coo  = sims.tocoo()

    mask             = sims_coo.col != u
    neighbor_indices = sims_coo.col[mask]
    neighbor_scores  = sims_coo.data[mask]

    if neighbor_scores.size == 0:
        return (user_ids[u], None, None)

    if neighbor_scores.size > K:
        top_k_idx    = np.argpartition(neighbor_scores, -K)[-K:]
        sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
        top_neighbors = neighbor_indices[top_k_idx][sorted_order]
    else:
        sorted_order  = np.argsort(neighbor_scores)[::-1]
        top_neighbors = neighbor_indices[sorted_order]

    recommended_user_ids = user_ids[top_neighbors]
    neighbor_rows       = UAM[top_neighbors, :]
    neighbor_coo        = neighbor_rows.tocoo()
    recommended_artists_idx = np.unique(neighbor_coo.col)

    seed_artists = UAM.getrow(u).indices
    recommended_artists_idx = np.setdiff1d(
        recommended_artists_idx, seed_artists
    )

    if recommended_artists_idx.size > 0:
        num_to_select   = min(5, recommended_artists_idx.size)
        random_elements = random.sample(
            list(recommended_artists_idx), num_to_select
        )
        rec_artist_names = [artist_ids[i] for i in random_elements]
        return (user_ids[u], recommended_user_ids, rec_artist_names)
    else:
        return (user_ids[u], recommended_user_ids, None)

# — Main Program —
if __name__ == "__main__":
    start_time  = time.time()
    all_results = []

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [
            executor.submit(process_single_user, u)
            for u in range(num_users)
        ]
        for future in as_completed(futures):
            res = future.result()
            all_results.append(res)

    for res in all_results:
        seed_user, neighbors, rec_artists = res
        print("Seed user-id:", seed_user)
        if neighbors is None:
            print("No similar users found for", seed_user)
            print('-' * 80)
            continue
        print(f"Nearest K={K} neighbors' user-ids:", neighbors.flatten())
        if rec_artists is not None:
            print("Recommended artist names:", rec_artists)
        else:
            print("No new recommended artists found.")
        print('-' * 80)

    end_time = time.time()
    avg_time  = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: b'user_000526'
# Nearest K=5 neighbors' user-ids: [b'user_000084' b'user_000518' b'user_000155' b'user_000285'
#  b'user_000771']
# Recommended artist names: [np.bytes_(b'Megamix'), np.bytes_(b'Stereophonics'), np.bytes_(b'Orgy'), np.bytes_(b'Carolina Liar'), np.bytes_(b'David Tavare')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000367'
# Nearest K=5 neighbors' user-ids: [b'user_000072' b'user_000018' b'user_000668' b'user_000386'
#  b'user_000414']
# Recommended artist names: [np.bytes_(b'The Feeling'), np.bytes_(b'Bogdan Raczynski'), np.bytes_(b'Macy Gray'), np.bytes_(b'Vanoni Paoli'), np.bytes_(b'Eagle-Eye Cherry')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000406'
# Nearest K=5 neighbors' user-ids: [b'user_000767' b'user_000070' b'user_000600' b'user_000219'
#  b'user_000922']
# Recommended artist names: [np.bytes_(b'Optiganally Yours'), np.bytes_(b'A Flock Of Seagulls'), np.bytes_(b'The Rentals'), np.bytes_(b'Babybird'), np.bytes_(b'The Vibrators')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000088'
# Nearest K=5 neighbors' user-ids: [b'user_000577' b'user_000204' b'user_000706' b'user_000626'
#  b'user_000897']
# Recommended artist names: [np.bytes_(b'Covenant'), np.bytes_(b'Hungarian Quartet'), np.bytes_(b'Royal Philharmonic Orchestra'), np.bytes_(b'Ben Folds Five'), np.bytes_(b'Os Mutantes')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000497'
# Nearest K=5 neighbors' user-ids: [b'user_000257' b'user_000014' b'user_000336' b'user_000443'
#  b'user_000129']
# Recommended artist names: [np.bytes_(b'Nancy Sinatra'), np.bytes_(b'Black Eyes'), np.bytes_(b'Tom Petty And The Heartbreakers'), np.bytes_(b'The One Am Radio'), np.bytes_(b'Kid British')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000107'
# Nearest K=5 neighbors' user-ids: [b'user_000382' b'user_000890' b'user_000976' b'user_000729'
#  b'user_000616']
# Recommended artist names: [np.bytes_(b'Eisley'), np.bytes_(b'Soul Assasins'), np.bytes_(b'The Sainte Catherines'), np.bytes_(b'Self Against City'), np.bytes_(b'Aphrodite/Roni Size')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000508'
# Nearest K=5 neighbors' user-ids: [b'user_000091' b'user_000499' b'user_000074' b'user_000210'
#  b'user_000939']
# Recommended artist names: [np.bytes_(b'Billy Bragg'), np.bytes_(b'Jorge Ben Jor'), np.bytes_(b'The Birthday Party'), np.bytes_(b'Bruno Coulais, Choir Of The Hungarian National Radio, Hungrarian Symphony Orchestra Budapest & Laurent Petitgirard'), np.bytes_(b'M.I.S.T.')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000275'
# Nearest K=5 neighbors' user-ids: [b'user_000653' b'user_000096' b'user_000596' b'user_000902'
#  b'user_000482']
# Recommended artist names: [np.bytes_(b'Papa Roach'), np.bytes_(b'\xd0\x91\xd1\x83\xd0\xb3\xd0\xbe\xd1\x82\xd0\xb0\xd0\xba'), np.bytes_(b'De La Soul'), np.bytes_(b'Shakira & Alejandro Sanz'), np.bytes_(b'Petter')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000369'
# Nearest K=5 neighbors' user-ids: [b'user_000912' b'user_000395' b'user_000084' b'user_000426'
#  b'user_000676']
# Recommended artist names: [np.bytes_(b'Junkie Xl Feat Lauren Rocket'), np.bytes_(b'Accept'), np.bytes_(b'Creed'), np.bytes_(b"Dakken Kaeon'S Retro Sphere"), np.bytes_(b'Overseer')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000144'
# Nearest K=5 neighbors' user-ids: [b'user_000155' b'user_000961' b'user_000190' b'user_000710'
#  b'user_000263']
# Recommended artist names: [np.bytes_(b'Neal Schon'), np.bytes_(b'Tom Cochrane'), np.bytes_(b'Alan Rickman, Helena Bonham Carter, Jamie Campbell Bower, Jayne Wisener, Johnny Depp, Laura Michelle Kelly'), np.bytes_(b'Lauryn Hill'), np.bytes_(b'La Caina')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000928'
# Nearest K=5 neighbors' user-ids: [b'user_000788' b'user_000512' b'user_000926' b'user_000185'
#  b'user_000542']
# Recommended artist names: [np.bytes_(b'Olive'), np.bytes_(b'Fatboy Slim'), np.bytes_(b'Aaliyah'), np.bytes_(b'Benjamin Britten'), np.bytes_(b'Placebo')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000668'
# Nearest K=5 neighbors' user-ids: [b'user_000837' b'user_000018' b'user_000072' b'user_000791'
#  b'user_000626']
# Recommended artist names: [np.bytes_(b'The Ordinary Boys Vs. Lady Sovereign'), np.bytes_(b'Eternal'), np.bytes_(b'Jack Savoretti'), np.bytes_(b'Bay City Rollers'), np.bytes_(b'Ballboy')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000488'
# Nearest K=5 neighbors' user-ids: [b'user_000520' b'user_000714' b'user_000205' b'user_000342'
#  b'user_000832']
# Recommended artist names: [np.bytes_(b'Chevelle'), np.bytes_(b'Limp Bizkit'), np.bytes_(b'Calle Ciega'), np.bytes_(b'American Hi-Fi'), np.bytes_(b'Flobots')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000877'
# Nearest K=5 neighbors' user-ids: [b'user_000215' b'user_000089' b'user_000977' b'user_000136'
#  b'user_000345']
# Recommended artist names: [np.bytes_(b'Jay Haze'), np.bytes_(b'Chris Botti'), np.bytes_(b'Delta 5'), np.bytes_(b'Dave Stephens'), np.bytes_(b'Sense')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000348'
# Nearest K=5 neighbors' user-ids: [b'user_000150' b'user_000654' b'user_000625' b'user_000643'
#  b'user_000095']
# Recommended artist names: [np.bytes_(b'Badi Assad'), np.bytes_(b'Gordian Knot'), np.bytes_(b'Aaron Neville'), np.bytes_(b'Eric Carmen'), np.bytes_(b'Mezarkabul')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000051'
# Nearest K=5 neighbors' user-ids: [b'user_000215' b'user_000089' b'user_000977' b'user_000803'
#  b'user_000478']
# Recommended artist names: [np.bytes_(b'Bitter:Sweet'), np.bytes_(b'The Whigs'), np.bytes_(b'Mercury Rev'), np.bytes_(b'Aimee Mann'), np.bytes_(b'Black Rebel Motorcycle Club')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000719'
# Nearest K=5 neighbors' user-ids: [b'user_000835' b'user_000300' b'user_000570' b'user_000776'
#  b'user_000611']
# Recommended artist names: [np.bytes_(b'Gianna Nannini'), np.bytes_(b'Billy Squier'), np.bytes_(b'Shocking Pinks'), np.bytes_(b'Seance'), np.bytes_(b'Ney Matogrosso')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000601'
# Nearest K=5 neighbors' user-ids: [b'user_000661' b'user_000568' b'user_000742' b'user_000649'
#  b'user_000650']
# Recommended artist names: [np.bytes_(b'Gaelle'), np.bytes_(b'Pet Shop Boys'), np.bytes_(b'Poison'), np.bytes_(b'Www.Hhqc.Com Dtm Ft Nessa'), np.bytes_(b'Comic Gate')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000219'
# Nearest K=5 neighbors' user-ids: [b'user_000600' b'user_000031' b'user_000102' b'user_000826'
#  b'user_000870']
# Recommended artist names: [np.bytes_(b'The Underwolves'), np.bytes_(b'The Doors'), np.bytes_(b'Trey Anastasio'), np.bytes_(b'Carl Loewe'), np.bytes_(b'Spektrum')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000503'
# Nearest K=5 neighbors' user-ids: [b'user_000634' b'user_000927' b'user_000999' b'user_000866'
#  b'user_000515']
# Recommended artist names: [np.bytes_(b'Rollerball'), np.bytes_(b'Felix Da Housecat'), np.bytes_(b'Jacek Sienkiewicz'), np.bytes_(b'Myslovitz'), np.bytes_(b'Michael Jackson')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000724'
# Nearest K=5 neighbors' user-ids: [b'user_000669' b'user_000880' b'user_000632' b'user_000500'
#  b'user_000702']
# Recommended artist names: [np.bytes_(b'Ray Brown'), np.bytes_(b'Tito Paris'), np.bytes_(b'Audra Mcdonald'), np.bytes_(b'Melody Gardot'), np.bytes_(b'Mah Damba')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000832'
# Nearest K=5 neighbors' user-ids: [b'user_000791' b'user_000897' b'user_000626' b'user_000016'
#  b'user_000513']
# Recommended artist names: [np.bytes_(b'The Tubes'), np.bytes_(b'Nightmares On Wax'), np.bytes_(b'The Sword'), np.bytes_(b'Xxx'), np.bytes_(b'Prething')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000627'
# Nearest K=5 neighbors' user-ids: [b'user_000560' b'user_000606' b'user_000584' b'user_000873'
#  b'user_000956']
# Recommended artist names: [np.bytes_(b'Dj Kentaro'), np.bytes_(b'Daler Mehndi'), np.bytes_(b'Tony Bennett'), np.bytes_(b'Shakira'), np.bytes_(b'Gilbert B\xc3\xa9caud')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000906'
# Nearest K=5 neighbors' user-ids: [b'user_000099' b'user_000543' b'user_000238' b'user_000360'
#  b'user_000217']
# Recommended artist names: [np.bytes_(b'Lasgo'), np.bytes_(b'Cat Power & The Dirty Delta Blues'), np.bytes_(b'Team Sleep'), np.bytes_(b'Scissorborough'), np.bytes_(b'Tin Machine')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000651'
# Nearest K=5 neighbors' user-ids: [b'user_000479' b'user_000233' b'user_000124' b'user_000409'
#  b'user_000765']
# Recommended artist names: [np.bytes_(b'Trey Songz'), np.bytes_(b'Hhh (Ryu\xe2\x98\x86 & Dai)'), np.bytes_(b'Pulse 81 Featuring Marijana'), np.bytes_(b'Brandi Carlile'), np.bytes_(b'Da Juice')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000614'
# Nearest K=5 neighbors' user-ids: [b'user_000573' b'user_000271' b'user_000048' b'user_000255'
#  b'user_000970']
# Recommended artist names: [np.bytes_(b'Almedal'), np.bytes_(b'The Apples In Stereo'), np.bytes_(b'Jesse Spencer'), np.bytes_(b'Blizihizake'), np.bytes_(b'Magnify')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000397'
# Nearest K=5 neighbors' user-ids: [b'user_000569' b'user_000795' b'user_000693' b'user_000345'
#  b'user_000249']
# Recommended artist names: [np.bytes_(b'Barenaked Ladies'), np.bytes_(b'Faca'), np.bytes_(b'Ryuichi Sakamoto & David Sylvian'), np.bytes_(b'Samhain'), np.bytes_(b'Dykehouse')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000845'
# Nearest K=5 neighbors' user-ids: [b'user_000957' b'user_000461' b'user_000612' b'user_000453'
#  b'user_000182']
# Recommended artist names: [np.bytes_(b'Rivendell'), np.bytes_(b'Dj Suv'), np.bytes_(b'York Feat. Angelina'), np.bytes_(b'John Lennon'), np.bytes_(b'Black Mamba')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000615'
# Nearest K=5 neighbors' user-ids: [b'user_000041' b'user_000649' b'user_000409' b'user_000198'
#  b'user_000873']
# Recommended artist names: [np.bytes_(b'St0Rm3Ru'), np.bytes_(b'Peaches & Cream'), np.bytes_(b'Tommy Guerrero'), np.bytes_(b'Dean Peters & The Edison Factor'), np.bytes_(b'Solit Sleep')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000366'
# Nearest K=5 neighbors' user-ids: [b'user_000173' b'user_000230' b'user_000912' b'user_000395'
#  b'user_000152']
# Recommended artist names: [np.bytes_(b'Metal Church'), np.bytes_(b'Rage'), np.bytes_(b'Intense Degree'), np.bytes_(b'Gabry Ponte'), np.bytes_(b"Blackmore'S Night")]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000029'
# Nearest K=5 neighbors' user-ids: [b'user_000024' b'user_000703' b'user_000513' b'user_000826'
#  b'user_000345']
# Recommended artist names: [np.bytes_(b'"Weird Al" Yankovic'), np.bytes_(b'No Doubt'), np.bytes_(b'Venus Infers'), np.bytes_(b'Ursula'), np.bytes_(b'Atom And His Package')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000302'
# Nearest K=5 neighbors' user-ids: [b'user_000116' b'user_000766' b'user_000170' b'user_000885'
#  b'user_000198']
# Recommended artist names: [np.bytes_(b'Rufus Thomas'), np.bytes_(b'Trans Am'), np.bytes_(b'Franco Battiato'), np.bytes_(b'Heaven 17'), np.bytes_(b'Dirty Princess')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000782'
# Nearest K=5 neighbors' user-ids: [b'user_000808' b'user_000199' b'user_000142' b'user_000507'
#  b'user_000557']
# Recommended artist names: [np.bytes_(b'Lil Wayne'), np.bytes_(b'Steel Attack'), np.bytes_(b'The Maytals'), np.bytes_(b'Geezer Lake'), np.bytes_(b'Bristles')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000067'
# Nearest K=5 neighbors' user-ids: [b'user_000658' b'user_000760' b'user_000624' b'user_000122'
#  b'user_000020']
# Recommended artist names: [np.bytes_(b'[Dialogue]'), np.bytes_(b'Echo & The Bunnymen'), np.bytes_(b'Sander Van Doorn'), np.bytes_(b'Apollonia'), np.bytes_(b'Varnu Vejas')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000850'
# Nearest K=5 neighbors' user-ids: [b'user_000421' b'user_000299' b'user_000400' b'user_000805'
#  b'user_000960']
# Recommended artist names: [np.bytes_(b'Across The Universe'), np.bytes_(b'Duffy'), np.bytes_(b'Deerhoof'), np.bytes_(b'Carbon Leaf'), np.bytes_(b'John Mayer Trio')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000220'
# Nearest K=5 neighbors' user-ids: [b'user_000704' b'user_000294' b'user_000870' b'user_000086'
#  b'user_000753']
# Recommended artist names: [np.bytes_(b'Jackie Mittoo'), np.bytes_(b'Os Mutantes'), np.bytes_(b'Neu!'), np.bytes_(b'Swayzak'), np.bytes_(b'Manual')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000761'
# Nearest K=5 neighbors' user-ids: [b'user_000889' b'user_000970' b'user_000532' b'user_000378'
#  b'user_000047']
# Recommended artist names: [np.bytes_(b'Al Martino'), np.bytes_(b'Ill Ni\xc3\xb1o'), np.bytes_(b'British Sea Power'), np.bytes_(b'Ian Siegal'), np.bytes_(b'Deejay 4 Speed')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000139'
# Nearest K=5 neighbors' user-ids: [b'user_000020' b'user_000624' b'user_000683' b'user_000658'
#  b'user_000327']
# Recommended artist names: [np.bytes_(b'Lightning Bolt'), np.bytes_(b'[Disney]'), np.bytes_(b'Mates Of State'), np.bytes_(b'Nickelback'), np.bytes_(b'Burhan \xc3\x96cal & Jamaaledeen Tacuma Feat. Natacha Atlas')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000707'
# Nearest K=5 neighbors' user-ids: [b'user_000020' b'user_000624' b'user_000683' b'user_000139'
#  b'user_000658']
# Recommended artist names: [np.bytes_(b'Olivia'), np.bytes_(b'Fronda'), np.bytes_(b'Otis Redding'), np.bytes_(b'Ours'), np.bytes_(b'Maia Hirasawa')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000544'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000059' b'user_000467' b'user_000189'
#  b'user_000031']
# Recommended artist names: [np.bytes_(b'Love Spirals Downwards'), np.bytes_(b'Stock, Hausen & Walkman'), np.bytes_(b'All Girl Summer Fun Band'), np.bytes_(b'Aqua Bassino'), np.bytes_(b'Blue Stone')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000628'
# Nearest K=5 neighbors' user-ids: [b'user_000024' b'user_000345' b'user_001000' b'user_000998'
#  b'user_000031']
# Recommended artist names: [np.bytes_(b'Vince K'), np.bytes_(b'Zolt\xc3\xa1n Kod\xc3\xa1ly'), np.bytes_(b'Tryo'), np.bytes_(b'Archers Of Loaf'), np.bytes_(b'D-Sisive')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000281'
# Nearest K=5 neighbors' user-ids: [b'user_000154' b'user_000744' b'user_000631' b'user_000691'
#  b'user_000882']
# Recommended artist names: [np.bytes_(b'Blue Man Group'), np.bytes_(b'Viva Saturn'), np.bytes_(b'Japan'), np.bytes_(b'Naked Eyes'), np.bytes_(b'Murray Perahia, Academy Of St. Martin In The Fields')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000821'
# Nearest K=5 neighbors' user-ids: [b'user_000504' b'user_000871' b'user_000488' b'user_000714'
#  b'user_000089']
# Recommended artist names: [np.bytes_(b'Fito P\xc3\xa1ez'), np.bytes_(b'Ricardo Arjona'), np.bytes_(b'Talking Heads'), np.bytes_(b'Buddy'), np.bytes_(b'Kevin Johansen')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000970'
# Nearest K=5 neighbors' user-ids: [b'user_000731' b'user_000393' b'user_000691' b'user_000108'
#  b'user_000761']
# Recommended artist names: [np.bytes_(b'Void Settler'), np.bytes_(b'Bono'), np.bytes_(b'Days Away'), np.bytes_(b'Louiz Banks, Sikkil Gurucharan, John Mclaughlin, U. Shrinivas'), np.bytes_(b'Jennifer Lopez')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000498'
# Nearest K=5 neighbors' user-ids: [b'user_000565' b'user_000692' b'user_000952' b'user_000381'
#  b'user_000833']
# Recommended artist names: [np.bytes_(b'Weeping Willows'), np.bytes_(b'Wes Montgomery'), np.bytes_(b'Blue Foundation'), np.bytes_(b'Angelzoom'), np.bytes_(b'Dubfire')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000108'
# Nearest K=5 neighbors' user-ids: [b'user_000393' b'user_000912' b'user_000970' b'user_000650'
#  b'user_000431']
# Recommended artist names: [np.bytes_(b'Kamikaze Peace Brigade'), np.bytes_(b'Blindspott'), np.bytes_(b'Macadamia'), np.bytes_(b'Gia Farrell'), np.bytes_(b'Electric President')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000031'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000513' b'user_000164' b'user_000159'
#  b'user_000242']
# Recommended artist names: [np.bytes_(b'Hatebreed'), np.bytes_(b'\xd0\x95\xd0\xbb\xd0\xb5\xd0\xbd\xd0\xb0 \xd0\x9a\xd0\xb0\xd1\x82\xd0\xb8\xd0\xbd\xd0\xb0'), np.bytes_(b'Kalte Farben'), np.bytes_(b'Jon Lucien'), np.bytes_(b'Popsicle')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000454'
# Nearest K=5 neighbors' user-ids: [b'user_000606' b'user_000135' b'user_000987' b'user_000077'
#  b'user_000171']
# Recommended artist names: [np.bytes_(b'Afrika Bambaataa'), np.bytes_(b'Generation Dub'), np.bytes_(b'Aden'), np.bytes_(b'Panjabi Mc'), np.bytes_(b'Deja-Move')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000136'
# Nearest K=5 neighbors' user-ids: [b'user_000995' b'user_000034' b'user_000089' b'user_000910'
#  b'user_000345']
# Recommended artist names: [np.bytes_(b'Young Marble Giants'), np.bytes_(b'Alejandra Alberti'), np.bytes_(b'Immortal Technique'), np.bytes_(b'Babybird'), np.bytes_(b'The Damnwells')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000953'
# Nearest K=5 neighbors' user-ids: [b'user_000715' b'user_000741' b'user_000291' b'user_000705'
#  b'user_000637']
# Recommended artist names: [np.bytes_(b'Morton Feldman'), np.bytes_(b'Will-O-The Wisp'), np.bytes_(b'Animal Collective'), np.bytes_(b'Ayreon'), np.bytes_(b'Carly Simon')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000196'
# Nearest K=5 neighbors' user-ids: [b'user_000629' b'user_000862' b'user_000114' b'user_000779'
#  b'user_000844']
# Recommended artist names: [np.bytes_(b'Oasis'), np.bytes_(b'Planet E'), np.bytes_(b'Meanwhile, Back In Communist Russia...'), np.bytes_(b'Snowboy'), np.bytes_(b'Matthew Herbert')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000584'
# Nearest K=5 neighbors' user-ids: [b'user_000763' b'user_000807' b'user_000606' b'user_000059'
#  b'user_000560']
# Recommended artist names: [np.bytes_(b'Fountains Of Wayne'), np.bytes_(b'J-88'), np.bytes_(b'X-Dream'), np.bytes_(b'Deadly Avenger'), np.bytes_(b'Avail')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000695'
# Nearest K=5 neighbors' user-ids: [b'user_000584' b'user_000606' b'user_000822' b'user_000627'
#  b'user_000345']
# Recommended artist names: [np.bytes_(b'Fuel'), np.bytes_(b'Bed\xc3\xbck'), np.bytes_(b'Arno Cost'), np.bytes_(b'No Knife'), np.bytes_(b'Keller Williams')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000351'
# Nearest K=5 neighbors' user-ids: [b'user_000493' b'user_000795' b'user_000596' b'user_000653'
#  b'user_000024']
# Recommended artist names: [np.bytes_(b'James Newton Howard'), np.bytes_(b'Mystery Jets'), np.bytes_(b'Someone Still Loves You Boris Yeltsin'), np.bytes_(b'Jimmy Edwards'), np.bytes_(b'The Cochran Brothers')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000191'
# Nearest K=5 neighbors' user-ids: [b'user_000691' b'user_000858' b'user_000910' b'user_000681'
#  b'user_000754']
# Recommended artist names: [np.bytes_(b'Peter, Paul & Mary'), np.bytes_(b'Sheila Chandra'), np.bytes_(b'Dis-'), np.bytes_(b'The News'), np.bytes_(b'Pelican')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000347'
# Nearest K=5 neighbors' user-ids: [b'user_000225' b'user_000535' b'user_000413' b'user_000134'
#  b'user_000252']
# Recommended artist names: [np.bytes_(b'Thelma Houston'), np.bytes_(b'Sebastian Ingrosso And John Da'), np.bytes_(b'Kasabian'), np.bytes_(b'Violent Femmes'), np.bytes_(b'Rehab')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000403'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000513' b'user_000024' b'user_000698'
#  b'user_000031']
# Recommended artist names: [np.bytes_(b'Ministry Of Sound'), np.bytes_(b'Rufus Wainwright'), np.bytes_(b'Xbxrx'), np.bytes_(b'\xd0\x9d\xd0\xb8\xd0\xbd\xd0\xb0 \xd0\x9f\xd0\xb0\xd0\xbd\xd1\x82\xd0\xb5\xd0\xbb\xd0\xb5\xd0\xb5\xd0\xb2\xd0\xb0'), np.bytes_(b'Pylon')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000126'
# Nearest K=5 neighbors' user-ids: [b'user_000448' b'user_000420' b'user_000512' b'user_000668'
#  b'user_000237']
# Recommended artist names: [np.bytes_(b'Blanks 77'), np.bytes_(b'Voicst'), np.bytes_(b'Rage'), np.bytes_(b'Amos Lee'), np.bytes_(b"Go-Go'S")]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000501'
# Nearest K=5 neighbors' user-ids: [b'user_000837' b'user_000118' b'user_000285' b'user_000345'
#  b'user_000575']
# Recommended artist names: [np.bytes_(b'Bon Iver'), np.bytes_(b'Slint'), np.bytes_(b'Deaf Center'), np.bytes_(b'The Vandals'), np.bytes_(b'Seefeel')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000054'
# Nearest K=5 neighbors' user-ids: [b'user_000912' b'user_000776' b'user_000142' b'user_000835'
#  b'user_000570']
# Recommended artist names: [np.bytes_(b'Jeanette'), np.bytes_(b'Los Del R\xc3\xado'), np.bytes_(b'Mukeka Di Rato'), np.bytes_(b'Vince Steve Porter'), np.bytes_(b'2Badazz4Abandname')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000458'
# Nearest K=5 neighbors' user-ids: [b'user_000932' b'user_000137' b'user_000263' b'user_000623'
#  b'user_000898']
# Recommended artist names: [np.bytes_(b'Grace Jones & Tricky'), np.bytes_(b'Killing Joke'), np.bytes_(b'The Essex'), np.bytes_(b'Ub40'), np.bytes_(b'Boyz Ii Men')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000374'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000467' b'user_000024' b'user_000031'
#  b'user_000336']
# Recommended artist names: [np.bytes_(b'Dave Blackledge'), np.bytes_(b'Populous'), np.bytes_(b'Hawkwind'), np.bytes_(b'Ltj Bukem'), np.bytes_(b'Greg Macpherson')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000433'
# Nearest K=5 neighbors' user-ids: [b'user_000336' b'user_000345' b'user_000544' b'user_000569'
#  b'user_000089']
# Recommended artist names: [np.bytes_(b'Hurray For The Riff Raff'), np.bytes_(b'Asian Kung-Fu Generation'), np.bytes_(b"Fat Freddy'S Drop"), np.bytes_(b'Alberta Cross'), np.bytes_(b'Johann Sebastian Bach')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000084'
# Nearest K=5 neighbors' user-ids: [b'user_000155' b'user_000771' b'user_000610' b'user_000894'
#  b'user_000342']
# Recommended artist names: [np.bytes_(b'Mind Electric'), np.bytes_(b'Difuntos Correa'), np.bytes_(b'Megan Barton'), np.bytes_(b'Bump'), np.bytes_(b'Buddha-Bar / Angel Tears')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000346'
# Nearest K=5 neighbors' user-ids: [b'user_000085' b'user_000442' b'user_000559' b'user_000705'
#  b'user_000727']
# Recommended artist names: [np.bytes_(b'Woods Of Ypres'), np.bytes_(b'The Warriors'), np.bytes_(b'Lhasa'), np.bytes_(b"Kanjar'Oc"), np.bytes_(b'King Crimson')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000194'
# Nearest K=5 neighbors' user-ids: [b'user_000708' b'user_000857' b'user_000315' b'user_000770'
#  b'user_000048']
# Recommended artist names: [np.bytes_(b'The Runaways'), np.bytes_(b"Jack'S Mannequin"), np.bytes_(b'Rx Bandits'), np.bytes_(b'The Disposable Heroes Of Hiphoprisy'), np.bytes_(b'Lydia Lunch')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000957'
# Nearest K=5 neighbors' user-ids: [b'user_000611' b'user_000173' b'user_000442' b'user_000395'
#  b'user_000230']
# Recommended artist names: [np.bytes_(b'Aardoz'), np.bytes_(b'Dissection'), np.bytes_(b'Avenger'), np.bytes_(b'Hyades'), np.bytes_(b'Nuclear Assault')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000273'
# Nearest K=5 neighbors' user-ids: [b'user_000569' b'user_000345' b'user_000249' b'user_000371'
#  b'user_000910']
# Recommended artist names: [np.bytes_(b'Bobby Womack'), np.bytes_(b'David Axelrod'), np.bytes_(b'The Bran Flakes'), np.bytes_(b'Christmas Baubles'), np.bytes_(b'The Bevis Frond')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000737'
# Nearest K=5 neighbors' user-ids: [b'user_000478' b'user_000008' b'user_000558' b'user_000813'
#  b'user_000215']
# Recommended artist names: [np.bytes_(b'Kirsty Hawkshaw'), np.bytes_(b'High Life'), np.bytes_(b'Funk Junkeez'), np.bytes_(b'Flosstradamus/Zongamin'), np.bytes_(b'Acen')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000158'
# Nearest K=5 neighbors' user-ids: [b'user_000059' b'user_000584' b'user_000345' b'user_000577'
#  b'user_000763']
# Recommended artist names: [np.bytes_(b'Shedaisy'), np.bytes_(b'Howe Gelb'), np.bytes_(b'Cinque Cento'), np.bytes_(b'Elysian Fields'), np.bytes_(b'Manish Vyas')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000327'
# Nearest K=5 neighbors' user-ids: [b'user_000093' b'user_000020' b'user_000624' b'user_000658'
#  b'user_000683']
# Recommended artist names: [np.bytes_(b'The John Morris Orchestra'), np.bytes_(b'A. R. Rahman'), np.bytes_(b'Goldfinger'), np.bytes_(b'[Unknown]'), np.bytes_(b'Yeah Yeah Yeahs')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000689'
# Nearest K=5 neighbors' user-ids: [b'user_000690' b'user_000031' b'user_000345' b'user_000513'
#  b'user_000882']
# Recommended artist names: [np.bytes_(b'Pagan Wanderer Lu'), np.bytes_(b'Ulver'), np.bytes_(b'Plone'), np.bytes_(b'Urge Overkill'), np.bytes_(b'Celestial')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000313'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000910' b'user_000820' b'user_000691'
#  b'user_000371']
# Recommended artist names: [np.bytes_(b'Lou Rawls'), np.bytes_(b'Nortec Collective'), np.bytes_(b'Yip-Yip'), np.bytes_(b'Nels Cline'), np.bytes_(b'Say Hi To Your Mom')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000949'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000569' b'user_000701' b'user_000364'
#  b'user_000837']
# Recommended artist names: [np.bytes_(b'The Lion King'), np.bytes_(b'The Les Claypool Frog Brigade'), np.bytes_(b'In Flames'), np.bytes_(b'We Smoke Fags'), np.bytes_(b'James S. Taylor')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000020'
# Nearest K=5 neighbors' user-ids: [b'user_000624' b'user_000683' b'user_000327' b'user_000139'
#  b'user_000658']
# Recommended artist names: [np.bytes_(b'Dead Can Dance'), np.bytes_(b'Coconut Records'), np.bytes_(b'Deastro'), np.bytes_(b'The Cloud Room'), np.bytes_(b'Xandria')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000579'
# Nearest K=5 neighbors' user-ids: [b'user_000765' b'user_000894' b'user_000479' b'user_000233'
#  b'user_000649']
# Recommended artist names: [np.bytes_(b'Matt Pokora'), np.bytes_(b'Michael Sarver'), np.bytes_(b'Dave Mccullen'), np.bytes_(b'Sarah Brightman & Andrea Bocelli'), np.bytes_(b'Blaze Feat. Ultra Nat\xc3\xa9')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000379'
# Nearest K=5 neighbors' user-ids: [b'user_000329' b'user_000940' b'user_000813' b'user_000010'
#  b'user_000818']
# Recommended artist names: [np.bytes_(b'Liquid'), np.bytes_(b'Concord Dawn'), np.bytes_(b'The Outsiders'), np.bytes_(b'The Wildhearts'), np.bytes_(b'The Cool Kids')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000168'
# Nearest K=5 neighbors' user-ids: [b'user_000030' b'user_000753' b'user_000001' b'user_000362'
#  b'user_000076']
# Recommended artist names: [np.bytes_(b'Fiona Apple'), np.bytes_(b'The Cars'), np.bytes_(b'Nathan Haines'), np.bytes_(b'The World Experience Orchestra'), np.bytes_(b'Amp Fiddler')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000170'
# Nearest K=5 neighbors' user-ids: [b'user_000277' b'user_000582' b'user_000304' b'user_000060'
#  b'user_000261']
# Recommended artist names: [np.bytes_(b"Dat'R"), np.bytes_(b'Sean Burke/Friday'), np.bytes_(b'Sterling'), np.bytes_(b'Hammerfall'), np.bytes_(b'Blitz Boys')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000080'
# Nearest K=5 neighbors' user-ids: [b'user_000315' b'user_000870' b'user_000273' b'user_000242'
#  b'user_000031']
# Recommended artist names: [np.bytes_(b'Pigment Vehicle'), np.bytes_(b'Nac\xcc\xa7A\xcc\x83O Zumbi'), np.bytes_(b'China Crisis'), np.bytes_(b'Hans Werner Henze'), np.bytes_(b'Armando Trovajoli')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000647'
# Nearest K=5 neighbors' user-ids: [b'user_000604' b'user_000318' b'user_000783' b'user_000026'
#  b'user_000188']
# Recommended artist names: [np.bytes_(b'Sugizo'), np.bytes_(b'The Absence'), np.bytes_(b'Playing Enemy'), np.bytes_(b'Ketamine'), np.bytes_(b'Earthless')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000984'
# Nearest K=5 neighbors' user-ids: [b'user_000731' b'user_000118' b'user_000351' b'user_000373'
#  b'user_000837']
# Recommended artist names: [np.bytes_(b'John Williams'), np.bytes_(b'Baden Powell'), np.bytes_(b'Nas'), np.bytes_(b'Sean Paul'), np.bytes_(b'Helmerto')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000834'
# Nearest K=5 neighbors' user-ids: [b'user_000225' b'user_000535' b'user_000347' b'user_000413'
#  b'user_000134']
# Recommended artist names: [np.bytes_(b'Linkin Park'), np.bytes_(b'Sezyum.Kom'), np.bytes_(b'Camille'), np.bytes_(b'Sylvie Marks & Hal 9000'), np.bytes_(b'Jay-Jay Johanson')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000632'
# Nearest K=5 neighbors' user-ids: [b'user_000655' b'user_000440' b'user_000724' b'user_000669'
#  b'user_000253']
# Recommended artist names: [np.bytes_(b'Mike Dowling'), np.bytes_(b'Elvis Perkins'), np.bytes_(b'Andromeda Mega Express Orchestra'), np.bytes_(b'Manfred Siebald'), np.bytes_(b'Borknagar')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000237'
# Nearest K=5 neighbors' user-ids: [b'user_000448' b'user_000170' b'user_000261' b'user_000582'
#  b'user_000277']
# Recommended artist names: [np.bytes_(b'Sven Libaek'), np.bytes_(b'Twilightning'), np.bytes_(b'Harry Chapin'), np.bytes_(b'Carrie Underwood'), np.bytes_(b'Maria Mena')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000740'
# Nearest K=5 neighbors' user-ids: [b'user_000344' b'user_000745' b'user_000570' b'user_000776'
#  b'user_000173']
# Recommended artist names: [np.bytes_(b'Death By Stereo'), np.bytes_(b'Vaticano 69'), np.bytes_(b'Jay-Z'), np.bytes_(b'Insomnium'), np.bytes_(b'Baustelle')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000902'
# Nearest K=5 neighbors' user-ids: [b'user_000057' b'user_000551' b'user_000324' b'user_000890'
#  b'user_000300']
# Recommended artist names: [np.bytes_(b"Jamie O'Neal"), np.bytes_(b'Assemblage 23'), np.bytes_(b'Cascada'), np.bytes_(b'Ra Ra Riot'), np.bytes_(b'High School Musical Cast')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000441'
# Nearest K=5 neighbors' user-ids: [b'user_000529' b'user_000910' b'user_000343' b'user_000224'
#  b'user_000012']
# Recommended artist names: [np.bytes_(b'Liz Phair'), np.bytes_(b'The Magic Numbers'), np.bytes_(b'Nilsson'), np.bytes_(b'Finch'), np.bytes_(b'Sound Team')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000704'
# Nearest K=5 neighbors' user-ids: [b'user_000294' b'user_000031' b'user_000857' b'user_000995'
#  b'user_000159']
# Recommended artist names: [np.bytes_(b'Kanye West'), np.bytes_(b'Blurt'), np.bytes_(b'Rose Royce'), np.bytes_(b'Spin Doctors'), np.bytes_(b'Reamonn')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000573'
# Nearest K=5 neighbors' user-ids: [b'user_000614' b'user_000271' b'user_000048' b'user_000970'
#  b'user_000255']
# Recommended artist names: [np.bytes_(b'Scott'), np.bytes_(b'Spike Jones New Band'), np.bytes_(b'Aeroz'), np.bytes_(b'Alice In Chains'), np.bytes_(b'Alejandro Fuentes')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000131'
# Nearest K=5 neighbors' user-ids: [b'user_000089' b'user_000336' b'user_000467' b'user_000345'
#  b'user_000856']
# Recommended artist names: [np.bytes_(b'Alexis Weissenberg'), np.bytes_(b'Miracle Fortress'), np.bytes_(b'I-F'), np.bytes_(b'Sepultura'), np.bytes_(b'Pikku-Orava')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000235'
# Nearest K=5 neighbors' user-ids: [b'user_000644' b'user_000622' b'user_000201' b'user_000505'
#  b'user_000548']
# Recommended artist names: [np.bytes_(b'Dat Phan'), np.bytes_(b'Filo & Peri Meets Fisher'), np.bytes_(b'Karen Overton'), np.bytes_(b'Sarah Maclachlan  W/Shawn Colvin And Paula Cole)'), np.bytes_(b'Young Jeezy Ft Jay-Z & Fat Joe')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000044'
# Nearest K=5 neighbors' user-ids: [b'user_000115' b'user_000435' b'user_000442' b'user_000527'
#  b'user_000473']
# Recommended artist names: [np.bytes_(b'Hypocrisy'), np.bytes_(b'Amon Amarth'), np.bytes_(b'Machine Head'), np.bytes_(b'Symphorce'), np.bytes_(b'Mass Hysteria')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000576'
# Nearest K=5 neighbors' user-ids: [b'user_000478' b'user_000345' b'user_000059' b'user_000031'
#  b'user_000255']
# Recommended artist names: [np.bytes_(b'Stereo Total'), np.bytes_(b'Steve Bug'), np.bytes_(b'Chop Shop'), np.bytes_(b'Sonny Clark'), np.bytes_(b'Dead Or Alive')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000835'
# Nearest K=5 neighbors' user-ids: [b'user_000719' b'user_000173' b'user_000643' b'user_000054'
#  b'user_000611']
# Recommended artist names: [np.bytes_(b'Eisah'), np.bytes_(b'Afi'), np.bytes_(b"Mama'S Boys"), np.bytes_(b"Satan'S Host"), np.bytes_(b'Krust')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000631'
# Nearest K=5 neighbors' user-ids: [b'user_000778' b'user_000476' b'user_000829' b'user_000328'
#  b'user_000048']
# Recommended artist names: [np.bytes_(b'Andy Bell'), np.bytes_(b'Colbie Caillat'), np.bytes_(b'Da Rick'), np.bytes_(b'Cazuza'), np.bytes_(b'Tindersticks')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000143'
# Nearest K=5 neighbors' user-ids: [b'user_000513' b'user_000345' b'user_000384' b'user_000031'
#  b'user_000726']
# Recommended artist names: [np.bytes_(b'M. Hederos & M. Hellberg'), np.bytes_(b'Jay-Z Vs Marc Mac'), np.bytes_(b'Stephen Malkmus With Elastica'), np.bytes_(b'The Congos'), np.bytes_(b'Codeine')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000082'
# Nearest K=5 neighbors' user-ids: [b'user_000577' b'user_000376' b'user_000838' b'user_000361'
#  b'user_000617']
# Recommended artist names: [np.bytes_(b'Lou Rawls'), np.bytes_(b'Crazy Town'), np.bytes_(b'Axwell'), np.bytes_(b'The Dixie Cups'), np.bytes_(b'The Platters')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000024'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000031' b'user_000493' b'user_000998'
#  b'user_000371']
# Recommended artist names: [np.bytes_(b'Baader Meinhof'), np.bytes_(b'Lush Progress'), np.bytes_(b'Mr. Flagio'), np.bytes_(b'Digital And The Analogues'), np.bytes_(b'The Showmen')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000891'
# Nearest K=5 neighbors' user-ids: [b'user_000093' b'user_000327' b'user_000658' b'user_000996'
#  b'user_000624']
# Recommended artist names: [np.bytes_(b'Les Savy Fav'), np.bytes_(b'Golden Earring'), np.bytes_(b'Get Cape. Wear Cape. Fly'), np.bytes_(b'The Animals'), np.bytes_(b'Sargasso Trio')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000746'
# Nearest K=5 neighbors' user-ids: [b'user_000775' b'user_000706' b'user_000881' b'user_000423'
#  b'user_000606']
# Recommended artist names: [np.bytes_(b'Horace Parlan'), np.bytes_(b'The Rembrandts'), np.bytes_(b'Athlete'), np.bytes_(b'Tina Turner'), np.bytes_(b'Anouk')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000846'
# Nearest K=5 neighbors' user-ids: [b'user_000654' b'user_000516' b'user_000296' b'user_000953'
#  b'user_000742']
# Recommended artist names: [np.bytes_(b'Johnny Prez'), np.bytes_(b'Steve Angello'), np.bytes_(b'War'), np.bytes_(b'Madlib'), np.bytes_(b'Kai Tracid')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000120'
# Nearest K=5 neighbors' user-ids: [b'user_000285' b'user_000890' b'user_000575' b'user_000837'
#  b'user_000224']
# Recommended artist names: [np.bytes_(b'Realpeople'), np.bytes_(b'Black Flag'), np.bytes_(b'Four Tet'), np.bytes_(b'Trans-Siberian Orchestra'), np.bytes_(b'Terrestrial Tones')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000548'
# Nearest K=5 neighbors' user-ids: [b'user_000644' b'user_000622' b'user_000505' b'user_000235'
#  b'user_000201']
# Recommended artist names: [np.bytes_(b'Blonde Redhead'), np.bytes_(b'Full Company'), np.bytes_(b'Dennis Ferrer'), np.bytes_(b'Dillinger Four'), np.bytes_(b'Timbaland Feat. Tony Yayo & 50 Cent')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000447'
# Nearest K=5 neighbors' user-ids: [b'user_000584' b'user_000606' b'user_000763' b'user_000807'
#  b'user_000560']
# Recommended artist names: [np.bytes_(b'Afro Elements'), np.bytes_(b'Vladislav Delay'), np.bytes_(b'The Dave Brubeck Quartet'), np.bytes_(b'Stardust'), np.bytes_(b'Ramsey Lewis')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000293'
# Nearest K=5 neighbors' user-ids: [b'user_000897' b'user_000694' b'user_000016' b'user_000791'
#  b'user_000941']
# Recommended artist names: [np.bytes_(b'Europe'), np.bytes_(b'Ben Mills'), np.bytes_(b"Lord Rockingham'S Xi"), np.bytes_(b'Lydia Lunch'), np.bytes_(b'Kode9 + The Space Ape')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000450'
# Nearest K=5 neighbors' user-ids: [b'user_000416' b'user_000382' b'user_000878' b'user_000021'
#  b'user_000960']
# Recommended artist names: [np.bytes_(b'Bob Mould'), np.bytes_(b'7000 Dying Rats'), np.bytes_(b'John Mayer'), np.bytes_(b'Permanent Me'), np.bytes_(b'Sweetheart')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000571'
# Nearest K=5 neighbors' user-ids: [b'user_000600' b'user_000070' b'user_000219' b'user_000923'
#  b'user_000770']
# Recommended artist names: [np.bytes_(b'Sam Cooke'), np.bytes_(b'Johnny Davis & The Arrows'), np.bytes_(b'Sixpence None The Richer'), np.bytes_(b'Jesus Acosta & The Professionals'), np.bytes_(b'Bill Callahan')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000187'
# Nearest K=5 neighbors' user-ids: [b'user_000574' b'user_000008' b'user_000737' b'user_000400'
#  b'user_000419']
# Recommended artist names: [np.bytes_(b'M\xc3\xa4rtini Br\xc3\xb6s.'), np.bytes_(b'Joachim Garraud & Wize'), np.bytes_(b'Jan Delay'), np.bytes_(b'Housse De Racket'), np.bytes_(b'Atari Teenage Riot')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000164'
# Nearest K=5 neighbors' user-ids: [b'user_000345' b'user_000031' b'user_000858' b'user_000242'
#  b'user_000249']
# Recommended artist names: [np.bytes_(b'Temple Of The Dog'), np.bytes_(b'Movietone'), np.bytes_(b'David Ruffin'), np.bytes_(b'I Wayne'), np.bytes_(b'Morphine')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000305'
# Nearest K=5 neighbors' user-ids: [b'user_000390' b'user_000743' b'user_000934' b'user_000705'
#  b'user_000242']
# Recommended artist names: [np.bytes_(b'The Monkees'), np.bytes_(b'Y.B.U'), np.bytes_(b'Mike Birbiglia'), np.bytes_(b'Disarmonia Mundi'), np.bytes_(b'Joe And Everyday People')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000011'
# Nearest K=5 neighbors' user-ids: [b'user_000705' b'user_000417' b'user_000291' b'user_000715'
#  b'user_000953']
# Recommended artist names: [np.bytes_(b'Lou Reed'), np.bytes_(b'The Mountain Goats'), np.bytes_(b'Hindi New Songs'), np.bytes_(b'Men At Work'), np.bytes_(b'The Guess Who')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000324'
# Nearest K=5 neighbors' user-ids: [b'user_000902' b'user_000765' b'user_000481' b'user_000057'
#  b'user_000551']
# Recommended artist names: [np.bytes_(b'Jeff Samuel'), np.bytes_(b'All Saints'), np.bytes_(b'Luomo'), np.bytes_(b'Paulina Rubio'), np.bytes_(b'Justyn Matthew')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000721'
# Nearest K=5 neighbors' user-ids: [b'user_000093' b'user_000996' b'user_000059' b'user_000920'
#  b'user_000024']
# Recommended artist names: [np.bytes_(b'Kamal'), np.bytes_(b'The Gerbils'), np.bytes_(b'Machine Messiahs'), np.bytes_(b'Sexydeath'), np.bytes_(b'Vive La F\xc3\xaate')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000335'
# Nearest K=5 neighbors' user-ids: [b'user_000254' b'user_000931' b'user_000891' b'user_000834'
#  b'user_000395']
# Recommended artist names: [np.bytes_(b'Faithless Feat Prodigy'), np.bytes_(b'Mr. Flash'), np.bytes_(b'Shy Child'), np.bytes_(b'Cannibal Corpse'), np.bytes_(b'Django Reinhardt & St\xc3\xa9phane Grappelli')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000483'
# Nearest K=5 neighbors' user-ids: [b'user_000720' b'user_000351' b'user_000703' b'user_000415'
#  b'user_000558']
# Recommended artist names: [np.bytes_(b'School Of Seven Bells'), np.bytes_(b'Roman Fl\xc3\xbcgel'), np.bytes_(b'Spoon'), np.bytes_(b'Christophe Willem'), np.bytes_(b'Leila')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000567'
# Nearest K=5 neighbors' user-ids: [b'user_000996' b'user_000998' b'user_000031' b'user_000242'
#  b'user_000018']
# Recommended artist names: [np.bytes_(b'Martha And The Vandellas'), np.bytes_(b"The Lovin' Spoonful"), np.bytes_(b'The Juliana Hatfield Three'), np.bytes_(b'Marie Dubas'), np.bytes_(b'Ryan Adams')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000921'
# Nearest K=5 neighbors' user-ids: [b'user_000742' b'user_000418' b'user_000650' b'user_000610'
#  b'user_000233']
# Recommended artist names: [np.bytes_(b'Pillbox'), np.bytes_(b'Fifty Four All-Stars'), np.bytes_(b'Madison Avenue'), np.bytes_(b'Eiffel 65'), np.bytes_(b'Robyn')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000014'
# Nearest K=5 neighbors' user-ids: [b'user_000497' b'user_000257' b'user_000920' b'user_000443'
#  b'user_000129']
# Recommended artist names: [np.bytes_(b'Gang Gang Dance'), np.bytes_(b'Cut Copy'), np.bytes_(b'The Casual Dots'), np.bytes_(b'Godsmack'), np.bytes_(b'Samantha Ronson')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000539'
# Nearest K=5 neighbors' user-ids: [b'user_000003' b'user_000813' b'user_000400' b'user_000606'
#  b'user_000946']
# Recommended artist names: [np.bytes_(b'Jay-Jay Johanson'), np.bytes_(b'Eddie Amador'), np.bytes_(b'Fifth Entity'), np.bytes_(b'John Mayer'), np.bytes_(b'Timo Maas')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000727'
# Nearest K=5 neighbors' user-ids: [b'user_000032' b'user_000692' b'user_000529' b'user_000442'
#  b'user_000936']
# Recommended artist names: [np.bytes_(b'The Les Claypool Frog Brigade'), np.bytes_(b'Thunderstone'), np.bytes_(b'Chocolat Soundtrack'), np.bytes_(b'Sufjan Stevens'), np.bytes_(b'K.D. Lang')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000714'
# ...
#  b'user_000159']
# Recommended artist names: [np.bytes_(b'And One'), np.bytes_(b'The Rifles'), np.bytes_(b'The Nips'), np.bytes_(b'Lacuna Coil'), np.bytes_(b'Mercury Rev')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000900'
# Nearest K=5 neighbors' user-ids: [b'user_000251' b'user_000319' b'user_000715' b'user_000779'
#  b'user_000706']
# Recommended artist names: [np.bytes_(b'We Are Scientists'), np.bytes_(b'Transglobal Underground'), np.bytes_(b'Mos Def'), np.bytes_(b'Mandinga'), np.bytes_(b'Animal Collective')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000095'
# Nearest K=5 neighbors' user-ids: [b'user_000653' b'user_000096' b'user_000596' b'user_000705'
#  b'user_000482']
# Recommended artist names: [np.bytes_(b'Zielone \xc5\xbbabki'), np.bytes_(b'Bullet For My Valentine'), np.bytes_(b'John Petrucci & Jordan Rudess'), np.bytes_(b'Katsuo Ono, Tatsumi Yano'), np.bytes_(b'The Devlins')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000688'
# Nearest K=5 neighbors' user-ids: [b'user_000254' b'user_000659' b'user_000490' b'user_000689'
#  b'user_000660']
# Recommended artist names: [np.bytes_(b'Steve Vai'), np.bytes_(b'Geographyhorse+Brandon Carr'), np.bytes_(b'Lou Reed And Zeitkratzer'), np.bytes_(b'Minibosses'), np.bytes_(b'Jonathan Edwards')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000382'
# Nearest K=5 neighbors' user-ids: [b'user_000630' b'user_000971' b'user_000890' b'user_000107'
#  b'user_000450']
# Recommended artist names: [np.bytes_(b'Czes\xc5\x82aw \xc5\x9apiewa'), np.bytes_(b'Tom Vek'), np.bytes_(b'Madison'), np.bytes_(b'Go! With Fourteen O'), np.bytes_(b'Kury')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000626'
# Nearest K=5 neighbors' user-ids: [b'user_000897' b'user_000118' b'user_000832' b'user_000714'
#  b'user_000122']
# Recommended artist names: [np.bytes_(b'Traffic'), np.bytes_(b'\xe5\xa4\xa7\xe8\xb0\xb7\xe5\xb9\xb8'), np.bytes_(b'Don Omar Feat. Wisin & Yandel'), np.bytes_(b'\xc3\x91ejo'), np.bytes_(b'Marc Moulin')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000440'
# Nearest K=5 neighbors' user-ids: [b'user_000465' b'user_000596' b'user_000019' b'user_000412'
#  b'user_000892']
# Recommended artist names: [np.bytes_(b'Smoke City'), np.bytes_(b'Loney, Dear'), np.bytes_(b'The Thermals'), np.bytes_(b'Josh Martinez'), np.bytes_(b'Freddy Johnson And His Harlemites Featuring Arthur Briggs')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000212'
# Nearest K=5 neighbors' user-ids: [b'user_000778' b'user_000631' b'user_000829' b'user_000328'
#  b'user_000048']
# Recommended artist names: [np.bytes_(b'Burnage'), np.bytes_(b'Mando Diao'), np.bytes_(b'Tehosekoitin'), np.bytes_(b'Glenn Miller'), np.bytes_(b'The Byrds')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000457'
# Nearest K=5 neighbors' user-ids: [b'user_000478' b'user_000527' b'user_000977' b'user_000215'
#  b'user_000737']
# Recommended artist names: [np.bytes_(b'Riot In Belgium'), np.bytes_(b'Para One'), np.bytes_(b"Port O'Brien"), np.bytes_(b'Shitdisco'), np.bytes_(b'Sarah Mcleod')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000391'
# Nearest K=5 neighbors' user-ids: [b'user_000393' b'user_000149' b'user_000031' b'user_000617'
#  b'user_000357']
# Recommended artist names: [np.bytes_(b'Zilch'), np.bytes_(b'Bebel Gilberto'), np.bytes_(b'Evan Duby'), np.bytes_(b'Baba Ani & Egypt 80'), np.bytes_(b'Los Fabulosos Cadillacs')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000558'
# Nearest K=5 neighbors' user-ids: [b'user_000813' b'user_000203' b'user_000438' b'user_000739'
#  b'user_000405']
# Recommended artist names: [np.bytes_(b'Jeremy Soule'), np.bytes_(b'The National'), np.bytes_(b'Luke Dzierzek'), np.bytes_(b'Olav Basoski'), np.bytes_(b'Dj Sakin & Friends')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000843'
# Nearest K=5 neighbors' user-ids: [b'user_000077' b'user_000763' b'user_000059' b'user_000749'
#  b'user_000606']
# Recommended artist names: [np.bytes_(b'Jadakiss'), np.bytes_(b'Easy Star All-Stars'), np.bytes_(b'Pedro The Lion'), np.bytes_(b'Joe Gibbs'), np.bytes_(b'G. Love & Special Sauce')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000232'
# Nearest K=5 neighbors' user-ids: [b'user_000795' b'user_000511' b'user_000262' b'user_000960'
#  b'user_000698']
# Recommended artist names: [np.bytes_(b'Jacques Brel'), np.bytes_(b'Matthew Good'), np.bytes_(b'Train'), np.bytes_(b'Jay-Z'), np.bytes_(b'Jackson Browne')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000723'
# Nearest K=5 neighbors' user-ids: [b'user_000626' b'user_000897' b'user_000985' b'user_000603'
#  b'user_000849']
# Recommended artist names: [np.bytes_(b'Sy & Unknown'), np.bytes_(b'Three Drives'), np.bytes_(b'The Power Station'), np.bytes_(b'Overseer'), np.bytes_(b'Delerium')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000574'
# Nearest K=5 neighbors' user-ids: [b'user_000187' b'user_000966' b'user_000400' b'user_000661'
#  b'user_000483']
# Recommended artist names: [np.bytes_(b'Da Beatminerz Feat. Flipmode Squad'), np.bytes_(b'Arno Cost & Arias Vs. Robin S'), np.bytes_(b'Lil Wayne & Mack Maine'), np.bytes_(b'Techno Animal'), np.bytes_(b'Man Like Me')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000895'
# Nearest K=5 neighbors' user-ids: [b'user_000448' b'user_000126' b'user_000593' b'user_000580'
#  b'user_000662']
# Recommended artist names: [np.bytes_(b'Panacea'), np.bytes_(b'Echo & The Bunnymen'), np.bytes_(b'R.E.M.'), np.bytes_(b'The Features'), np.bytes_(b'Noisia')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000394'
# Nearest K=5 neighbors' user-ids: [b'user_000255' b'user_000753' b'user_000031' b'user_000691'
#  b'user_000970']
# Recommended artist names: [np.bytes_(b'Leonard Bernstein: New York Philharmonic Orchestra'), np.bytes_(b'Blinker The Star'), np.bytes_(b'Charalambides'), np.bytes_(b'Sioux Valley Singers'), np.bytes_(b'Ellywu2')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000332'
# Nearest K=5 neighbors' user-ids: [b'user_000175' b'user_000229' b'user_000855' b'user_000341'
#  b'user_000421']
# Recommended artist names: [np.bytes_(b'William Orbit'), np.bytes_(b'The Grass Roots'), np.bytes_(b'The Libertines'), np.bytes_(b'Deepak Ram'), np.bytes_(b'Ritarikunta')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000919'
# Nearest K=5 neighbors' user-ids: [b'user_000395' b'user_000409' b'user_000649' b'user_000537'
#  b'user_000461']
# Recommended artist names: [np.bytes_(b'Herd & Fitz'), np.bytes_(b'Larry Carlton'), np.bytes_(b'Loleatta Holloway'), np.bytes_(b'Carrie Lucus'), np.bytes_(b'St0Rm3Ru')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000964'
# Nearest K=5 neighbors' user-ids: [b'user_000721' b'user_000059' b'user_000268' b'user_000716'
#  b'user_000996']
# Recommended artist names: [np.bytes_(b'Jdsy'), np.bytes_(b'Helicopter Girl'), np.bytes_(b'Adam F'), np.bytes_(b'Dr. Dre'), np.bytes_(b'Monks Of The Abbey Of Notre Dame')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000465'
# Nearest K=5 neighbors' user-ids: [b'user_000440' b'user_000535' b'user_000225' b'user_000347'
#  b'user_000198']
# Recommended artist names: [np.bytes_(b'Captain Comatose'), np.bytes_(b'The Dream Academy'), np.bytes_(b'Ypey'), np.bytes_(b'Y\xc4\xb1ld\xc4\xb1z Tilbe'), np.bytes_(b'Dj Merlyn')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000473'
# Nearest K=5 neighbors' user-ids: [b'user_000435' b'user_000452' b'user_000044' b'user_000442'
#  b'user_000009']
# Recommended artist names: [np.bytes_(b'Insane Clown Posse'), np.bytes_(b'Angelspit'), np.bytes_(b'Wednesday 13'), np.bytes_(b'Mickey Avalon'), np.bytes_(b'L\xc3\xbanasa')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000931'
# Nearest K=5 neighbors' user-ids: [b'user_000393' b'user_000942' b'user_000415' b'user_000345'
#  b'user_000059']
# Recommended artist names: [np.bytes_(b'Field Music'), np.bytes_(b'For Your Ears Only'), np.bytes_(b'Harry Connick, Jr.'), np.bytes_(b'Gazebo Penguins'), np.bytes_(b'Eliades Ochoa')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000995'
# Nearest K=5 neighbors' user-ids: [b'user_000704' b'user_000914' b'user_000593' b'user_000870'
#  b'user_000136']
# Recommended artist names: [np.bytes_(b'Blake Boy'), np.bytes_(b'Paul Kantner'), np.bytes_(b'Vnv Nation'), np.bytes_(b'Bruce Springsteen & The E Street Band'), np.bytes_(b'Citizen Fish')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000545'
# Nearest K=5 neighbors' user-ids: [b'user_000691' b'user_000970' b'user_000753' b'user_000393'
#  b'user_000031']
# Recommended artist names: [np.bytes_(b'Dieter Hallervorden'), np.bytes_(b'Jorane'), np.bytes_(b'Oval'), np.bytes_(b'Mingus Dynasty'), np.bytes_(b'Chris Rea')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000629'
# Nearest K=5 neighbors' user-ids: [b'user_000862' b'user_000779' b'user_000715' b'user_000114'
#  b'user_000291']
# Recommended artist names: [np.bytes_(b'The Dirtbombs'), np.bytes_(b'Science Of Sleep'), np.bytes_(b'Bomb The Bass'), np.bytes_(b'Sleeve Channel'), np.bytes_(b'Sukhwinder')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000907'
# Nearest K=5 neighbors' user-ids: [b'user_000139' b'user_000116' b'user_000766' b'user_000624'
#  b'user_000658']
# Recommended artist names: [np.bytes_(b'Ted G\xc3\xa4rdestad'), np.bytes_(b'Lapko'), np.bytes_(b'The Hold Steady'), np.bytes_(b'Mystery Jets'), np.bytes_(b'Fischerspooner')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000228'
# Nearest K=5 neighbors' user-ids: [b'user_000824' b'user_000517' b'user_000925' b'user_000621'
#  b'user_000603']
# Recommended artist names: [np.bytes_(b'Cabaret Voltaire'), np.bytes_(b'George Thorogood & The Destroyers'), np.bytes_(b'The Donnas'), np.bytes_(b'Young Galaxy'), np.bytes_(b'Motion City Soundtrack')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000378'
# Nearest K=5 neighbors' user-ids: [b'user_000047' b'user_000973' b'user_000970' b'user_000260'
#  b'user_000761']
# Recommended artist names: [np.bytes_(b'Evert Taube'), np.bytes_(b'Obie Trice'), np.bytes_(b'Drowning Pool'), np.bytes_(b'??Ujtsnit Mieblrka'), np.bytes_(b'Juliette Lewis')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000147'
# Nearest K=5 neighbors' user-ids: [b'user_000980' b'user_000438' b'user_000703' b'user_000720'
#  b'user_000123']
# Recommended artist names: [np.bytes_(b'Lopazz'), np.bytes_(b'Nada Surf'), np.bytes_(b'Bear Vs. Shark'), np.bytes_(b'Dimbiman'), np.bytes_(b'Ricardo Tobar')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000530'
# Nearest K=5 neighbors' user-ids: [b'user_000778' b'user_000048' b'user_000328' b'user_000830'
#  b'user_000631']
# Recommended artist names: [np.bytes_(b'Lustral'), np.bytes_(b'The Graham Bond Organisation'), np.bytes_(b'Joe Strummer & The Mescaleros'), np.bytes_(b'Lady Gaga'), np.bytes_(b'The Decemberists')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000238'
# Nearest K=5 neighbors' user-ids: [b'user_000906' b'user_000099' b'user_000543' b'user_000002'
#  b'user_000217']
# Recommended artist names: [np.bytes_(b'Lovebugs'), np.bytes_(b'Potc - Klaus Badelt'), np.bytes_(b'Cazals'), np.bytes_(b'The Bellrays'), np.bytes_(b'Extreme')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000354'
# Nearest K=5 neighbors' user-ids: [b'user_000344' b'user_000173' b'user_000776' b'user_000426'
#  b'user_000142']
# Recommended artist names: [np.bytes_(b'Q-Tip'), np.bytes_(b'Glamour Of The Kill'), np.bytes_(b'Red Aunts'), np.bytes_(b'Europe'), np.bytes_(b'Funeral For A Friend')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000372'
# Nearest K=5 neighbors' user-ids: [b'user_000899' b'user_000927' b'user_000634' b'user_000414'
#  b'user_000999']
# Recommended artist names: [np.bytes_(b'Nosferatu'), np.bytes_(b'\xc5\x81ydka Grubasa'), np.bytes_(b'Michael Showalter'), np.bytes_(b'Gang Of Four'), np.bytes_(b'Meese')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000901'
# Nearest K=5 neighbors' user-ids: [b'user_000158' b'user_000114' b'user_000131' b'user_000239'
#  b'user_000914']
# Recommended artist names: [np.bytes_(b'The Donnas'), np.bytes_(b"The O'Kanes"), np.bytes_(b'Martha Argerich'), np.bytes_(b'P.O.D.'), np.bytes_(b'Carlos Vives [Paul Oakenfold M')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000808'
# Nearest K=5 neighbors' user-ids: [b'user_000782' b'user_000772' b'user_000167' b'user_000557'
#  b'user_000617']
# Recommended artist names: [np.bytes_(b'Superkings'), np.bytes_(b'Doctor Krapula'), np.bytes_(b'The Soft Boys'), np.bytes_(b'Mindless Drug Hoover'), np.bytes_(b'Arcturus')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000749'
# Nearest K=5 neighbors' user-ids: [b'user_000540' b'user_000807' b'user_000584' b'user_000869'
#  b'user_000763']
# Recommended artist names: [np.bytes_(b'Suburban Lawns'), np.bytes_(b'Basement Jaxx'), np.bytes_(b'Olive'), np.bytes_(b'Christophe Goze'), np.bytes_(b'Dark New Day')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000122'
# Nearest K=5 neighbors' user-ids: [b'user_000837' b'user_000048' b'user_000714' b'user_000525'
#  b'user_000118']
# Recommended artist names: [np.bytes_(b'Karsh Kale'), np.bytes_(b'Ewan Mcgregor/Jacek Koman/Jos\xc3\xa9 Feliciano'), np.bytes_(b'Arctic Monkeys Vs The Killers'), np.bytes_(b'Bleu'), np.bytes_(b'The Lightning Seeds')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000309'
# Nearest K=5 neighbors' user-ids: [b'user_000159' b'user_000242' b'user_000753' b'user_000031'
#  b'user_000743']
# Recommended artist names: [np.bytes_(b'Snakefinger'), np.bytes_(b'Metalheadz'), np.bytes_(b'Peaches & Herb'), np.bytes_(b'Betty Wright'), np.bytes_(b'Leo\xc5\xa1 Jan\xc3\xa1\xc4\x8dek')]
# --------------------------------------------------------------------------------
# Seed user-id: b'user_000207'
# Nearest K=5 neighbors' user-ids: [b'user_000114' b'user_000131' b'user_000929' b'user_000562'
#  b'user_000901']
# Recommended artist names: [np.bytes_(b'Silversun Pickups'), np.bytes_(b'The Shangri-Las'), np.bytes_(b'Life Without Buildings'), np.bytes_(b'Madonna (A-Teams Instrumental Remix Of Crack Commando Unit)'), np.bytes_(b'Drugs Make Me Smarter')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0007 seconds
