# %%
# !pip install annoy
# Out:
# Collecting annoy
#   Downloading annoy-1.17.3.tar.gz (647 kB)
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py): started
#   Building wheel for annoy (setup.py): finished with status 'done'
#   Created wheel for annoy: filename=annoy-1.17.3-cp39-cp39-win_amd64.whl size=54004 sha256=1f0625e06a712524fd87e27dac841260663e1c8c7a7d000b7321b95364963f1e
#   Stored in directory: c:\users\hahah\appdata\local\pip\cache\wheels\09\a9\54\37478e65995fe712f7da465749da9ddb21db6b1a599d591ac7
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.17.3

# %%
import pandas as pd
from scipy.sparse import csr_matrix
import numpy as np
import random
import time
from sklearn.preprocessing import normalize
from annoy import AnnoyIndex  # Make sure to install Annoy: pip install annoy

# %%
# Set number of neighbors to retrieve (K)
K = 5

# Load interaction log
file_path = "lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv"
interactions = pd.read_csv(file_path, sep="\t", header=None,
                           names=["user_id", "timestamp", "artist_id", "artist_name", "track_id", "track_name"],
                           on_bad_lines='skip')

# %%
# Count the number of times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mappings: user_id and artist_name to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map original user and artist identifiers to their indices
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the sparse User-Artist Matrix (UAM)
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# Normalize rows (for cosine similarity)
UAM = normalize(UAM, norm='l2', axis=1)

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

# ------------------------
# Build Annoy index
# ------------------------
# Annoy needs dense vectors. Here, each user vector is of dimension equal to the number of artists.
f = UAM.shape[1]
annoy_index = AnnoyIndex(f, 'angular')  # Using angular metric corresponds to cosine similarity on normalized vectors.

# Add each user's normalized playcount vector to the index.
for i in range(UAM.shape[0]):
    # Convert the sparse vector to a dense array
    vector = UAM.getrow(i).toarray()[0]
    annoy_index.add_item(i, vector)

# Build the Annoy index tree structure. The number of trees can be adjusted (more trees means higher precision at the cost of slower indexing).
n_trees = 10
annoy_index.build(n_trees)

# ------------------------
# Recommendation using Annoy
# ------------------------
start_time = time.time()
for u in range(UAM.shape[0]):
    print("Seed user-id: " + str(user_ids[u]))

    # Query Annoy for K+1 neighbors (we request one extra because the query user appears as the nearest neighbor)
    neighbor_indices, neighbor_distances = annoy_index.get_nns_by_item(u, K + 1, include_distances=True)
    
    # Exclude the seed user from the neighbor list
    neighbor_pairs = [(idx, dist) for idx, dist in zip(neighbor_indices, neighbor_distances) if idx != u]
    # In case there are more than K neighbors, we take the top K closest ones.
    top_neighbors = neighbor_pairs[:K]

    # Convert Annoy's angular distance to cosine similarity. For normalized vectors:
    # cosine_similarity = 1 - (angular_distance^2 / 2)
    top_neighbors_similarities = [1 - (dist * dist / 2) for idx, dist in top_neighbors]
    recommended_user_idx = [idx for idx, dist in top_neighbors]
    recommended_user_scores = top_neighbors_similarities

    print("Nearest K=" + str(K) + " neighbors' user-ids: ", user_ids[recommended_user_idx])

    # Aggregate artists from the recommended users
    recommended_artists_idx = []
    for u_idx in recommended_user_idx:
        recommended_artists_idx.extend(list(UAM.getrow(u_idx).indices))
    
    # Remove duplicates and sort
    recommended_artists_idx = sorted(set(recommended_artists_idx))
    
    # Exclude artists the seed user has already listened to
    seed_artist_indices = set(UAM.getrow(u).indices)
    recommended_artists_idx = np.setdiff1d(recommended_artists_idx, list(seed_artist_indices))

    # For illustration, randomly sample 5 recommended artists (if fewer than 5, take all)
    if len(recommended_artists_idx) < 5:
        random_elements = recommended_artists_idx.tolist()
    else:
        random_indices = random.sample(range(len(recommended_artists_idx)), 5)
        random_elements = [recommended_artists_idx[i] for i in random_indices]

    print("Indices of {} recommended artists: ".format(len(random_elements)), random_elements)
    print("Recommended artist names:", [artist_ids[i] for i in random_elements])
    print('-' * 80)

end_time = time.time()
total_users = UAM.shape[0]
avg_time = (end_time - start_time) / total_users
print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids:  ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Indices of 5 recommended artists:  [12649, 86741, 31788, 42929, 27598]
# Recommended artist names: ['Yoga', 'Rune Lindbæk', 'Out From Animals', 'Jazz Juice', 'Fictional - Hangman']
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids:  ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Indices of 5 recommended artists:  [140022, 528, 30747, 8575, 23459]
# Recommended artist names: ['Die Sekte', 'Squarepusher', 'Sailor Moon', 'Go Home Productions', 'Transwave']
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids:  ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Indices of 5 recommended artists:  [50899, 1697, 4472, 30706, 11931]
# Recommended artist names: ['Solar Factor', 'The Goo Goo Dolls', 'Martin Solveig', 'Thomas Bangalter & Dj Falcon', 'Lisa Loeb']
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Indices of 5 recommended artists:  [74986, 148574, 11761, 353, 7257]
# Recommended artist names: ['Todd Terry', 'Jorge Negrete Y Pedro Infante', 'Jeff Tweedy', 'Manoo & François A', "Gigi D'Agostino"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids:  ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Indices of 5 recommended artists:  [43438, 46860, 545, 17296, 28303]
# Recommended artist names: ['Zero Db', '14Th Precinct', 'Sébastien Tellier', 'Jon Kennedy', 'Deepak Ram']
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids:  ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Indices of 5 recommended artists:  [76624, 23434, 44068, 10007, 442]
# Recommended artist names: ['P. Lion', 'The Sunday Drivers', 'Sephiroth', 'Jon Brion', 'Pomassl']
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids:  ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Indices of 5 recommended artists:  [1767, 16325, 832, 43883, 146563]
# Recommended artist names: ['The Rolling Stones', '[Musical]', 'Bryan Adams', 'Esperanza Spalding', 'Anna David']
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids:  ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Indices of 5 recommended artists:  [565, 152, 1608, 2305, 22589]
# Recommended artist names: ['The Herbaliser', 'Donald Byrd', "Tapes 'N Tapes", 'Late Of The Pier', 'Alex M.O.R.P.H.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids:  ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Indices of 5 recommended artists:  [15901, 14792, 88196, 27982, 10568]
# Recommended artist names: ['Midnight Oil', 'Ashes Divide', 'Chaos Z', 'Z Prochek', 'Creed']
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids:  ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Indices of 5 recommended artists:  [63122, 1156, 15253, 35457, 30465]
# Recommended artist names: ['Hypnotic Beat', 'Jim Noir', 'Tkatka', 'Olav Basoski', 'S.O.A.P.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids:  ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Indices of 5 recommended artists:  [47286, 3653, 17020, 41428, 4693]
# Recommended artist names: ['Joe Williams', 'Scott Walker', '1 Giant Leap', 'Trainwreck', 'Simon Webbe']
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids:  ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Indices of 5 recommended artists:  [1055, 115564, 137037, 34735, 137011]
# Recommended artist names: ['Gabrielle', 'Souls', 'Treebound Story', 'Windsurf', 'Snax & Ianeq']
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids:  ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Indices of 5 recommended artists:  [51446, 51741, 626, 16544, 2021]
# Recommended artist names: ['Cem Ceminay', 'Papa Winnie', 'Yael Naim', 'T. Efe Varol', 'Broken Spindles']
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids:  ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Indices of 5 recommended artists:  [64897, 1086, 2545, 2047, 1700]
# Recommended artist names: ['Tim Booth', 'Hard-Fi', 'The Bloody Beetroots', 'Chromeo', 'The Hives']
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids:  ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Indices of 5 recommended artists:  [7280, 1767, 22270, 869, 52586]
# Recommended artist names: ['Jean Elan', 'The Rolling Stones', 'Japanese Telecom', 'Clap Your Hands Say Yeah', 'Robert Abigail']
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids:  ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Indices of 5 recommended artists:  [5855, 3137, 11354, 978, 15256]
# Recommended artist names: ['Sheila Chandra', 'Glen Hansard & Markéta Irglová', 'Cara Dillon', 'Eagle-Eye Cherry', 'Tujiko Noriko']
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids:  ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Indices of 5 recommended artists:  [17557, 16817, 4528, 1174, 137194]
# Recommended artist names: ['The Heptones', 'George Carlin', 'N.E.R.D.', 'John Williams', 'Schola Cantorum Riga']
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Indices of 5 recommended artists:  [3734, 921, 4568, 173833, 3826]
# Recommended artist names: ['Talking Heads', 'Deep Purple', 'Overseer', 'Second Hand Band', 'The Most Serene Republic']
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids:  ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Indices of 5 recommended artists:  [11172, 115646, 12176, 12347, 1788]
# Recommended artist names: ['Akron/Family', 'Cathie Ryan', 'Peter Kater', 'Smile Empty Soul', 'The Subways']
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids:  ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Indices of 5 recommended artists:  [2595, 3696, 1092, 2997, 769]
# Recommended artist names: ['Timbaland Feat. Keri Hilson & Nicole Scherzinger', 'Soul Asylum', 'Hoobastank', 'Depeche Mode', 'Band Of Horses']
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids:  ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Indices of 5 recommended artists:  [13808, 31947, 60475, 18819, 10516]
# Recommended artist names: ['Bunnygrunt', 'Ronny Elliott', 'Harbinger Complex', 'Macaco', 'Black Francis']
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids:  ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Indices of 5 recommended artists:  [3274, 9953, 2323, 13453, 132967]
# Recommended artist names: ['Kaffe Matthews', 'Eluvium', 'Lo-Fi-Fnk', 'The 101Ers', 'Jah Wobble And The English Root Band']
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Indices of 5 recommended artists:  [821, 28808, 6997, 99384, 73677]
# Recommended artist names: ['Boysetsfire', 'Captain Sensible', 'Mr. Mister', '6Bit', 'Bjork & Pj Harvey']
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Indices of 5 recommended artists:  [4440, 70733, 10989, 726, 29487]
# Recommended artist names: ['Ll Cool J', 'Matt Darey', 'The Dykeenies', 'Annie Lennox', 'The Forgotten Rebels']
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids:  ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Indices of 5 recommended artists:  [3276, 22926, 42659, 10888, 1657]
# Recommended artist names: ['Kamelot', 'Freddie Mercury', 'Barbara Lynn', 'Serena-Maneesh', 'The Cloud Room']
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids:  ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Indices of 5 recommended artists:  [51930, 1472, 1577, 50160, 16948]
# Recommended artist names: ['Âşık Veysel', 'Rihanna', 'Stephen Malkmus', 'Maija Vilkkumaa', 'Richard Pryor']
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids:  ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Indices of 5 recommended artists:  [67535, 71138, 71208, 125977, 71135]
# Recommended artist names: ['Bucky Covington', 'Rosabel Featuring Tamara Wallace', 'Shades Of Love', 'Wilder & Clarke Feast. Katherine Ellis', 'Rosabel']
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids:  ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Indices of 5 recommended artists:  [15062, 1134, 25211, 127694, 145084]
# Recommended artist names: ['Lyrics Born', 'Jamiroquai', 'Boot Camp Clik', 'Fire-Sessions', 'Brick City Kids']
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids:  ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Indices of 5 recommended artists:  [31922, 1914, 15062, 7476, 6851]
# Recommended artist names: ['Rhett Miller', 'Пётр Ильич Чайковский', 'Lyrics Born', 'Charon', 'Current 93']
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids:  ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Indices of 5 recommended artists:  [5384, 765, 10078, 2760, 1957]
# Recommended artist names: ['Jeff Samuel', 'Bad Religion', 'Pigface', 'Azam Ali', 'America']
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Indices of 5 recommended artists:  [21814, 50931, 1641, 3256, 13082]
# Recommended artist names: ['Sunset Blvd.', 'Bloc Party Vs. Katy Perry', 'The Besnard Lakes', 'Jill Sobule', 'Popsicle']
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids:  ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Indices of 5 recommended artists:  [2606, 124261, 133764, 17847, 1621]
# Recommended artist names: ['Tool', 'Íon', '41:30', 'Au Pairs', 'The 13Th Floor Elevators']
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids:  ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Indices of 5 recommended artists:  [60097, 30067, 60062, 740, 23126]
# Recommended artist names: ['Spylacopa', 'Farben Lehre', 'Penicillin', 'Arctic Monkeys', 'Mdfmk']
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Indices of 5 recommended artists:  [14506, 18979, 86450, 46292, 77480]
# Recommended artist names: ['The Drifters', 'Mystic Chord', 'Sukay', 'Ralph Towner', 'Zdzisława Sośnicka']
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids:  ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Indices of 5 recommended artists:  [2305, 1558, 106715, 4999, 49507]
# Recommended artist names: ['Late Of The Pier', 'Sophie Zelmani', 'Kenny Dope & Terry Hunter', 'Barbara Morgenstern', 'Sleazemore']
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids:  ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Indices of 5 recommended artists:  [34808, 36456, 108424, 25135, 173584]
# Recommended artist names: ['Chris Whitley', 'The Scarring Party', 'City On A Hill: Sing Alleluia Ffh/Nichole Nordeman', 'Azad', 'The Electrolytes']
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids:  ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Indices of 5 recommended artists:  [79377, 20164, 10539, 30011, 118311]
# Recommended artist names: ['Will White', 'Michelle Featherstone', 'Canned Heat', 'The Manhattan Transfer', 'Mrnorth']
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids:  ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Indices of 5 recommended artists:  [15008, 10281, 17242, 26232, 27584]
# Recommended artist names: ['James Newton Howard', 'Eisenfunk', 'Greenskeepers', 'Mescalinum United', 'Ex-Rental']
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids:  ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Indices of 5 recommended artists:  [114642, 120643, 154505, 75000, 488]
# Recommended artist names: ['Marc Nelson', 'Fonejacker', 'Love Games', 'Wilt', 'Röyksopp']
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids:  ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Indices of 5 recommended artists:  [19718, 1827, 1243, 3895, 3269]
# Recommended artist names: ['We Are The Fury', 'Tokyo Police Club', 'Leann Rimes', 'Tori Amos', 'Joy Zipper']
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids:  ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Indices of 5 recommended artists:  [9889, 9984, 2896, 30251, 14951]
# Recommended artist names: ['Arvo Pärt', 'Hank Williams Iii', 'Chandeen', 'Eiríkur Hauksson', 'Evil Nine']
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids:  ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Indices of 5 recommended artists:  [1548, 1613, 1267, 40239, 40283]
# Recommended artist names: ['Snow Patrol', 'Tegan And Sara', 'Low', 'Tattie Toes', 'A-Sides & Mc Fats']
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids:  ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Indices of 5 recommended artists:  [10185, 58193, 3204, 18309, 32422]
# Recommended artist names: ['Brandy', 'Juaneco Y Su Combo', 'Ian Pooley', 'Fela Ransome Kuti And Ginger Baker', 'Tiny Vipers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids:  ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Indices of 5 recommended artists:  [1714, 4254, 43743, 54000, 3532]
# Recommended artist names: ['The Kooks', 'Dope Stars Inc.', 'Russell Allen', 'Twilightning', 'Pain Of Salvation']
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids:  ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Indices of 5 recommended artists:  [24077, 24442, 3452, 17337, 111200]
# Recommended artist names: ['Azra', 'Bono', 'Moonspell', 'Los Lobos', 'Ben Sage']
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids:  ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Indices of 5 recommended artists:  [44369, 62058, 15233, 112479, 87610]
# Recommended artist names: ['Carnal Forge', 'Vaz', 'The Outsiders', 'Ffej', 'Végastar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids:  ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Indices of 5 recommended artists:  [146150, 2912, 10980, 2449, 53891]
# Recommended artist names: ['Manu Le Malin & The Dj Producer', 'Chubby Checker', 'The Crusaders', 'Rainbow', 'Negative Reaction']
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids:  ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Indices of 5 recommended artists:  [2117, 18575, 24412, 150176, 11459]
# Recommended artist names: ['Does It Offend You, Yeah?', 'Joan Jett And The Blackhearts', 'The Crazy World Of Arthur Brown', 'Déborah', 'Derek And The Dominos']
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids:  ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Indices of 5 recommended artists:  [9303, 3832, 74184, 2431, 92274]
# Recommended artist names: ['Right Said Fred', 'The Organ', '䄀爀挀愀搀攀\u2000䘀椀爀攀', 'People Under The Stairs', 'Gotan Project Feat. Juan Carlos Cáceres']
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Indices of 5 recommended artists:  [86109, 22259, 86154, 62355, 17541]
# Recommended artist names: ['Achtung Wunst', 'Herbert Grönemeyer', 'Cairo', 'Elán', 'Thalia Zedek']
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids:  ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Indices of 5 recommended artists:  [3657, 95750, 11200, 25563, 14729]
# Recommended artist names: ['Sea Wolf', 'Ricky Van Shelton', 'Ana', 'Dsl', 'Trashcan Sinatras']
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids:  ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Indices of 5 recommended artists:  [43720, 12580, 6865, 15581, 59311]
# Recommended artist names: ['For My Pain...', 'U.D.O.', 'Deine Lakaien', 'Envy', 'Thrudvangar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids:  ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Indices of 5 recommended artists:  [147193, 90253, 4772, 7180, 7327]
# Recommended artist names: ['Hail The Villain', 'Prem C Ft. Thre + Orifice', 'The Drill', 'Chris Lake Feat. Nastala', 'Mystikal']
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids:  ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Indices of 5 recommended artists:  [10014, 223, 9534, 116784, 23274]
# Recommended artist names: ['Katatonia', 'Herbie Hancock', 'Technotronic', 'Restless', "Richard O'Brien"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids:  ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Indices of 5 recommended artists:  [16175, 12629, 2380, 105349, 1285]
# Recommended artist names: ['The Church', 'Willie Nelson', 'Misfits', 'Mandi Perkins', 'Marit Larsen']
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids:  ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Indices of 5 recommended artists:  [1360, 23454, 18062, 19862, 46414]
# Recommended artist names: ['Nicole Kidman, Ewan Mcgregor And Jamie Allen', 'Tory Kay Vs. Alex Megane', 'Chris & Cosey', 'Kenny Chesney', 'Wael Kfoury']
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids:  ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Indices of 5 recommended artists:  [1811, 7198, 26151, 16615, 29249]
# Recommended artist names: ['The Zutons', 'Dave Spoon', 'M', 'Jocelyn Enriquez', 'Rapider Than Horsepower']
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids:  ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Indices of 5 recommended artists:  [11950, 58590, 1447, 14821, 1751]
# Recommended artist names: ['Loudon Wainwright Iii', 'The Chocolate Watch Band', 'Rage Against The Machine', 'Neu!', 'The Polyphonic Spree']
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Indices of 5 recommended artists:  [985, 1342, 2481, 17388, 980]
# Recommended artist names: ['Edwin Mccain', 'Natalie Imbruglia', 'September', 'Momus', 'Eartha Kitt']
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids:  ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Indices of 5 recommended artists:  [19668, 18474, 17916, 9770, 19345]
# Recommended artist names: ['Two Nice Girls', 'Hlmp', 'Bigbang', 'Tracie Spencer', 'Soldier String Quartet']
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids:  ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Indices of 5 recommended artists:  [69581, 71330, 169414, 1850, 21347]
# Recommended artist names: ['Ann Marie Boskovich', 'Summer Junkies', 'Ne-Yo Feat Candace Jones', 'Ub40', 'Todd Terry All Stars']
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids:  ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Indices of 5 recommended artists:  [18316, 51025, 34108, 86361, 50873]
# Recommended artist names: ['Fishtank Ensemble', 'The White Sport', 'Ava Leigh', 'No Wings Fins Or Fuselage', 'Julian Bream']
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids:  ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Indices of 5 recommended artists:  [3198, 6062, 35794, 16440, 22919]
# Recommended artist names: ['Hungry Lucy', 'Velvet Revolver', 'Komety', 'Hypocrisy', 'Floorfilla']
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids:  ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Indices of 5 recommended artists:  [10, 171902, 12998, 2507, 753]
# Recommended artist names: ['A. R. Rahman', 'Daryl Stay', 'Crescent', 'Soulwax', 'Audioslave']
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids:  ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Indices of 5 recommended artists:  [3671, 7142, 4969, 32694, 1828]
# Recommended artist names: ['Shearwater', 'Akala', 'Arab Strap', 'Brad Mehldau', 'Tom Jones']
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids:  ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Indices of 5 recommended artists:  [29269, 73669, 29894, 10693, 8681]
# Recommended artist names: ['Robert Ashley', 'Balligomingo', 'Gare Du Nord', 'James Morrison', 'Instrumental']
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids:  ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Indices of 5 recommended artists:  [6520, 11935, 8760, 2143, 1449]
# Recommended artist names: ['Magic System', 'Lit', 'Jorge Ben', 'Eric Prydz', 'Rancid']
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids:  ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Indices of 5 recommended artists:  [92032, 1851, 1860, 85782, 25696]
# Recommended artist names: ['P. Diddy & The Bad Boy Family', "Umphrey'S Mcgee", 'Vast', 'Schola Cantorum Of Oxford', 'Freddy Fresh']
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids:  ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Indices of 5 recommended artists:  [58505, 17014, 25009, 76230, 3088]
# Recommended artist names: ['Silkie', 'Young Noble', 'Adagio', 'Lil Jon F. E-40 & Sean Paul', 'Fischerspooner']
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids:  ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Indices of 5 recommended artists:  [11329, 1114, 12404, 80191, 24394]
# Recommended artist names: ['Brant Bjork', 'Incubus', 'Syd Barrett', 'A.R. Rahman Feat. Blaaze & Tanvi Shah', 'Pink Grease']
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids:  ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Indices of 5 recommended artists:  [1511, 19123, 999, 17597, 2983]
# Recommended artist names: ['Savage Garden', 'Polysics', 'Elvis Presley', 'Tim Deluxe', 'Dead Can Dance']
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids:  ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Indices of 5 recommended artists:  [2259, 8574, 48006, 60747, 6508]
# Recommended artist names: ['Johann Sebastian Bach', 'Gloria Estefan', 'Sum', 'Swirl 360', 'Lloyd']
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids:  ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Indices of 5 recommended artists:  [109999, 28331, 62125, 67, 302]
# Recommended artist names: ['Cast King', 'Electric Skychurch', 'Benny Neyman', 'Blockhead', 'Ken Ishii']
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids:  ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Indices of 5 recommended artists:  [28419, 158012, 25185, 7847, 739]
# Recommended artist names: ['La Nev Diva', 'Hey Gringo', 'Bjørn Torske', 'Yes', 'Architecture In Helsinki']
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids:  ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Indices of 5 recommended artists:  [19910, 2983, 11273, 10928, 19251]
# Recommended artist names: ['Vasco Rossi', 'Dead Can Dance', 'Bernard Fanning', 'Stray Cats', 'Sahara Hotnights']
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids:  ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Indices of 5 recommended artists:  [64334, 16764, 99526, 64361, 60364]
# Recommended artist names: ['Maxence Cyrin', 'Digital Mystikz', 'Lipali', 'Miracle Fortress', 'Christine Pilzer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids:  ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Indices of 5 recommended artists:  [2638, 51183, 43519, 74647, 118718]
# Recommended artist names: ['Wink', 'Kill Your Idols', 'Arkestra One', 'Todos Tus Muertos', "Bollywood'S Best With Neel And Esha On Www.Chutneyradio.Com"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids:  ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Indices of 5 recommended artists:  [146539, 57897, 24073, 124532, 16930]
# Recommended artist names: ['The Trudy', 'Brooks', 'Amerie', 'Wukimon', 'Plan B']
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids:  ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Indices of 5 recommended artists:  [2363, 110824, 157998, 2389, 34678]
# Recommended artist names: ['Metro Station', 'The Rocky Horror Show - Original Norwegian Cast', 'Chaz Rough', 'My Bloody Valentine', 'The Free Association']
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids:  ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Indices of 5 recommended artists:  [19471, 11027, 2916, 38208, 3017]
# Recommended artist names: ['The Ernie Freeman Combo', 'The Makers', 'Cinema Strange', 'The Spencer Davis Group', 'Donna Summer']
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids:  ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Indices of 5 recommended artists:  [42095, 1841, 17793, 1169, 1352]
# Recommended artist names: ['Dj Inphinity', 'Travis', 'Anal Cunt', 'John Mayer', 'New Found Glory']
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids:  ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Indices of 5 recommended artists:  [5193, 17265, 510, 118254, 9678]
# Recommended artist names: ['Dub Pistols', 'Hybrid', 'Sketch Show', 'Josh Fix', 'The Specials']
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids:  ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Indices of 5 recommended artists:  [34786, 41490, 42054, 41772, 4116]
# Recommended artist names: ['Adam Again', 'Angervoice', '[Religious Music]', 'Letters To Cleo', 'Booty Luv']
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids:  ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Indices of 5 recommended artists:  [2727, 959, 17043, 9802, 163366]
# Recommended artist names: ['Angra', 'Dispatch', 'Angel Moon', 'Van She', 'San & Sebastian Moore']
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids:  ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Indices of 5 recommended artists:  [4710, 47467, 767, 6873, 2103]
# Recommended artist names: ['Sofi Marinova', 'Neda', 'Badly Drawn Boy', 'Dishwalla', 'Dj Krush']
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids:  ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Indices of 5 recommended artists:  [1449, 86480, 1953, 65928, 26463]
# Recommended artist names: ['Rancid', 'The Professional Americans', 'Alter Ego', 'Mosquitos', 'Paulson']
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids:  ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Indices of 5 recommended artists:  [5703, 16166, 2360, 96772, 44874]
# Recommended artist names: ['Paris Avenue Feat. Robin One', 'The Attic', 'Mest', 'Donald', 'Becky Baeling']
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids:  ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Indices of 5 recommended artists:  [13976, 7054, 9166, 14847, 62273]
# Recommended artist names: ['Girls In Hawaii', 'Sirenia', 'Orchestral Manoeuvres In The Dark', 'Alan Reeves, Phil Steele & Philip Brigham', 'Rosey']
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Indices of 5 recommended artists:  [38798, 25019, 89629, 8657, 18728]
# Recommended artist names: ['Dragon', 'Adventure', 'Julien Clerc', 'Hugh Masekela', 'Lee Feldman']
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids:  ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Indices of 5 recommended artists:  [72347, 72334, 2566, 6931, 3282]
# Recommended artist names: ['Rohan', 'La Excepción', 'The Lively Ones', 'Icon Of Coil', 'Kate Bush']
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids:  ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Indices of 5 recommended artists:  [28404, 34164, 9997, 5712, 15174]
# Recommended artist names: ['K.I.A.', 'Climnoizer', 'Imani Coppola', 'Paul Kalkbrenner', 'Smith & Mighty']
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids:  ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Indices of 5 recommended artists:  [26879, 74149, 9767, 17088, 8276]
# Recommended artist names: ['Tha Alkaholiks', 'Bunky', 'Touch And Go', 'Bosco', 'David Benoit']
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids:  ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Indices of 5 recommended artists:  [2543, 33664, 162687, 162721, 140230]
# Recommended artist names: ['The Black Eyed Peas', 'Litfiba', 'Daft Punk Vs Benny Benassi', 'Rancid & The Specials', 'Dari']
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids:  ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Indices of 5 recommended artists:  [83160, 107609, 84804, 73747, 23129]
# Recommended artist names: ['Flii Stylz', 'Youngsta', 'Me, Myself And I', 'Fasolki', 'Mental Theo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids:  ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Indices of 5 recommended artists:  [3715, 87362, 2541, 137135, 7106]
# Recommended artist names: ['Stratovarius', 'Jovem Guarda', 'The Avalanches', 'Internationales Musikinstitut Darmstadt', 'Train']
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids:  ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Indices of 5 recommended artists:  [2886, 44052, 77570, 147828, 36650]
# Recommended artist names: ['Castanets', 'Reeves Gabrels', 'Marshmallow Coast', 'Liam Gallagher & Steve Cradock', 'Robbie & William']
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids:  ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Indices of 5 recommended artists:  [12255, 14867, 13005, 171947, 8880]
# Recommended artist names: ['Rodrigo Rodriguez', 'Banbarra', 'Dir En Grey', 'Liontamer', 'Lee Ranaldo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids:  ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Indices of 5 recommended artists:  [1427, 17062, 3327, 1187, 57669]
# Recommended artist names: ['Pink Floyd', 'Barry Manilow', 'Le Tigre', 'Joni Mitchell', 'O Teatro Mágico']
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids:  ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Indices of 5 recommended artists:  [1103, 11815, 19490, 9511, 50478]
# Recommended artist names: ['Huey Lewis & The News', 'Jonathan Coulton', 'The Gentle Waves', "Sérgio Mendes & Brasil '66", 'The Jealous Sound']
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids:  ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Indices of 5 recommended artists:  [1560, 1639, 1473, 1901, 2699]
# Recommended artist names: ['South', 'The Bees', 'Rilo Kiley', 'Yo La Tengo', 'All Girl Summer Fun Band']
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids:  ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Indices of 5 recommended artists:  [78190, 125066, 29745, 26149, 19976]
# Recommended artist names: ['Pete Belasco', 'Meï Teï Shô', 'Tubeway Army', 'Lyricson', "Bruno Coulais, Mathilde Pellegrini,The Children'S Choir Of Nice, Helene Breschand, Hungrarian Symphony Orchestra Budapest & Laurent Petitgirard"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids:  ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Indices of 5 recommended artists:  [18441, 18115, 36491, 3619, 19175]
# Recommended artist names: ['Happy Rhodes', 'Crass', 'Bob Dorough', 'Robin Thicke', 'Raïna Raï']
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids:  ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Indices of 5 recommended artists:  [13469, 17775, 8072, 12596, 1049]
# Recommended artist names: ['The Bones', 'Ali Akbar Khan', 'Bran Van 3000', 'Van Halen', 'Frou Frou']
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids:  ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Indices of 5 recommended artists:  [33670, 67856, 7641, 24868, 23764]
# Recommended artist names: ['Love Spit Love', 'Insision', 'Kotiteollisuus', 'Zonata', 'Axxis']
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Indices of 5 recommended artists:  [21857, 19527, 51362, 37273, 71365]
# Recommended artist names: ['Yoav', 'The March Violets', 'Alim Qasimov Ens', 'Elliot Minor', 'Tenth Planet']
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids:  ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Indices of 5 recommended artists:  [63726, 2397, 3151, 18517, 32598]
# Recommended artist names: ['Current 93 And Nurse With Wound', 'Nikka Costa', 'Graham Coxon', 'Islaja', 'Zoë Keating']
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids:  ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Indices of 5 recommended artists:  [1728, 4733, 13392, 2412, 6663]
# Recommended artist names: ['The Marvelettes', 'Sting', 'Red Animal War', 'Outkast', 'Tyrese']
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Indices of 5 recommended artists:  [32681, 120686, 13298, 11864, 30444]
# Recommended artist names: ['Blackstreet', 'Alexander Prievert', 'Joey Ramone', 'Kenny Rogers', 'Ray Parker Snr.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids:  ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Indices of 5 recommended artists:  [17399, 87414, 108928, 162248, 99822]
# Recommended artist names: ['Muki', 'Mythril Nazgul', 'Casey Donovan', 'Yo Gotti & Dj Rpm Featuring Young Jeezy & Allstar', 'The Used And Mcr']
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids:  ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Indices of 5 recommended artists:  [19660, 2596, 53886, 9848, 12134]
# Recommended artist names: ['Tryo', 'Timbaland; Nelly Furtado, Justin Timberlake', "Los Holy'S", 'Yacht', 'Orishas']
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids:  ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Indices of 5 recommended artists:  [172290, 172225, 2203, 109449, 9977]
# Recommended artist names: ['Dutch Coleman & Red Whitehead', 'Cracked Cop Skulls', 'Groove Coverage', 'Brigata Cani Da Birra', 'Gogol Bordello']
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids:  ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Indices of 5 recommended artists:  [3316, 17142, 18451, 56735, 48830]
# Recommended artist names: ['Labradford', 'David Sylvian', 'Hector Berlioz', 'Spanky Wilson & The Qso', 'S4E']
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids:  ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Indices of 5 recommended artists:  [43728, 24752, 11295, 12954, 69]
# Recommended artist names: ['Marilyn Monroe And Jane Russell', 'Osoboe', 'Blake', 'Игорь Фёдорович Стравинский', 'Boards Of Canada']
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids:  ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Indices of 5 recommended artists:  [123713, 56122, 158554, 1394, 108879]
# Recommended artist names: ['43', 'Morris Nightingale', 'Icotec', 'Paolo Nutini', 'Tickley Feather']
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids:  ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Indices of 5 recommended artists:  [151543, 10126, 24893, 1475, 10065]
# Recommended artist names: ['Rendez-Vous', 'Sunn O)))', 'Дубовый Гаайъ', 'Rise Against', 'Norma Jean']
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids:  ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Indices of 5 recommended artists:  [1838, 2932, 39744, 1386, 165146]
# Recommended artist names: ['Toto', 'Cloud Cult', 'The Starsound Orchestra', 'Orson', '?????A Spa??A']
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids:  ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Indices of 5 recommended artists:  [34438, 4824, 17857, 9799, 10848]
# Recommended artist names: ['Mike & Rich', 'Uriah Heep', 'Avril', 'Utah Saints', 'Project Divinity']
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids:  ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Indices of 5 recommended artists:  [68661, 8285, 1032, 14167, 11464]
# Recommended artist names: ['Lorna', 'David Usher', 'Foo Fighters', 'Mintzkov', 'Diana Ross']
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids:  ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Indices of 5 recommended artists:  [19399, 10048, 1342, 19910, 23422]
# Recommended artist names: ['Synesthesia', 'Ministry', 'Natalie Imbruglia', 'Vasco Rossi', 'The Machinist']
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids:  ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Indices of 5 recommended artists:  [1816, 111592, 21023, 16206, 1912]
# Recommended artist names: ['Thirteen Senses', 'Airborne', 'Lia', 'The Penguins', 'Édith Piaf']
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids:  ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Indices of 5 recommended artists:  [13050, 1817, 23184, 1127, 17820]
# Recommended artist names: ['Los Hermanos', 'Thrice', 'Nitrous Oxide', "Jack'S Mannequin", 'Anything Box']
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids:  ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# ...
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Indices of 5 recommended artists:  [24750, 2249, 628, 3615, 39192]
# Recommended artist names: ['One-T', 'Jedi Mind Tricks', 'Yesterdays New Quintet', 'Riverside', 'Love Sculpture']
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids:  ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Indices of 5 recommended artists:  [138180, 38518, 38625, 39201, 23004]
# Recommended artist names: ['Todd Rubenstein', 'Barry Biggs', 'Carmen Miranda', 'M.O.V.E', 'Jimmy Somerville']
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids:  ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Indices of 5 recommended artists:  [12262, 18631, 29303, 9369, 19157]
# Recommended artist names: ['Rose Hill Drive', 'Junpei Asashina', 'Seagull Screaming Kiss Her Kiss Her', 'Sega', 'Rachel Stevens']
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids:  ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Indices of 5 recommended artists:  [17246, 18518, 11301, 8138, 32258]
# Recommended artist names: ['Guitar', 'Ist', 'Blue Cheer', 'Catherine Wheel', 'The Low Frequency In Stereo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids:  ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Indices of 5 recommended artists:  [15155, 12749, 28604, 28299, 28469]
# Recommended artist names: ['Sam Sparro', 'Blindside', 'Tegan Northwood', 'Day One', 'Miss Bunty']
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids:  ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Indices of 5 recommended artists:  [113816, 61548, 12967, 14449, 14234]
# Recommended artist names: ['Meursault', 'Carrie Nations', 'Angels Of Light', 'The Apples In Stereo', 'Parenthetical Girls']
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids:  ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Indices of 5 recommended artists:  [118055, 7034, 86418, 9890, 3405]
# Recommended artist names: ['The Murderers', 'Psyclon Nine', 'Rootpowder', 'As I Lay Dying', 'Martina Topley-Bird']
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids:  ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Indices of 5 recommended artists:  [11783, 55377, 2499, 9322, 47009]
# Recommended artist names: ['Joan Armatrading', 'Harlem River Drive', 'Sneaker Pimps', 'Roxy Music', 'Charlie Hunter']
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids:  ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Indices of 5 recommended artists:  [79805, 19315, 90632, 673, 19218]
# Recommended artist names: ['Suzanne Gabriello', 'Silver Apples', 'Stefie Shock & Suzie Mclellan', 'A.C. Newman', 'Robyn Hitchcock']
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids:  ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Indices of 5 recommended artists:  [1800, 97935, 10197, 97494, 47080]
# Recommended artist names: ['The Vines', 'Winston Jarret And The Righteo', 'Mis-Teeq', 'Madd Anju', 'Dj Die']
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids:  ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Indices of 5 recommended artists:  [17581, 146158, 2563, 123432, 86491]
# Recommended artist names: ['The Sheila Divine', 'Mark 13', 'The Juliana Theory', 'Bebe Brown Vs Phunk Investigation', 'The Winter Blanket']
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids:  ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Indices of 5 recommended artists:  [12031, 1585, 91585, 24364, 123928]
# Recommended artist names: ['Melvins', 'Straylight Run', 'Strangers', 'Frank Turner', 'I Object']
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids:  ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Indices of 5 recommended artists:  [28229, 91667, 12142, 91250, 74288]
# Recommended artist names: ['Army Of Me', 'The Path Of Resistance', 'P.O.D.', 'C.Aarmé', 'Nikad']
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids:  ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Indices of 5 recommended artists:  [894, 27242, 28666, 2803, 24103]
# Recommended artist names: ['Crosby, Stills, Nash & Young', 'Kilgore', 'Will Young', 'Billy Idol', 'Ciara Feat T.I. And Jazze Pha']
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids:  ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Indices of 5 recommended artists:  [140668, 1757, 1426, 44617, 2505]
# Recommended artist names: ['Dan Andriano', 'The Promise Ring', 'Pinback', 'Merry Clayton', "Soulja Boy Tell 'Em"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids:  ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Indices of 5 recommended artists:  [14041, 50969, 2565, 114494, 3075]
# Recommended artist names: ['Ivy', 'Les Incompétents', 'The Like', 'Maria Nayler', 'Explosions In The Sky']
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids:  ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Indices of 5 recommended artists:  [2022, 1727, 162668, 1935, 154483]
# Recommended artist names: ['Bt', 'The Mars Volta', 'Thomas T.', 'Ace Of Base', 'Cyanide - Gérard Teyssier']
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids:  ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Indices of 5 recommended artists:  [14757, 660, 1801, 25720, 66275]
# Recommended artist names: ['Vincent Vincent And The Villains', '...And You Will Know Us By The Trail Of Dead', 'The Von Bondies', 'Gallows', 'Ratty Rat Rat']
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids:  ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Indices of 5 recommended artists:  [18593, 42752, 26064, 4015, 20169]
# Recommended artist names: ['John Mclaughlin Trio', 'Cuarteto Patria', 'Lambert, Hendricks & Ross', '2Pac', 'Moi Dix Mois']
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids:  ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Indices of 5 recommended artists:  [393, 153535, 921, 19803, 9706]
# Recommended artist names: ['Monday満ちる', 'Dj Design', 'Deep Purple', 'עפרה חזה', 'The Wedding Present']
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids:  ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Indices of 5 recommended artists:  [49680, 3134, 49292, 9632, 48905]
# Recommended artist names: ['Ÿþd', 'Girl Talk', 'Len Brown Society', 'The Juan Maclean', 'Aaron Tyler']
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids:  ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Indices of 5 recommended artists:  [59176, 7162, 22639, 11486, 7406]
# Recommended artist names: ['Luna Spice', 'Bk', 'Barbra Streisand', 'Donald Fagen', 'Xzibit']
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids:  ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Indices of 5 recommended artists:  [27803, 47298, 11362, 97425, 59185]
# Recommended artist names: ['Red Flag', 'Jp Juice', 'Cee-Lo', 'Kumar Sanu', 'Manau']
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids:  ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Indices of 5 recommended artists:  [1722, 95936, 28178, 10202, 7641]
# Recommended artist names: ['The Long Blondes', 'Tim Neu', 'Pustki', 'The Appleseed Cast', 'Kotiteollisuus']
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids:  ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Indices of 5 recommended artists:  [2294, 3513, 8990, 26689, 157903]
# Recommended artist names: ['Kool & The Gang', 'Ocean Colour Scene', 'Matthew Good', 'Shing02', 'Pierce Brosnan & Company']
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids:  ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Indices of 5 recommended artists:  [705, 2446, 2472, 3273, 80066]
# Recommended artist names: ['Ambulance Ltd', 'Queen', 'Scooter', 'Junior Senior', 'Scott Simons']
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids:  ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Indices of 5 recommended artists:  [147686, 1925, 148109, 13114, 9852]
# Recommended artist names: ['Hal Willner', '7L & Esoteric', 'Steve Reichkronos Quartet, Pat Metheny', 'The Plan', 'Young Marble Giants']
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids:  ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Indices of 5 recommended artists:  [102180, 10710, 9949, 21024, 73245]
# Recommended artist names: ['Solid Steel - 1998-12-20 [3]', 'John Vanderslice', 'Efterklang', 'Like A Tim', 'Mike Bones']
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids:  ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Indices of 5 recommended artists:  [4422, 10452, 1808, 17142, 10735]
# Recommended artist names: ['Laura Branigan', '2 Unlimited', 'The Wombats', 'David Sylvian', 'Keith']
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids:  ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Indices of 5 recommended artists:  [18061, 1830, 1120, 1657, 16668]
# Recommended artist names: ['Choking Victim', 'Tom Petty And The Heartbreakers', 'Islands', 'The Cloud Room', 'Vivian Green']
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids:  ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Indices of 5 recommended artists:  [16479, 21502, 60135, 789, 3917]
# Recommended artist names: ['Moving Mountains', 'Graveworm', 'Unsraw', 'Bernard Herrmann', 'Under Byen']
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids:  ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Indices of 5 recommended artists:  [126301, 5006, 1677, 12903, 1003]
# Recommended artist names: ['Geoff Tate\\James Lomenzo\\Ray Luzier\\Carlos Cavazo', 'Beastie Boys', 'The Duke Spirit', 'Soda Stereo', 'Eric Clapton']
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids:  ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Indices of 5 recommended artists:  [86508, 43421, 15258, 34921, 1010]
# Recommended artist names: ['Watson & Company', 'Watoo Watoo', 'Ugly Casanova', 'The Handsome Family', 'Evanescence']
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids:  ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Indices of 5 recommended artists:  [6872, 24517, 125468, 205, 11700]
# Recommended artist names: ['Dirty Vegas', 'Angelzoom', 'Mozart-Wiener Philharmoniker-Levine', 'Goldie', 'Hem']
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids:  ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Indices of 5 recommended artists:  [161706, 10114, 25236, 86397, 3702]
# Recommended artist names: ['Tim Smith', 'Soilwork', 'Brothomstates', 'Postmen', 'Squirrel Nut Zippers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids:  ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Indices of 5 recommended artists:  [1126, 1684, 6984, 2977, 11700]
# Recommended artist names: ['Jack Peñate', 'The Feeling', 'Melotron', 'David & The Citizens', 'Hem']
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids:  ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Indices of 5 recommended artists:  [1142, 1657, 37643, 690, 16180]
# Recommended artist names: ['Jason Mraz', 'The Cloud Room', 'Brad Kane & Lea Salonga', 'Alanis Morissette', 'The Crickets']
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids:  ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Indices of 5 recommended artists:  [4332, 7811, 12221, 15148, 133464]
# Recommended artist names: ['Gusgus', 'The Rasmus', 'Rainer Maria', 'Rolla', 'Nancy Boy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Indices of 5 recommended artists:  [786, 110092, 42987, 47254, 739]
# Recommended artist names: ['Ben Kweller', 'Juno Reactor & The Creatures', 'Lassigue Bendthaus', 'Jacknife Lee', 'Architecture In Helsinki']
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids:  ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Indices of 5 recommended artists:  [1069, 3513, 13921, 3666, 867]
# Recommended artist names: ['Good Shoes', 'Ocean Colour Scene', 'Elias & The Wizzkids', 'Shannon Wright', 'Chuck Berry']
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.1580 seconds

# %%
# Count the number of times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mappings: user_id and artist_name to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map original user and artist identifiers to their indices
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the sparse User-Artist Matrix (UAM)
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# Normalize rows (for cosine similarity)
UAM = normalize(UAM, norm='l2', axis=1)

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

# ------------------------
# Build Annoy index
# ------------------------
# Annoy needs dense vectors. Here, each user vector is of dimension equal to the number of artists.
f = UAM.shape[1]
annoy_index = AnnoyIndex(f, 'angular')  # Using angular metric corresponds to cosine similarity on normalized vectors.

# Add each user's normalized playcount vector to the index.
for i in range(UAM.shape[0]):
    # Convert the sparse vector to a dense array
    vector = UAM.getrow(i).toarray()[0]
    annoy_index.add_item(i, vector)

# Build the Annoy index tree structure. The number of trees can be adjusted (more trees means higher precision at the cost of slower indexing).
n_trees = 5
annoy_index.build(n_trees)

# ------------------------
# Recommendation using Annoy
# ------------------------
start_time = time.time()
for u in range(UAM.shape[0]):
    print("Seed user-id: " + str(user_ids[u]))

    # Query Annoy for K+1 neighbors (we request one extra because the query user appears as the nearest neighbor)
    neighbor_indices, neighbor_distances = annoy_index.get_nns_by_item(u, K + 1, include_distances=True)
    
    # Exclude the seed user from the neighbor list
    neighbor_pairs = [(idx, dist) for idx, dist in zip(neighbor_indices, neighbor_distances) if idx != u]
    # In case there are more than K neighbors, we take the top K closest ones.
    top_neighbors = neighbor_pairs[:K]

    # Convert Annoy's angular distance to cosine similarity. For normalized vectors:
    # cosine_similarity = 1 - (angular_distance^2 / 2)
    top_neighbors_similarities = [1 - (dist * dist / 2) for idx, dist in top_neighbors]
    recommended_user_idx = [idx for idx, dist in top_neighbors]
    recommended_user_scores = top_neighbors_similarities

    print("Nearest K=" + str(K) + " neighbors' user-ids: ", user_ids[recommended_user_idx])

    # Aggregate artists from the recommended users
    recommended_artists_idx = []
    for u_idx in recommended_user_idx:
        recommended_artists_idx.extend(list(UAM.getrow(u_idx).indices))
    
    # Remove duplicates and sort
    recommended_artists_idx = sorted(set(recommended_artists_idx))
    
    # Exclude artists the seed user has already listened to
    seed_artist_indices = set(UAM.getrow(u).indices)
    recommended_artists_idx = np.setdiff1d(recommended_artists_idx, list(seed_artist_indices))

    # For illustration, randomly sample 5 recommended artists (if fewer than 5, take all)
    if len(recommended_artists_idx) < 5:
        random_elements = recommended_artists_idx.tolist()
    else:
        random_indices = random.sample(range(len(recommended_artists_idx)), 5)
        random_elements = [recommended_artists_idx[i] for i in random_indices]

    print("Indices of {} recommended artists: ".format(len(random_elements)), random_elements)
    print("Recommended artist names:", [artist_ids[i] for i in random_elements])
    print('-' * 80)

end_time = time.time()
total_users = UAM.shape[0]
avg_time = (end_time - start_time) / total_users
print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids:  ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Indices of 5 recommended artists:  [12920, 1665, 12923, 52765, 5653]
# Recommended artist names: ['The Posies', 'The Cribs', 'The Seeds', "D'Sound", 'Nathan Fake']
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids:  ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Indices of 5 recommended artists:  [2499, 11029, 10800, 9205, 30671]
# Recommended artist names: ['Sneaker Pimps', 'The Milestone Corporation', 'Money Mark', 'Pet Shop Boys', 'Philippe Zdar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids:  ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Indices of 5 recommended artists:  [59730, 125706, 6799, 115172, 745]
# Recommended artist names: ['Les Petits Pilous', 'Gipsy', 'Alice In Chains', 'Daft Mafia', 'Ash']
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Indices of 5 recommended artists:  [1166, 16206, 137045, 137027, 13299]
# Recommended artist names: ['John Frusciante', 'The Penguins', 'Zero Sospiro', 'The Hungry Nurses', 'John Doe']
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids:  ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Indices of 5 recommended artists:  [19005, 5624, 10734, 104125, 35469]
# Recommended artist names: ['New Vaudeville Band', 'Mossa', 'Kathleen Edwards', 'Electronic Noise Controller', 'Pecheur']
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids:  ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Indices of 5 recommended artists:  [8678, 6957, 8593, 128868, 8006]
# Recommended artist names: ['Information Society', 'Kidneythieves', 'Guy David', 'Mindhole', 'Benny Goodman']
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids:  ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Indices of 5 recommended artists:  [1865, 87183, 7375, 146580, 22334]
# Recommended artist names: ['Virginia Jetzt!', 'Big Walter Horton', 'Stonebridge', 'Metafore', 'Mediengruppe Telekommander']
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids:  ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Indices of 5 recommended artists:  [59731, 113606, 333, 7387, 21245]
# Recommended artist names: ['Lethal Bizzle (Ft. Kate Nash)', 'Herve & A-Trak Featuring Cadence Weapon', 'London Elektricity', 'The Group Dynamic', 'Scratch Massive']
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids:  ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Indices of 5 recommended artists:  [3700, 1817, 43740, 19283, 88319]
# Recommended artist names: ['Spiritualized', 'Thrice', 'Rain Paint', 'Section 25', 'Mania D.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids:  ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Indices of 5 recommended artists:  [47162, 63278, 11614, 2495, 90961]
# Recommended artist names: ['Future Loop Foundation', 'Sdg', 'Funkerman', 'Sl2', 'Ruffneck']
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids:  ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Indices of 5 recommended artists:  [137066, 76512, 78821, 372, 4848]
# Recommended artist names: ['Amit Trivedi', 'Jools Holland', 'Djan & Fam', 'Maurice Ravel', 'Yello']
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids:  ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Indices of 5 recommended artists:  [5265, 34537, 108687, 132720, 115479]
# Recommended artist names: ['Francesco Tristano', 'Philip Jeck', 'Gershon Kingsley', 'Gza/Genius / Santi White / The Genius', 'Jimmy Hamilton']
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids:  ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Indices of 5 recommended artists:  [4113, 4924, 741, 1384, 8128]
# Recommended artist names: ['Bodyrox', 'Al Hirt', 'Aretha Franklin', 'Olspur', 'Captain Beefheart & His Magic Band']
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids:  ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Indices of 5 recommended artists:  [1605, 16345, 37301, 1028, 989]
# Recommended artist names: ['Taking Back Sunday', 'Agalloch', 'Woods', 'Firefox Ak', 'Elefant']
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids:  ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Indices of 5 recommended artists:  [106526, 17306, 1839, 782, 2444]
# Recommended artist names: ['Ekstrak', 'Kenna', 'Tracy Chapman', 'Ben Folds', 'Punks Jump Up']
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids:  ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Indices of 5 recommended artists:  [69604, 2597, 21653, 3687, 17331]
# Recommended artist names: ['Arrola', 'Tiësto', 'Elvis Perkins', 'Smoke City', 'Lole Y Manuel']
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids:  ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Indices of 5 recommended artists:  [10095, 47669, 76846, 137149, 34904]
# Recommended artist names: ['Robert Schumann', 'Tango Saloon', 'Rudolf Serkin', 'Joi Barua', 'Sivert Høyem']
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Indices of 5 recommended artists:  [1433, 1477, 2942, 14671, 14449]
# Recommended artist names: ['Porcupine Tree', 'Robbie Williams', 'Conjure One', 'The Snake The Cross The Crown', 'The Apples In Stereo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids:  ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Indices of 5 recommended artists:  [63065, 12964, 1214, 3115, 19355]
# Recommended artist names: ['Envio', 'Andreas Johnson', 'Katie Melua', 'Gaelic Storm', 'Spain']
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids:  ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Indices of 5 recommended artists:  [20170, 12493, 1574, 10295, 1354]
# Recommended artist names: ['Moulin Rouge', 'The Pogues', 'Starsailor', 'Girls Aloud', 'Nickelback']
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids:  ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Indices of 5 recommended artists:  [130344, 12357, 18174, 24258, 1095]
# Recommended artist names: ['Marquis De Tren & Bonnie Billy', 'Soul Coughing', 'Der Plan', 'Divinity', 'Horace Silver']
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids:  ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Indices of 5 recommended artists:  [115396, 16017, 599, 1365, 6911]
# Recommended artist names: ['Blast Off Country Style', 'Psychic Tv', 'U2', 'Nirvana', 'Gary Numan']
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Indices of 5 recommended artists:  [48964, 1713, 1536, 1726, 27869]
# Recommended artist names: ['Big Face', 'The Knife', 'Silverchair', 'The Magnetic Fields', 'Snake River Conspiracy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Indices of 5 recommended artists:  [9196, 472, 7569, 12867, 22467]
# Recommended artist names: ['Paula Abdul', 'Rob Swift', 'Gluecifer', 'Mineral', 'Sylvain Chauveau']
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids:  ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Indices of 5 recommended artists:  [7062, 23952, 50024, 19828, 28282]
# Recommended artist names: ['Static-X', 'Warmen', 'Nosound', 'Battlelore', 'Coldfinger']
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids:  ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Indices of 5 recommended artists:  [2005, 24058, 18514, 11700, 6275]
# Recommended artist names: ['Bloodhound Gang', 'Φίλιππος Πλιάτσικας', 'International Pony', 'Hem', '布袋寅泰']
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids:  ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Indices of 5 recommended artists:  [69607, 1540, 2818, 9551, 69532]
# Recommended artist names: ['Ascension', "Sinéad O'Connor", 'Blondie', 'The 5Th Dimension', 'Alisha Chinoy & Anu Malik']
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids:  ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Indices of 5 recommended artists:  [14978, 8345, 152, 26003, 127771]
# Recommended artist names: ['Halifax', 'Dj Fresh Feat. Adam F.', 'Donald Byrd', 'Keith Murray', 'Krezip @ 4Uonly.Biz']
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids:  ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Indices of 5 recommended artists:  [13538, 24328, 15199, 8247, 15150]
# Recommended artist names: ['The Paragons', 'Xela', 'The Avett Brothers', 'Curtis Mayfield', 'Ruby Falls']
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids:  ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Indices of 5 recommended artists:  [19119, 1267, 1134, 16739, 17942]
# Recommended artist names: ['Play Dead', 'Low', 'Jamiroquai', 'Chumbawamba', 'Blow Up Hollywood']
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Indices of 5 recommended artists:  [1059, 10618, 3012, 86389, 8805]
# Recommended artist names: ['Gavin Degraw', 'Field Music', 'Dodgy', 'Pine', 'Kevin Yost']
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids:  ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Indices of 5 recommended artists:  [9949, 28488, 110083, 99697, 43725]
# Recommended artist names: ['Efterklang', 'Nigel Kennedy', 'Infra', 'Psychedelic Research Lab', 'Keelhaul']
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids:  ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Indices of 5 recommended artists:  [11583, 36779, 11508, 60024, 1594]
# Recommended artist names: ['Femi Kuti', 'Pg.Lost', 'Earshot', 'Kollaa Kestää', 'Supergrass']
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Indices of 5 recommended artists:  [18498, 15155, 77394, 1818, 17579]
# Recommended artist names: ['Ian Laczynski', 'Sam Sparro', 'Marcelo Vianna', 'Thursday', 'The Sabres Of Paradise']
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids:  ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Indices of 5 recommended artists:  [545, 9662, 15115, 6646, 47761]
# Recommended artist names: ['Sébastien Tellier', 'The Originals', 'Os Mutantes', "The O'Jays", 'Vinicio Capossela']
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids:  ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Indices of 5 recommended artists:  [10517, 28967, 108561, 3359, 3410]
# Recommended artist names: ['Black Label Society', 'Girls Against Boys', 'Tibet Incantations', 'Louis Armstrong', 'Matt Elliott']
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids:  ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Indices of 5 recommended artists:  [30034, 54139, 160678, 34373, 11074]
# Recommended artist names: ['Ünlü', 'Sterling Void', 'Kezz Stone', 'Kiln', 'The Twang']
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids:  ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Indices of 5 recommended artists:  [23907, 112926, 12827, 2016, 18751]
# Recommended artist names: ['Akira', 'Aktorių Trio', 'Jean Sibelius', 'Boys Like Girls', 'Lesbians On Ecstasy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids:  ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Indices of 5 recommended artists:  [6350, 14652, 19559, 41083, 25720]
# Recommended artist names: ['Cassie', 'The Saw Doctors', 'The Rogers Sisters', 'Better Luck Next Time', 'Gallows']
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids:  ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Indices of 5 recommended artists:  [12961, 3394, 23918, 1273, 10601]
# Recommended artist names: ['Alig Fodder', "Margot & The Nuclear So And So'S", 'El Canto Del Loco', 'Madonna', 'Elf Power']
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids:  ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Indices of 5 recommended artists:  [18038, 1582, 12502, 46155, 122456]
# Recommended artist names: ['Chavez', 'Stevie Wonder', 'The Robins', 'Jiří Pavlica', 'Morpheus']
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids:  ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Indices of 5 recommended artists:  [1581, 1620, 3435, 40283, 29117]
# Recommended artist names: ['Steve Miller Band', 'The (International) Noise Conspiracy', 'Millionaire', 'A-Sides & Mc Fats', 'Mary Timony']
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids:  ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Indices of 5 recommended artists:  [32547, 15833, 35656, 182, 19338]
# Recommended artist names: ['West Indian Girl', 'Lloyd Price', "Mary Margaret O'Hara", 'Fink', 'Smokers Die Younger']
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids:  ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Indices of 5 recommended artists:  [9889, 10981, 62269, 104995, 2544]
# Recommended artist names: ['Arvo Pärt', 'The Cult', "Luca Turilli'S Dreamquest", 'Twofortwoelectric/Greyvision/Twofortwoelectric/Greyvision', 'The Black Ghosts']
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids:  ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Indices of 5 recommended artists:  [101084, 1541, 10045, 111215, 7989]
# Recommended artist names: ['Nightwish - Tarja Project', 'Sixpence None The Richer', 'Meshuggah', 'Raras Tocatas Pencas', 'Bananarama']
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids:  ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Indices of 5 recommended artists:  [87799, 87717, 87734, 17960, 112503]
# Recommended artist names: ['Lager Louts', 'Anti Establishment', 'Carnal Grief', 'Boom Bip', 'Inni']
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids:  ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Indices of 5 recommended artists:  [36507, 77831, 63126, 1002, 142684]
# Recommended artist names: ['D.R.I.', 'Charlie Chaplin', 'Innerstate', 'Erasure', 'Mindcrimers']
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids:  ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Indices of 5 recommended artists:  [75534, 107991, 17062, 14024, 11015]
# Recommended artist names: ['The Network', 'Charlene Soraia', 'Barry Manilow', 'Horse Feathers', 'The Knack']
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids:  ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Indices of 5 recommended artists:  [1660, 1319, 16709, 92251, 15747]
# Recommended artist names: ['The Coral', 'Minus The Bear', 'Big Punisher', 'Douglas Wood', 'John Williams & The Boston Pops Orchestra']
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Indices of 5 recommended artists:  [34724, 23717, 86120, 4518, 86129]
# Recommended artist names: ['Venus Hum', 'Son Ambulance', 'Aphasic', 'Mousse T.', 'Axe Riverboy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids:  ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Indices of 5 recommended artists:  [31886, 14774, 3377, 3247, 2459]
# Recommended artist names: ['Quit Your Dayjob', 'Wizzard', 'Madrugada', 'Jay-Z', 'Robyn']
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids:  ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Indices of 5 recommended artists:  [1697, 43729, 59201, 4084, 43483]
# Recommended artist names: ['The Goo Goo Dolls', 'May I Cry', 'Myrkvar', 'Bangles', 'Norgram']
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids:  ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Indices of 5 recommended artists:  [30682, 12539, 6777, 147230, 72530]
# Recommended artist names: ['Rivers Cuomo', 'Tito & Tarantula', 'Westlife', 'Pac Div', 'Kami@Viperroom.Com']
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids:  ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Indices of 5 recommended artists:  [38211, 67678, 13687, 116787, 2069]
# Recommended artist names: ['The Wurzels', 'Cadaver', 'Anti-Nowhere League', 'Revoltz', 'Dane Cook']
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids:  ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Indices of 5 recommended artists:  [82182, 4356, 36527, 118602, 86269]
# Recommended artist names: ['The Trouble With Sweeney', 'Inner City', 'Exilia', 'Tarisha', 'Itskasofa']
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids:  ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Indices of 5 recommended artists:  [10381, 23200, 46291, 1804, 6509]
# Recommended artist names: ['Sara Bareilles', 'Orion Too', 'Ralph Stanley & Vince Gill & P', 'The Weakerthans', 'Lloyd Banks']
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids:  ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Indices of 5 recommended artists:  [2173, 139, 125472, 6800, 1613]
# Recommended artist names: ['Forgive Durden', 'Dido', 'Playmaker', 'All That Remains', 'Tegan And Sara']
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids:  ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Indices of 5 recommended artists:  [16663, 29745, 9297, 25437, 1064]
# Recommended artist names: ['The White Tie Affair', 'Tubeway Army', 'Richard Hell & The Voidoids', 'Dear And The Headlights', "Gilbert O'Sullivan"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Indices of 5 recommended artists:  [16553, 11282, 24777, 13527, 11922]
# Recommended artist names: ['The Boondock Saints', 'Billie The Vision & The Dancers', 'Saltillo', 'The Melodians', "Lightnin' Hopkins"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids:  ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Indices of 5 recommended artists:  [19547, 3698, 3124, 3349, 16449]
# Recommended artist names: ['The Pist', 'Space', 'Georg Philipp Telemann', 'Little Birdy', 'John Dowland']
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids:  ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Indices of 5 recommended artists:  [69669, 491, 105729, 71048, 1600]
# Recommended artist names: ['Berlin Feat. Terri Nunn', 'Salt Tank', 'Dj Russ Harris', 'Rachel Auburn Vs Madonna', 'System Of A Down']
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids:  ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Indices of 5 recommended artists:  [16449, 17753, 16271, 19251, 2411]
# Recommended artist names: ['John Dowland', 'Air Formation', 'Tyskarna Från Lund', 'Sahara Hotnights', 'Orgy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids:  ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Indices of 5 recommended artists:  [1776, 699, 99373, 137205, 121451]
# Recommended artist names: ['The Smashing Pumpkins', 'All Saints', '! Www.Polskie-Mp3.Tk ! Zbeer', 'Sudwesfunk Orchestra', 'Hayden Panettiere']
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids:  ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Indices of 5 recommended artists:  [3860, 12873, 1527, 42445, 20660]
# Recommended artist names: ['The Turtles', 'Mxpx', 'Sheryl Crow', 'The Glenn Miller Orchestra', 'Bryan Zentz']
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids:  ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Indices of 5 recommended artists:  [9416, 19845, 27656, 1570, 10918]
# Recommended artist names: ['Slow Train Soul', 'Eamon', 'Jonezetta', 'Stacie Orrico', 'Stealers Wheel']
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids:  ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Indices of 5 recommended artists:  [13920, 77, 95793, 27725, 12134]
# Recommended artist names: ['Elephant Parade', 'Bonobo', 'Zarahn', 'Mosqitoo', 'Orishas']
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids:  ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Indices of 5 recommended artists:  [72279, 58795, 41969, 4571, 3342]
# Recommended artist names: ['The Muttering Retreats', 'Chicane Feat. Tom Jones', 'The Appearance', 'P!Nk', 'Limp Bizkit']
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids:  ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Indices of 5 recommended artists:  [164047, 12065, 144868, 50940, 2621]
# Recommended artist names: ['Rappy Mcrappperson', 'Monster Magnet', 'Solenoid', 'Dave Hamilton', 'Unwritten Law']
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids:  ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Indices of 5 recommended artists:  [25036, 6473, 132091, 127770, 17012]
# Recommended artist names: ['Alchemist', "Juelz Santana & Lil' Wayne", 'Naledge', 'Kreem.Com & Guru', 'Xxl Raps Vol.1']
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids:  ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Indices of 5 recommended artists:  [3239, 685, 19626, 155995, 1690]
# Recommended artist names: ['Jarvis Cocker', 'Air Traffic', 'Tobias Fröberg', 'Pete Doherty & Carl Barrat', 'The Fratellis']
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids:  ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Indices of 5 recommended artists:  [3377, 11518, 38387, 1068, 16932]
# Recommended artist names: ['Madrugada', 'Eddie Vedder', 'Sean Paul Ft. Rihanna', 'Good Charlotte', 'Puff Daddy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids:  ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Indices of 5 recommended artists:  [13722, 157904, 76260, 89633, 157868]
# Recommended artist names: ['Band Aid Ii', 'Pretty Rick', 'Super Mash Bros.', 'Michel Berger', 'Jack Ventimiglia']
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids:  ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Indices of 5 recommended artists:  [160329, 48856, 4225, 10369, 1225]
# Recommended artist names: ['Richard Gibbs & Bear Mccreary', 'The Pinker Tones', 'Dj Dean', 'Reaper', 'Kettcar']
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids:  ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Indices of 5 recommended artists:  [24324, 72732, 28187, 79168, 10773]
# Recommended artist names: ['Union Jack', 'Richard X', 'T-Bone Burnett', 'Blackcat Revival', 'Ludes']
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids:  ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Indices of 5 recommended artists:  [3543, 12684, 35856, 11724, 35911]
# Recommended artist names: ['Patrick Wolf', '志方あきこ', "Best Of '80", 'Illapu', 'Full Blown Rose']
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids:  ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Indices of 5 recommended artists:  [23413, 64469, 15212, 64285, 867]
# Recommended artist names: ['The Congos', 'Paul Burch & The Wpa Ballclub', 'The Feelies', 'Madep', 'Chuck Berry']
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids:  ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Indices of 5 recommended artists:  [3288, 47353, 42789, 141370, 19756]
# Recommended artist names: ['Keely Smith', 'Laroque', 'Downliners Sekt', 'Thomas A. Dorsey', 'Yuri Yunakov']
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids:  ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Indices of 5 recommended artists:  [86220, 8409, 10312, 1813, 41635]
# Recommended artist names: ['Filewile', 'Ed Harcourt', 'Jordin Sparks', 'They Might Be Giants', 'Earthsuit']
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids:  ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Indices of 5 recommended artists:  [23969, 1058, 21629, 27474, 34705]
# Recommended artist names: ['Carcass', 'Gary Jules', 'Dakota Suite', 'Butch Walker', 'Tom Burbank']
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids:  ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Indices of 5 recommended artists:  [3420, 9555, 35500, 2566, 18110]
# Recommended artist names: ['Menomena', 'The Association', 'Si-{Cut}.Db', 'The Lively Ones', 'Cornell Campbell']
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids:  ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Indices of 5 recommended artists:  [1499, 1485, 2507, 783, 41772]
# Recommended artist names: ['Ryan Adams', 'Rocky Votolato', 'Soulwax', 'Ben Folds Five', 'Letters To Cleo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids:  ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Indices of 5 recommended artists:  [49716, 1580, 48995, 14966, 118342]
# Recommended artist names: ['Dirt', 'Stereophonics', 'Buddy Akai', 'Ghosts And Vodka', 'Peter Buffett']
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids:  ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Indices of 5 recommended artists:  [11791, 41769, 41725, 41944, 3094]
# Recommended artist names: ['Joe Lynn Turner', 'Latvijas Himna', 'Into Eternity', 'Strata', 'Flowers From The Man Who Shot Your Cousin']
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids:  ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Indices of 5 recommended artists:  [7062, 47991, 3113, 10305, 147016]
# Recommended artist names: ['Static-X', 'Sanalejo', 'G-Unit', 'Ill Niño', 'Hsm2 Cast']
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids:  ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Indices of 5 recommended artists:  [2190, 2499, 16439, 3513, 22926]
# Recommended artist names: ['Global Deejays', 'Sneaker Pimps', 'Hatesphere', 'Ocean Colour Scene', 'Freddie Mercury']
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids:  ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Indices of 5 recommended artists:  [7072, 14308, 86357, 42734, 136875]
# Recommended artist names: ['Switchblade Symphony', 'Rough Bunnies', 'New End Original', 'Cinque Cento', 'Ali Khan']
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids:  ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Indices of 5 recommended artists:  [12158, 2685, 7604, 9955, 12070]
# Recommended artist names: ['Paul Gilbert', 'Afterhours', 'Immortal Technique', 'Ephel Duath', 'Mother Love Bone']
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids:  ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Indices of 5 recommended artists:  [118361, 9501, 11474, 37571, 1921]
# Recommended artist names: ['Salvage', 'Sven Van Hees', 'Dixie Chicks', 'Al Ventura', '4 Strings']
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Indices of 5 recommended artists:  [34189, 17368, 34, 1546, 505]
# Recommended artist names: ['Deru', 'Mcalmont & Butler', 'Arthur Blythe', 'Smog', 'Shugo Tokumaru']
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids:  ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Indices of 5 recommended artists:  [23742, 28184, 171, 173609, 740]
# Recommended artist names: ['Ttc', 'Sistars', 'Enya', 'Killer Queen & Yuppies', 'Arctic Monkeys']
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids:  ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Indices of 5 recommended artists:  [8128, 128762, 150823, 29677, 66963]
# Recommended artist names: ['Captain Beefheart & His Magic Band', 'Don Moy', 'Marchetti / Noetinger / Werchowski', 'The Toy Dolls', 'Unique 3']
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids:  ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Indices of 5 recommended artists:  [79256, 79234, 10123, 83937, 16800]
# Recommended artist names: ['Jayne Wisener', 'George Gershwin - Ella Fitzgerald', 'Styx', 'Cankat', 'Fabolous']
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids:  ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Indices of 5 recommended artists:  [94082, 10526, 2518, 1155, 18995]
# Recommended artist names: ['Magnus Moriarty™', 'Brakes', 'Sugarcult', 'Jim Jacobs & Warren Casey', 'Neon Zoo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids:  ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Indices of 5 recommended artists:  [44050, 101525, 107328, 19887, 75698]
# Recommended artist names: ['Rapoon', 'Benny Ill V Dj Hatcha', 'Disco Storia', 'Roy Paci & Aretuska', 'Feng Shui']
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids:  ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Indices of 5 recommended artists:  [34353, 7062, 36100, 3532, 18864]
# Recommended artist names: ['July Skies', 'Static-X', 'Camila', 'Pain Of Salvation', 'Mariza']
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids:  ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Indices of 5 recommended artists:  [42269, 17789, 42374, 1813, 2716]
# Recommended artist names: ['Benjamin Robinson', 'Amsterdam Klezmer Band', 'Mark Booth', 'They Might Be Giants', 'Anathema']
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids:  ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Indices of 5 recommended artists:  [12040, 7051, 137545, 17392, 11828]
# Recommended artist names: ['Michael Brook', 'Shinedown', 'A Few Hundred Pop Stars', 'Mory Kanté', 'Jude']
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids:  ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Indices of 5 recommended artists:  [1258, 44100, 1785, 1634, 1922]
# Recommended artist names: ['Little Barrie', 'Superguidis', 'The String Cheese Incident', 'The Band', '50 Cent']
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids:  ['user_000906' 'user_000543' 'user_000238' 'user_000360' 'user_000217']
# Indices of 5 recommended artists:  [23177, 8324, 1725, 1808, 88827]
# Recommended artist names: ['Nic & The Family', 'Dinosaur Jr.', 'The Magic Numbers', 'The Wombats', 'Captain F.U.B.A.R.']
# --------------------------------------------------------------------------------
# Seed user-id: user_000100
# Nearest K=5 neighbors' user-ids:  ['user_000918' 'user_000234' 'user_000913' 'user_000371' 'user_000390']
# Indices of 5 recommended artists:  [164847, 233, 17618, 8312, 82212]
# Recommended artist names: ['Christopher Maltman - Marieke Blankestijn, Ursula Smith, Malcolm Martineau', 'I Am Robot And Proud', 'What Made Milwaukee Famous', 'Detroit Grand Pubahs', 'Tres Chicas']
# --------------------------------------------------------------------------------
# Seed user-id: user_000101
# Nearest K=5 neighbors' user-ids:  ['user_000886' 'user_000643' 'user_000667' 'user_000637' 'user_000654']
# Indices of 5 recommended artists:  [19263, 40303, 17765, 1620, 1430]
# Recommended artist names: ['Sanseverino', 'April Wine', 'Alan Parker And Alan Hawkshaw', 'The (International) Noise Conspiracy', 'Pixies']
# --------------------------------------------------------------------------------
# Seed user-id: user_000102
# Nearest K=5 neighbors' user-ids:  ['user_000753' 'user_000031' 'user_000582' 'user_000704' 'user_000274']
# Indices of 5 recommended artists:  [18614, 18728, 3917, 76492, 12923]
# Recommended artist names: ['Josef Strauss', 'Lee Feldman', 'Under Byen', 'Jaime López', 'The Seeds']
# --------------------------------------------------------------------------------
# Seed user-id: user_000103
# Nearest K=5 neighbors' user-ids:  ['user_000839' 'user_000616' 'user_000414' 'user_000567' 'user_000513']
# Indices of 5 recommended artists:  [1646, 3546, 1414, 12631, 2031]
# Recommended artist names: ['The Bravery', 'Patti Smith', 'Peter Bjorn And John', 'Willy Mason', 'Calvin Harris']
# --------------------------------------------------------------------------------
# Seed user-id: user_000104
# Nearest K=5 neighbors' user-ids:  ['user_000442' 'user_000594' 'user_000853' 'user_000523' 'user_000032']
# Indices of 5 recommended artists:  [59196, 111017, 119738, 110930, 110989]
# Recommended artist names: ['Morgenstern', 'Kaira', 'Lonewolf', 'Death Dies', 'Hardingrock']
# --------------------------------------------------------------------------------
# Seed user-id: user_000105
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000161' 'user_000779' 'user_000018' 'user_000093']
# Indices of 5 recommended artists:  [3329, 9764, 936, 51718, 51685]
# Recommended artist names: ['Lenny Kravitz', 'Tosca', 'Diana Krall', 'Nino Rota & Carmine Coppola', 'Mert Icgören']
# --------------------------------------------------------------------------------
# Seed user-id: user_000106
# Nearest K=5 neighbors' user-ids:  ['user_000499' 'user_000844' 'user_000992' 'user_000074' 'user_000629']
# Indices of 5 recommended artists:  [14231, 108457, 3058, 10171, 92781]
# Recommended artist names: ['Paolo Conte', 'Ep Allan', 'Eskobar', 'Vetiver', 'Pete Namlook & Mixmaster Morris']
# --------------------------------------------------------------------------------
# Seed user-id: user_000107
# Nearest K=5 neighbors' user-ids:  ['user_000382' 'user_000890' 'user_000976' 'user_000729' 'user_000616']
# Indices of 5 recommended artists:  [1456, 162626, 13295, 16365, 25483]
# Recommended artist names: ['Razorlight', 'B2C', 'Jesse Malin', 'Bettie Serveert', 'Divider']
# --------------------------------------------------------------------------------
# Seed user-id: user_000108
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000912' 'user_000970' 'user_000650' 'user_000431']
# Indices of 5 recommended artists:  [12300, 4140, 125476, 17413, 75239]
# Recommended artist names: ['Schiller', 'Chocolate Puma', 'Roxane', 'One Inch Punch', 'Lisa Miller']
# --------------------------------------------------------------------------------
# Seed user-id: user_000109
# Nearest K=5 neighbors' user-ids:  ['user_000878' 'user_000741' 'user_000434' 'user_000501' 'user_000603']
# Indices of 5 recommended artists:  [2715, 33841, 1685, 1307, 3699]
# Recommended artist names: ['Anastacia', 'Tyler Hilton & Bethany Joy Lenz', 'The Films', 'Metric', 'Sparklehorse']
# --------------------------------------------------------------------------------
# Seed user-id: user_000110
# Nearest K=5 neighbors' user-ids:  ['user_000653' 'user_000096' 'user_000596' 'user_000169' 'user_000493']
# Indices of 5 recommended artists:  [1229, 126170, 12989, 19618, 16864]
# Recommended artist names: ['Kings Of Convenience', 'Franklin Brothers', 'Christie', 'Tiger Baby', "Lil' Kim"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000111
# Nearest K=5 neighbors' user-ids:  ['user_000378' 'user_000047' 'user_000648' 'user_000973' 'user_000868']
# Indices of 5 recommended artists:  [32690, 172611, 172550, 162914, 10669]
# Recommended artist names: ['Bob Wills', 'Reno Divorce', 'Phantom Cowboys', 'Grant Brothers & Their Music', 'Hinder']
# --------------------------------------------------------------------------------
# Seed user-id: user_000112
# Nearest K=5 neighbors' user-ids:  ['user_000135' 'user_000945' 'user_000177' 'user_000358' 'user_000933']
# Indices of 5 recommended artists:  [28351, 21271, 166274, 12433, 24079]
# Recommended artist names: ['Ganga', 'Silver Convention', 'Hotel De Paris', 'Thalía', 'Baha Men']
# --------------------------------------------------------------------------------
# Seed user-id: user_000113
# Nearest K=5 neighbors' user-ids:  ['user_000052' 'user_000115' 'user_000395' 'user_000676' 'user_000247']
# Indices of 5 recommended artists:  [3102, 632, 43749, 18771, 69]
# Recommended artist names: ['Franz Schubert', '[Unknown]', 'Siglo Xx', 'Living Colour', 'Boards Of Canada']
# --------------------------------------------------------------------------------
# Seed user-id: user_000114
# Nearest K=5 neighbors' user-ids:  ['user_000629' 'user_000862' 'user_000844' 'user_000584' 'user_000196']
# Indices of 5 recommended artists:  [1131, 110850, 12860, 143420, 27650]
# Recommended artist names: ['Jamie Cullum', 'Yuri Mrakadi', 'Marc-Antoine Charpentier', 'Team Brick', "Iris - Loose In Wanting (Loveletter'S Sonar Eclipse Mix)"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000115
# Nearest K=5 neighbors' user-ids:  ['user_000044' 'user_000052' 'user_000113' 'user_000802' 'user_000798']
# Indices of 5 recommended artists:  [86972, 59136, 38040, 24529, 10048]
# Recommended artist names: ['Martti Servo Ja Napander', 'Hurtlocker', 'Paul Mccartney & Stevie Wonder', 'Behold... The Arctopus', 'Ministry']
# --------------------------------------------------------------------------------
# Seed user-id: user_000116
# Nearest K=5 neighbors' user-ids:  ['user_000766' 'user_000624' 'user_000658' 'user_000350' 'user_000920']
# Indices of 5 recommended artists:  [10647, 882, 72846, 16373, 94082]
# Recommended artist names: ['Get Set Go', 'Common Rider', '[Ingenting]', 'Bloodbath', 'Magnus Moriarty™']
# --------------------------------------------------------------------------------
# Seed user-id: user_000117
# Nearest K=5 neighbors' user-ids:  ['user_000806' 'user_000383' 'user_000256' 'user_000807' 'user_000368']
# Indices of 5 recommended artists:  [11091, 8082, 11613, 10312, 94203]
# Recommended artist names: ['Tom & Joyce', 'Brian Eno', 'Frozen Silence', 'Jordin Sparks', 'Napoleon Dynamite']
# --------------------------------------------------------------------------------
# Seed user-id: user_000118
# Nearest K=5 neighbors' user-ids:  ['user_000626' 'user_000837' 'user_000653' 'user_000493' 'user_000096']
# Indices of 5 recommended artists:  [76012, 1280, 26356, 38390, 1242]
# Recommended artist names: ['Saving Jane', 'Mansun', 'N.O.R.E.', 'Sisterlove', 'Lcd Soundsystem']
# --------------------------------------------------------------------------------
# Seed user-id: user_000119
# Nearest K=5 neighbors' user-ids:  ['user_000395' 'user_000182' 'user_000453' 'user_000594' 'user_000173']
# Indices of 5 recommended artists:  [41500, 12451, 11997, 62721, 810]
# Recommended artist names: ['Arjen Anthony Lucassen', 'The Dubliners', 'Maria Mena', 'Misery Inc.', 'Blur']
# --------------------------------------------------------------------------------
# Seed user-id: user_000120
# Nearest K=5 neighbors' user-ids:  ['user_000285' 'user_000890' 'user_000575' 'user_000837' 'user_000224']
# Indices of 5 recommended artists:  [69841, 3493, 3508, 118070, 1740]
# Recommended artist names: ['Clear Static', 'New Order', 'Nouvelle Vague', 'A Day In The Life', 'The Ordinary Boys']
# --------------------------------------------------------------------------------
# Seed user-id: user_000121
# Nearest K=5 neighbors' user-ids:  ['user_000277' 'user_000345' 'user_000851' 'user_000202' 'user_000493']
# Indices of 5 recommended artists:  [50436, 84687, 24598, 66120, 20937]
# Recommended artist names: ['Dykehouse', 'Echoboy', 'Deutsch Nepal', 'Mark Thomas', 'James Ruskin']
# --------------------------------------------------------------------------------
# Seed user-id: user_000122
# Nearest K=5 neighbors' user-ids:  ['user_000837' 'user_000048' 'user_000714' 'user_000525' 'user_000118']
# Indices of 5 recommended artists:  [91900, 61170, 138558, 363, 9205]
# ...
# --------------------------------------------------------------------------------
# Seed user-id: user_000960
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000511' 'user_000024' 'user_000698' 'user_000403']
# Indices of 5 recommended artists:  [7700, 14930, 7231, 6679, 3170]
# Recommended artist names: ['Neil Young & Crazy Horse', 'Distopia', 'Dragonforce', "Youssou N'Dour", 'Halou']
# --------------------------------------------------------------------------------
# Seed user-id: user_000961
# Nearest K=5 neighbors' user-ids:  ['user_000591' 'user_000709' 'user_000753' 'user_000097' 'user_000294']
# Indices of 5 recommended artists:  [9503, 678, 24376, 32677, 14785]
# Recommended artist names: ['Sweet Sensation', 'Acid House Kings', 'Joe Lean & The Jing Jang Jong', 'Billy Murray', 'Zoot Money']
# --------------------------------------------------------------------------------
# Seed user-id: user_000962
# Nearest K=5 neighbors' user-ids:  ['user_000691' 'user_000705' 'user_000970' 'user_000031' 'user_000910']
# Indices of 5 recommended artists:  [19184, 2945, 2344, 19366, 15121]
# Recommended artist names: ['Remedy', 'Controller.Controller', "Manfred Mann'S Earth Band", "St O'Neal", 'Pela']
# --------------------------------------------------------------------------------
# Seed user-id: user_000963
# Nearest K=5 neighbors' user-ids:  ['user_000210' 'user_000691' 'user_000794' 'user_000345' 'user_000412']
# Indices of 5 recommended artists:  [76977, 57573, 19274, 39989, 47491]
# Recommended artist names: ['Henry Makobi', 'Gypsy Caravan', 'Scissors For Lefty', 'Loop', 'Nova Nova']
# --------------------------------------------------------------------------------
# Seed user-id: user_000964
# Nearest K=5 neighbors' user-ids:  ['user_000721' 'user_000059' 'user_000268' 'user_000716' 'user_000996']
# Indices of 5 recommended artists:  [8109, 28294, 53778, 14885, 3682]
# Recommended artist names: ['Buena Vista Social Club', 'Darkwood Dub', 'Ray Bryant', 'Breakestra', 'Skunk Anansie']
# --------------------------------------------------------------------------------
# Seed user-id: user_000965
# Nearest K=5 neighbors' user-ids:  ['user_000397' 'user_000569' 'user_000795' 'user_001000' 'user_000628']
# Indices of 5 recommended artists:  [3137, 834, 13401, 19106, 9755]
# Recommended artist names: ['Glen Hansard & Markéta Irglová', 'Built To Spill', 'Rocket From The Crypt', 'Picastro', 'Tommy James & The Shondells']
# --------------------------------------------------------------------------------
# Seed user-id: user_000966
# Nearest K=5 neighbors' user-ids:  ['user_000574' 'user_000043' 'user_000345' 'user_000143' 'user_000397']
# Indices of 5 recommended artists:  [3453, 3380, 8476, 86346, 74594]
# Recommended artist names: ['Morcheeba', 'Magneta Lane', 'Falco', 'Musta Joutsen', 'Charly García']
# --------------------------------------------------------------------------------
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids:  ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Indices of 5 recommended artists:  [9030, 3153, 43252, 9810, 47253]
# Recommended artist names: ['Miguel Miggs', 'Grand National', 'Seductive Souls', 'Visage', 'Jackie Mclean']
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids:  ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Indices of 5 recommended artists:  [10483, 90513, 3866, 64361, 1238]
# Recommended artist names: ['Archie Bronson Outfit', 'Jence', 'The Veronicas', 'Miracle Fortress', 'Larrikin Love']
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids:  ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Indices of 5 recommended artists:  [25538, 19665, 97173, 15514, 6317]
# Recommended artist names: ['Don Johnson Big Band', 'Turbulence', 'Dr. Dre & Dj Quik Feat. Mimi', 'Cut Chemist Meets Shortkut', 'Baby Bash']
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids:  ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Indices of 5 recommended artists:  [2837, 4828, 7327, 133208, 4507]
# Recommended artist names: ['Brandi Carlile', 'Various Artists', 'Mystikal', 'Conrad Herwig', 'Modern Talking']
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids:  ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Indices of 5 recommended artists:  [36489, 88124, 61495, 1027, 91466]
# Recommended artist names: ['Blitzkid', 'Una Corda', 'Bambix', 'Fiona Apple', 'Mystery Of Dawn']
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids:  ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Indices of 5 recommended artists:  [61565, 91236, 832, 23672, 91706]
# Recommended artist names: ['Clair De Lune', 'Blktop Project', 'Bryan Adams', 'Make Model', 'Trial By Fire']
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids:  ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Indices of 5 recommended artists:  [9444, 132, 77104, 2613, 6777]
# Recommended artist names: ['Spandau Ballet', 'Deep Dish', 'West Coast Natural Gas', 'Twista', 'Westlife']
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids:  ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Indices of 5 recommended artists:  [1300, 9441, 44639, 44598, 10667]
# Recommended artist names: ['Matthew Sweet', 'Sound Team', 'Shakira Ft Wyclef Jean', 'Kristin Cifelli', 'Hell Is For Heroes']
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids:  ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Indices of 5 recommended artists:  [68365, 75036, 3878, 914, 1754]
# Recommended artist names: ['Pandatransport', 'Amiel', 'The Zombies', 'David Gray', 'The Pretenders']
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids:  ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Indices of 5 recommended artists:  [34096, 10016, 162633, 27914, 59084]
# Recommended artist names: ['Andy Hunter°', 'Khoma', 'Division Four', 'The Black Maria', 'Doug Pinnick']
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids:  ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Indices of 5 recommended artists:  [3360, 1600, 16213, 141, 66296]
# Recommended artist names: ['Lovage', 'System Of A Down', 'The Simpsons', 'Digitalism', 'The Dirty Secrets']
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids:  ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Indices of 5 recommended artists:  [6645, 1647, 43733, 77756, 6440]
# Recommended artist names: ['The Notorious B.I.G.', 'The Breeders', 'Moonlight', 'Ayhan Yener', 'Ismael Miranda']
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids:  ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Indices of 5 recommended artists:  [6857, 1708, 5431, 1805, 11139]
# Recommended artist names: ['David Arkenstone', 'The Jesus And Mary Chain', 'Karri O.', 'The White Stripes', 'Сергей Сергеевич Прокофьев']
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids:  ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Indices of 5 recommended artists:  [9350, 8710, 16599, 10748, 48927]
# Recommended artist names: ['Say Hi', 'Jean Michel Jarre', 'Do Or Die', 'Kula Shaker', 'Ana Da Silva']
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids:  ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Indices of 5 recommended artists:  [2009, 70128, 5897, 7375, 138633]
# Recommended artist names: ['Bob Sinclar', 'Ethan', 'Spice Girls', 'Stonebridge', 'Chopin - Complete Edition']
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids:  ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Indices of 5 recommended artists:  [6327, 2543, 12265, 2206, 9902]
# Recommended artist names: ['Bitter:Sweet', 'The Black Eyed Peas', 'Roy Buchanan', "Guns N' Roses", 'Bohren & Der Club Of Gore']
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids:  ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Indices of 5 recommended artists:  [26566, 15792, 1494, 9, 12328]
# Recommended artist names: ['Reaching Quiet', 'Kronos Quartet', 'Roy Orbison', 'A Tribe Called Quest', 'Sigur Rós & Hilmar Örn Hilmarsson']
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids:  ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Indices of 5 recommended artists:  [157934, 2015, 124232, 157914, 19533]
# Recommended artist names: ['Tufts Jackson Jills', 'Boston', 'Stephen Speaks', 'Stanford Everyday People', 'The Miracles']
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids:  ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Indices of 5 recommended artists:  [26957, 10203, 1376, 6911, 21676]
# Recommended artist names: ['The Reddmen', 'The Distillers', 'O.A.R.', 'Gary Numan', 'Iningrid Michaelson']
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids:  ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Indices of 5 recommended artists:  [36508, 147906, 22558, 12970, 15089]
# Recommended artist names: ['Deadbolt', 'Monophace', '12 Moons', 'Autolux', 'Mississippi John Hurt']
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids:  ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Indices of 5 recommended artists:  [8712, 14135, 5069, 16987, 21793]
# Recommended artist names: ['Jean-Jacques Perrey', 'Madeline', 'Chicks On Speed', 'Talib Kweli & Madlib', 'Russian Red']
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids:  ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Indices of 5 recommended artists:  [12022, 1308, 1074, 17829, 38549]
# Recommended artist names: ['Mcauley-Schenker Group', 'Mgmt', 'Grandaddy', 'Art Tatum', "Bill Nelson'S Red Noise"]
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids:  ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Indices of 5 recommended artists:  [1682, 16787, 4314, 10720, 19743]
# Recommended artist names: ['The Faint', 'Edan', 'G-Pal', 'Jr. Walker & The All Stars', 'Yazoo']
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids:  ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Indices of 5 recommended artists:  [10069, 5966, 9980, 99493, 60130]
# Recommended artist names: ['Omega Massif', "The 5.6.7.8'S", 'Grails', 'Irv Gotti Presents The Inc. Featuring Ja Rule, Ashanti, Charli Baltimore & Vita', 'Transmission0']
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids:  ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Indices of 5 recommended artists:  [45707, 77464, 33799, 837, 6088]
# Recommended artist names: ['First Floor Power', 'Thingy', 'Skank & Nando Reis Milton Lou', 'Bushido', 'Yagya']
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids:  ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Indices of 5 recommended artists:  [34596, 47285, 78778, 10984, 4192]
# Recommended artist names: ['Rothko', 'Joe Henderson', 'The Prize Fighter Inferno', 'The Dead Girls', 'Dave Gahan']
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids:  ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Indices of 5 recommended artists:  [14888, 41764, 53623, 22002, 105783]
# Recommended artist names: ['Buggles', 'Ktulu', 'Audio Active', 'The Kovenant', 'Gizelle']
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids:  ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Indices of 5 recommended artists:  [550, 19248, 17235, 749, 90064]
# Recommended artist names: ['Talvin Singh', 'Sad Lovers And Giants', 'Giuseppe Verdi', 'At The Drive-In', 'Gabriella & Troy']
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids:  ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Indices of 5 recommended artists:  [1134, 100873, 19665, 45495, 6910]
# Recommended artist names: ['Jamiroquai', 'Monica Mancini', 'Turbulence', 'The Spinanes', 'Gackt']
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids:  ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Indices of 5 recommended artists:  [13400, 3773, 15015, 29139, 806]
# Recommended artist names: ["Rock 'N' Roll Soldiers", 'The Chi-Lites', 'Jeniferever', 'Modest Proposal', 'Bloc Party']
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids:  ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Indices of 5 recommended artists:  [15014, 14889, 15246, 19599, 9200]
# Recommended artist names: ['Jaylib', 'Burzum', 'The Whigs', 'The Weather Girls', 'Pelle Carlberg']
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Indices of 5 recommended artists:  [109100, 8082, 3274, 10280, 18588]
# Recommended artist names: ['2008-10 Cd Swap', 'Brian Eno', 'Kaffe Matthews', 'Eisbrecher', 'John Cage']
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids:  ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Indices of 5 recommended artists:  [42463, 2893, 22413, 12743, 8668]
# Recommended artist names: ['Valley Of The Giants', 'Chad Vangaalen', 'Puppetmastaz', 'Babasónicos', 'I Am The World Trade Center']
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.1616 seconds
