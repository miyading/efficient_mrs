# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.19.5 in ./Downloads/hw4/code/.conda/lib/python3.9/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in ./Downloads/hw4/code/.conda/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 16.3 MB/s eta 0:00:00a 0:00:01
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 threadpoolctl-3.6.0

# %%
import pandas as pd
from scipy.sparse import csr_matrix
import numpy as np
import random
import time 
from sklearn.preprocessing import normalize

# %%
K = 5

file_path = "Downloads/lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv"

# Load interaction log
interactions = pd.read_csv(file_path, sep="\t", header=None,
                           names=["user_id", "timestamp", "artist_id", "artist_name", "track_id", "track_name"], on_bad_lines='skip')

# %%
# Count number of times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mappings: user/artist to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map to index
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the sparse matrix (UAM)
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# normalize rows (for cosine similarity)

UAM = normalize(UAM, norm='l2', axis=1)

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))


if __name__ == '__main__':
    start_time = time.time()
    for u in range(0, UAM.shape[0]):
        print("Seed user-id: " + str(user_ids[u]))

        # Get normalized playcount vector for current user
        pc_vec = UAM.getrow(u)

        # Compute cosine similarity between this user and all users
        uU_sim = pc_vec.dot(UAM.transpose()).tocoo()
        uU_user_idx = uU_sim.col
        uU_data = uU_sim.data

        # Remove self-similarity
        uU_data[uU_user_idx == u] = 0

        # Eliminate zeros
        uU_sim.data = uU_data
        uU_sim = uU_sim.tocsr()
        uU_sim.eliminate_zeros()
        uU_sim = uU_sim.tocoo()

        # Re-assign user indices and scores
        uU_user_idx = uU_sim.col
        uU_data = uU_sim.data

        # Sort by similarity score
        sort_index = np.argsort(uU_data)

        # Select top-K nearest neighbors
        # Note that uU_user_idx indeed provides the indices for users in UAM
        recommended_user_idx = uU_user_idx[sort_index[-K:]]
        # Get user_ids corresponding to nearest neighbors
        recommended_user_ids = user_ids[recommended_user_idx]
        # Get similarity score for nearest neighbors
        recommended_user_scores = uU_data[sort_index[-K:]]

        print("Nearest K=" + str(K) + " neighbors' user-ids: ", recommended_user_ids.flatten())

        # Get all artists these similar users have listened to
        recommended_artists_idx = []
        for u_idx in recommended_user_idx:
            recommended_artists_idx.extend(list(UAM.getrow(u_idx).indices))

        # Remove duplicates and sort
        recommended_artists_idx = sorted(set(recommended_artists_idx))

        # Remove artists already known to seed user
        recommended_artists_idx = np.setdiff1d(recommended_artists_idx, pc_vec.indices)

        # Narrow down to random 5 artist out of all artists that similar users listen to for illustration purpose
        random_indices = random.sample(range(len(recommended_artists_idx)), 5)
        random_elements = [recommended_artists_idx[i] for i in random_indices]

        print("Indices of " + str(len(random_elements)) + " recommended artists: ", random_elements)
        print("Recommended artist names:", [artist_ids[i] for i in random_elements])
        print('-' * 80)

    end_time = time.time()
    total_users = UAM.shape[0]
    avg_time = (end_time - start_time) / total_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids:  ['user_000168' 'user_000844' 'user_000862' 'user_000629' 'user_000074']
# Indices of 5 recommended artists:  [np.int32(29828), np.int32(12423), np.int32(2138), np.int32(1714), np.int32(10856)]
# Recommended artist names: [np.str_('Audio Lotion'), np.str_('Team Sleep'), np.str_('Emerson, Lake & Palmer'), np.str_('The Kooks'), np.str_('Racoon')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids:  ['user_000513' 'user_000726' 'user_000143' 'user_000238' 'user_000673']
# Indices of 5 recommended artists:  [np.int32(13470), np.int32(120605), np.int32(10615), np.int32(10578), np.int32(22845)]
# Recommended artist names: [np.str_('The Bouncing Souls'), np.str_('Peter, Bjorn & John Feat Victoria Bergsman'), np.str_('Ex Pistols'), np.str_('Desmond Dekker'), np.str_('Download')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids:  ['user_000392' 'user_000741' 'user_000400' 'user_000558' 'user_000813']
# Indices of 5 recommended artists:  [np.int32(3015), np.int32(59898), np.int32(115289), np.int32(8025), np.int32(62049)]
# Recommended artist names: [np.str_('Don Mclean'), np.str_('Tv Rock Feat. Rudy'), np.str_("Rollin' Gear"), np.str_('Bizarre Inc.'), np.str_('Tyga')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids:  ['user_000703' 'user_000998' 'user_000089' 'user_000779' 'user_000996']
# Indices of 5 recommended artists:  [np.int32(6005), np.int32(83), np.int32(17114), np.int32(13192), np.int32(136928)]
# Recommended artist names: [np.str_('Thomas Schumacher'), np.str_('Burial'), np.str_('Chuck Love'), np.str_('Buju Banton'), np.str_('Hemmann & Kaden')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids:  ['user_000627' 'user_000807' 'user_000560' 'user_000584' 'user_000307']
# Indices of 5 recommended artists:  [np.int32(82397), np.int32(5249), np.int32(3181), np.int32(14476), np.int32(49760)]
# Recommended artist names: [np.str_('Ab Ovo'), np.str_('Fatboy Slim'), np.str_('Heartsrevolution'), np.str_('The Books'), np.str_('Middle Class')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids:  ['user_000675' 'user_000415' 'user_000885' 'user_000766' 'user_000116']
# Indices of 5 recommended artists:  [np.int32(49851), np.int32(44119), np.int32(107029), np.int32(42763), np.int32(15122)]
# Recommended artist names: [np.str_('Black Devil'), np.str_('The Hope Conspiracy'), np.str_('Sonna'), np.str_('Deceptikon'), np.str_('Pelican')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids:  ['user_000437' 'user_000781' 'user_000402' 'user_000236' 'user_000765']
# Indices of 5 recommended artists:  [np.int32(100179), np.int32(100317), np.int32(2655), np.int32(72033), np.int32(1994)]
# Recommended artist names: [np.str_('Brian La Mantagne - Drivin Me Crazy'), np.str_('J-Bo (Of Youngbloodz) Feat. T-Pain'), np.str_('Étienne De Crécy'), np.str_('Symphony Of Evangelion'), np.str_('Benny Benassi')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids:  ['user_000123' 'user_000187' 'user_000737' 'user_000419' 'user_000864']
# Indices of 5 recommended artists:  [np.int32(428), np.int32(4472), np.int32(99260), np.int32(42958), np.int32(44840)]
# Recommended artist names: [np.str_('Pendulum'), np.str_('Martin Solveig'), np.str_('Pharrell & The Yessirs'), np.str_('Jumbonics'), np.str_('Sun Tzu')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids:  ['user_000833' 'user_000115' 'user_000473' 'user_000758' 'user_000357']
# Indices of 5 recommended artists:  [np.int32(88297), np.int32(11518), np.int32(47142), np.int32(15994), np.int32(749)]
# Recommended artist names: [np.str_('John R. Shannon'), np.str_('Eddie Vedder'), np.str_('Fletcher Henderson'), np.str_('Pf Project'), np.str_('At The Drive-In')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids:  ['user_000813' 'user_000379' 'user_000329' 'user_000981' 'user_000208']
# Indices of 5 recommended artists:  [np.int32(57727), np.int32(4400), np.int32(84326), np.int32(25348), np.int32(84274)]
# Recommended artist names: [np.str_('Sun Control Species'), np.str_('Kelly Rowland'), np.str_('Dr.Kucho'), np.str_('Coco Steel & Lovebomb'), np.str_('Bis Social')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids:  ['user_000953' 'user_000715' 'user_000291' 'user_000417' 'user_000705']
# Indices of 5 recommended artists:  [np.int32(10977), np.int32(9716), np.int32(16151), np.int32(3015), np.int32(3508)]
# Recommended artist names: [np.str_('The Contours'), np.str_('Thelonious Monk'), np.str_('T2'), np.str_('Don Mclean'), np.str_('Nouvelle Vague')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids:  ['user_000203' 'user_000564' 'user_000703' 'user_000698' 'user_000689']
# Indices of 5 recommended artists:  [np.int32(48121), np.int32(790), np.int32(2444), np.int32(881), np.int32(3513)]
# Recommended artist names: [np.str_('My Life Story'), np.str_('Bert Jansch'), np.str_('Punks Jump Up'), np.str_('Colin Hay'), np.str_('Ocean Colour Scene')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids:  ['user_000026' 'user_000927' 'user_000935' 'user_000932' 'user_000161']
# Indices of 5 recommended artists:  [np.int32(16536), np.int32(16580), np.int32(51465), np.int32(10330), np.int32(23070)]
# Recommended artist names: [np.str_('Solar Fields'), np.str_('喜多郎'), np.str_('Color Tango'), np.str_('Meat Beat Manifesto'), np.str_('Lichtenfels')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids:  ['user_000129' 'user_000443' 'user_000920' 'user_000257' 'user_000497']
# Indices of 5 recommended artists:  [np.int32(2167), np.int32(8719), np.int32(9345), np.int32(35580), np.int32(18483)]
# Recommended artist names: [np.str_('Flogging Molly'), np.str_('Jesse Mccartney'), np.str_('Santigold'), np.str_('Cadallaca'), np.str_('Hope Sandoval & The Warm Inventions')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids:  ['user_000503' 'user_000515' 'user_000634' 'user_000532' 'user_000927']
# Indices of 5 recommended artists:  [np.int32(5799), np.int32(97839), np.int32(64289), np.int32(18913), np.int32(110272)]
# Recommended artist names: [np.str_('Ricochet'), np.str_('The Detroit Escalator Co.'), np.str_('Makunouchi Bento'), np.str_('Midival Punditz'), np.str_('Yunx')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids:  ['user_000328' 'user_000048' 'user_000897' 'user_000293' 'user_000791']
# Indices of 5 recommended artists:  [np.int32(30667), np.int32(14842), np.int32(1175), np.int32(14600), np.int32(36646)]
# Recommended artist names: [np.str_('Patrick Watson'), np.str_('Abandoned Pools'), np.str_('Johnathan Rice'), np.str_('The Mendoza Line'), np.str_('Ours')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids:  ['user_000705' 'user_000075' 'user_000937' 'user_000731' 'user_000905']
# Indices of 5 recommended artists:  [np.int32(5600), np.int32(38357), np.int32(34798), np.int32(63729), np.int32(19879)]
# Recommended artist names: [np.str_('Ministry Of Sound'), np.str_('Mick Jagger'), np.str_('Black Kali Ma'), np.str_('Currituck Co.'), np.str_('Novembers Doom')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids:  ['user_000123' 'user_000486' 'user_000998' 'user_000093' 'user_000996']
# Indices of 5 recommended artists:  [np.int32(10584), np.int32(9661), np.int32(25720), np.int32(1116), np.int32(889)]
# Recommended artist names: [np.str_('Dizzee Rascal'), np.str_('The Olivia Tremor Control'), np.str_('Gallows'), np.str_('Ingrid Michaelson'), np.str_('Counting Crows')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids:  ['user_000020' 'user_000565' 'user_000554' 'user_000139' 'user_000440']
# Indices of 5 recommended artists:  [np.int32(19442), np.int32(3217), np.int32(11745), np.int32(1709), np.int32(48144)]
# Recommended artist names: [np.str_('The Cassandra Complex'), np.str_('Indigo Girls'), np.str_('Jam & Spoon'), np.str_('The John Butler Trio'), np.str_('Thc!!')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids:  ['user_000658' 'user_000139' 'user_000327' 'user_000683' 'user_000624']
# Indices of 5 recommended artists:  [np.int32(12044), np.int32(1311), np.int32(30497), np.int32(1151), np.int32(1652)]
# Recommended artist names: [np.str_('Michael Masley'), np.str_('Michael Cera & Ellen Page'), np.str_('Sten & Stanley'), np.str_('Jessica Simpson'), np.str_('The Charlatans')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids:  ['user_000681' 'user_000691' 'user_000673' 'user_000617' 'user_000882']
# Indices of 5 recommended artists:  [np.int32(122932), np.int32(64786), np.int32(78621), np.int32(9265), np.int32(94148)]
# Recommended artist names: [np.str_('Larry & The Blue Notes'), np.str_("The Cryan' Shames"), np.str_('Dianogah'), np.str_('Quincy Jones'), np.str_('Cincinnati Jug Band')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids:  ['user_000858' 'user_000249' 'user_000534' 'user_000564' 'user_000690']
# Indices of 5 recommended artists:  [np.int32(17549), np.int32(10168), np.int32(132926), np.int32(17170), np.int32(133010)]
# Recommended artist names: [np.str_('The Fatima Mansions'), np.str_('Unsane'), np.str_('Debbie Allen, Erica Gimpel'), np.str_('Djavan'), np.str_('Locus')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids:  ['user_000866' 'user_000503' 'user_000927' 'user_000515' 'user_000634']
# Indices of 5 recommended artists:  [np.int32(34138), np.int32(2670), np.int32(3954), np.int32(15416), np.int32(27940)]
# Recommended artist names: [np.str_('Bluetech'), np.str_('A Flock Of Seagulls'), np.str_('Within Temptation'), np.str_('Belinda Carlisle'), np.str_('Tumor')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids:  ['user_000371' 'user_000998' 'user_000493' 'user_000031' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(18189), np.int32(53760), np.int32(2623), np.int32(1224), np.int32(14665)]
# Recommended artist names: [np.str_('Dj Amable'), np.str_('On!Air!Library!'), np.str_('Urge Overkill'), np.str_('Kent'), np.str_('The Shermans')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids:  ['user_000476' 'user_000096' 'user_000151' 'user_000118' 'user_000653']
# Indices of 5 recommended artists:  [np.int32(33485), np.int32(85397), np.int32(126166), np.int32(37766), np.int32(38415)]
# Recommended artist names: [np.str_('Cazuza'), np.str_('Sister'), np.str_('Fabulous Boogie Kings'), np.str_('Eliane Elias'), np.str_('Tommy James')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids:  ['user_000565' 'user_000839' 'user_000188' 'user_000833' 'user_000161']
# Indices of 5 recommended artists:  [np.int32(6737), np.int32(1146), np.int32(5006), np.int32(156301), np.int32(12506)]
# Recommended artist names: [np.str_('Jay-Z And Linkin Park'), np.str_('Jem'), np.str_('Beastie Boys'), np.str_('Saves The Day/Moneen'), np.str_('The Shadows')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids:  ['user_000651' 'user_000205' 'user_000124' 'user_000233' 'user_000714']
# Indices of 5 recommended artists:  [np.int32(71060), np.int32(125610), np.int32(70124), np.int32(1756), np.int32(69518)]
# Recommended artist names: [np.str_('Ray Roc Checo'), np.str_('Darude Feat. Tammy Marie'), np.str_('Ernest Kohl'), np.str_('The Prodigy'), np.str_('Alawan')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids:  ['user_000485' 'user_000373' 'user_000756' 'user_000069' 'user_000661']
# Indices of 5 recommended artists:  [np.int32(2548), np.int32(8362), np.int32(78449), np.int32(4176), np.int32(145248)]
# Recommended artist names: [np.str_('The Deadly Snakes'), np.str_('Dj Sneak'), np.str_('One Track Mind'), np.str_('D12'), np.str_('T.D.')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids:  ['user_000345' 'user_000826' 'user_000513' 'user_000703' 'user_000024']
# Indices of 5 recommended artists:  [np.int32(3246), np.int32(31479), np.int32(9000), np.int32(19222), np.int32(39841)]
# Recommended artist names: [np.str_('Jay-Jay Johanson'), np.str_('Kid Dakota'), np.str_('Mc5'), np.str_('Rodrigo Leão'), np.str_('Kenickie')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids:  ['user_000858' 'user_000753' 'user_000703' 'user_000031' 'user_000564']
# Indices of 5 recommended artists:  [np.int32(89650), np.int32(8760), np.int32(25115), np.int32(19816), np.int32(28881)]
# Recommended artist names: [np.str_('Catalpa Catalpa'), np.str_('Jorge Ben'), np.str_('Arnold Schönberg'), np.str_('長嶌寛幸'), np.str_('Decibully')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids:  ['user_000242' 'user_000159' 'user_000164' 'user_000513' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(34687), np.int32(3891), np.int32(86240), np.int32(41486), np.int32(12139)]
# Recommended artist names: [np.str_('The Plot To Blow Up The Eiffel Tower'), np.str_('Toktok'), np.str_('Gofer'), np.str_('Alicia De Larrocha'), np.str_('Overkill')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids:  ['user_000206' 'user_000115' 'user_000442' 'user_000727' 'user_000692']
# Indices of 5 recommended artists:  [np.int32(140108), np.int32(38274), np.int32(7841), np.int32(134317), np.int32(2076)]
# Recommended artist names: [np.str_('Saviour Machine'), np.str_('Axenstar'), np.str_('Von Hertzen Brothers'), np.str_('Siobhan Donaghy - [Emg]'), np.str_('Das Ich')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids:  ['user_000991' 'user_000999' 'user_000588' 'user_000188' 'user_000758']
# Indices of 5 recommended artists:  [np.int32(6918), np.int32(104399), np.int32(2363), np.int32(32966), np.int32(1426)]
# Recommended artist names: [np.str_('Godhead'), np.str_('新興宗教楽団Nogod'), np.str_('Metro Station'), np.str_('Lemon Demon'), np.str_('Pinback')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids:  ['user_000280' 'user_000086' 'user_000031' 'user_000164' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(36423), np.int32(77341), np.int32(17356), np.int32(18110), np.int32(18458)]
# Recommended artist names: [np.str_('Projekct X'), np.str_('Casa1'), np.str_('Maria Callas'), np.str_('Cornell Campbell'), np.str_('Henri Salvador')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids:  ['user_000415' 'user_000023' 'user_000483' 'user_000664' 'user_000720']
# Indices of 5 recommended artists:  [np.int32(7246), np.int32(79527), np.int32(478), np.int32(43746), np.int32(16714)]
# Recommended artist names: [np.str_('Fannypack'), np.str_('Boy Vs. Bacteria'), np.str_('Roni Size & Reprazent'), np.str_('Shade Empire'), np.str_('Black Rob')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids:  ['user_000086' 'user_000770' 'user_000495' 'user_000992' 'user_000499']
# Indices of 5 recommended artists:  [np.int32(6940), np.int32(3615), np.int32(1157), np.int32(7700), np.int32(1467)]
# Recommended artist names: [np.str_('Jack Off Jill'), np.str_('Riverside'), np.str_('Jimi Hendrix'), np.str_('Neil Young & Crazy Horse'), np.str_('Richard Cheese')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids:  ['user_000062' 'user_000304' 'user_000294' 'user_000862' 'user_000577']
# Indices of 5 recommended artists:  [np.int32(2008), np.int32(1512), np.int32(25289), np.int32(61898), np.int32(922)]
# Recommended artist names: [np.str_('Bob Marley & The Wailers'), np.str_('Saves The Day'), np.str_('Cass Elliot'), np.str_('Shaimus'), np.str_('Deerhoof')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids:  ['user_000056' 'user_000780' 'user_000015' 'user_000612' 'user_000588']
# Indices of 5 recommended artists:  [np.int32(1049), np.int32(148808), np.int32(1013), np.int32(1921), np.int32(54278)]
# Recommended artist names: [np.str_('Frou Frou'), np.str_('Ghost Away'), np.str_('Extreme'), np.str_('4 Strings'), np.str_('Alex Xxxchange')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids:  ['user_000603' 'user_000551' 'user_000985' 'user_000849' 'user_000814']
# Indices of 5 recommended artists:  [np.int32(1755), np.int32(41948), np.int32(68775), np.int32(89632), np.int32(14800)]
# Recommended artist names: [np.str_('The Proclaimers'), np.str_('Subseven'), np.str_('Silent Film'), np.str_('Melody Fall'), np.str_('Enemy')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids:  ['user_000624' 'user_000658' 'user_000093' 'user_000327' 'user_000020']
# Indices of 5 recommended artists:  [np.int32(13125), np.int32(3324), np.int32(3581), np.int32(13096), np.int32(37264)]
# Recommended artist names: [np.str_('X'), np.str_('Laura Marling'), np.str_('Pulp'), np.str_('Spacemen 3'), np.str_('Air & Beth Hirsch')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids:  ['user_000615' 'user_000831' 'user_000444' 'user_000134' 'user_000132']
# Indices of 5 recommended artists:  [np.int32(46386), np.int32(46083), np.int32(31093), np.int32(8355), np.int32(21889)]
# Recommended artist names: [np.str_('Trond Erics'), np.str_('Futurama'), np.str_('Dennis Mccarthy'), np.str_('Dj Orange'), np.str_('Ataraxia')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids:  ['user_000256' 'user_000383' 'user_000103' 'user_000806' 'user_000117']
# Indices of 5 recommended artists:  [np.int32(44172), np.int32(10135), np.int32(651), np.int32(16218), np.int32(153556)]
# Recommended artist names: [np.str_('Avrocar'), np.str_('The Birthday Party'), np.str_('竹村延和'), np.str_('The Tangent'), np.str_('Mr. Fantastik')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000143' 'user_000513' 'user_000345' 'user_000031']
# Indices of 5 recommended artists:  [np.int32(18684), np.int32(18896), np.int32(17989), np.int32(57617), np.int32(1508)]
# Recommended artist names: [np.str_('Klint'), np.str_('Mental As Anything'), np.str_('Bukka White'), np.str_('Luca Mundaca'), np.str_('Santana')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids:  ['user_000473' 'user_000527' 'user_000442' 'user_000435' 'user_000115']
# Indices of 5 recommended artists:  [np.int32(4507), np.int32(37622), np.int32(57455), np.int32(43719), np.int32(44324)]
# Recommended artist names: [np.str_('Modern Talking'), np.str_('Beth Fowler'), np.str_('Ricardo Arjona'), np.str_('Feiled -Rehearsal'), np.str_('Carole King & Louise Goffin')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids:  ['user_000346' 'user_000457' 'user_000289' 'user_000527' 'user_000442']
# Indices of 5 recommended artists:  [np.int32(12205), np.int32(18749), np.int32(30499), np.int32(78489), np.int32(57490)]
# Recommended artist names: [np.str_('Primal Fear'), np.str_('Les Ogres De Barback'), np.str_('Steps'), np.str_('Joey Boy'), np.str_('Barão Vermelho')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids:  ['user_000013' 'user_000537' 'user_000783' 'user_000912' 'user_000354']
# Indices of 5 recommended artists:  [np.int32(43760), np.int32(129540), np.int32(3817), np.int32(83644), np.int32(2734)]
# Recommended artist names: [np.str_('Witchery'), np.str_('Asteroid'), np.str_('The Legendary Pink Dots'), np.str_('Meathook Seed'), np.str_('Annuals')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids:  ['user_000354' 'user_000761' 'user_000260' 'user_000973' 'user_000378']
# Indices of 5 recommended artists:  [np.int32(18776), np.int32(123928), np.int32(29080), np.int32(74451), np.int32(24275)]
# Recommended artist names: [np.str_('Lloyd Charmers'), np.str_('Indecision'), np.str_('Lee Rocker'), np.str_('Sheperds, In Field Abiding'), np.str_('Joe Pass')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids:  ['user_000847' 'user_000328' 'user_000631' 'user_000791' 'user_000769']
# Indices of 5 recommended artists:  [np.int32(3002), np.int32(25565), np.int32(13912), np.int32(8200), np.int32(79231)]
# Recommended artist names: [np.str_('Devotchka'), np.str_('Duane Eddy'), np.str_('Echobelly'), np.str_('Colin James'), np.str_('George And Antony')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids:  ['user_000256' 'user_000668' 'user_000387' 'user_000420' 'user_000126']
# Indices of 5 recommended artists:  [np.int32(7031), np.int32(2574), np.int32(2133), np.int32(2660), np.int32(92447)]
# Recommended artist names: [np.str_('Prince & The Revolution'), np.str_('The Rapture'), np.str_('Eiffel 65'), np.str_('!!!'), np.str_('Vernon Elliot')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids:  ['user_000467' 'user_000511' 'user_000620' 'user_000336' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(11928), np.int32(8109), np.int32(8798), np.int32(86351), np.int32(86507)]
# Recommended artist names: [np.str_('Liquid Tension Experiment'), np.str_('Buena Vista Social Club'), np.str_('Ketch Harbour Wolves'), np.str_('Naked Rhythm'), np.str_('Vitro')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids:  ['user_000478' 'user_000803' 'user_000977' 'user_000089' 'user_000215']
# Indices of 5 recommended artists:  [np.int32(1225), np.int32(2526), np.int32(53144), np.int32(21818), np.int32(21779)]
# Recommended artist names: [np.str_('Kettcar'), np.str_('Surkin'), np.str_('586'), np.str_('Taylor Swift'), np.str_('Perla Batalla')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids:  ['user_000247' 'user_000173' 'user_000115' 'user_000182' 'user_000113']
# Indices of 5 recommended artists:  [np.int32(10311), np.int32(1348), np.int32(37083), np.int32(15335), np.int32(12782)]
# Recommended artist names: [np.str_('Jonas Brothers'), np.str_('Neil Young'), np.str_('Hugh Jackman'), np.str_('Alannah Myles'), np.str_('Dick Dale')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids:  ['user_000773' 'user_000606' 'user_000756' 'user_000241' 'user_000373']
# Indices of 5 recommended artists:  [np.int32(2727), np.int32(9692), np.int32(72575), np.int32(145142), np.int32(11127)]
# Recommended artist names: [np.str_('Angra'), np.str_('The Telescopes'), np.str_('Powerhouse'), np.str_('Ghetto Mafia'), np.str_('White Rabbits')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids:  ['user_000570' 'user_000835' 'user_000142' 'user_000776' 'user_000912']
# Indices of 5 recommended artists:  [np.int32(116837), np.int32(2412), np.int32(21898), np.int32(164818), np.int32(45326)]
# Recommended artist names: [np.str_('Trem Da Alegria'), np.str_('Outkast'), np.str_('Cannibal Corpse'), np.str_('Nin And The Beatles'), np.str_("Tucker B'S")]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids:  ['user_000763' 'user_000591' 'user_000577' 'user_000579' 'user_000894']
# Indices of 5 recommended artists:  [np.int32(6863), np.int32(18867), np.int32(40304), np.int32(28407), np.int32(28595)]
# Recommended artist names: [np.str_('Default'), np.str_('Mark Kozelek'), np.str_('Arcturus'), np.str_('Karmacoda'), np.str_('Strifeii')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids:  ['user_000043' 'user_000132' 'user_000134' 'user_000700' 'user_000041']
# Indices of 5 recommended artists:  [np.int32(23366), np.int32(3106), np.int32(93030), np.int32(34983), np.int32(23710)]
# Recommended artist names: [np.str_('Starecase'), np.str_('French Kicks'), np.str_('Arts Of Erebus'), np.str_('Aube'), np.str_('Rohff')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids:  ['user_000557' 'user_000742' 'user_000551' 'user_000650' 'user_000902']
# Indices of 5 recommended artists:  [np.int32(12937), np.int32(7080), np.int32(4), np.int32(11015), np.int32(41079)]
# Recommended artist names: [np.str_('Uk Subs'), np.str_('The Blood Brothers'), np.str_('4Hero'), np.str_('The Knack'), np.str_('Bedlight For Blueeyes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids:  ['user_000070' 'user_000598' 'user_000463' 'user_000828' 'user_000770']
# Indices of 5 recommended artists:  [np.int32(3368), np.int32(1258), np.int32(3654), np.int32(1168), np.int32(14706)]
# Recommended artist names: [np.str_('Lupen Crook'), np.str_('Little Barrie'), np.str_('Scout Niblett'), np.str_('John Lennon'), np.str_('The Wonder Stuff')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids:  ['user_000024' 'user_000837' 'user_000763' 'user_000584' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(14882), np.int32(11027), np.int32(19617), np.int32(157929), np.int32(3108)]
# Recommended artist names: [np.str_('Boredoms'), np.str_('The Makers'), np.str_('Tied & Tickled Trio'), np.str_('Tufts Amalgamates'), np.str_('Fuck Buttons')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids:  ['user_000633' 'user_000448' 'user_000031' 'user_000170' 'user_000582']
# Indices of 5 recommended artists:  [np.int32(2570), np.int32(3059), np.int32(11102), np.int32(18870), np.int32(19476)]
# Recommended artist names: [np.str_('The Moody Blues'), np.str_('Espers'), np.str_('U2 And Green Day'), np.str_('Mart'), np.str_('The Family')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids:  ['user_000479' 'user_000579' 'user_000959' 'user_000233' 'user_000765']
# Indices of 5 recommended artists:  [np.int32(44605), np.int32(69513), np.int32(18723), np.int32(18383), np.int32(4356)]
# Recommended artist names: [np.str_('Lesley Roy'), np.str_('Akasa'), np.str_('Laurie Anderson'), np.str_('Gibson Brothers'), np.str_('Inner City')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids:  ['user_000159' 'user_000345' 'user_000031' 'user_000304' 'user_000170']
# Indices of 5 recommended artists:  [np.int32(1258), np.int32(19779), np.int32(18076), np.int32(17920), np.int32(13262)]
# Recommended artist names: [np.str_('Little Barrie'), np.str_('Александр Тихонович Гречанинов'), np.str_('Clancy Eccles'), np.str_('Bill Perkins'), np.str_('Good Riddance')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids:  ['user_000188' 'user_000705' 'user_000338' 'user_000305' 'user_000431']
# Indices of 5 recommended artists:  [np.int32(11729), np.int32(3337), np.int32(50809), np.int32(99424), np.int32(11481)]
# Recommended artist names: [np.str_('Inkubus Sukkubus'), np.str_('Lhasa'), np.str_('Tunturia'), np.str_('Brian Laruso'), np.str_('Dolly Parton')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids:  ['user_000853' 'user_000832' 'user_000970' 'user_000360' 'user_000495']
# Indices of 5 recommended artists:  [np.int32(956), np.int32(171956), np.int32(41591), np.int32(1343), np.int32(1080)]
# Recommended artist names: [np.str_('Dirty Pretty Things'), np.str_('Mutagene'), np.str_('Dc Talk'), np.str_('Natasha Bedingfield'), np.str_('Guillemots')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids:  ['user_000803' 'user_000603' 'user_000960' 'user_000403' 'user_000467']
# Indices of 5 recommended artists:  [np.int32(61828), np.int32(2691), np.int32(3078), np.int32(16365), np.int32(13998)]
# Recommended artist names: [np.str_('On Wave'), np.str_('Akira Yamaoka'), np.str_('Faithless'), np.str_('Bettie Serveert'), np.str_('Handsome Furs')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids:  ['user_000396' 'user_000392' 'user_000586' 'user_000418' 'user_000609']
# Indices of 5 recommended artists:  [np.int32(120924), np.int32(914), np.int32(40483), np.int32(170), np.int32(29154)]
# Recommended artist names: [np.str_('Bob Carlisle'), np.str_('David Gray'), np.str_('Go Go Girls'), np.str_('Ennio Morricone'), np.str_('Mêlée')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids:  ['user_000020' 'user_000122' 'user_000624' 'user_000760' 'user_000658']
# Indices of 5 recommended artists:  [np.int32(86990), np.int32(2351), np.int32(3672), np.int32(4631), np.int32(12999)]
# Recommended artist names: [np.str_('Mysterio'), np.str_('Maroon'), np.str_('Shitdisco'), np.str_('Rednex'), np.str_('David Sandström')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids:  ['user_000753' 'user_000898' 'user_000343' 'user_000735' 'user_000159']
# Indices of 5 recommended artists:  [np.int32(164152), np.int32(164013), np.int32(135032), np.int32(136718), np.int32(17445)]
# Recommended artist names: [np.str_('Very Proper Dragonflies'), np.str_('Pink & William Orbit'), np.str_('Ytcracker'), np.str_('The Putrid Flowers'), np.str_('Pulse')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids:  ['user_000707' 'user_000756' 'user_000273' 'user_000661' 'user_000028']
# Indices of 5 recommended artists:  [np.int32(77230), np.int32(16750), np.int32(479), np.int32(6870), np.int32(26217)]
# Recommended artist names: [np.str_('Demon'), np.str_('Curren$Y'), np.str_('Roots Manuva'), np.str_('Dimmu Borgir'), np.str_('Mc Serch')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids:  ['user_000600' 'user_000598' 'user_000770' 'user_000463' 'user_000828']
# Indices of 5 recommended artists:  [np.int32(11306), np.int32(32301), np.int32(2872), np.int32(155969), np.int32(102)]
# Recommended artist names: [np.str_('Blues Explosion'), np.str_("The People'S Revolutionary Choir"), np.str_('Cansei De Ser Sexy'), np.str_('Coast Ghost'), np.str_('City')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000512' 'user_000513' 'user_000448' 'user_000209']
# Indices of 5 recommended artists:  [np.int32(807), np.int32(41322), np.int32(9165), np.int32(9822), np.int32(10146)]
# Recommended artist names: [np.str_('Blues Traveler'), np.str_('Paperboy'), np.str_('Orange Juice'), np.str_('Ween'), np.str_('The Hold Steady')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids:  ['user_000520' 'user_000018' 'user_000837' 'user_000668' 'user_000367']
# Indices of 5 recommended artists:  [np.int32(38334), np.int32(69), np.int32(6352), np.int32(37143), np.int32(53948)]
# Recommended artist names: [np.str_('John Lennon & Yoko Ono'), np.str_('Boards Of Canada'), np.str_('Chaka Khan'), np.str_('N.A.S.A.'), np.str_('John Potter')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids:  ['user_000515' 'user_000935' 'user_000503' 'user_000634' 'user_000927']
# Indices of 5 recommended artists:  [np.int32(110114), np.int32(166669), np.int32(110255), np.int32(50478), np.int32(110125)]
# Recommended artist names: [np.str_('Lollop'), np.str_('Uusi Aaltoääni'), np.str_('Unit Four Plsu Two'), np.str_('The Jealous Sound'), np.str_('Martin Roth')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids:  ['user_000844' 'user_000577' 'user_000807' 'user_000079' 'user_000838']
# Indices of 5 recommended artists:  [np.int32(71242), np.int32(6363), np.int32(157976), np.int32(18507), np.int32(31932)]
# Recommended artist names: [np.str_('Sirens'), np.str_('Ciara'), np.str_('10 Teo Torriatte(Let Us Cling'), np.str_('Ike & Tina Turner'), np.str_('Robinella')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids:  ['user_000905' 'user_000083' 'user_000017' 'user_000859' 'user_000937']
# Indices of 5 recommended artists:  [np.int32(17933), np.int32(12638), np.int32(11370), np.int32(12260), np.int32(2699)]
# Recommended artist names: [np.str_('Black Uhuru'), np.str_('Woody Guthrie'), np.str_('Celtic Woman'), np.str_('Ronan Hardiman'), np.str_('All Girl Summer Fun Band')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids:  ['user_000210' 'user_000086' 'user_000091' 'user_000792' 'user_000168']
# Indices of 5 recommended artists:  [np.int32(1647), np.int32(64034), np.int32(119624), np.int32(2165), np.int32(12490)]
# Recommended artist names: [np.str_('The Breeders'), np.str_('Ian Boddy'), np.str_('Morte Macabre'), np.str_('Fleetwood Mac'), np.str_('The Pentangle')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids:  ['user_000606' 'user_000807' 'user_000584' 'user_000135' 'user_000763']
# Indices of 5 recommended artists:  [np.int32(47251), np.int32(7047), np.int32(57581), np.int32(35362), np.int32(47711)]
# Recommended artist names: [np.str_('Jablkoň'), np.str_('Seabound'), np.str_('Ian Carey'), np.str_('Estron'), np.str_('This Is Kevin')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids:  ['user_000763' 'user_000606' 'user_000560' 'user_000807' 'user_000584']
# Indices of 5 recommended artists:  [np.int32(74), np.int32(14019), np.int32(860), np.int32(15864), np.int32(13410)]
# Recommended artist names: [np.str_('Bobby Womack'), np.str_('Honeybus'), np.str_('Chet Baker'), np.str_('Manfred Mann'), np.str_('Sam Roberts')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids:  ['user_000862' 'user_000074' 'user_000801' 'user_000522' 'user_000838']
# Indices of 5 recommended artists:  [np.int32(277), np.int32(2700), np.int32(1580), np.int32(110746), np.int32(14913)]
# Recommended artist names: [np.str_('Jimmy Edgar'), np.str_('Alphawezen'), np.str_('Stereophonics'), np.str_('Marte Heggelund'), np.str_('Dana Fuchs')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids:  ['user_000031' 'user_000242' 'user_000273' 'user_000870' 'user_000315']
# Indices of 5 recommended artists:  [np.int32(46806), np.int32(18033), np.int32(18282), np.int32(17828), np.int32(15203)]
# Recommended artist names: [np.str_('Nina Persson'), np.str_('Charles Dodge'), np.str_('Extrabreit'), np.str_('Arranco De Varsóvia'), np.str_('The Brothers Johnson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids:  ['user_000569' 'user_000983' 'user_000960' 'user_000511' 'user_000795']
# Indices of 5 recommended artists:  [np.int32(37301), np.int32(3180), np.int32(3051), np.int32(116413), np.int32(1797)]
# Recommended artist names: [np.str_('Woods'), np.str_('Health'), np.str_('Emilíana Torrini'), np.str_('Dag'), np.str_('The Velvet Underground')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids:  ['user_000993' 'user_000617' 'user_000838' 'user_000376' 'user_000577']
# Indices of 5 recommended artists:  [np.int32(37762), np.int32(8950), np.int32(9968), np.int32(52714), np.int32(19831)]
# Recommended artist names: [np.str_('Elaine Paige'), np.str_('Luxxury'), np.str_('Foetus'), np.str_('Andrew Parrott'), np.str_('Briskey')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids:  ['user_000075' 'user_000108' 'user_000905' 'user_000937' 'user_000859']
# Indices of 5 recommended artists:  [np.int32(10517), np.int32(7662), np.int32(41585), np.int32(6580), np.int32(41656)]
# Recommended artist names: [np.str_('Black Label Society'), np.str_('Luniz'), np.str_('Dan Finnerty'), np.str_('Peter White'), np.str_('Exit')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids:  ['user_000342' 'user_000894' 'user_000610' 'user_000771' 'user_000155']
# Indices of 5 recommended artists:  [np.int32(50526), np.int32(90064), np.int32(1456), np.int32(24442), np.int32(1045)]
# Recommended artist names: [np.str_('Curtis Lee'), np.str_('Gabriella & Troy'), np.str_('Razorlight'), np.str_('Bono'), np.str_('Fred Astaire')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids:  ['user_000676' 'user_000110' 'user_000686' 'user_000579' 'user_000346']
# Indices of 5 recommended artists:  [np.int32(15864), np.int32(9042), np.int32(3866), np.int32(11129), np.int32(36191)]
# Recommended artist names: [np.str_('Manfred Mann'), np.str_('Mint Royale'), np.str_('The Veronicas'), np.str_('Wild Cherry'), np.str_('Sin Bandera')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids:  ['user_000703' 'user_000415' 'user_000345' 'user_000031' 'user_000034']
# Indices of 5 recommended artists:  [np.int32(11692), np.int32(17020), np.int32(1475), np.int32(802), np.int32(1581)]
# Recommended artist names: [np.str_('Hawkwind'), np.str_('1 Giant Leap'), np.str_('Rise Against'), np.str_('Bing Crosby'), np.str_('Steve Miller Band')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids:  ['user_000173' 'user_000776' 'user_000426' 'user_000650' 'user_000607']
# Indices of 5 recommended artists:  [np.int32(96814), np.int32(10472), np.int32(54181), np.int32(4796), np.int32(125476)]
# Recommended artist names: [np.str_('Juz And Matt'), np.str_('Alex Party'), np.str_('Symphorce'), np.str_('Timo Maas'), np.str_('Shaun Baker & Marc Van Linden')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids:  ['user_000897' 'user_000626' 'user_000706' 'user_000204' 'user_000577']
# Indices of 5 recommended artists:  [np.int32(59525), np.int32(12749), np.int32(123416), np.int32(11910), np.int32(707)]
# Recommended artist names: [np.str_('Andy Moor'), np.str_('Blindside'), np.str_('Bpt Feat Dm Binxter'), np.str_('Lee "Scratch" Perry'), np.str_('Amiina')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids:  ['user_000403' 'user_000467' 'user_000131' 'user_000031' 'user_000345']
# Indices of 5 recommended artists:  [np.int32(86198), np.int32(9265), np.int32(17662), np.int32(7934), np.int32(8152)]
# Recommended artist names: [np.str_('Dj Core'), np.str_('Quincy Jones'), np.str_('Isan'), np.str_('Apes And Androids'), np.str_('Charles Mingus')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids:  ['user_000238' 'user_000361' 'user_000333' 'user_000385' 'user_000993']
# Indices of 5 recommended artists:  [np.int32(14821), np.int32(1229), np.int32(6792), np.int32(11571), np.int32(5964)]
# Recommended artist names: [np.str_('Neu!'), np.str_('Kings Of Convenience'), np.str_('Absurd Minds'), np.str_('Fairport Convention'), np.str_('Terre Thaemlitz')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids:  ['user_000703' 'user_000074' 'user_000792' 'user_000807' 'user_000675']
# Indices of 5 recommended artists:  [np.int32(69975), np.int32(26612), np.int32(32383), np.int32(161), np.int32(3167)]
# Recommended artist names: [np.str_('Deuce'), np.str_('Rolfe Kent'), np.str_('The Voom Blooms'), np.str_('Earth, Wind & Fire'), np.str_('Hadouken!')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids:  ['user_000294' 'user_000687' 'user_000284' 'user_000860' 'user_000326']
# Indices of 5 recommended artists:  [np.int32(12065), np.int32(2608), np.int32(78353), np.int32(2175), np.int32(941)]
# Recommended artist names: [np.str_('Monster Magnet'), np.str_('Traffic'), np.str_('Wc And The Maad Circle'), np.str_('Frankie Knuckles'), np.str_('Die Fantastischen Vier')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids:  ['user_000996' 'user_000018' 'user_000891' 'user_000658' 'user_000327']
# Indices of 5 recommended artists:  [np.int32(11029), np.int32(1778), np.int32(1901), np.int32(105501), np.int32(3699)]
# Recommended artist names: [np.str_('The Milestone Corporation'), np.str_('The Sonics'), np.str_('Yo La Tengo'), np.str_('Universal Hall Pass'), np.str_('Sparklehorse')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000179' 'user_000484' 'user_000927' 'user_000431']
# Indices of 5 recommended artists:  [np.int32(12686), np.int32(107321), np.int32(99372), np.int32(24676), np.int32(2903)]
# Recommended artist names: [np.str_('浜崎あゆみ'), np.str_('Dfrnt'), np.str_('! Www.Polskie-Mp3.Tk ! Sweet N'), np.str_('Immortal'), np.str_('Cher')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids:  ['user_000482' 'user_000596' 'user_000705' 'user_000096' 'user_000653']
# Indices of 5 recommended artists:  [np.int32(6363), np.int32(1866), np.int32(2008), np.int32(3849), np.int32(23632)]
# Recommended artist names: [np.str_('Ciara'), np.str_('Vonda Shepard'), np.str_('Bob Marley & The Wailers'), np.str_('The Spinto Band'), np.str_('Gentleman')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids:  ['user_000493' 'user_000829' 'user_000110' 'user_000596' 'user_000653']
# Indices of 5 recommended artists:  [np.int32(42347), np.int32(20391), np.int32(1676), np.int32(141), np.int32(820)]
# Recommended artist names: [np.str_('Kite'), np.str_('久石譲'), np.str_('The Dresden Dolls'), np.str_('Digitalism'), np.str_('Boy Division')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids:  ['user_000970' 'user_000989' 'user_000753' 'user_000294' 'user_000709']
# Indices of 5 recommended artists:  [np.int32(164066), np.int32(137778), np.int32(30709), np.int32(137686), np.int32(80279)]
# Recommended artist names: [np.str_('Secret Cinema'), np.str_('Ginny Simms'), np.str_('Ai'), np.str_('Da Bluez Preacher'), np.str_('Roch Voisine')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids:  ['user_000328' 'user_000476' 'user_000002' 'user_000631' 'user_000778']
# Indices of 5 recommended artists:  [np.int32(3858), np.int32(1340), np.int32(7257), np.int32(830), np.int32(1129)]
# Recommended artist names: [np.str_('The Ting Tings'), np.str_('Napoleon Xiv'), np.str_("Gigi D'Agostino"), np.str_('Broder Daniel'), np.str_('Jacques Brel')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# Nearest K=5 neighbors' user-ids:  ['user_000217' 'user_000360' 'user_000238' 'user_000543' 'user_000906']
# Indices of 5 recommended artists:  [np.int32(11993), np.int32(39073), np.int32(41880), np.int32(113009), np.int32(164600)]
# ...
# Recommended artist names: [np.str_('Bob Sinclar'), np.str_('Asha Bhosle'), np.str_('Kaiser Chiefs'), np.str_('Tom Jobim & Vinicius De Moraes'), np.str_('Troublemakers')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids:  ['user_000789' 'user_000784' 'user_000376' 'user_000562' 'user_000824']
# Indices of 5 recommended artists:  [np.int32(3565), np.int32(74968), np.int32(3203), np.int32(10747), np.int32(16305)]
# Recommended artist names: [np.str_('Pj Harvey'), np.str_('The Jaynetts'), np.str_('Iamx'), np.str_('Kubichek!'), np.str_('Whyte Seeds')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids:  ['user_000140' 'user_000485' 'user_000295' 'user_000427' 'user_000750']
# Indices of 5 recommended artists:  [np.int32(577), np.int32(6672), np.int32(867), np.int32(97625), np.int32(97636)]
# Recommended artist names: [np.str_('The Underwolves'), np.str_('Will Smith'), np.str_('Chuck Berry'), np.str_('Outkast - Andre 3K'), np.str_('Pashtun Orchestra')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids:  ['user_000761' 'user_000108' 'user_000691' 'user_000393' 'user_000731']
# Indices of 5 recommended artists:  [np.int32(23009), np.int32(133218), np.int32(45920), np.int32(38704), np.int32(47586)]
# Recommended artist names: [np.str_('Jones & Stephenson'), np.str_('Danbert Nobacon'), np.str_('Whirlwind Heat'), np.str_('Danny & The Juniors'), np.str_('Sammy Rollins')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids:  ['user_000630' 'user_000382' 'user_000491' 'user_000434' 'user_000575']
# Indices of 5 recommended artists:  [np.int32(91260), np.int32(17389), np.int32(13134), np.int32(10563), np.int32(123943)]
# Recommended artist names: [np.str_('Casket Architects'), np.str_('Monster Squad'), np.str_('3 Minute Warning'), np.str_('Comets On Fire'), np.str_('Krakdown')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids:  ['user_000893' 'user_000852' 'user_000382' 'user_000630' 'user_000259']
# Indices of 5 recommended artists:  [np.int32(776), np.int32(90061), np.int32(124007), np.int32(91316), np.int32(123870)]
# Recommended artist names: [np.str_('Bedouin Soundclash'), np.str_('Chris Tomlin'), np.str_('Shere Khan'), np.str_('Ericson'), np.str_('Celly Cel / Chill / Reese, Mac')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids:  ['user_000111' 'user_000054' 'user_000047' 'user_000276' 'user_000378']
# Indices of 5 recommended artists:  [np.int32(10629), np.int32(34956), np.int32(16449), np.int32(3928), np.int32(15936)]
# Recommended artist names: [np.str_('Free'), np.str_('Akira Rabelais'), np.str_('John Dowland'), np.str_('Veruca Salt'), np.str_('Nicole')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids:  ['user_000575' 'user_000120' 'user_000285' 'user_000729' 'user_000890']
# Indices of 5 recommended artists:  [np.int32(1943), np.int32(7682), np.int32(21733), np.int32(13048), np.int32(13137)]
# Recommended artist names: [np.str_('Alan Jackson'), np.str_('Mike Oldfield'), np.str_('Matt White'), np.str_('Little Witches'), np.str_('A Wilhelm Scream')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids:  ['user_000257' 'user_000224' 'user_000497' 'user_000789' 'user_000549']
# Indices of 5 recommended artists:  [np.int32(21772), np.int32(1380), np.int32(10404), np.int32(4115), np.int32(149681)]
# Recommended artist names: [np.str_('Olivia Ruiz'), np.str_('Ok Go'), np.str_('Sunblock'), np.str_('Boney M.'), np.str_('Girls Aloud Vs Madonna')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids:  ['user_000729' 'user_000330' 'user_000814' 'user_000145' 'user_000890']
# Indices of 5 recommended artists:  [np.int32(1084), np.int32(38575), np.int32(1119), np.int32(140669), np.int32(1426)]
# Recommended artist names: [np.str_('Hank Williams, Jr.'), np.str_('Bob Marley Vs Funkstar De Luxe Remix'), np.str_('Iron & Wine'), np.str_('Jimmy Duke'), np.str_('Pinback')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids:  ['user_000457' 'user_000093' 'user_000051' 'user_000478' 'user_000215']
# Indices of 5 recommended artists:  [np.int32(2351), np.int32(3046), np.int32(10712), np.int32(1462), np.int32(66207)]
# Recommended artist names: [np.str_('Maroon'), np.str_('Elysian Fields'), np.str_('Johnny Flynn'), np.str_('Remy Zero'), np.str_('Expatriate')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids:  ['user_000702' 'user_000901' 'user_000440' 'user_000381' 'user_000284']
# Indices of 5 recommended artists:  [np.int32(103089), np.int32(18669), np.int32(11748), np.int32(18037), np.int32(33988)]
# Recommended artist names: [np.str_('Sandro De América'), np.str_('Kindred The Family Soul'), np.str_('James Cotton'), np.str_('Charming Hostess'), np.str_('Mahalia Jackson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids:  ['user_000873' 'user_000135' 'user_000806' 'user_000077' 'user_000807']
# Indices of 5 recommended artists:  [np.int32(47748), np.int32(89299), np.int32(89078), np.int32(7870), np.int32(19681)]
# Recommended artist names: [np.str_('Uschi'), np.str_('Rimco'), np.str_('George Kranz'), np.str_('808 State'), np.str_('Vanessa Da Mata')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids:  ['user_000977' 'user_000897' 'user_000438' 'user_000215' 'user_000147']
# Indices of 5 recommended artists:  [np.int32(1877), np.int32(100711), np.int32(3673), np.int32(3831), np.int32(22087)]
# Recommended artist names: [np.str_('Weezer'), np.str_('³Å¿O'), np.str_('Shocking Blue'), np.str_('The One Am Radio'), np.str_('Adam Kesher')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids:  ['user_000715' 'user_000208' 'user_000940' 'user_000706' 'user_000010']
# Indices of 5 recommended artists:  [np.int32(4474), np.int32(2417), np.int32(1786), np.int32(63151), np.int32(10718)]
# Recommended artist names: [np.str_('Mary J. Blige'), np.str_('Pakito'), np.str_('The Strokes'), np.str_('Jussi Polet'), np.str_('Josh Pyke')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids:  ['user_000606' 'user_000956' 'user_000560' 'user_000873' 'user_000584']
# Indices of 5 recommended artists:  [np.int32(8389), np.int32(17808), np.int32(4799), np.int32(38897), np.int32(5173)]
# Recommended artist names: [np.str_('Dreamlin'), np.str_('Anima Sound System'), np.str_('Tom Novy'), np.str_('Gene Chandler'), np.str_('Dj Smash')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids:  ['user_000475' 'user_001000' 'user_000414' 'user_000596' 'user_000993']
# Indices of 5 recommended artists:  [np.int32(772), np.int32(35508), np.int32(1808), np.int32(1660), np.int32(13177)]
# Recommended artist names: [np.str_('Barry Louis Polisar'), np.str_('Solu Music'), np.str_('The Wombats'), np.str_('The Coral'), np.str_('Black Lips')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids:  ['user_000837' 'user_000373' 'user_000351' 'user_000118' 'user_000731']
# Indices of 5 recommended artists:  [np.int32(12561), np.int32(16958), np.int32(3342), np.int32(44336), np.int32(8333)]
# Recommended artist names: [np.str_('Trevor Jones'), np.str_('Saigon'), np.str_('Limp Bizkit'), np.str_('Mr.Team'), np.str_('Divinyls')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids:  ['user_000039' 'user_000298' 'user_000849' 'user_000902' 'user_000551']
# Indices of 5 recommended artists:  [np.int32(1667), np.int32(4088), np.int32(43130), np.int32(12515), np.int32(2314)]
# Recommended artist names: [np.str_('The Dandy Warhols'), np.str_('Beatfreakz'), np.str_('Orlando "Cachaito" López'), np.str_('The Vaughan Brothers'), np.str_('Lil Wayne')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids:  ['user_000393' 'user_000774' 'user_000229' 'user_000140' 'user_000909']
# Indices of 5 recommended artists:  [np.int32(26582), np.int32(69320), np.int32(18967), np.int32(6881), np.int32(5618)]
# Recommended artist names: [np.str_('Rhythm Section'), np.str_('Kluster'), np.str_('Mr. Velcro Fastener'), np.str_('Dope'), np.str_('Monolake')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids:  ['user_000572' 'user_000454' 'user_000910' 'user_000451' 'user_000249']
# Indices of 5 recommended artists:  [np.int32(101827), np.int32(14267), np.int32(10526), np.int32(12920), np.int32(18488)]
# Recommended artist names: [np.str_('Jel & Odd Nosdam'), np.str_('Preston School Of Industry'), np.str_('Brakes'), np.str_('The Posies'), np.str_('Howard Zinn')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids:  ['user_000097' 'user_000545' 'user_000294' 'user_000854' 'user_000581']
# Indices of 5 recommended artists:  [np.int32(10615), np.int32(38824), np.int32(39658), np.int32(15200), np.int32(33003)]
# Recommended artist names: [np.str_('Ex Pistols'), np.str_('Elton John & Luciano Pavarotti'), np.str_('The Five Keys'), np.str_('The Belle Stars'), np.str_('Maria Bello')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids:  ['user_000791' 'user_000520' 'user_000059' 'user_000606' 'user_000837']
# Indices of 5 recommended artists:  [np.int32(32822), np.int32(28578), np.int32(3434), np.int32(149008), np.int32(12406)]
# Recommended artist names: [np.str_('Fancois Couperin / Reitzell'), np.str_('Solar Quest'), np.str_('Miles Davis'), np.str_('Hynda Hicks'), np.str_('T-Bone Walker')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids:  ['user_000634' 'user_000927' 'user_000524' 'user_000188' 'user_000452']
# Indices of 5 recommended artists:  [np.int32(1120), np.int32(59930), np.int32(16530), np.int32(60048), np.int32(60091)]
# Recommended artist names: [np.str_('Islands'), np.str_('Baiser'), np.str_('Shadow Gallery'), np.str_('Nevernettles'), np.str_('Sir Elwoodin Hiljaiset Värit')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids:  ['user_000106' 'user_000796' 'user_000036' 'user_000654' 'user_000499']
# Indices of 5 recommended artists:  [np.int32(10718), np.int32(7058), np.int32(108518), np.int32(13324), np.int32(95788)]
# Recommended artist names: [np.str_('Josh Pyke'), np.str_('Skinny Puppy'), np.str_('Panalog'), np.str_('Loretta Lynn'), np.str_('Sweets')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids:  ['user_000361' 'user_000089' 'user_000467' 'user_000345' 'user_000620']
# Indices of 5 recommended artists:  [np.int32(23632), np.int32(677), np.int32(1157), np.int32(12441), np.int32(1114)]
# Recommended artist names: [np.str_('Gentleman'), np.str_('Ac/Dc'), np.str_('Jimi Hendrix'), np.str_('The Carter Family'), np.str_('Incubus')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids:  ['user_000650' 'user_000393' 'user_000565' 'user_000986' 'user_000108']
# Indices of 5 recommended artists:  [np.int32(10121), np.int32(1142), np.int32(12390), np.int32(41950), np.int32(10494)]
# Recommended artist names: [np.str_('Strapping Young Lad'), np.str_('Jason Mraz'), np.str_('Stille Volk'), np.str_('Supafly'), np.str_('Barefoot')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids:  ['user_000136' 'user_000870' 'user_000593' 'user_000914' 'user_000704']
# Indices of 5 recommended artists:  [np.int32(118462), np.int32(89175), np.int32(64008), np.int32(15061), np.int32(58115)]
# Recommended artist names: [np.str_('Duke Ellington & Johnny Hodges'), np.str_('Singers & Players'), np.str_('High Rise'), np.str_('Lunatic Calm'), np.str_('Gravious')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids:  ['user_000093' 'user_000998' 'user_000779' 'user_000123' 'user_000018']
# Indices of 5 recommended artists:  [np.int32(2999), np.int32(148602), np.int32(2978), np.int32(2365), np.int32(1416)]
# Recommended artist names: [np.str_('Deus'), np.str_('Mitchell Sigman'), np.str_('David Byrne'), np.str_('Michael Andrews'), np.str_('Peter Doherty')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids:  ['user_000060' 'user_000345' 'user_000371' 'user_000467' 'user_000086']
# Indices of 5 recommended artists:  [np.int32(81716), np.int32(28835), np.int32(76332), np.int32(1518), np.int32(2706)]
# Recommended artist names: [np.str_('Human Highway'), np.str_('Cichlids'), np.str_('Belouis Some'), np.str_('Scritti Politti'), np.str_('Amanda Palmer')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids:  ['user_000918' 'user_000996' 'user_000920' 'user_000024' 'user_000201']
# Indices of 5 recommended artists:  [np.int32(1858), np.int32(12147), np.int32(2831), np.int32(7994), np.int32(8274)]
# Recommended artist names: [np.str_('Van Morrison'), np.str_('Paloma'), np.str_('Booka Shade'), np.str_('Be Your Own Pet'), np.str_('David Axelrod')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids:  ['user_000866' 'user_000515' 'user_000927' 'user_000503' 'user_000634']
# Indices of 5 recommended artists:  [np.int32(1010), np.int32(1413), np.int32(9071), np.int32(2075), np.int32(2691)]
# Recommended artist names: [np.str_('Evanescence'), np.str_('Pete Yorn'), np.str_('Mr. Scruff'), np.str_('Darude'), np.str_('Akira Yamaoka')]
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids:  ['user_000371' 'user_000795' 'user_000628' 'user_000345' 'user_000024']
# Indices of 5 recommended artists:  [np.int32(10861), np.int32(90064), np.int32(14111), np.int32(86510), np.int32(90054)]
# Recommended artist names: [np.str_('Reverend And The Makers'), np.str_('Gabriella & Troy'), np.str_('Liam Finn'), np.str_('White Light Riot'), np.str_('Brian Stokes Mitchell, Audra Mcdonald')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0051 seconds

# %%
# Count how many times each user listened to each artist
playcounts = interactions.groupby(["user_id", "artist_name"]).size().reset_index(name="playcount")

# Create mapping dictionaries for user/artist to index
user_id_to_idx = {user: idx for idx, user in enumerate(playcounts["user_id"].unique())}
artist_name_to_idx = {artist: idx for idx, artist in enumerate(playcounts["artist_name"].unique())}

# Map user/artist names to indices in the dataframe
playcounts["user_idx"] = playcounts["user_id"].map(user_id_to_idx)
playcounts["artist_idx"] = playcounts["artist_name"].map(artist_name_to_idx)

# Build the user-artist matrix (UAM) in sparse format
UAM = csr_matrix((playcounts["playcount"],
                  (playcounts["user_idx"], playcounts["artist_idx"])),
                 shape=(len(user_id_to_idx), len(artist_name_to_idx)))

# Normalize rows (each row becomes a unit vector for cosine similarity)
UAM = normalize(UAM, norm='l2', axis=1)

# Precompute UAM transpose for efficient cosine similarity calculations
# This avoids repeatedly computing UAM.transpose() within the loop.
UAM_T = UAM.transpose().tocsr()

# Create lists for reverse lookup
user_ids = np.array(list(user_id_to_idx.keys()))
artist_ids = np.array(list(artist_name_to_idx.keys()))

if __name__ == '__main__':
    start_time = time.time()
    num_users = UAM.shape[0]
    
    for u in range(num_users):
        print("Seed user-id:", user_ids[u])
        
        # Retrieve the normalized playcount vector (row) for the current user
        pc_vec = UAM.getrow(u)
        
        # Compute cosine similarity between the seed user and all other users
        # Using the precomputed UAM_T speeds up the dot-product calculation.
        sims = pc_vec.dot(UAM_T)
        
        # Convert the similarity result to COO format to easily access indices and data.
        sims_coo = sims.tocoo()
        
        # Remove self-similarity by filtering out the element where the column index equals the seed user.
        mask = sims_coo.col != u
        neighbor_indices = sims_coo.col[mask]
        neighbor_scores = sims_coo.data[mask]
        
        # Proceed only if there is at least one similar user
        if neighbor_scores.size == 0:
            print("No similar users found for", user_ids[u])
            print('-' * 80)
            continue
        
        # Use argpartition to quickly find indices of top K similarities.
        # For cases where there are fewer than K neighbors, return all.
        if neighbor_scores.size > K:
            top_k_idx = np.argpartition(neighbor_scores, -K)[-K:]
            # Sort the top K neighbors in descending order by their similarity scores.
            sorted_order = np.argsort(neighbor_scores[top_k_idx])[::-1]
            top_neighbors = neighbor_indices[top_k_idx][sorted_order]
        else:
            sorted_order = np.argsort(neighbor_scores)[::-1]
            top_neighbors = neighbor_indices[sorted_order]
        
        # Retrieve the actual user IDs for the top K neighbors
        recommended_user_ids = user_ids[top_neighbors]
        print(f"Nearest K={K} neighbors' user-ids:", recommended_user_ids.flatten())
        
        # Get all artist indices listened to by the top K similar users in one vectorized operation.
        # This avoids looping over each neighbor.
        neighbor_rows = UAM[top_neighbors, :]
        neighbor_coo = neighbor_rows.tocoo()
        recommended_artists_idx = np.unique(neighbor_coo.col)
        
        # Remove artists already known to the seed user
        seed_artists = pc_vec.indices
        recommended_artists_idx = np.setdiff1d(recommended_artists_idx, seed_artists)
        
        # Randomly choose 5 artists (or fewer, if not enough exist) for recommendation
        if recommended_artists_idx.size > 0:
            num_to_select = min(5, recommended_artists_idx.size)
            random_elements = random.sample(list(recommended_artists_idx), num_to_select)
            print(f"Indices of {len(random_elements)} recommended artists:", random_elements)
            rec_artist_names = [artist_ids[i] for i in random_elements]
            print("Recommended artist names:", rec_artist_names)
        else:
            print("No new recommended artists found.")
            
        print('-' * 80)
    
    end_time = time.time()
    avg_time = (end_time - start_time) / num_users
    print(f"Average time per user recommendation: {avg_time:.4f} seconds")
# Out:
# Seed user-id: user_000001
# Nearest K=5 neighbors' user-ids: ['user_000074' 'user_000629' 'user_000862' 'user_000844' 'user_000168']
# Indices of 5 recommended artists: [np.int32(123814), np.int32(17426), np.int32(34351), np.int32(53763), np.int32(47752)]
# Recommended artist names: [np.str_('The Vogado Projects Vol. 1'), np.str_('Pastora'), np.str_('Juiceboxxx And Dre Skull'), np.str_('Operator & Baffled'), np.str_('Vanja Lazarova')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000002
# Nearest K=5 neighbors' user-ids: ['user_000673' 'user_000238' 'user_000143' 'user_000726' 'user_000513']
# Indices of 5 recommended artists: [np.int32(72353), np.int32(109929), np.int32(180), np.int32(2003), np.int32(2743)]
# Recommended artist names: [np.str_('Villancicos'), np.str_("D'Malicious"), np.str_('Fila Brazillia'), np.str_('Black Sabbath'), np.str_('Aqualung')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000003
# Nearest K=5 neighbors' user-ids: ['user_000813' 'user_000558' 'user_000400' 'user_000741' 'user_000392']
# Indices of 5 recommended artists: [np.int32(93133), np.int32(19482), np.int32(4129), np.int32(4307), np.int32(154384)]
# Recommended artist names: [np.str_('Akifumi Oota'), np.str_('The Fixx'), np.str_('Cassius'), np.str_('Freemasons'), np.str_('831')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000004
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000779' 'user_000089' 'user_000998' 'user_000703']
# Indices of 5 recommended artists: [np.int32(136945), np.int32(89756), np.int32(104172), np.int32(10394), np.int32(55989)]
# Recommended artist names: [np.str_('Joe Fitzgerald'), np.str_('Dakota/Dakota'), np.str_('Benjamin Costello'), np.str_('Sopor Aeternus & The Ensemble Of Shadows'), np.str_('Mark E')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000005
# Nearest K=5 neighbors' user-ids: ['user_000307' 'user_000584' 'user_000560' 'user_000807' 'user_000627']
# Indices of 5 recommended artists: [np.int32(16456), np.int32(2233), np.int32(12561), np.int32(428), np.int32(3842)]
# Recommended artist names: [np.str_('Klaus Schulze'), np.str_('Iio'), np.str_('Trevor Jones'), np.str_('Pendulum'), np.str_('The Rubettes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000006
# Nearest K=5 neighbors' user-ids: ['user_000116' 'user_000766' 'user_000885' 'user_000415' 'user_000675']
# Indices of 5 recommended artists: [np.int32(95608), np.int32(95635), np.int32(12049), np.int32(233), np.int32(43522)]
# Recommended artist names: [np.str_('Melanoma'), np.str_('Perturbazione'), np.str_("Michaels' @ Maximum"), np.str_('I Am Robot And Proud'), np.str_('Arthur')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000007
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000236' 'user_000402' 'user_000781' 'user_000437']
# Indices of 5 recommended artists: [np.int32(100535), np.int32(23724), np.int32(148986), np.int32(44726), np.int32(100620)]
# Recommended artist names: [np.str_('Rama Duke'), np.str_('T.O.K.'), np.str_('Bone Thugs - N - Harmony (Feat. Mariah Carey & Bow Wow)'), np.str_('City High'), np.str_('The Unit')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000008
# Nearest K=5 neighbors' user-ids: ['user_000864' 'user_000419' 'user_000737' 'user_000187' 'user_000123']
# Indices of 5 recommended artists: [np.int32(59588), np.int32(7322), np.int32(1199), np.int32(1814), np.int32(4579)]
# Recommended artist names: [np.str_('Daniele Papini'), np.str_('Mos Def'), np.str_('Justin Timberlake'), np.str_('Thievery Corporation'), np.str_('Panjabi Mc')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000009
# Nearest K=5 neighbors' user-ids: ['user_000357' 'user_000758' 'user_000473' 'user_000115' 'user_000833']
# Indices of 5 recommended artists: [np.int32(10428), np.int32(632), np.int32(9214), np.int32(88336), np.int32(9205)]
# Recommended artist names: [np.str_('Umbra Et Imago'), np.str_('[Unknown]'), np.str_('Peter Murphy'), np.str_('Miro Miroe'), np.str_('Pet Shop Boys')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000010
# Nearest K=5 neighbors' user-ids: ['user_000208' 'user_000981' 'user_000329' 'user_000379' 'user_000813']
# Indices of 5 recommended artists: [np.int32(8015), np.int32(16966), np.int32(17597), np.int32(407), np.int32(52126)]
# Recommended artist names: [np.str_('Bill Evans'), np.str_('Skream'), np.str_('Tim Deluxe'), np.str_('Oasis'), np.str_('Lovestation')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000011
# Nearest K=5 neighbors' user-ids: ['user_000705' 'user_000417' 'user_000291' 'user_000715' 'user_000953']
# Indices of 5 recommended artists: [np.int32(137204), np.int32(37267), np.int32(9435), np.int32(53998), np.int32(3125)]
# Recommended artist names: [np.str_('Sujata Trivedi'), np.str_('Bill Bailey'), np.str_('Sonny Rollins'), np.str_('Todd Barry'), np.str_('George Michael')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000012
# Nearest K=5 neighbors' user-ids: ['user_000689' 'user_000698' 'user_000703' 'user_000564' 'user_000203']
# Indices of 5 recommended artists: [np.int32(28736), np.int32(14260), np.int32(12534), np.int32(115508), np.int32(132813)]
# Recommended artist names: [np.str_('As Mercenárias'), np.str_('Polvo'), np.str_('Tim Buckley'), np.str_('Mark Borthwick And Holland'), np.str_('Sue Lynne')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000013
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000932' 'user_000935' 'user_000927' 'user_000026']
# Indices of 5 recommended artists: [np.int32(3836), np.int32(3586), np.int32(27566), np.int32(2025), np.int32(3008)]
# Recommended artist names: [np.str_('The Pierces'), np.str_('Q And Not U'), np.str_('Electrovamp'), np.str_('Butthole Surfers'), np.str_('Dire Straits')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000014
# Nearest K=5 neighbors' user-ids: ['user_000497' 'user_000257' 'user_000920' 'user_000443' 'user_000129']
# Indices of 5 recommended artists: [np.int32(3136), np.int32(36692), np.int32(2797), np.int32(171), np.int32(6844)]
# Recommended artist names: [np.str_('Glen Hansard'), np.str_('Karen O'), np.str_('Beth Orton'), np.str_('Enya'), np.str_('Collective Soul')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000015
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000532' 'user_000634' 'user_000515' 'user_000503']
# Indices of 5 recommended artists: [np.int32(18776), np.int32(2936), np.int32(74704), np.int32(34241), np.int32(7110)]
# Recommended artist names: [np.str_('Lloyd Charmers'), np.str_('Cocorosie'), np.str_('Lilith'), np.str_('Farley Jackmaster Funk'), np.str_('Type O Negative')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000016
# Nearest K=5 neighbors' user-ids: ['user_000791' 'user_000293' 'user_000897' 'user_000048' 'user_000328']
# Indices of 5 recommended artists: [np.int32(4784), np.int32(7453), np.int32(1250), np.int32(853), np.int32(78920)]
# Recommended artist names: [np.str_('The Supermen Lovers'), np.str_('Bo Hansson'), np.str_('Less Than Jake'), np.str_('Cat Stevens'), np.str_('Christina Millian Feat Young Jeezy')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000017
# Nearest K=5 neighbors' user-ids: ['user_000905' 'user_000731' 'user_000937' 'user_000075' 'user_000705']
# Indices of 5 recommended artists: [np.int32(14943), np.int32(57782), np.int32(14840), np.int32(137136), np.int32(8038)]
# Recommended artist names: [np.str_('Elis Regina'), np.str_('3 Daft Monkeys'), np.str_('500Won Project'), np.str_('Javed Ali & Sonu Nigam'), np.str_('Blossom Dearie')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000018
# Nearest K=5 neighbors' user-ids: ['user_000996' 'user_000093' 'user_000998' 'user_000486' 'user_000123']
# Indices of 5 recommended artists: [np.int32(37279), np.int32(1714), np.int32(23593), np.int32(2531), np.int32(40223)]
# Recommended artist names: [np.str_("I'M Sorry I Haven'T A Clue - Radio Show (Guest: Jeremy Hardy)"), np.str_('The Kooks'), np.str_('Antipop Consortium'), np.str_('Ted Nugent'), np.str_('Sackville')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000019
# Nearest K=5 neighbors' user-ids: ['user_000440' 'user_000139' 'user_000554' 'user_000565' 'user_000020']
# Indices of 5 recommended artists: [np.int32(13036), np.int32(1218), np.int32(19355), np.int32(16378), np.int32(1695)]
# Recommended artist names: [np.str_('James Chadwick'), np.str_('Keith Jarrett'), np.str_('Spain'), np.str_('Candlemass'), np.str_('The Get Up Kids')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000020
# Nearest K=5 neighbors' user-ids: ['user_000624' 'user_000683' 'user_000327' 'user_000139' 'user_000658']
# Indices of 5 recommended artists: [np.int32(1838), np.int32(123377), np.int32(3508), np.int32(1914), np.int32(37287)]
# Recommended artist names: [np.str_('Toto'), np.str_('Александр Васильевич Александров'), np.str_('Nouvelle Vague'), np.str_('Пётр Ильич Чайковский'), np.str_('Lisa Mitchell')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000021
# Nearest K=5 neighbors' user-ids: ['user_000882' 'user_000617' 'user_000673' 'user_000691' 'user_000681']
# Indices of 5 recommended artists: [np.int32(67290), np.int32(3275), np.int32(15102), np.int32(129584), np.int32(81941)]
# Recommended artist names: [np.str_('The Kirby Grips'), np.str_('Kaki King'), np.str_('Neva Dinova'), np.str_('Belreve'), np.str_('Patty Loveless')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000022
# Nearest K=5 neighbors' user-ids: ['user_000690' 'user_000564' 'user_000534' 'user_000249' 'user_000858']
# Indices of 5 recommended artists: [np.int32(93918), np.int32(115560), np.int32(82050), np.int32(36592), np.int32(133049)]
# Recommended artist names: [np.str_('Squadra Blanco'), np.str_('Smith, Jedediah'), np.str_('Souled American'), np.str_('The Great Depression'), np.str_('Raw Noise')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000023
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000515' 'user_000927' 'user_000503' 'user_000866']
# Indices of 5 recommended artists: [np.int32(70755), np.int32(58546), np.int32(7811), np.int32(81595), np.int32(11112)]
# Recommended artist names: [np.str_('Mellow Trax'), np.str_('Stud'), np.str_('The Rasmus'), np.str_('Deathcamp Project'), np.str_('Vashti Bunyan')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000024
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000493' 'user_000998' 'user_000371']
# Indices of 5 recommended artists: [np.int32(3621), np.int32(72219), np.int32(18603), np.int32(17227), np.int32(17802)]
# Recommended artist names: [np.str_('Robots In Disguise'), np.str_('Riddle Of Steel'), np.str_('Johnny Lowebow'), np.str_('Gal Costa'), np.str_('André Cluytens')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000025
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000118' 'user_000151' 'user_000096' 'user_000476']
# Indices of 5 recommended artists: [np.int32(7257), np.int32(57581), np.int32(38391), np.int32(47356), np.int32(1473)]
# Recommended artist names: [np.str_("Gigi D'Agostino"), np.str_('Ian Carey'), np.str_('Skytone'), np.str_('Lavern Baker'), np.str_('Rilo Kiley')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000026
# Nearest K=5 neighbors' user-ids: ['user_000161' 'user_000833' 'user_000188' 'user_000839' 'user_000565']
# Indices of 5 recommended artists: [np.int32(24600), np.int32(10180), np.int32(13973), np.int32(51451), np.int32(12793)]
# Recommended artist names: [np.str_('Diablo'), np.str_('Yonderboi'), np.str_('Get Him Eat Him'), np.str_('Cherry Bikini'), np.str_('Ensemble Orchestral Synaxis')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000027
# Nearest K=5 neighbors' user-ids: ['user_000714' 'user_000233' 'user_000124' 'user_000205' 'user_000651']
# Indices of 5 recommended artists: [np.int32(105866), np.int32(69942), np.int32(8745), np.int32(1486), np.int32(19805)]
# Recommended artist names: [np.str_('Kleerup Feat Robyn'), np.str_('David Vendetta & Barbara Tucker'), np.str_('John Mellencamp'), np.str_('Rod Stewart'), np.str_('अनुराधा पौडवाल')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000028
# Nearest K=5 neighbors' user-ids: ['user_000661' 'user_000069' 'user_000756' 'user_000373' 'user_000485']
# Indices of 5 recommended artists: [np.int32(9171), np.int32(22145), np.int32(13893), np.int32(34283), np.int32(584)]
# Recommended artist names: [np.str_('Our Lady Peace'), np.str_('College Feat. Anoraak'), np.str_('Die Happy'), np.str_('Groupe El Azhar'), np.str_('Thom Yorke')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000029
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000703' 'user_000513' 'user_000826' 'user_000345']
# Indices of 5 recommended artists: [np.int32(79765), np.int32(16013), np.int32(14092), np.int32(26356), np.int32(1641)]
# Recommended artist names: [np.str_('Tracy Vierra'), np.str_('Pseudo Echo'), np.str_('Kukl'), np.str_('N.O.R.E.'), np.str_('The Besnard Lakes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000030
# Nearest K=5 neighbors' user-ids: ['user_000564' 'user_000031' 'user_000703' 'user_000753' 'user_000858']
# Indices of 5 recommended artists: [np.int32(15141), np.int32(2917), np.int32(18871), np.int32(38885), np.int32(64700)]
# Recommended artist names: [np.str_('Relient K'), np.str_('Cinerama'), np.str_('Martial Solal'), np.str_('G.Q.'), np.str_('Spanky & Our Gang')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000031
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000513' 'user_000164' 'user_000159' 'user_000242']
# Indices of 5 recommended artists: [np.int32(47370), np.int32(236), np.int32(36542), np.int32(9501), np.int32(86404)]
# Recommended artist names: [np.str_('Los Chicharrons'), np.str_('Idris Muhammad'), np.str_('Klingonz'), np.str_('Sven Van Hees'), np.str_('Racetrack Babies')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000032
# Nearest K=5 neighbors' user-ids: ['user_000692' 'user_000727' 'user_000442' 'user_000115' 'user_000206']
# Indices of 5 recommended artists: [np.int32(3940), np.int32(25421), np.int32(27923), np.int32(3813), np.int32(16281)]
# Recommended artist names: [np.str_('Waldeck'), np.str_('Dark Moor'), np.str_('The Nine'), np.str_('The Jam'), np.str_('Venom')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000033
# Nearest K=5 neighbors' user-ids: ['user_000758' 'user_000188' 'user_000588' 'user_000999' 'user_000991']
# Indices of 5 recommended artists: [np.int32(9907), np.int32(2528), np.int32(26179), np.int32(44463), np.int32(60106)]
# Recommended artist names: [np.str_('Building Castles Out Of Matchsticks'), np.str_('T.I.'), np.str_('Mandrill'), np.str_('Popeda'), np.str_('Superchrist')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000034
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000164' 'user_000031' 'user_000086' 'user_000280']
# Indices of 5 recommended artists: [np.int32(17753), np.int32(18444), np.int32(77481), np.int32(41324), np.int32(19474)]
# Recommended artist names: [np.str_('Air Formation'), np.str_('Hariprasad Chaurasia'), np.str_('Zé Da Velha, Silvério Pontes E Yamandú Costa'), np.str_('Perspecto'), np.str_('The Eyeliners')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000035
# Nearest K=5 neighbors' user-ids: ['user_000720' 'user_000664' 'user_000483' 'user_000023' 'user_000415']
# Indices of 5 recommended artists: [np.int32(95590), np.int32(7717), np.int32(8227), np.int32(843), np.int32(13718)]
# Recommended artist names: [np.str_('Lucien N Luciano/(Cadenza,Mental Groove)'), np.str_('Pharoahe Monch'), np.str_('Corina'), np.str_('Calexico'), np.str_('Bad Manners')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000036
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000992' 'user_000495' 'user_000770' 'user_000086']
# Indices of 5 recommended artists: [np.int32(30727), np.int32(25060), np.int32(9304), np.int32(41464), np.int32(8514)]
# Recommended artist names: [np.str_('Heartsdales'), np.str_('Amanda Rogers'), np.str_('Ringo Starr'), np.str_('Ymck'), np.str_('Françoise Hardy')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000037
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000862' 'user_000294' 'user_000304' 'user_000062']
# Indices of 5 recommended artists: [np.int32(9486), np.int32(44617), np.int32(12001), np.int32(9804), np.int32(4015)]
# Recommended artist names: [np.str_('Stevie Nicks'), np.str_('Merry Clayton'), np.str_('Mark Lanegan'), np.str_('Vega'), np.str_('2Pac')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000038
# Nearest K=5 neighbors' user-ids: ['user_000588' 'user_000612' 'user_000015' 'user_000780' 'user_000056']
# Indices of 5 recommended artists: [np.int32(27447), np.int32(148770), np.int32(88352), np.int32(44734), np.int32(24619)]
# Recommended artist names: [np.str_('Bald Terror'), np.str_('Diktatura'), np.str_('Norma Loy'), np.str_('Henryk Szeryng'), np.str_('Drop Dead, Gorgeous')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000039
# Nearest K=5 neighbors' user-ids: ['user_000814' 'user_000849' 'user_000985' 'user_000551' 'user_000603']
# Indices of 5 recommended artists: [np.int32(46545), np.int32(7747), np.int32(31361), np.int32(41039), np.int32(7067)]
# Recommended artist names: [np.str_('Jeff Finlin'), np.str_('Run-D.M.C.'), np.str_('Iain Archer'), np.str_('A Thorn For Every Heart'), np.str_('Stone Sour')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000040
# Nearest K=5 neighbors' user-ids: ['user_000020' 'user_000327' 'user_000093' 'user_000658' 'user_000624']
# Indices of 5 recommended artists: [np.int32(19274), np.int32(3273), np.int32(1297), np.int32(37276), np.int32(82000)]
# Recommended artist names: [np.str_('Scissors For Lefty'), np.str_('Junior Senior'), np.str_('Matt Costa'), np.str_('Hoax Funeral'), np.str_('Rita Eriksen')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000041
# Nearest K=5 neighbors' user-ids: ['user_000132' 'user_000134' 'user_000444' 'user_000831' 'user_000615']
# Indices of 5 recommended artists: [np.int32(18154), np.int32(5391), np.int32(94630), np.int32(46338), np.int32(5963)]
# Recommended artist names: [np.str_('David E. Sugar'), np.str_('Joel Mull'), np.str_('Gencab'), np.str_('Svein Westad, Anne S. Haugan'), np.str_('Terranova')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000042
# Nearest K=5 neighbors' user-ids: ['user_000117' 'user_000806' 'user_000103' 'user_000383' 'user_000256']
# Indices of 5 recommended artists: [np.int32(1886), np.int32(1559), np.int32(74158), np.int32(40174), np.int32(2607)]
# Recommended artist names: [np.str_('Wir Sind Helden'), np.str_('Soundtrack'), np.str_('Kraan'), np.str_('James Orr Complex'), np.str_('Total Science')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000043
# Nearest K=5 neighbors' user-ids: ['user_000031' 'user_000345' 'user_000513' 'user_000143' 'user_000393']
# Indices of 5 recommended artists: [np.int32(17790), np.int32(17901), np.int32(28319), np.int32(2608), np.int32(8191)]
# Recommended artist names: [np.str_('Amy Marcy Cheney Beach'), np.str_('Bert Kaempfert'), np.str_('Dorothy Ashby'), np.str_('Traffic'), np.str_('Club Des Belugas')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000044
# Nearest K=5 neighbors' user-ids: ['user_000115' 'user_000435' 'user_000442' 'user_000527' 'user_000473']
# Indices of 5 recommended artists: [np.int32(7669), np.int32(23608), np.int32(6957), np.int32(10517), np.int32(7123)]
# Recommended artist names: [np.str_('Marillion'), np.str_('Concrete Blonde'), np.str_('Kidneythieves'), np.str_('Black Label Society'), np.str_('Zeromancer')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000045
# Nearest K=5 neighbors' user-ids: ['user_000442' 'user_000527' 'user_000289' 'user_000457' 'user_000346']
# Indices of 5 recommended artists: [np.int32(10402), np.int32(2484), np.int32(21764), np.int32(38443), np.int32(12100)]
# Recommended artist names: [np.str_('Stoa'), np.str_('Shaggy'), np.str_('Natasha St-Pier'), np.str_('911'), np.str_('Nick Carter')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000046
# Nearest K=5 neighbors' user-ids: ['user_000354' 'user_000912' 'user_000783' 'user_000537' 'user_000013']
# Indices of 5 recommended artists: [np.int32(44666), np.int32(40094), np.int32(10912), np.int32(3043), np.int32(10263)]
# Recommended artist names: [np.str_('Anthony Johnson'), np.str_('The Pale Fountains'), np.str_('Sons And Daughters'), np.str_('Ellen Allien & Apparat'), np.str_('Die Krupps')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000047
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000973' 'user_000260' 'user_000761' 'user_000354']
# Indices of 5 recommended artists: [np.int32(146216), np.int32(65047), np.int32(16817), np.int32(71121), np.int32(23237)]
# Recommended artist names: [np.str_('Paddy Day'), np.str_('Ace Cosmic'), np.str_('George Carlin'), np.str_('Rodeo'), np.str_('Prince Far I')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000048
# Nearest K=5 neighbors' user-ids: ['user_000769' 'user_000791' 'user_000631' 'user_000328' 'user_000847']
# Indices of 5 recommended artists: [np.int32(50221), np.int32(1788), np.int32(39656), np.int32(1205), np.int32(1773)]
# Recommended artist names: [np.str_('Tehosekoitin'), np.str_('The Subways'), np.str_('The Equals'), np.str_('Kanye West'), np.str_('The Shins')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000049
# Nearest K=5 neighbors' user-ids: ['user_000126' 'user_000420' 'user_000387' 'user_000668' 'user_000256']
# Indices of 5 recommended artists: [np.int32(57004), np.int32(2562), np.int32(92252), np.int32(46492), np.int32(92308)]
# Recommended artist names: [np.str_('The Jazzistics'), np.str_('The Jimi Hendrix Experience'), np.str_('Dui - Tim Ellis'), np.str_('Chubb Rock'), np.str_('Kind & Kinky Zoo')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000050
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000336' 'user_000620' 'user_000511' 'user_000467']
# Indices of 5 recommended artists: [np.int32(10762), np.int32(8770), np.int32(86241), np.int32(53269), np.int32(12772)]
# Recommended artist names: [np.str_('Little Feat'), np.str_('Julian Cope'), np.str_('Gorie With Jasmine & Joann'), np.str_('Fonda 500'), np.str_('Criteria')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000051
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000089' 'user_000977' 'user_000803' 'user_000478']
# Indices of 5 recommended artists: [np.int32(1419), np.int32(1702), np.int32(36690), np.int32(2158), np.int32(15140)]
# Recommended artist names: [np.str_('Phantom Planet'), np.str_('The Hoosiers'), np.str_('Jonna Lee'), np.str_('Felix Da Housecat'), np.str_('Red Riders')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000052
# Nearest K=5 neighbors' user-ids: ['user_000113' 'user_000182' 'user_000115' 'user_000173' 'user_000247']
# Indices of 5 recommended artists: [np.int32(7062), np.int32(24369), np.int32(46810), np.int32(1800), np.int32(30072)]
# Recommended artist names: [np.str_('Static-X'), np.str_('He Is Legend'), np.str_('Operation Phoenix'), np.str_('The Vines'), np.str_('Gjallarhorn')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000053
# Nearest K=5 neighbors' user-ids: ['user_000373' 'user_000241' 'user_000756' 'user_000606' 'user_000773']
# Indices of 5 recommended artists: [np.int32(9322), np.int32(145127), np.int32(105661), np.int32(4707), np.int32(46690)]
# Recommended artist names: [np.str_('Roxy Music'), np.str_('Ella Washington'), np.str_('Ciara Ft. Chamillionaire'), np.str_('Snap!'), np.str_("Umc'S")]
# --------------------------------------------------------------------------------
# Seed user-id: user_000054
# Nearest K=5 neighbors' user-ids: ['user_000912' 'user_000776' 'user_000142' 'user_000835' 'user_000570']
# Indices of 5 recommended artists: [np.int32(97521), np.int32(23375), np.int32(116771), np.int32(69085), np.int32(36507)]
# Recommended artist names: [np.str_('Maskavo'), np.str_('Stryper'), np.str_('Psykóze'), np.str_('Nocturnal'), np.str_('D.R.I.')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000055
# Nearest K=5 neighbors' user-ids: ['user_000894' 'user_000579' 'user_000577' 'user_000591' 'user_000763']
# Indices of 5 recommended artists: [np.int32(8900), np.int32(17878), np.int32(18811), np.int32(31030), np.int32(13038)]
# Recommended artist names: [np.str_('Level 42'), np.str_('Bargain Music'), np.str_('Luna'), np.str_('Cliff Eberhardt'), np.str_('Juanes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000056
# Nearest K=5 neighbors' user-ids: ['user_000041' 'user_000700' 'user_000134' 'user_000132' 'user_000043']
# Indices of 5 recommended artists: [np.int32(15761), np.int32(23621), np.int32(545), np.int32(46339), np.int32(33497)]
# Recommended artist names: [np.str_('Just D'), np.str_('Dog Traders'), np.str_('Sébastien Tellier'), np.str_('Svein Westad, John Wright, Tran Quang Hai, Leo Tadagawa'), np.str_('Cinema Bizarre')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000057
# Nearest K=5 neighbors' user-ids: ['user_000902' 'user_000650' 'user_000551' 'user_000742' 'user_000557']
# Indices of 5 recommended artists: [np.int32(10785), np.int32(1271), np.int32(69915), np.int32(59463), np.int32(2518)]
# Recommended artist names: [np.str_('Maria Taylor'), np.str_('Mad Caddies'), np.str_('Dave Armstrong'), np.str_('Flo Rida Feat. T-Pain'), np.str_('Sugarcult')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000058
# Nearest K=5 neighbors' user-ids: ['user_000770' 'user_000828' 'user_000463' 'user_000598' 'user_000070']
# Indices of 5 recommended artists: [np.int32(11519), np.int32(979), np.int32(2291), np.int32(43942), np.int32(13117)]
# Recommended artist names: [np.str_('Eddie Vedder & The Million Dollar Bashers'), np.str_('Eagles Of Death Metal'), np.str_('Klaxons'), np.str_('Jubilee'), np.str_('The Warlocks')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000059
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000584' 'user_000763' 'user_000837' 'user_000024']
# Indices of 5 recommended artists: [np.int32(2138), np.int32(5404), np.int32(11608), np.int32(1690), np.int32(15102)]
# Recommended artist names: [np.str_('Emerson, Lake & Palmer'), np.str_('Jonas Bering'), np.str_('Freddie King'), np.str_('The Fratellis'), np.str_('Neva Dinova')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000060
# Nearest K=5 neighbors' user-ids: ['user_000582' 'user_000170' 'user_000031' 'user_000448' 'user_000633']
# Indices of 5 recommended artists: [np.int32(18184), np.int32(351), np.int32(18099), np.int32(23555), np.int32(3365)]
# Recommended artist names: [np.str_('Dif Juz'), np.str_('Madlib'), np.str_('Colour Kane'), np.str_('Entheogenic'), np.str_('Lucky Soul')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000061
# Nearest K=5 neighbors' user-ids: ['user_000765' 'user_000233' 'user_000959' 'user_000579' 'user_000479']
# Indices of 5 recommended artists: [np.int32(71456), np.int32(1273), np.int32(2671), np.int32(70122), np.int32(103475)]
# Recommended artist names: [np.str_('Tom Stephan & The S-Man Featuring Kevin Aviance'), np.str_('Madonna'), np.str_('A Perfect Circle'), np.str_('Erik'), np.str_('Akina')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000062
# Nearest K=5 neighbors' user-ids: ['user_000170' 'user_000304' 'user_000031' 'user_000345' 'user_000159']
# Indices of 5 recommended artists: [np.int32(19713), np.int32(1833), np.int32(34837), np.int32(12980), np.int32(1662)]
# Recommended artist names: [np.str_('Wanda Sá'), np.str_('Tomte'), np.str_('Frameshift'), np.str_('Blackfield'), np.str_('The Corrs')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000063
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000305' 'user_000338' 'user_000705' 'user_000188']
# Indices of 5 recommended artists: [np.int32(37337), np.int32(27547), np.int32(35473), np.int32(60126), np.int32(13125)]
# Recommended artist names: [np.str_('Cela Nr 3'), np.str_('Do As Infinity'), np.str_('Phillip Boa & The Voodooclub'), np.str_('To Destination'), np.str_('X')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000064
# Nearest K=5 neighbors' user-ids: ['user_000495' 'user_000360' 'user_000970' 'user_000832' 'user_000853']
# Indices of 5 recommended artists: [np.int32(31999), np.int32(9604), np.int32(160043), np.int32(93114), np.int32(156212)]
# Recommended artist names: [np.str_('Sesame Street'), np.str_('The Escape Club'), np.str_('Earle Hagen'), np.str_('The Green Car Motel'), np.str_('Carling Live')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000065
# Nearest K=5 neighbors' user-ids: ['user_000467' 'user_000403' 'user_000960' 'user_000603' 'user_000803']
# Indices of 5 recommended artists: [np.int32(10572), np.int32(1328), np.int32(7939), np.int32(12254), np.int32(82175)]
# Recommended artist names: [np.str_('Daniel Powter'), np.str_('Mumm-Ra'), np.str_('April Stevens'), np.str_('Roddy Woomble'), np.str_('The Rutabega')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000066
# Nearest K=5 neighbors' user-ids: ['user_000609' 'user_000418' 'user_000586' 'user_000392' 'user_000396']
# Indices of 5 recommended artists: [np.int32(90931), np.int32(23224), np.int32(2071), np.int32(34082), np.int32(8710)]
# Recommended artist names: [np.str_('Mr Oizo - Reanimator Feat. Big Daddi & Vanilla Ice'), np.str_('Phutureprimitive'), np.str_('Danzel'), np.str_('Airlock'), np.str_('Jean Michel Jarre')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000067
# Nearest K=5 neighbors' user-ids: ['user_000658' 'user_000760' 'user_000624' 'user_000122' 'user_000020']
# Indices of 5 recommended artists: [np.int32(4654), np.int32(145562), np.int32(145483), np.int32(22638), np.int32(6019)]
# Recommended artist names: [np.str_('Roxette'), np.str_('Party Pimpz Feat Mc Miker G & Dj Sven'), np.str_('Errik'), np.str_('Baracuda'), np.str_('Toktok Vs. Soffy O.')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000068
# Nearest K=5 neighbors' user-ids: ['user_000159' 'user_000735' 'user_000343' 'user_000898' 'user_000753']
# Indices of 5 recommended artists: [np.int32(144823), np.int32(163781), np.int32(4922), np.int32(129179), np.int32(34330)]
# Recommended artist names: [np.str_('Illuminations'), np.str_('Dj Sasha & Dj Dado'), np.str_('Akufen'), np.str_('Sofia Radio Symphony Orchestra'), np.str_('Jack Wall & Sam Hulick')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000069
# Nearest K=5 neighbors' user-ids: ['user_000028' 'user_000661' 'user_000273' 'user_000756' 'user_000707']
# Indices of 5 recommended artists: [np.int32(10820), np.int32(104948), np.int32(45569), np.int32(145169), np.int32(1963)]
# Recommended artist names: [np.str_('Nicole Willis & The Soul Investigators'), np.str_('Kish Mauve'), np.str_('Nazgûl'), np.str_('K-Def'), np.str_('Andy Caldwell')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000070
# Nearest K=5 neighbors' user-ids: ['user_000828' 'user_000463' 'user_000770' 'user_000598' 'user_000600']
# Indices of 5 recommended artists: [np.int32(5069), np.int32(87560), np.int32(80190), np.int32(1308), np.int32(1646)]
# Recommended artist names: [np.str_('Chicks On Speed'), np.str_('Victoria Spivey'), np.str_('A.R. Rahman Feat. Alka Yagnik & Ila Arun'), np.str_('Mgmt'), np.str_('The Bravery')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000071
# Nearest K=5 neighbors' user-ids: ['user_000209' 'user_000448' 'user_000513' 'user_000512' 'user_000393']
# Indices of 5 recommended artists: [np.int32(3191), np.int32(1858), np.int32(53915), np.int32(15175), np.int32(967)]
# Recommended artist names: [np.str_('Holly Golightly'), np.str_('Van Morrison'), np.str_('Ant & Dec'), np.str_('Snowden'), np.str_('Doves')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000072
# Nearest K=5 neighbors' user-ids: ['user_000367' 'user_000668' 'user_000837' 'user_000018' 'user_000520']
# Indices of 5 recommended artists: [np.int32(12868), np.int32(3875), np.int32(157897), np.int32(45921), np.int32(157936)]
# Recommended artist names: [np.str_('Missy Elliott'), np.str_('The Whip'), np.str_('P. Diddy Ft Faith Evens'), np.str_('Whispertown2000'), np.str_('Unc Loreleis')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000073
# Nearest K=5 neighbors' user-ids: ['user_000927' 'user_000634' 'user_000503' 'user_000935' 'user_000515']
# Indices of 5 recommended artists: [np.int32(10626), np.int32(12436), np.int32(1833), np.int32(7084), np.int32(107028)]
# Recommended artist names: [np.str_('Frankie Goes To Hollywood'), np.str_('The Atomic Bitchwax'), np.str_('Tomte'), np.str_('The Human League'), np.str_('Snap Vs. Tom Novy')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000074
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000079' 'user_000807' 'user_000577' 'user_000844']
# Indices of 5 recommended artists: [np.int32(158662), np.int32(18920), np.int32(2563), np.int32(8599), np.int32(18868)]
# Recommended artist names: [np.str_('Sara Valenzuela'), np.str_('Milla'), np.str_('The Juliana Theory'), np.str_('Haircut One Hundred'), np.str_('Marlena Shaw')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000075
# Nearest K=5 neighbors' user-ids: ['user_000937' 'user_000859' 'user_000017' 'user_000083' 'user_000905']
# Indices of 5 recommended artists: [np.int32(39222), np.int32(2926), np.int32(11512), np.int32(1412), np.int32(11946)]
# Recommended artist names: [np.str_('Mark Russell'), np.str_('Client'), np.str_('Eberhard Weber'), np.str_('Pete Townshend'), np.str_('Los Fabulosos Cadillacs')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000076
# Nearest K=5 neighbors' user-ids: ['user_000168' 'user_000792' 'user_000091' 'user_000086' 'user_000210']
# Indices of 5 recommended artists: [np.int32(1774), np.int32(64803), np.int32(64689), np.int32(12154), np.int32(63566)]
# Recommended artist names: [np.str_('The Shirelles'), np.str_('The Focus Group'), np.str_('Soinari Ensemble'), np.str_('Patty Griffin'), np.str_('Bettie After Midnight')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000077
# Nearest K=5 neighbors' user-ids: ['user_000763' 'user_000135' 'user_000584' 'user_000807' 'user_000606']
# Indices of 5 recommended artists: [np.int32(12897), np.int32(47146), np.int32(47417), np.int32(35301), np.int32(6672)]
# Recommended artist names: [np.str_('Roomful Of Emptiness'), np.str_('Four80East'), np.str_('Mcd'), np.str_('Beatniks'), np.str_('Will Smith')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000078
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000807' 'user_000560' 'user_000606' 'user_000763']
# Indices of 5 recommended artists: [np.int32(12255), np.int32(64383), np.int32(3321), np.int32(7424), np.int32(50622)]
# Recommended artist names: [np.str_('Rodrigo Rodriguez'), np.str_('Mv + Ee'), np.str_('Lambchop'), np.str_('Anton Maiden'), np.str_('Shareefa')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000079
# Nearest K=5 neighbors' user-ids: ['user_000838' 'user_000522' 'user_000801' 'user_000074' 'user_000862']
# Indices of 5 recommended artists: [np.int32(110785), np.int32(34495), np.int32(13096), np.int32(34668), np.int32(8579)]
# Recommended artist names: [np.str_('Rumi'), np.str_('Nicolette'), np.str_('Spacemen 3'), np.str_('Tape'), np.str_('Gotye')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000080
# Nearest K=5 neighbors' user-ids: ['user_000315' 'user_000870' 'user_000273' 'user_000242' 'user_000031']
# Indices of 5 recommended artists: [np.int32(18672), np.int32(10563), np.int32(190), np.int32(90295), np.int32(10551)]
# Recommended artist names: [np.str_('King Louie'), np.str_('Comets On Fire'), np.str_('Frank Bretschneider'), np.str_('Main'), np.str_('Cave In')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000081
# Nearest K=5 neighbors' user-ids: ['user_000795' 'user_000511' 'user_000960' 'user_000983' 'user_000569']
# Indices of 5 recommended artists: [np.int32(15486), np.int32(680), np.int32(6703), np.int32(13955), np.int32(30667)]
# Recommended artist names: [np.str_('Chad Kroeger'), np.str_('Adam Green'), np.str_('Chevelle'), np.str_('Forest Fire'), np.str_('Patrick Watson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000082
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000376' 'user_000838' 'user_000617' 'user_000993']
# Indices of 5 recommended artists: [np.int32(29889), np.int32(1590), np.int32(10579), np.int32(14511), np.int32(3572)]
# Recommended artist names: [np.str_('Frank Black And The Catholics'), np.str_('Sugarplum Fairy'), np.str_('Dexys Midnight Runners'), np.str_('The Ettes'), np.str_('Pretty Balanced')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000083
# Nearest K=5 neighbors' user-ids: ['user_000859' 'user_000937' 'user_000905' 'user_000108' 'user_000075']
# Indices of 5 recommended artists: [np.int32(10890), np.int32(3002), np.int32(6306), np.int32(15159), np.int32(1732)]
# Recommended artist names: [np.str_('Seth Lakeman'), np.str_('Devotchka'), np.str_('Alicia Keys'), np.str_('Scott Mckenzie'), np.str_('The Mighty Mighty Bosstones')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000084
# Nearest K=5 neighbors' user-ids: ['user_000155' 'user_000771' 'user_000610' 'user_000894' 'user_000342']
# Indices of 5 recommended artists: [np.int32(3210), np.int32(47638), np.int32(57455), np.int32(3088), np.int32(1533)]
# Recommended artist names: [np.str_('Ima Robot.'), np.str_('Special K'), np.str_('Ricardo Arjona'), np.str_('Fischerspooner'), np.str_('Shout Out Louds')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000085
# Nearest K=5 neighbors' user-ids: ['user_000346' 'user_000579' 'user_000686' 'user_000110' 'user_000676']
# Indices of 5 recommended artists: [np.int32(72413), np.int32(12237), np.int32(1591), np.int32(1864), np.int32(84800)]
# Recommended artist names: [np.str_('Support Lesbiens'), np.str_('Richard And Linda Thompson'), np.str_('Sum 41'), np.str_('Violent Femmes'), np.str_('Mandragora')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000086
# Nearest K=5 neighbors' user-ids: ['user_000034' 'user_000031' 'user_000345' 'user_000415' 'user_000703']
# Indices of 5 recommended artists: [np.int32(10621), np.int32(466), np.int32(18226), np.int32(137001), np.int32(76563)]
# Recommended artist names: [np.str_('Flobots'), np.str_('Rinôçérôse'), np.str_('Eddie Baker'), np.str_('Richard Gateaux'), np.str_('Madoka')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000087
# Nearest K=5 neighbors' user-ids: ['user_000607' 'user_000650' 'user_000426' 'user_000776' 'user_000173']
# Indices of 5 recommended artists: [np.int32(4405), np.int32(16137), np.int32(96800), np.int32(96776), np.int32(26757)]
# Recommended artist names: [np.str_('Kim Leoni'), np.str_('Superego'), np.str_('Insecticide'), np.str_('Dysinity'), np.str_('Soul Seekerz')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000088
# Nearest K=5 neighbors' user-ids: ['user_000577' 'user_000204' 'user_000706' 'user_000626' 'user_000897']
# Indices of 5 recommended artists: [np.int32(6873), np.int32(13651), np.int32(118223), np.int32(61894), np.int32(10531)]
# Recommended artist names: [np.str_('Dishwalla'), np.str_('Adorable'), np.str_('Getaway Cruiser'), np.str_('Scrawl'), np.str_('Brendan Benson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000089
# Nearest K=5 neighbors' user-ids: ['user_000345' 'user_000031' 'user_000131' 'user_000467' 'user_000403']
# Indices of 5 recommended artists: [np.int32(31031), np.int32(86239), np.int32(77490), np.int32(1356), np.int32(16517)]
# Recommended artist names: [np.str_('Clue To Kalo'), np.str_('Goem'), np.str_('Bear Claw'), np.str_('Nicola Conte'), np.str_('Richard Bona')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000090
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000385' 'user_000333' 'user_000361' 'user_000238']
# Indices of 5 recommended artists: [np.int32(89004), np.int32(1833), np.int32(173595), np.int32(36884), np.int32(2739)]
# Recommended artist names: [np.str_('Íîæ Äëÿ Frau Muller'), np.str_('Tomte'), np.str_('Celda & Sonja'), np.str_('Metallic Falcons'), np.str_('Apollo 440')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000091
# Nearest K=5 neighbors' user-ids: ['user_000675' 'user_000807' 'user_000792' 'user_000074' 'user_000703']
# Indices of 5 recommended artists: [np.int32(17843), np.int32(49764), np.int32(43259), np.int32(92481), np.int32(34582)]
# Recommended artist names: [np.str_('Atom And His Package'), np.str_('Negative Approach'), np.str_('Shimon'), np.str_('Alexey V'), np.str_('Relapxych.0')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000092
# Nearest K=5 neighbors' user-ids: ['user_000326' 'user_000860' 'user_000284' 'user_000687' 'user_000294']
# Indices of 5 recommended artists: [np.int32(3653), np.int32(77744), np.int32(27376), np.int32(78270), np.int32(58021)]
# Recommended artist names: [np.str_('Scott Walker'), np.str_('Antonio Banderas, Madonna'), np.str_('The Walker Brothers'), np.str_('Snoop Dogg Ft.(Mr. Kane, Bootsy Collins, Quaze, Fred Wesley)'), np.str_('Dub Specialist')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000093
# Nearest K=5 neighbors' user-ids: ['user_000327' 'user_000658' 'user_000891' 'user_000018' 'user_000996']
# Indices of 5 recommended artists: [np.int32(1734), np.int32(33636), np.int32(89943), np.int32(115072), np.int32(3861)]
# Recommended artist names: [np.str_('The Moldy Peaches'), np.str_('Jovanotti'), np.str_('Rosolina Mar'), np.str_('香奈'), np.str_('The Twilight Sad')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000094
# Nearest K=5 neighbors' user-ids: ['user_000431' 'user_000927' 'user_000484' 'user_000179' 'user_000634']
# Indices of 5 recommended artists: [np.int32(19456), np.int32(99513), np.int32(107500), np.int32(107379), np.int32(7077)]
# Recommended artist names: [np.str_('The Dave Brubeck Quartet'), np.str_('Ksu [Jabol Pank'), np.str_('Niels De Vries'), np.str_('Elektra'), np.str_('The 69 Eyes')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000095
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000096' 'user_000705' 'user_000596' 'user_000482']
# Indices of 5 recommended artists: [np.int32(10197), np.int32(10708), np.int32(85774), np.int32(3050), np.int32(3573)]
# Recommended artist names: [np.str_('Mis-Teeq'), np.str_('John Lee Hooker, Jr.'), np.str_('Radio Lingua International'), np.str_('Emily Haines & The Soft Skeleton'), np.str_('Primal Scream')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000096
# Nearest K=5 neighbors' user-ids: ['user_000653' 'user_000596' 'user_000110' 'user_000829' 'user_000493']
# Indices of 5 recommended artists: [np.int32(20047), np.int32(36023), np.int32(11045), np.int32(1608), np.int32(2117)]
# Recommended artist names: [np.str_('Girugämesh'), np.str_('The Dying Breed Feat. Tanaka Koyuki'), np.str_('The Pioneers'), np.str_("Tapes 'N Tapes"), np.str_('Does It Offend You, Yeah?')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000097
# Nearest K=5 neighbors' user-ids: ['user_000709' 'user_000294' 'user_000753' 'user_000989' 'user_000970']
# Indices of 5 recommended artists: [np.int32(3343), np.int32(3794), np.int32(45213), np.int32(16), np.int32(42023)]
# Recommended artist names: [np.str_('Linda Perry'), np.str_('The Essex Green'), np.str_('J.M.K.E.'), np.str_('Afx'), np.str_('Vacuum')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000098
# Nearest K=5 neighbors' user-ids: ['user_000778' 'user_000631' 'user_000002' 'user_000476' 'user_000328']
# Indices of 5 recommended artists: [np.int32(1170), np.int32(1052), np.int32(1745), np.int32(1801), np.int32(746)]
# Recommended artist names: [np.str_('John Mayer Trio'), np.str_('Fünf Sterne Deluxe'), np.str_('The Piano Tribute Players'), np.str_('The Von Bondies'), np.str_('Ashlee Simpson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000099
# ...
# Seed user-id: user_000967
# Nearest K=5 neighbors' user-ids: ['user_000945' 'user_000585' 'user_000606' 'user_000135' 'user_000243']
# Indices of 5 recommended artists: [np.int32(361), np.int32(793), np.int32(18424), np.int32(8566), np.int32(47553)]
# Recommended artist names: [np.str_('Marsmobil'), np.str_('Beyoncé'), np.str_('Guillaume De Machaut'), np.str_('Glass Candy'), np.str_('Raiden')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000968
# Nearest K=5 neighbors' user-ids: ['user_000824' 'user_000562' 'user_000376' 'user_000784' 'user_000789']
# Indices of 5 recommended artists: [np.int32(8138), np.int32(74762), np.int32(29597), np.int32(14006), np.int32(1603)]
# Recommended artist names: [np.str_('Catherine Wheel'), np.str_('Billy Childish'), np.str_('The Passions'), np.str_('Headland'), np.str_('T. Rex')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000969
# Nearest K=5 neighbors' user-ids: ['user_000750' 'user_000427' 'user_000295' 'user_000485' 'user_000140']
# Indices of 5 recommended artists: [np.int32(11838), np.int32(97763), np.int32(311), np.int32(6368), np.int32(37401)]
# Recommended artist names: [np.str_('K.D. Lang'), np.str_('Singers & Players Feat. Bim Sherman'), np.str_('Kraak & Smaak'), np.str_('Colli Buddz'), np.str_('Jamal')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000970
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000393' 'user_000691' 'user_000108' 'user_000761']
# Indices of 5 recommended artists: [np.int32(145650), np.int32(41765), np.int32(14852), np.int32(145842), np.int32(81530)]
# Recommended artist names: [np.str_('03 Celsius'), np.str_('Kutless'), np.str_('Alpha'), np.str_('Clarence Samuels'), np.str_('Charlie Poole & The North Carolina Ramblers')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000971
# Nearest K=5 neighbors' user-ids: ['user_000575' 'user_000434' 'user_000491' 'user_000382' 'user_000630']
# Indices of 5 recommended artists: [np.int32(13373), np.int32(75747), np.int32(123930), np.int32(91667), np.int32(2423)]
# Recommended artist names: [np.str_('Only Crime'), np.str_('Jamie Scott'), np.str_('Iron Lung'), np.str_('The Path Of Resistance'), np.str_('Paris Hilton')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000972
# Nearest K=5 neighbors' user-ids: ['user_000259' 'user_000630' 'user_000382' 'user_000852' 'user_000893']
# Indices of 5 recommended artists: [np.int32(91309), np.int32(163232), np.int32(6860), np.int32(36756), np.int32(91190)]
# Recommended artist names: [np.str_('Driver Side Impact'), np.str_('Sum 41 W/ Iggy Pop'), np.str_('Dead Poetic'), np.str_('Japancakes'), np.str_('A Scanner Darkly')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000973
# Nearest K=5 neighbors' user-ids: ['user_000378' 'user_000276' 'user_000047' 'user_000054' 'user_000111']
# Indices of 5 recommended artists: [np.int32(22702), np.int32(24183), np.int32(27772), np.int32(24190), np.int32(3360)]
# Recommended artist names: [np.str_('Cetu Javu'), np.str_('Pink Feat. Redman'), np.str_('Pan Sonic'), np.str_('Severina'), np.str_('Lovage')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000974
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000729' 'user_000285' 'user_000120' 'user_000575']
# Indices of 5 recommended artists: [np.int32(23909), np.int32(3185), np.int32(6860), np.int32(1817), np.int32(6416)]
# Recommended artist names: [np.str_('Bond'), np.str_('Her Space Holiday'), np.str_('Dead Poetic'), np.str_('Thrice'), np.str_('Flo Rida')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000975
# Nearest K=5 neighbors' user-ids: ['user_000549' 'user_000789' 'user_000497' 'user_000224' 'user_000257']
# Indices of 5 recommended artists: [np.int32(795), np.int32(17634), np.int32(114495), np.int32(953), np.int32(7551)]
# Recommended artist names: [np.str_('Big D And The Kids Table'), np.str_('Yves Montand'), np.str_("Masif Dj'S"), np.str_('Dionne Warwick'), np.str_('Felt')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000976
# Nearest K=5 neighbors' user-ids: ['user_000890' 'user_000145' 'user_000814' 'user_000330' 'user_000729']
# Indices of 5 recommended artists: [np.int32(45406), np.int32(4059), np.int32(1348), np.int32(8290), np.int32(140193)]
# Recommended artist names: [np.str_('Sea Monkeys'), np.str_('Armand Van Helden'), np.str_('Neil Young'), np.str_('Dead Or Alive'), np.str_('B-East')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000977
# Nearest K=5 neighbors' user-ids: ['user_000215' 'user_000478' 'user_000051' 'user_000093' 'user_000457']
# Indices of 5 recommended artists: [np.int32(1082), np.int32(7450), np.int32(400), np.int32(2412), np.int32(44088)]
# Recommended artist names: [np.str_('Gwen Stefani'), np.str_('Blind Faith'), np.str_('Nitin Sawhney'), np.str_('Outkast'), np.str_('Stephen Marley')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000978
# Nearest K=5 neighbors' user-ids: ['user_000284' 'user_000381' 'user_000440' 'user_000901' 'user_000702']
# Indices of 5 recommended artists: [np.int32(135397), np.int32(77714), np.int32(87407), np.int32(100891), np.int32(542)]
# Recommended artist names: [np.str_('Blakai'), np.str_('Ajdar Anik'), np.str_('Miltinho'), np.str_('Ryan'), np.str_('Susumu Yokota')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000979
# Nearest K=5 neighbors' user-ids: ['user_000807' 'user_000077' 'user_000806' 'user_000135' 'user_000873']
# Indices of 5 recommended artists: [np.int32(47527), np.int32(81528), np.int32(17448), np.int32(57641), np.int32(696)]
# Recommended artist names: [np.str_('Phonosynthese'), np.str_('Charlie Hunter Trio'), np.str_('Pure Fiction'), np.str_('Mazedude'), np.str_('Alien Ant Farm')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000980
# Nearest K=5 neighbors' user-ids: ['user_000147' 'user_000215' 'user_000438' 'user_000897' 'user_000977']
# Indices of 5 recommended artists: [np.int32(782), np.int32(5226), np.int32(2383), np.int32(3632), np.int32(49527)]
# Recommended artist names: [np.str_('Ben Folds'), np.str_('Eric Prydz Vs. Floyd'), np.str_('Modjo'), np.str_('Róisín Murphy'), np.str_('Spirit Pie')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000981
# Nearest K=5 neighbors' user-ids: ['user_000010' 'user_000706' 'user_000940' 'user_000208' 'user_000715']
# Indices of 5 recommended artists: [np.int32(1667), np.int32(72533), np.int32(40490), np.int32(63385), np.int32(57883)]
# Recommended artist names: [np.str_('The Dandy Warhols'), np.str_('Kmc (Feat. Danny)'), np.str_('Horny United'), np.str_('Verdugo Brothers'), np.str_('Boom Clap Bachelors')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000982
# Nearest K=5 neighbors' user-ids: ['user_000584' 'user_000873' 'user_000560' 'user_000956' 'user_000606']
# Indices of 5 recommended artists: [np.int32(791), np.int32(3575), np.int32(2869), np.int32(5897), np.int32(16743)]
# Recommended artist names: [np.str_('Better Than Ezra'), np.str_('Priscilla Ahn'), np.str_('Can'), np.str_('Spice Girls'), np.str_('Company Flow')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000983
# Nearest K=5 neighbors' user-ids: ['user_000993' 'user_000596' 'user_000414' 'user_001000' 'user_000475']
# Indices of 5 recommended artists: [np.int32(3780), np.int32(78723), np.int32(28178), np.int32(7818), np.int32(891)]
# Recommended artist names: [np.str_('The Cool Kids'), np.str_('Piglet'), np.str_('Pustki'), np.str_('Thomas Dolby'), np.str_('Creedence Clearwater Revisited')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000984
# Nearest K=5 neighbors' user-ids: ['user_000731' 'user_000118' 'user_000351' 'user_000373' 'user_000837']
# Indices of 5 recommended artists: [np.int32(1094), np.int32(759), np.int32(3659), np.int32(50658), np.int32(8432)]
# Recommended artist names: [np.str_('Horace Parlan'), np.str_('B*Witched'), np.str_('Semisonic'), np.str_('李宇春'), np.str_('Emf')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000985
# Nearest K=5 neighbors' user-ids: ['user_000551' 'user_000902' 'user_000849' 'user_000298' 'user_000039']
# Indices of 5 recommended artists: [np.int32(58834), np.int32(3726), np.int32(10529), np.int32(21635), np.int32(23668)]
# Recommended artist names: [np.str_('Greg Laswell'), np.str_('Suzanne Vega'), np.str_('Breaking Point'), np.str_('David Visan'), np.str_('Lily Frost')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000986
# Nearest K=5 neighbors' user-ids: ['user_000909' 'user_000140' 'user_000229' 'user_000774' 'user_000393']
# Indices of 5 recommended artists: [np.int32(3106), np.int32(147845), np.int32(1560), np.int32(148014), np.int32(15896)]
# Recommended artist names: [np.str_('French Kicks'), np.str_('Mac Powell & Jennifer Knapp'), np.str_('South'), np.str_('Plus Ganzwind'), np.str_('Mezquita')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000987
# Nearest K=5 neighbors' user-ids: ['user_000249' 'user_000451' 'user_000910' 'user_000454' 'user_000572']
# Indices of 5 recommended artists: [np.int32(35577), np.int32(3936), np.int32(23612), np.int32(934), np.int32(22076)]
# Recommended artist names: [np.str_('Bongwater'), np.str_('Vivian Girls'), np.str_('Dan The Automator'), np.str_('Devendra Banhart'), np.str_('Westside Connection')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000989
# Nearest K=5 neighbors' user-ids: ['user_000581' 'user_000854' 'user_000294' 'user_000545' 'user_000097']
# Indices of 5 recommended artists: [np.int32(23080), np.int32(11343), np.int32(12180), np.int32(59233), np.int32(38779)]
# Recommended artist names: [np.str_('Loona'), np.str_('Buffy Sainte-Marie'), np.str_('Peter, Paul & Mary'), np.str_('Odroerir'), np.str_('Dns')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000990
# Nearest K=5 neighbors' user-ids: ['user_000837' 'user_000606' 'user_000059' 'user_000520' 'user_000791']
# Indices of 5 recommended artists: [np.int32(338), np.int32(17866), np.int32(10964), np.int32(11392), np.int32(4684)]
# Recommended artist names: [np.str_('Losoul'), np.str_('Balil'), np.str_('The Blue Nile'), np.str_('Cinderella'), np.str_('Shakedown')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000991
# Nearest K=5 neighbors' user-ids: ['user_000452' 'user_000188' 'user_000524' 'user_000927' 'user_000634']
# Indices of 5 recommended artists: [np.int32(2804), np.int32(59922), np.int32(7259), np.int32(124304), np.int32(89889)]
# Recommended artist names: [np.str_('Bishop Allen'), np.str_('Andy Irvine'), np.str_('Godsmack'), np.str_('New Maximum Donkey'), np.str_('Mz.412')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000992
# Nearest K=5 neighbors' user-ids: ['user_000499' 'user_000654' 'user_000036' 'user_000796' 'user_000106']
# Indices of 5 recommended artists: [np.int32(63155), np.int32(2334), np.int32(10198), np.int32(15058), np.int32(21561)]
# Recommended artist names: [np.str_('Kaz Mashino'), np.str_('Lykke Li'), np.str_('Morningwood'), np.str_('Logh'), np.str_('Tikitiklip')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000993
# Nearest K=5 neighbors' user-ids: ['user_000620' 'user_000345' 'user_000467' 'user_000089' 'user_000361']
# Indices of 5 recommended artists: [np.int32(6485), np.int32(63434), np.int32(26711), np.int32(14709), np.int32(9705)]
# Recommended artist names: [np.str_('Kem'), np.str_('A Small Good Thing'), np.str_('Sissy Wish'), np.str_('Them'), np.str_('The Waterboys')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000994
# Nearest K=5 neighbors' user-ids: ['user_000108' 'user_000986' 'user_000565' 'user_000393' 'user_000650']
# Indices of 5 recommended artists: [np.int32(70771), np.int32(3094), np.int32(10667), np.int32(100853), np.int32(34257)]
# Recommended artist names: [np.str_('Mickey Oliver'), np.str_('Flowers From The Man Who Shot Your Cousin'), np.str_('Hell Is For Heroes'), np.str_('Electrostatic'), np.str_('Fripp & Eno')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000995
# Nearest K=5 neighbors' user-ids: ['user_000704' 'user_000914' 'user_000593' 'user_000870' 'user_000136']
# Indices of 5 recommended artists: [np.int32(36621), np.int32(137050), np.int32(3593), np.int32(161653), np.int32(161703)]
# Recommended artist names: [np.str_('Zombina And The Skeletones'), np.str_('Peeping Tom Feat. Dub Trio'), np.str_('Raekwon'), np.str_('Seven Nation Army'), np.str_('Thunderbolt')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000996
# Nearest K=5 neighbors' user-ids: ['user_000018' 'user_000123' 'user_000779' 'user_000998' 'user_000093']
# Indices of 5 recommended artists: [np.int32(43979), np.int32(11766), np.int32(12686), np.int32(1009), np.int32(1116)]
# Recommended artist names: [np.str_('Ludov'), np.str_('Jennifer Paige'), np.str_('浜崎あゆみ'), np.str_('Eva Cassidy'), np.str_('Ingrid Michaelson')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000997
# Nearest K=5 neighbors' user-ids: ['user_000086' 'user_000467' 'user_000371' 'user_000345' 'user_000060']
# Indices of 5 recommended artists: [np.int32(36742), np.int32(1913), np.int32(28281), np.int32(10598), np.int32(61091)]
# Recommended artist names: [np.str_('Erik De Vahl'), np.str_('Émilie Simon'), np.str_('Cluster'), np.str_('Eddy Grant'), np.str_("Bossa N' Marley")]
# --------------------------------------------------------------------------------
# Seed user-id: user_000998
# Nearest K=5 neighbors' user-ids: ['user_000201' 'user_000024' 'user_000920' 'user_000996' 'user_000918']
# Indices of 5 recommended artists: [np.int32(165123), np.int32(812), np.int32(3734), np.int32(8911), np.int32(8022)]
# Recommended artist names: [np.str_('Bulbasaur'), np.str_('Bob Seger'), np.str_('Talking Heads'), np.str_('Linton Kwesi Johnson'), np.str_('Bis')]
# --------------------------------------------------------------------------------
# Seed user-id: user_000999
# Nearest K=5 neighbors' user-ids: ['user_000634' 'user_000503' 'user_000927' 'user_000515' 'user_000866']
# Indices of 5 recommended artists: [np.int32(18706), np.int32(34122), np.int32(17377), np.int32(109972), np.int32(9317)]
# Recommended artist names: [np.str_('Lackluster'), np.str_('Ben Frost'), np.str_('Midfield General'), np.str_('Alta Infidelidad'), np.str_('Romeo Void')]
# --------------------------------------------------------------------------------
# Seed user-id: user_001000
# Nearest K=5 neighbors' user-ids: ['user_000024' 'user_000345' 'user_000628' 'user_000795' 'user_000371']
# Indices of 5 recommended artists: [np.int32(696), np.int32(14844), np.int32(90088), np.int32(44609), np.int32(6431)]
# Recommended artist names: [np.str_('Alien Ant Farm'), np.str_('Adam Beebe'), np.str_('The Eskimos'), np.str_('Little Fish'), np.str_('Groove Theory')]
# --------------------------------------------------------------------------------
# Average time per user recommendation: 0.0009 seconds
